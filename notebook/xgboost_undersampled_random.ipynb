# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_28736\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_28736\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### ADASYN Oversampling on Training Data

# %%
resampler = RandomUnderSampler()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = xgb.XGBClassifier(random_state=42, eval_metric='logloss')

# %% [markdown]
# ### Create grid for hyperparameter tuning

# %%
param_grid_xgb = {
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'scale_pos_weight': [1, 3, 5, 10, 15, 20]
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_xgb = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_xgb,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Importance': importances}).sort_values(
    'Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Importance
# 0                              age    0.192292
# 8                            smoke    0.127312
# 17  smoking_status_formerly_smoked    0.084639
# 5                              bmi    0.059759
# 13               work_type_private    0.059366
# 20                age_ever_married    0.048798
# 1                     hypertension    0.048514
# 7                            urban    0.045211
# 4                avg_glucose_level    0.044965
# 11              work_type_govt_job    0.040692
# 18     smoking_status_never_smoked    0.039717
# 19           smoking_status_smokes    0.039091
# 6                             male    0.038543
# 2                    heart_disease    0.038243
# 3                     ever_married    0.027773
# 10   hypertension_or_heart_disease    0.024713
# 14         work_type_self_employed    0.023738
# 16          smoking_status_unknown    0.016634
# 23                         log_bmi    0.000000
# 21                           obese    0.000000
# 22          high_avg_glucose_level    0.000000
# 12          work_type_never_worked    0.000000
# 15              work_type_children    0.000000
# 9                        have_work    0.000000
# 24           log_avg_glucose_level    0.000000

# %%
retained_columns = ['age', 'work_type_govt_job', 'hypertension_or_heart_disease', 'smoking_status_never_smoked', 'work_type_self_employed', 'smoke', 'avg_glucose_level', 'bmi', 'urban', 'smoking_status_unknown']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.15

# %%
def objective_xgb(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 7),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 1),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 15),
        'random_state': 42,
        'eval_metric': 'logloss'
    }
    
    model = xgb.XGBClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    
    if precision < MIN_PRECISION:
        return 0
    return recall + (precision * 0.01)

# %%
# grid_xgb.fit(X_train_res_retained, y_train_res)

# %%
study_xgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_xgb.optimize(objective_xgb, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 20:41:11,354] A new study created in memory with name: no-name-28d00211-21f0-4448-a707-c425332c5ea2
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 20:41:11,589] Trial 0 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.2536999076681772, 'n_estimators': 233, 'min_child_weight': 5, 'subsample': 0.5780093202212182, 'colsample_bytree': 0.5779972601681014, 'gamma': 0.05808361216819946, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 10.913016089144637}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:11,762] Trial 1 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.2708160864249968, 'n_estimators': 258, 'min_child_weight': 2, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'gamma': 0.3042422429595377, 'reg_alpha': 0.5247564316322378, 'reg_lambda': 0.43194501864211576, 'scale_pos_weight': 5.077207962772587}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:11,903] Trial 2 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.01607123851203988, 'n_estimators': 123, 'min_child_weight': 3, 'subsample': 0.728034992108518, 'colsample_bytree': 0.8925879806965068, 'gamma': 0.19967378215835974, 'reg_alpha': 0.5142344384136116, 'reg_lambda': 0.5924145688620425, 'scale_pos_weight': 1.6503057780799681}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:11,981] Trial 3 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.0178601378893971, 'n_estimators': 66, 'min_child_weight': 7, 'subsample': 0.9828160165372797, 'colsample_bytree': 0.9041986740582306, 'gamma': 0.3046137691733707, 'reg_alpha': 0.09767211400638387, 'reg_lambda': 0.6842330265121569, 'scale_pos_weight': 7.162134912354418}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:12,039] Trial 4 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.05388108577817234, 'n_estimators': 58, 'min_child_weight': 7, 'subsample': 0.6293899908000085, 'colsample_bytree': 0.831261142176991, 'gamma': 0.31171107608941095, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796, 'scale_pos_weight': 3.5879623773573783}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:12,208] Trial 5 finished with value: 0.0 and parameters: {'max_depth': 20, 'learning_rate': 0.13962563737015762, 'n_estimators': 285, 'min_child_weight': 7, 'subsample': 0.7989499894055425, 'colsample_bytree': 0.9609371175115584, 'gamma': 0.0884925020519195, 'reg_alpha': 0.1959828624191452, 'reg_lambda': 0.045227288910538066, 'scale_pos_weight': 5.554624630685701}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:12,427] Trial 6 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.02516607127550297, 'n_estimators': 258, 'min_child_weight': 3, 'subsample': 0.6404672548436904, 'colsample_bytree': 0.7713480415791243, 'gamma': 0.14092422497476265, 'reg_alpha': 0.8021969807540397, 'reg_lambda': 0.07455064367977082, 'scale_pos_weight': 14.816417112407242}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:12,483] Trial 7 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.019657448966046126, 'n_estimators': 51, 'min_child_weight': 6, 'subsample': 0.8534286719238086, 'colsample_bytree': 0.8645035840204937, 'gamma': 0.7712703466859457, 'reg_alpha': 0.07404465173409036, 'reg_lambda': 0.3584657285442726, 'scale_pos_weight': 2.622166833351816}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:12,653] Trial 8 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.08330803890301997, 'n_estimators': 133, 'min_child_weight': 1, 'subsample': 0.6554911608578311, 'colsample_bytree': 0.6625916610133735, 'gamma': 0.7296061783380641, 'reg_alpha': 0.6375574713552131, 'reg_lambda': 0.8872127425763265, 'scale_pos_weight': 7.61100895226729}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:12,809] Trial 9 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.1131225105716033, 'n_estimators': 240, 'min_child_weight': 4, 'subsample': 0.8854835899772805, 'colsample_bytree': 0.7468977981821954, 'gamma': 0.5227328293819941, 'reg_alpha': 0.42754101835854963, 'reg_lambda': 0.02541912674409519, 'scale_pos_weight': 2.5104799779062623}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:12,968] Trial 10 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.23875379742034009, 'n_estimators': 198, 'min_child_weight': 5, 'subsample': 0.5076838686640521, 'colsample_bytree': 0.5193625999805915, 'gamma': 0.9597707459454198, 'reg_alpha': 0.9761398998579952, 'reg_lambda': 0.9469618763901493, 'scale_pos_weight': 11.337677626150288}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:13,120] Trial 11 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.2681707850815186, 'n_estimators': 207, 'min_child_weight': 1, 'subsample': 0.5168163024120214, 'colsample_bytree': 0.5472666635128242, 'gamma': 0.006878590338739575, 'reg_alpha': 0.9940403736301033, 'reg_lambda': 0.31464503711868463, 'scale_pos_weight': 11.139350674858177}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:13,365] Trial 12 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.29874245429060897, 'n_estimators': 299, 'min_child_weight': 3, 'subsample': 0.573934948755293, 'colsample_bytree': 0.609303657185796, 'gamma': 0.460359543543538, 'reg_alpha': 0.742347534737023, 'reg_lambda': 0.3568935701127543, 'scale_pos_weight': 10.444569125382994}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:13,585] Trial 13 finished with value: 0.0 and parameters: {'max_depth': 6, 'learning_rate': 0.15927835559461273, 'n_estimators': 236, 'min_child_weight': 5, 'subsample': 0.7052548278984161, 'colsample_bytree': 0.6511020710303068, 'gamma': 0.3309128418068149, 'reg_alpha': 0.33171814206359374, 'reg_lambda': 0.7583635489314875, 'scale_pos_weight': 13.504240115989738}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:13,719] Trial 14 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.05355557329356672, 'n_estimators': 165, 'min_child_weight': 2, 'subsample': 0.559834872154931, 'colsample_bytree': 0.5785932138359383, 'gamma': 0.013134538836077542, 'reg_alpha': 0.7946453641120889, 'reg_lambda': 0.43200028731684337, 'scale_pos_weight': 5.068729332790817}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:13,927] Trial 15 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.1830757039878521, 'n_estimators': 267, 'min_child_weight': 5, 'subsample': 0.5813833144057525, 'colsample_bytree': 0.6966713259977332, 'gamma': 0.48471577332400884, 'reg_alpha': 0.6732717907646599, 'reg_lambda': 0.2550570692138962, 'scale_pos_weight': 9.07728843445549}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:14,146] Trial 16 finished with value: 0.0 and parameters: {'max_depth': 7, 'learning_rate': 0.08632290017244112, 'n_estimators': 217, 'min_child_weight': 4, 'subsample': 0.6818008844279342, 'colsample_bytree': 0.511847705752916, 'gamma': 0.20179286701624133, 'reg_alpha': 0.389664524207145, 'reg_lambda': 0.7163755998306335, 'scale_pos_weight': 5.484756293610838}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:14,384] Trial 17 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.19780299461419043, 'n_estimators': 183, 'min_child_weight': 2, 'subsample': 0.7752847229001597, 'colsample_bytree': 0.6123467940735869, 'gamma': 0.37590301139649895, 'reg_alpha': 0.8956049237047359, 'reg_lambda': 0.17747344841110274, 'scale_pos_weight': 9.276026950369001}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:14,594] Trial 18 finished with value: 0.0 and parameters: {'max_depth': 7, 'learning_rate': 0.03952419420259876, 'n_estimators': 157, 'min_child_weight': 4, 'subsample': 0.6091330191487017, 'colsample_bytree': 0.7201273557961427, 'gamma': 0.5805859497908505, 'reg_alpha': 0.2415834261767888, 'reg_lambda': 0.49221563552671455, 'scale_pos_weight': 13.038959206855834}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:14,920] Trial 19 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.010772327371165246, 'n_estimators': 233, 'min_child_weight': 2, 'subsample': 0.5478007053666223, 'colsample_bytree': 0.5666077607075912, 'gamma': 0.24283208131223918, 'reg_alpha': 0.5864640754480753, 'reg_lambda': 0.5963089090685653, 'scale_pos_weight': 6.341477518984426}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:15,131] Trial 20 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.12161927779542983, 'n_estimators': 269, 'min_child_weight': 6, 'subsample': 0.6793741362572109, 'colsample_bytree': 0.6427023912763987, 'gamma': 0.10567104105974079, 'reg_alpha': 0.878627006583033, 'reg_lambda': 0.8624808991805704, 'scale_pos_weight': 4.090692621335416}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:15,296] Trial 21 finished with value: 0.0 and parameters: {'max_depth': 17, 'learning_rate': 0.030037279641300742, 'n_estimators': 106, 'min_child_weight': 3, 'subsample': 0.7327122497128112, 'colsample_bytree': 0.9987349142404867, 'gamma': 0.15122004927923907, 'reg_alpha': 0.5699054756297403, 'reg_lambda': 0.619330480889154, 'scale_pos_weight': 1.195278708358487}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:15,479] Trial 22 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.013441330443675917, 'n_estimators': 126, 'min_child_weight': 3, 'subsample': 0.7305883778847561, 'colsample_bytree': 0.8170064962868606, 'gamma': 0.24225217179231937, 'reg_alpha': 0.43523619548996173, 'reg_lambda': 0.4984172041931467, 'scale_pos_weight': 1.5266365178414296}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:15,692] Trial 23 finished with value: 0.0 and parameters: {'max_depth': 12, 'learning_rate': 0.08886017365654376, 'n_estimators': 93, 'min_child_weight': 2, 'subsample': 0.8246507912215363, 'colsample_bytree': 0.9280029567477267, 'gamma': 0.3713005234129264, 'reg_alpha': 0.6898576129152496, 'reg_lambda': 0.7973378203494244, 'scale_pos_weight': 3.997546801750582}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:15,996] Trial 24 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.03930010295474171, 'n_estimators': 144, 'min_child_weight': 1, 'subsample': 0.9300204271817573, 'colsample_bytree': 0.8050213718606852, 'gamma': 0.20621483091595683, 'reg_alpha': 0.48481890068854183, 'reg_lambda': 0.654364235383882, 'scale_pos_weight': 8.805247122019306}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:16,200] Trial 25 finished with value: 0.0 and parameters: {'max_depth': 10, 'learning_rate': 0.21805411403367933, 'n_estimators': 183, 'min_child_weight': 4, 'subsample': 0.5994063371547237, 'colsample_bytree': 0.6916721404977116, 'gamma': 0.0911243056854184, 'reg_alpha': 0.2452016505767063, 'reg_lambda': 0.42975581329342616, 'scale_pos_weight': 2.7120975306509143}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:16,430] Trial 26 finished with value: 0.0 and parameters: {'max_depth': 19, 'learning_rate': 0.06727604471859662, 'n_estimators': 106, 'min_child_weight': 6, 'subsample': 0.5358466440512449, 'colsample_bytree': 0.6174798275951675, 'gamma': 0.4166658794895915, 'reg_alpha': 0.5227968940126628, 'reg_lambda': 0.5931372159164537, 'scale_pos_weight': 6.603469007209854}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:16,682] Trial 27 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.16346226838756223, 'n_estimators': 222, 'min_child_weight': 3, 'subsample': 0.7629402760816223, 'colsample_bytree': 0.8839468442608407, 'gamma': 0.6090485969983004, 'reg_alpha': 0.2978070889826723, 'reg_lambda': 0.4416836166131589, 'scale_pos_weight': 12.214827218394566}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:16,930] Trial 28 finished with value: 0.0 and parameters: {'max_depth': 8, 'learning_rate': 0.2948632227943201, 'n_estimators': 246, 'min_child_weight': 5, 'subsample': 0.6778719927785625, 'colsample_bytree': 0.7723543022392799, 'gamma': 0.04927362806969959, 'reg_alpha': 0.5943749537281457, 'reg_lambda': 0.5423712182276632, 'scale_pos_weight': 9.888840015575571}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:17,266] Trial 29 finished with value: 0.0 and parameters: {'max_depth': 12, 'learning_rate': 0.01400985974088348, 'n_estimators': 197, 'min_child_weight': 2, 'subsample': 0.9991417930830014, 'colsample_bytree': 0.9154724933789339, 'gamma': 0.2961084472494581, 'reg_alpha': 0.18271365535206224, 'reg_lambda': 0.6622672567826405, 'scale_pos_weight': 8.13618742322151}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:17,385] Trial 30 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.02147832616623022, 'n_estimators': 86, 'min_child_weight': 4, 'subsample': 0.6244505102303797, 'colsample_bytree': 0.5472987942580846, 'gamma': 0.1702093466321276, 'reg_alpha': 0.7541088348288341, 'reg_lambda': 0.2370088886214864, 'scale_pos_weight': 4.720402071285555}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:17,513] Trial 31 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.016397195687761032, 'n_estimators': 74, 'min_child_weight': 7, 'subsample': 0.9954008935556706, 'colsample_bytree': 0.8653207917124405, 'gamma': 0.28155134755130967, 'reg_alpha': 0.021891514820133573, 'reg_lambda': 0.6964867909872028, 'scale_pos_weight': 7.143275740175859}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:17,630] Trial 32 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.029784685721307096, 'n_estimators': 67, 'min_child_weight': 7, 'subsample': 0.9246001190937587, 'colsample_bytree': 0.9598482300597748, 'gamma': 0.33947522852320955, 'reg_alpha': 0.1139534584726818, 'reg_lambda': 0.5534966207562758, 'scale_pos_weight': 6.625497077956275}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:17,950] Trial 33 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.010484695133683303, 'n_estimators': 285, 'min_child_weight': 7, 'subsample': 0.8001109328074758, 'colsample_bytree': 0.8420697677008246, 'gamma': 0.2581441641805786, 'reg_alpha': 0.5082677359152044, 'reg_lambda': 0.7747897038141311, 'scale_pos_weight': 5.8538737837982735}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:18,455] Trial 34 finished with value: 0.0 and parameters: {'max_depth': 10, 'learning_rate': 0.018162035041615284, 'n_estimators': 108, 'min_child_weight': 6, 'subsample': 0.6431257518257574, 'colsample_bytree': 0.9170493802452836, 'gamma': 0.12677254593379295, 'reg_alpha': 0.3606032092822813, 'reg_lambda': 0.531814722612808, 'scale_pos_weight': 8.062910525947009}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:18,616] Trial 35 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.023583598145096085, 'n_estimators': 119, 'min_child_weight': 6, 'subsample': 0.881964567474754, 'colsample_bytree': 0.9963252442894389, 'gamma': 0.4228039687060874, 'reg_alpha': 0.8719966273016766, 'reg_lambda': 0.472168090817362, 'scale_pos_weight': 3.3911963684455397}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:18,748] Trial 36 finished with value: 0.0 and parameters: {'max_depth': 20, 'learning_rate': 0.029211410592451827, 'n_estimators': 53, 'min_child_weight': 3, 'subsample': 0.9633350602583183, 'colsample_bytree': 0.7766726777775903, 'gamma': 0.06417460508458783, 'reg_alpha': 0.13342292081136484, 'reg_lambda': 0.8491251209281683, 'scale_pos_weight': 2.0974626301964197}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:18,971] Trial 37 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.043247406839255244, 'n_estimators': 145, 'min_child_weight': 1, 'subsample': 0.8393396094693069, 'colsample_bytree': 0.8434718425145458, 'gamma': 0.18994613739353344, 'reg_alpha': 0.4547514833554062, 'reg_lambda': 0.37052625840845455, 'scale_pos_weight': 14.39318495466463}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:19,365] Trial 38 finished with value: 0.0 and parameters: {'max_depth': 4, 'learning_rate': 0.1191961278939686, 'n_estimators': 255, 'min_child_weight': 5, 'subsample': 0.7116216505597965, 'colsample_bytree': 0.7378700370812161, 'gamma': 0.9759141759438077, 'reg_alpha': 0.6470872887336561, 'reg_lambda': 0.697165810520577, 'scale_pos_weight': 7.390704160301894}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:19,909] Trial 39 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.013275913285964296, 'n_estimators': 279, 'min_child_weight': 7, 'subsample': 0.653760461323467, 'colsample_bytree': 0.8878972101534367, 'gamma': 0.5649731607634911, 'reg_alpha': 0.010447734008491971, 'reg_lambda': 0.9386408426081372, 'scale_pos_weight': 3.192262589950266}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:20,108] Trial 40 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.13978393021419994, 'n_estimators': 298, 'min_child_weight': 3, 'subsample': 0.5962095249081718, 'colsample_bytree': 0.9646942991694355, 'gamma': 0.9100400375907811, 'reg_alpha': 0.7225632578719812, 'reg_lambda': 0.10523860989743106, 'scale_pos_weight': 4.508021668700345}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:20,214] Trial 41 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.05457438569505658, 'n_estimators': 53, 'min_child_weight': 7, 'subsample': 0.5228708349681424, 'colsample_bytree': 0.8144208173352626, 'gamma': 0.3149103581997459, 'reg_alpha': 0.5407771822091715, 'reg_lambda': 0.6376140242933288, 'scale_pos_weight': 2.1440710856569414}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:20,322] Trial 42 finished with value: 0.0 and parameters: {'max_depth': 4, 'learning_rate': 0.24636801071027156, 'n_estimators': 68, 'min_child_weight': 6, 'subsample': 0.6258341476388531, 'colsample_bytree': 0.889612847708508, 'gamma': 0.4076427103135537, 'reg_alpha': 0.4026065762763772, 'reg_lambda': 0.5615706907021569, 'scale_pos_weight': 3.415286652607569}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:20,444] Trial 43 finished with value: 0.0 and parameters: {'max_depth': 6, 'learning_rate': 0.06583127887004564, 'n_estimators': 88, 'min_child_weight': 7, 'subsample': 0.5500800234913644, 'colsample_bytree': 0.5830758856154384, 'gamma': 0.22722957218535034, 'reg_alpha': 0.619731842478561, 'reg_lambda': 0.3682147326998184, 'scale_pos_weight': 5.581226569533445}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:20,593] Trial 44 finished with value: 0.0 and parameters: {'max_depth': 8, 'learning_rate': 0.01623567397219364, 'n_estimators': 72, 'min_child_weight': 2, 'subsample': 0.7933477250657269, 'colsample_bytree': 0.9485898346132119, 'gamma': 0.6895432972689399, 'reg_alpha': 0.9334159012892634, 'reg_lambda': 0.724439516940762, 'scale_pos_weight': 10.582158380443126}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:20,727] Trial 45 finished with value: 0.0 and parameters: {'max_depth': 4, 'learning_rate': 0.10104264991044044, 'n_estimators': 84, 'min_child_weight': 6, 'subsample': 0.5058472708433118, 'colsample_bytree': 0.6772158673081285, 'gamma': 0.15579070278847726, 'reg_alpha': 0.8247480368863458, 'reg_lambda': 0.5814093952920381, 'scale_pos_weight': 3.939902119924429}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:20,901] Trial 46 finished with value: 0.0 and parameters: {'max_depth': 10, 'learning_rate': 0.16814420548674178, 'n_estimators': 166, 'min_child_weight': 5, 'subsample': 0.5902709743360955, 'colsample_bytree': 0.8498908602378278, 'gamma': 0.02874003411134514, 'reg_alpha': 0.31465090530232964, 'reg_lambda': 0.2928591365969716, 'scale_pos_weight': 1.6017912919223627}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:21,097] Trial 47 finished with value: 0.0 and parameters: {'max_depth': 6, 'learning_rate': 0.20259999293306966, 'n_estimators': 204, 'min_child_weight': 7, 'subsample': 0.5780732260013026, 'colsample_bytree': 0.6324879829877151, 'gamma': 0.5096166884400746, 'reg_alpha': 0.4757556078867084, 'reg_lambda': 0.407093993963048, 'scale_pos_weight': 5.153316954234892}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:21,272] Trial 48 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.02555234586026089, 'n_estimators': 226, 'min_child_weight': 4, 'subsample': 0.6200584258369659, 'colsample_bytree': 0.5379023106760519, 'gamma': 0.33933261155757427, 'reg_alpha': 0.5578825840923461, 'reg_lambda': 0.5109518464562459, 'scale_pos_weight': 11.985324934444652}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:21,448] Trial 49 finished with value: 0.0 and parameters: {'max_depth': 8, 'learning_rate': 0.04536297616844404, 'n_estimators': 140, 'min_child_weight': 2, 'subsample': 0.666369839886574, 'colsample_bytree': 0.5050155788141772, 'gamma': 0.2784628859037707, 'reg_alpha': 0.3586403297298141, 'reg_lambda': 0.47504209460854685, 'scale_pos_weight': 2.777508348992211}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:21,634] Trial 50 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.14162204177615048, 'n_estimators': 249, 'min_child_weight': 3, 'subsample': 0.6933386764452504, 'colsample_bytree': 0.7944446139623412, 'gamma': 0.47060879326209065, 'reg_alpha': 0.26242354172807925, 'reg_lambda': 0.6110268876502016, 'scale_pos_weight': 1.011141002111625}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:22,099] Trial 51 finished with value: 0.0 and parameters: {'max_depth': 20, 'learning_rate': 0.2509123717992227, 'n_estimators': 264, 'min_child_weight': 7, 'subsample': 0.5695576290899135, 'colsample_bytree': 0.9423721394492406, 'gamma': 0.07801805659376482, 'reg_alpha': 0.08607779346666294, 'reg_lambda': 0.16327056337489082, 'scale_pos_weight': 5.99232201391142}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:22,402] Trial 52 finished with value: 0.0 and parameters: {'max_depth': 17, 'learning_rate': 0.06948823623388627, 'n_estimators': 281, 'min_child_weight': 6, 'subsample': 0.8656353156637473, 'colsample_bytree': 0.8946342778368916, 'gamma': 0.12502682756216424, 'reg_alpha': 0.06707949399380081, 'reg_lambda': 0.014117513645384105, 'scale_pos_weight': 4.97657747382173}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:22,618] Trial 53 finished with value: 0.0 and parameters: {'max_depth': 7, 'learning_rate': 0.22135244524669512, 'n_estimators': 291, 'min_child_weight': 7, 'subsample': 0.7159604749803571, 'colsample_bytree': 0.9729067559222064, 'gamma': 0.19354558389360538, 'reg_alpha': 0.1995150678200393, 'reg_lambda': 0.6639581298254219, 'scale_pos_weight': 8.649924413781884}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:22,932] Trial 54 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.266252792718987, 'n_estimators': 273, 'min_child_weight': 1, 'subsample': 0.7486840703774122, 'colsample_bytree': 0.5873855864222522, 'gamma': 0.1041957260803155, 'reg_alpha': 0.4139473633145524, 'reg_lambda': 0.735841114766941, 'scale_pos_weight': 7.032648743650528}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:23,167] Trial 55 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.1838616422319852, 'n_estimators': 258, 'min_child_weight': 6, 'subsample': 0.8148654200876876, 'colsample_bytree': 0.8668351259090606, 'gamma': 0.0003249515577355422, 'reg_alpha': 0.1705538949632084, 'reg_lambda': 0.791840220453422, 'scale_pos_weight': 4.322420962262662}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:23,338] Trial 56 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.29797888547733203, 'n_estimators': 213, 'min_child_weight': 4, 'subsample': 0.916873947987675, 'colsample_bytree': 0.9148190418680525, 'gamma': 0.22058681929619353, 'reg_alpha': 0.6253916064546046, 'reg_lambda': 0.6300298150568213, 'scale_pos_weight': 9.577609116593813}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:23,570] Trial 57 finished with value: 0.0 and parameters: {'max_depth': 12, 'learning_rate': 0.03388682117653558, 'n_estimators': 235, 'min_child_weight': 7, 'subsample': 0.646106321468307, 'colsample_bytree': 0.9357363902921597, 'gamma': 0.37404999153965157, 'reg_alpha': 0.6736070107309176, 'reg_lambda': 0.06633657274313334, 'scale_pos_weight': 6.346041098472719}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:23,733] Trial 58 finished with value: 0.0 and parameters: {'max_depth': 4, 'learning_rate': 0.09297712004231139, 'n_estimators': 100, 'min_child_weight': 5, 'subsample': 0.7775560588775221, 'colsample_bytree': 0.8271492710828734, 'gamma': 0.14327126851622654, 'reg_alpha': 0.7893650875624196, 'reg_lambda': 0.20320497197278428, 'scale_pos_weight': 3.77498798052825}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:23,857] Trial 59 finished with value: 0.0 and parameters: {'max_depth': 6, 'learning_rate': 0.07537690888603704, 'n_estimators': 63, 'min_child_weight': 2, 'subsample': 0.5359053986477897, 'colsample_bytree': 0.7244982207237002, 'gamma': 0.05918763771934715, 'reg_alpha': 0.4484702528434814, 'reg_lambda': 0.3149469549968126, 'scale_pos_weight': 7.6292117331053575}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:24,056] Trial 60 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.1394078592029071, 'n_estimators': 182, 'min_child_weight': 6, 'subsample': 0.900642614057124, 'colsample_bytree': 0.9048881830287946, 'gamma': 0.2576431016314839, 'reg_alpha': 0.045530600129577214, 'reg_lambda': 0.5231513247503518, 'scale_pos_weight': 2.381025851318704}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:24,459] Trial 61 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.019891298525592106, 'n_estimators': 245, 'min_child_weight': 3, 'subsample': 0.6123560694226875, 'colsample_bytree': 0.7864289933500633, 'gamma': 0.17013470690935173, 'reg_alpha': 0.959101803367184, 'reg_lambda': 0.02519448152245185, 'scale_pos_weight': 13.565747780947301}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:25,143] Trial 62 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.014693705317995444, 'n_estimators': 263, 'min_child_weight': 3, 'subsample': 0.9471063654215159, 'colsample_bytree': 0.7454074353951752, 'gamma': 0.09511785514931434, 'reg_alpha': 0.8504582432210853, 'reg_lambda': 0.11108705635572343, 'scale_pos_weight': 12.380585253467988}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:25,587] Trial 63 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.01145703525137234, 'n_estimators': 272, 'min_child_weight': 2, 'subsample': 0.6310490925938566, 'colsample_bytree': 0.5328065911717674, 'gamma': 0.04230465420119614, 'reg_alpha': 0.9974342005408586, 'reg_lambda': 0.08253770207508748, 'scale_pos_weight': 14.976917400280914}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:25,713] Trial 64 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.012020456166565345, 'n_estimators': 79, 'min_child_weight': 4, 'subsample': 0.6918534408158064, 'colsample_bytree': 0.8723625507142793, 'gamma': 0.30733922070200703, 'reg_alpha': 0.9310168880499717, 'reg_lambda': 0.6820052112108576, 'scale_pos_weight': 11.643861578591276}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:25,891] Trial 65 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.02347725754902967, 'n_estimators': 60, 'min_child_weight': 3, 'subsample': 0.5654199840349741, 'colsample_bytree': 0.9779398755334614, 'gamma': 0.1233645795814641, 'reg_alpha': 0.7109930061667491, 'reg_lambda': 0.13375315468733012, 'scale_pos_weight': 10.671515659755789}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:26,169] Trial 66 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.017826226608086748, 'n_estimators': 293, 'min_child_weight': 7, 'subsample': 0.737954578857372, 'colsample_bytree': 0.7554995543948265, 'gamma': 0.1789365108964614, 'reg_alpha': 0.7556104374710458, 'reg_lambda': 0.8371975624882191, 'scale_pos_weight': 12.738512409416431}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:26,447] Trial 67 finished with value: 0.0 and parameters: {'max_depth': 10, 'learning_rate': 0.035450029784865944, 'n_estimators': 227, 'min_child_weight': 4, 'subsample': 0.6643976425376488, 'colsample_bytree': 0.5600284578348128, 'gamma': 0.22839677889245885, 'reg_alpha': 0.5045414155115758, 'reg_lambda': 0.5801019874883537, 'scale_pos_weight': 13.550326094533473}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:26,631] Trial 68 finished with value: 0.0 and parameters: {'max_depth': 7, 'learning_rate': 0.02059302877359541, 'n_estimators': 115, 'min_child_weight': 5, 'subsample': 0.6053795718201128, 'colsample_bytree': 0.6590375142550173, 'gamma': 0.35371063889670473, 'reg_alpha': 0.5989245877861689, 'reg_lambda': 0.0456087279116427, 'scale_pos_weight': 5.504514463967124}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:27,065] Trial 69 finished with value: 0.0 and parameters: {'max_depth': 12, 'learning_rate': 0.015281372073501833, 'n_estimators': 253, 'min_child_weight': 1, 'subsample': 0.6380303463541146, 'colsample_bytree': 0.7069897903193029, 'gamma': 0.4432499638818216, 'reg_alpha': 0.1367099066998907, 'reg_lambda': 0.20756071991726652, 'scale_pos_weight': 6.84654258049699}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:27,233] Trial 70 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.06086808840805426, 'n_estimators': 128, 'min_child_weight': 3, 'subsample': 0.587952106239127, 'colsample_bytree': 0.591727370534469, 'gamma': 0.2662929076364866, 'reg_alpha': 0.5354348086620837, 'reg_lambda': 0.9847579735405627, 'scale_pos_weight': 6.020607328353822}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:27,630] Trial 71 finished with value: 0.0 and parameters: {'max_depth': 17, 'learning_rate': 0.02589841076968949, 'n_estimators': 50, 'min_child_weight': 7, 'subsample': 0.8542442108199895, 'colsample_bytree': 0.8345178170217014, 'gamma': 0.8494002773805416, 'reg_alpha': 0.09963359330643386, 'reg_lambda': 0.4125683687481292, 'scale_pos_weight': 2.965328686501972}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:27,771] Trial 72 finished with value: 0.0 and parameters: {'max_depth': 19, 'learning_rate': 0.018314653941221597, 'n_estimators': 61, 'min_child_weight': 6, 'subsample': 0.9768439371587803, 'colsample_bytree': 0.8695256016743248, 'gamma': 0.828535740635486, 'reg_alpha': 0.049224505605033275, 'reg_lambda': 0.4620866442751006, 'scale_pos_weight': 1.4998247869706336}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:28,068] Trial 73 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.04919274046059957, 'n_estimators': 239, 'min_child_weight': 5, 'subsample': 0.7699139522554536, 'colsample_bytree': 0.849983372959537, 'gamma': 0.708774988845349, 'reg_alpha': 0.17289986576589964, 'reg_lambda': 0.32655497116351156, 'scale_pos_weight': 8.40210979414694}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:28,262] Trial 74 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.012303205950147136, 'n_estimators': 95, 'min_child_weight': 7, 'subsample': 0.8433357078806747, 'colsample_bytree': 0.9264174533315551, 'gamma': 0.6599837889179423, 'reg_alpha': 0.21524629836220263, 'reg_lambda': 0.5002202644954783, 'scale_pos_weight': 3.6203685720993715}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:28,380] Trial 75 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.23186221131933596, 'n_estimators': 56, 'min_child_weight': 6, 'subsample': 0.7980307453294159, 'colsample_bytree': 0.7650814207784951, 'gamma': 0.40511534537506116, 'reg_alpha': 0.2748536270168155, 'reg_lambda': 0.5689840811714673, 'scale_pos_weight': 1.906335311804825}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:28,530] Trial 76 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.02243087391856811, 'n_estimators': 77, 'min_child_weight': 7, 'subsample': 0.8171289815486029, 'colsample_bytree': 0.8003876288366606, 'gamma': 0.5432733296254771, 'reg_alpha': 0.13787396901969762, 'reg_lambda': 0.6075359254566933, 'scale_pos_weight': 4.7515107567617525}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:28,921] Trial 77 finished with value: 0.0 and parameters: {'max_depth': 19, 'learning_rate': 0.026858382116531226, 'n_estimators': 277, 'min_child_weight': 6, 'subsample': 0.7557721972929156, 'colsample_bytree': 0.8164114862568372, 'gamma': 0.032954674210873336, 'reg_alpha': 0.7903110508753951, 'reg_lambda': 0.4006137405759115, 'scale_pos_weight': 4.245003110173019}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:29,109] Trial 78 finished with value: 0.0 and parameters: {'max_depth': 12, 'learning_rate': 0.10823691188130424, 'n_estimators': 154, 'min_child_weight': 2, 'subsample': 0.7832710477410147, 'colsample_bytree': 0.902594113316476, 'gamma': 0.7687088998693277, 'reg_alpha': 0.3746800126299998, 'reg_lambda': 0.2797666618532465, 'scale_pos_weight': 2.493545196035021}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:29,401] Trial 79 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.0171929529709365, 'n_estimators': 287, 'min_child_weight': 7, 'subsample': 0.5573150593870391, 'colsample_bytree': 0.609911048318764, 'gamma': 0.20479051212859056, 'reg_alpha': 0.47344392288553416, 'reg_lambda': 0.7523934955869798, 'scale_pos_weight': 3.1544006607024477}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:29,519] Trial 80 finished with value: 0.0 and parameters: {'max_depth': 8, 'learning_rate': 0.20144485178704333, 'n_estimators': 69, 'min_child_weight': 5, 'subsample': 0.5369016337788761, 'colsample_bytree': 0.951643790591922, 'gamma': 0.30015203193538925, 'reg_alpha': 0.5626326661603267, 'reg_lambda': 0.4462506229210011, 'scale_pos_weight': 11.089838585970057}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:29,763] Trial 81 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.07670542623985012, 'n_estimators': 189, 'min_child_weight': 1, 'subsample': 0.6578099597827671, 'colsample_bytree': 0.6307124987095372, 'gamma': 0.6245229859421526, 'reg_alpha': 0.5208147062550009, 'reg_lambda': 0.943395329253638, 'scale_pos_weight': 7.6387849216049055}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:29,959] Trial 82 finished with value: 0.0 and parameters: {'max_depth': 20, 'learning_rate': 0.12612148913037313, 'n_estimators': 135, 'min_child_weight': 1, 'subsample': 0.7181765850794709, 'colsample_bytree': 0.8815946688197376, 'gamma': 0.7620397832561911, 'reg_alpha': 0.893143136687355, 'reg_lambda': 0.534299577342279, 'scale_pos_weight': 7.677704178531985}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:30,261] Trial 83 finished with value: 0.0 and parameters: {'max_depth': 17, 'learning_rate': 0.019457771316401428, 'n_estimators': 258, 'min_child_weight': 2, 'subsample': 0.6718927103205621, 'colsample_bytree': 0.562142134300233, 'gamma': 0.9123326136971536, 'reg_alpha': 0.6516490961302087, 'reg_lambda': 0.64518067522773, 'scale_pos_weight': 9.188169168723064}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:30,484] Trial 84 finished with value: 0.0 and parameters: {'max_depth': 19, 'learning_rate': 0.1715634005921079, 'n_estimators': 171, 'min_child_weight': 1, 'subsample': 0.6139389946037256, 'colsample_bytree': 0.6236730844178947, 'gamma': 0.7356239609811295, 'reg_alpha': 0.0009587832449938771, 'reg_lambda': 0.8318478552123724, 'scale_pos_weight': 10.07129416759383}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:30,855] Trial 85 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.010006351213635307, 'n_estimators': 244, 'min_child_weight': 2, 'subsample': 0.5803772483278672, 'colsample_bytree': 0.8550906990676761, 'gamma': 0.14230993328193386, 'reg_alpha': 0.8412402198800478, 'reg_lambda': 0.8758868589591218, 'scale_pos_weight': 8.836685328382789}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:31,022] Trial 86 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.2764441598762208, 'n_estimators': 112, 'min_child_weight': 7, 'subsample': 0.6920710108640286, 'colsample_bytree': 0.6828986045143759, 'gamma': 0.7971632008081321, 'reg_alpha': 0.42442095015604864, 'reg_lambda': 0.34827711574119147, 'scale_pos_weight': 6.406006048889164}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:31,225] Trial 87 finished with value: 0.0 and parameters: {'max_depth': 4, 'learning_rate': 0.01566853354604514, 'n_estimators': 161, 'min_child_weight': 4, 'subsample': 0.8848656695709712, 'colsample_bytree': 0.6425198154734315, 'gamma': 0.07698345485310576, 'reg_alpha': 0.5868866065536631, 'reg_lambda': 0.8828386071552328, 'scale_pos_weight': 5.181138107200043}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:31,465] Trial 88 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.0134797998811173, 'n_estimators': 149, 'min_child_weight': 6, 'subsample': 0.5979323935343818, 'colsample_bytree': 0.5952919081767137, 'gamma': 0.4917924485814523, 'reg_alpha': 0.50011694564489, 'reg_lambda': 0.6880871113390686, 'scale_pos_weight': 14.092917345101394}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:31,671] Trial 89 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.14822924214502495, 'n_estimators': 216, 'min_child_weight': 3, 'subsample': 0.6500841551193169, 'colsample_bytree': 0.5749027623265409, 'gamma': 0.3228190630400823, 'reg_alpha': 0.03807250127433677, 'reg_lambda': 0.5466750289320149, 'scale_pos_weight': 1.6668491556454086}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:31,933] Trial 90 finished with value: 0.0 and parameters: {'max_depth': 6, 'learning_rate': 0.08477744991241155, 'n_estimators': 267, 'min_child_weight': 7, 'subsample': 0.6337381805877148, 'colsample_bytree': 0.9851753185285479, 'gamma': 0.23751285315033627, 'reg_alpha': 0.8182566636117423, 'reg_lambda': 0.000446262849625588, 'scale_pos_weight': 2.6866201330264214}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:32,214] Trial 91 finished with value: 0.0 and parameters: {'max_depth': 7, 'learning_rate': 0.10485682993281495, 'n_estimators': 233, 'min_child_weight': 4, 'subsample': 0.8752843339038391, 'colsample_bytree': 0.6645037308309937, 'gamma': 0.39387857121760567, 'reg_alpha': 0.33566452623826354, 'reg_lambda': 0.05444421327960787, 'scale_pos_weight': 2.3778328477824537}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:33,297] Trial 92 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.09556784691714579, 'n_estimators': 205, 'min_child_weight': 5, 'subsample': 0.9406158050004698, 'colsample_bytree': 0.7869827219840289, 'gamma': 0.01457785806824674, 'reg_alpha': 0.5511002033772532, 'reg_lambda': 0.13889490884870684, 'scale_pos_weight': 1.3254332363356678}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:33,456] Trial 93 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.1163059005661877, 'n_estimators': 81, 'min_child_weight': 4, 'subsample': 0.8355240120258629, 'colsample_bytree': 0.7289440558445104, 'gamma': 0.5260074882053125, 'reg_alpha': 0.6149524124180725, 'reg_lambda': 0.08327224389297423, 'scale_pos_weight': 1.8829661533192041}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:33,688] Trial 94 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.06082435948559374, 'n_estimators': 251, 'min_child_weight': 2, 'subsample': 0.8240276502862861, 'colsample_bytree': 0.6031571355305828, 'gamma': 0.6318638688403213, 'reg_alpha': 0.4620958840933809, 'reg_lambda': 0.48054075653763423, 'scale_pos_weight': 3.50623788815102}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:33,890] Trial 95 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.12675610304106424, 'n_estimators': 240, 'min_child_weight': 3, 'subsample': 0.9844235008592638, 'colsample_bytree': 0.5232747019665247, 'gamma': 0.1106520585762177, 'reg_alpha': 0.07046955489356685, 'reg_lambda': 0.04320762418398115, 'scale_pos_weight': 7.326991984578243}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:34,124] Trial 96 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.0776215965143238, 'n_estimators': 300, 'min_child_weight': 4, 'subsample': 0.8982545223424974, 'colsample_bytree': 0.7143324580464682, 'gamma': 0.35235616605060865, 'reg_alpha': 0.7650962646323348, 'reg_lambda': 0.3820623356308145, 'scale_pos_weight': 7.984947154322965}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:34,303] Trial 97 finished with value: 0.0 and parameters: {'max_depth': 20, 'learning_rate': 0.1846445192453505, 'n_estimators': 224, 'min_child_weight': 5, 'subsample': 0.8092651010573269, 'colsample_bytree': 0.829804425005131, 'gamma': 0.4550865117172421, 'reg_alpha': 0.7271914642273605, 'reg_lambda': 0.5961316814495188, 'scale_pos_weight': 3.918451089192608}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:34,433] Trial 98 finished with value: 0.0 and parameters: {'max_depth': 4, 'learning_rate': 0.21629008540641118, 'n_estimators': 123, 'min_child_weight': 6, 'subsample': 0.9129609248266662, 'colsample_bytree': 0.8969410663483214, 'gamma': 0.8978081424841732, 'reg_alpha': 0.48919249851844954, 'reg_lambda': 0.027335021882709823, 'scale_pos_weight': 5.770260738950132}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 20:41:34,579] Trial 99 finished with value: 0.0 and parameters: {'max_depth': 10, 'learning_rate': 0.26978786858686926, 'n_estimators': 100, 'min_child_weight': 7, 'subsample': 0.9615358893960999, 'colsample_bytree': 0.5449895326265931, 'gamma': 0.16075925428191376, 'reg_alpha': 0.6948915256846262, 'reg_lambda': 0.09273033048855113, 'scale_pos_weight': 6.69864984773184}. Best is trial 0 with value: 0.0.

# %%
# best_params_xgb = grid_xgb.best_params_

# %%
best_params_xgb = study_xgb.best_params

# %%
print(best_params_xgb)
# Out:
# {'max_depth': 9, 'learning_rate': 0.2536999076681772, 'n_estimators': 233, 'min_child_weight': 5, 'subsample': 0.5780093202212182, 'colsample_bytree': 0.5779972601681014, 'gamma': 0.05808361216819946, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 10.913016089144637}

# %%
final_classifier = xgb.XGBClassifier(**best_params_xgb, random_state=42, eval_metric='logloss')

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5779972601681014, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=0.05808361216819946, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2536999076681772,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=5, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=233, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[446 283]
#  [  5  32]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.6240208877284595

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.10158730158730159

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.8648648648648649

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.34557235421166305
