# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8988\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8988\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### ADASYN Oversampling on Training Data

# %%
resampler = ADASYN()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = lgb.LGBMClassifier(random_state=42, verbose=-1)

# %% [markdown]
# ### Create grid for hyperparameter tuning

# %%
param_grid_lgbm = {
    'num_leaves': [15, 31, 63, 127],
    'max_depth': [3, 5, 7, 10, -1], 
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 300],
    'min_child_samples': [5, 10, 20, 30],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha': [0, 0.1, 0.5, 1], 
    'reg_lambda': [0, 0.1, 0.5, 1],  
    'scale_pos_weight': [1, 3, 5, 10, 15, 20]  
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_lgbm = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_lgbm,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# LGBMClassifier(random_state=42, verbose=-1)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Importance': importances}).sort_values(
    'Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Importance
# 4                avg_glucose_level         661
# 0                              age         504
# 5                              bmi         435
# 20                age_ever_married         257
# 24           log_avg_glucose_level         168
# 14         work_type_self_employed          92
# 18     smoking_status_never_smoked          91
# 23                         log_bmi          90
# 13               work_type_private          87
# 16          smoking_status_unknown          87
# 6                             male          74
# 11              work_type_govt_job          67
# 17  smoking_status_formerly_smoked          63
# 7                            urban          59
# 19           smoking_status_smokes          53
# 21                           obese          47
# 8                            smoke          40
# 1                     hypertension          33
# 10   hypertension_or_heart_disease          32
# 9                        have_work          22
# 3                     ever_married          16
# 2                    heart_disease          11
# 15              work_type_children          10
# 22          high_avg_glucose_level           1
# 12          work_type_never_worked           0

# %%
retained_columns = ['avg_glucose_level', 'age', 'bmi', 'work_type_self_employed', 'smoking_status_never_smoked', 'work_type_private', 'smoking_status_unknown', 'male', 'work_type_govt_job', 'smoking_status_formerly_smoked']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %%
MIN_PRECISION = 0.15

# %%
def objective_lgbm(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 15, 127),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 50),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 20),
        'random_state': 42,
        'verbose': -1
    }
    
    model = lgb.LGBMClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    
    if precision < MIN_PRECISION:
        return 0
    return recall + (precision * 0.01)

# %%
# grid_lgbm.fit(X_train_res_retained, y_train_res)

# %%
study_lgbm = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_lgbm.optimize(objective_lgbm, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 14:04:04,289] A new study created in memory with name: no-name-49996c8b-1bbc-438b-9295-0cdc996daa87
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 14:04:05,996] Trial 0 finished with value: 0.0 and parameters: {'num_leaves': 57, 'max_depth': 15, 'learning_rate': 0.1205712628744377, 'n_estimators': 200, 'min_child_samples': 12, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 14.453378978124864}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:04:06,200] Trial 1 finished with value: 0.4879990915285033 and parameters: {'num_leaves': 17, 'max_depth': 15, 'learning_rate': 0.16967533607196555, 'n_estimators': 103, 'min_child_samples': 13, 'subsample': 0.5917022549267169, 'colsample_bytree': 0.6521211214797689, 'reg_alpha': 0.5247564316322378, 'reg_lambda': 0.43194501864211576, 'scale_pos_weight': 6.533353663762797}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:06,648] Trial 2 finished with value: 0.0 and parameters: {'num_leaves': 84, 'max_depth': 4, 'learning_rate': 0.027010527749605478, 'n_estimators': 141, 'min_child_samples': 25, 'subsample': 0.8925879806965068, 'colsample_bytree': 0.5998368910791798, 'reg_alpha': 0.5142344384136116, 'reg_lambda': 0.5924145688620425, 'scale_pos_weight': 1.8825578416799567}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:08,219] Trial 3 finished with value: 0.0 and parameters: {'num_leaves': 83, 'max_depth': 5, 'learning_rate': 0.012476394272569451, 'n_estimators': 288, 'min_child_samples': 49, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'reg_alpha': 0.09767211400638387, 'reg_lambda': 0.6842330265121569, 'scale_pos_weight': 9.362897381052425}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:09,374] Trial 4 finished with value: 0.0 and parameters: {'num_leaves': 28, 'max_depth': 9, 'learning_rate': 0.011240768803005551, 'n_estimators': 278, 'min_child_samples': 16, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796, 'scale_pos_weight': 4.512234654985013}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:10,795] Trial 5 finished with value: 0.0 and parameters: {'num_leaves': 124, 'max_depth': 13, 'learning_rate': 0.24420460844911424, 'n_estimators': 274, 'min_child_samples': 32, 'subsample': 0.9609371175115584, 'colsample_bytree': 0.5442462510259598, 'reg_alpha': 0.1959828624191452, 'reg_lambda': 0.045227288910538066, 'scale_pos_weight': 7.181276284502022}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:11,340] Trial 6 finished with value: 0.0 and parameters: {'num_leaves': 58, 'max_depth': 6, 'learning_rate': 0.16755052359850303, 'n_estimators': 139, 'min_child_samples': 17, 'subsample': 0.7713480415791243, 'colsample_bytree': 0.5704621124873813, 'reg_alpha': 0.8021969807540397, 'reg_lambda': 0.07455064367977082, 'scale_pos_weight': 19.75085179540983}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:12,278] Trial 7 finished with value: 0.0 and parameters: {'num_leaves': 102, 'max_depth': 5, 'learning_rate': 0.010189592979395137, 'n_estimators': 254, 'min_child_samples': 37, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'reg_alpha': 0.07404465173409036, 'reg_lambda': 0.3584657285442726, 'scale_pos_weight': 3.2015121309774646}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:12,874] Trial 8 finished with value: 0.0 and parameters: {'num_leaves': 112, 'max_depth': 11, 'learning_rate': 0.030816017044468066, 'n_estimators': 65, 'min_child_samples': 19, 'subsample': 0.6625916610133735, 'colsample_bytree': 0.864803089169032, 'reg_alpha': 0.6375574713552131, 'reg_lambda': 0.8872127425763265, 'scale_pos_weight': 9.972083578077036}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:13,423] Trial 9 finished with value: 0.24494135645079043 and parameters: {'num_leaves': 28, 'max_depth': 12, 'learning_rate': 0.13297554090738672, 'n_estimators': 190, 'min_child_samples': 40, 'subsample': 0.7468977981821954, 'colsample_bytree': 0.7613664146909971, 'reg_alpha': 0.42754101835854963, 'reg_lambda': 0.02541912674409519, 'scale_pos_weight': 3.049937112872785}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:13,612] Trial 10 finished with value: 0.0 and parameters: {'num_leaves': 17, 'max_depth': 15, 'learning_rate': 0.0719075144108287, 'n_estimators': 54, 'min_child_samples': 5, 'subsample': 0.5193625999805915, 'colsample_bytree': 0.97988537297271, 'reg_alpha': 0.3253599979712848, 'reg_lambda': 0.32272630379083905, 'scale_pos_weight': 13.948927181086962}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:14,036] Trial 11 finished with value: 0.0 and parameters: {'num_leaves': 34, 'max_depth': 12, 'learning_rate': 0.10154145387080021, 'n_estimators': 198, 'min_child_samples': 43, 'subsample': 0.6672218185204386, 'colsample_bytree': 0.7615812730748872, 'reg_alpha': 0.3261687614846419, 'reg_lambda': 0.26699107294536956, 'scale_pos_weight': 5.782461337101238}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:14,315] Trial 12 finished with value: 0.1911891891891892 and parameters: {'num_leaves': 44, 'max_depth': 9, 'learning_rate': 0.2928322593378336, 'n_estimators': 118, 'min_child_samples': 29, 'subsample': 0.685498455862028, 'colsample_bytree': 0.7406442464830113, 'reg_alpha': 0.6738641489405021, 'reg_lambda': 0.18753263143336718, 'scale_pos_weight': 1.1002795406372483}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:14,611] Trial 13 finished with value: 0.461307285546416 and parameters: {'num_leaves': 15, 'max_depth': 13, 'learning_rate': 0.1597843901181593, 'n_estimators': 224, 'min_child_samples': 39, 'subsample': 0.5833775660192986, 'colsample_bytree': 0.7461526144014204, 'reg_alpha': 0.3720165450979667, 'reg_lambda': 0.8343963925162556, 'scale_pos_weight': 7.2992883441502245}. Best is trial 1 with value: 0.4879990915285033.
# [I 2026-01-19 14:04:14,978] Trial 14 finished with value: 0.5962363856393708 and parameters: {'num_leaves': 18, 'max_depth': 14, 'learning_rate': 0.052102913140168634, 'n_estimators': 238, 'min_child_samples': 7, 'subsample': 0.584199775295691, 'colsample_bytree': 0.6896868765954901, 'reg_alpha': 0.969269852048718, 'reg_lambda': 0.937561159366022, 'scale_pos_weight': 7.678911504531028}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:15,309] Trial 15 finished with value: 0.0 and parameters: {'num_leaves': 49, 'max_depth': 15, 'learning_rate': 0.0391493247270476, 'n_estimators': 104, 'min_child_samples': 5, 'subsample': 0.504879290726932, 'colsample_bytree': 0.6690010157890557, 'reg_alpha': 0.9796464996812289, 'reg_lambda': 0.7637473949148526, 'scale_pos_weight': 13.68337791119939}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:15,816] Trial 16 finished with value: 0.38019656019656023 and parameters: {'num_leaves': 37, 'max_depth': 10, 'learning_rate': 0.0607475943451666, 'n_estimators': 240, 'min_child_samples': 11, 'subsample': 0.5810266352402632, 'colsample_bytree': 0.843625566043863, 'reg_alpha': 0.6896744252117673, 'reg_lambda': 0.9983124835522814, 'scale_pos_weight': 8.09554340334844}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:17,109] Trial 17 finished with value: 0.0 and parameters: {'num_leaves': 74, 'max_depth': 14, 'learning_rate': 0.01953097315301984, 'n_estimators': 167, 'min_child_samples': 23, 'subsample': 0.6375970132231312, 'colsample_bytree': 0.6176952480837, 'reg_alpha': 0.9558264730105442, 'reg_lambda': 0.44911317337157636, 'scale_pos_weight': 12.02452285350427}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:17,345] Trial 18 finished with value: 0.0 and parameters: {'num_leaves': 22, 'max_depth': 7, 'learning_rate': 0.08659402510551069, 'n_estimators': 90, 'min_child_samples': 11, 'subsample': 0.7135891907932033, 'colsample_bytree': 0.7106073981498738, 'reg_alpha': 0.8122160264329289, 'reg_lambda': 0.4450184159097231, 'scale_pos_weight': 17.49631308068105}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:17,936] Trial 19 finished with value: 0.0 and parameters: {'num_leaves': 61, 'max_depth': 13, 'learning_rate': 0.042972852287206945, 'n_estimators': 162, 'min_child_samples': 7, 'subsample': 0.6200392464368687, 'colsample_bytree': 0.821025100021489, 'reg_alpha': 0.6203781714235388, 'reg_lambda': 0.9938427850497087, 'scale_pos_weight': 5.586814746258928}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:18,379] Trial 20 finished with value: 0.5420909281374398 and parameters: {'num_leaves': 43, 'max_depth': 11, 'learning_rate': 0.052848540004792, 'n_estimators': 222, 'min_child_samples': 20, 'subsample': 0.5336776185623248, 'colsample_bytree': 0.5086792017528844, 'reg_alpha': 0.7611983209859814, 'reg_lambda': 0.7347780293219217, 'scale_pos_weight': 11.57421433294984}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:18,861] Trial 21 finished with value: 0.0 and parameters: {'num_leaves': 35, 'max_depth': 11, 'learning_rate': 0.04955230168429516, 'n_estimators': 236, 'min_child_samples': 19, 'subsample': 0.5425279675626159, 'colsample_bytree': 0.519832743597177, 'reg_alpha': 0.8960607159667696, 'reg_lambda': 0.7057847405363491, 'scale_pos_weight': 11.37570177274305}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:19,553] Trial 22 finished with value: 0.3258827658827659 and parameters: {'num_leaves': 46, 'max_depth': 14, 'learning_rate': 0.07807066251694114, 'n_estimators': 218, 'min_child_samples': 14, 'subsample': 0.5536579066387141, 'colsample_bytree': 0.6968622933311692, 'reg_alpha': 0.801518798587549, 'reg_lambda': 0.8801800640652742, 'scale_pos_weight': 9.066331867001974}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:19,946] Trial 23 finished with value: 0.0 and parameters: {'num_leaves': 25, 'max_depth': 8, 'learning_rate': 0.06084409511823484, 'n_estimators': 257, 'min_child_samples': 21, 'subsample': 0.5974027371364075, 'colsample_bytree': 0.5011063468136578, 'reg_alpha': 0.7354352552990047, 'reg_lambda': 0.7997784052270356, 'scale_pos_weight': 12.193906852594742}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:20,952] Trial 24 finished with value: 0.0 and parameters: {'num_leaves': 15, 'max_depth': 14, 'learning_rate': 0.02969573097086817, 'n_estimators': 217, 'min_child_samples': 8, 'subsample': 0.5001310561523566, 'colsample_bytree': 0.5977920975466742, 'reg_alpha': 0.5623295984208537, 'reg_lambda': 0.6784968600650669, 'scale_pos_weight': 15.488750505155746}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:22,507] Trial 25 finished with value: 0.0 and parameters: {'num_leaves': 38, 'max_depth': 11, 'learning_rate': 0.021363196314674777, 'n_estimators': 176, 'min_child_samples': 26, 'subsample': 0.6297236619276361, 'colsample_bytree': 0.8041859363210639, 'reg_alpha': 0.900697217120888, 'reg_lambda': 0.9203663710160048, 'scale_pos_weight': 5.7486215560849665}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:23,003] Trial 26 finished with value: 0.0 and parameters: {'num_leaves': 28, 'max_depth': 12, 'learning_rate': 0.0383343314921216, 'n_estimators': 81, 'min_child_samples': 10, 'subsample': 0.5505861281903774, 'colsample_bytree': 0.6351311525108622, 'reg_alpha': 0.9940416898525785, 'reg_lambda': 0.4873450190060191, 'scale_pos_weight': 10.59727515087951}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:24,100] Trial 27 finished with value: 0.0 and parameters: {'num_leaves': 51, 'max_depth': 14, 'learning_rate': 0.21566211302793295, 'n_estimators': 143, 'min_child_samples': 15, 'subsample': 0.7068095012668912, 'colsample_bytree': 0.5710164128331697, 'reg_alpha': 0.7734291031918956, 'reg_lambda': 0.750485994964857, 'scale_pos_weight': 7.8447278688019235}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:25,544] Trial 28 finished with value: 0.29898960498960503 and parameters: {'num_leaves': 65, 'max_depth': 10, 'learning_rate': 0.05627774315840156, 'n_estimators': 298, 'min_child_samples': 30, 'subsample': 0.7949866834933749, 'colsample_bytree': 0.707094492847755, 'reg_alpha': 0.20007459192822186, 'reg_lambda': 0.3818965850086791, 'scale_pos_weight': 4.176259197537011}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:26,176] Trial 29 finished with value: 0.2990160472972973 and parameters: {'num_leaves': 41, 'max_depth': 15, 'learning_rate': 0.10787498374390138, 'n_estimators': 186, 'min_child_samples': 14, 'subsample': 0.6017476518916052, 'colsample_bytree': 0.9260741278503519, 'reg_alpha': 0.8667535737877008, 'reg_lambda': 0.6140472348362185, 'scale_pos_weight': 8.616449145822296}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:27,766] Trial 30 finished with value: 0.0 and parameters: {'num_leaves': 21, 'max_depth': 13, 'learning_rate': 0.016144657706984374, 'n_estimators': 212, 'min_child_samples': 22, 'subsample': 0.5472987942580846, 'colsample_bytree': 0.5530292830127539, 'reg_alpha': 0.44860277542239685, 'reg_lambda': 0.19127957177686886, 'scale_pos_weight': 15.578527118504962}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:28,609] Trial 31 finished with value: 0.4071099508599509 and parameters: {'num_leaves': 15, 'max_depth': 13, 'learning_rate': 0.16506676827737707, 'n_estimators': 235, 'min_child_samples': 33, 'subsample': 0.5793964927212469, 'colsample_bytree': 0.7935311922374512, 'reg_alpha': 0.37676038088603864, 'reg_lambda': 0.8053049394575509, 'scale_pos_weight': 7.24278751354102}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:29,896] Trial 32 finished with value: 0.29896396396396396 and parameters: {'num_leaves': 31, 'max_depth': 15, 'learning_rate': 0.13745709422828073, 'n_estimators': 249, 'min_child_samples': 48, 'subsample': 0.63839016136929, 'colsample_bytree': 0.6958022451045884, 'reg_alpha': 0.5910143219531507, 'reg_lambda': 0.8562504019302069, 'scale_pos_weight': 6.111036182505112}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:30,765] Trial 33 finished with value: 0.3800062853551226 and parameters: {'num_leaves': 22, 'max_depth': 12, 'learning_rate': 0.1684463887310135, 'n_estimators': 212, 'min_child_samples': 45, 'subsample': 0.5327174781814622, 'colsample_bytree': 0.7293487582794456, 'reg_alpha': 0.2568823514210457, 'reg_lambda': 0.9333817930788871, 'scale_pos_weight': 10.503966432914208}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:32,040] Trial 34 finished with value: 0.0 and parameters: {'num_leaves': 15, 'max_depth': 14, 'learning_rate': 0.09691912044094704, 'n_estimators': 219, 'min_child_samples': 37, 'subsample': 0.5698435273428073, 'colsample_bytree': 0.6603721293646065, 'reg_alpha': 0.464979852610706, 'reg_lambda': 0.5442343440591504, 'scale_pos_weight': 7.1442367938642395}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:34,915] Trial 35 finished with value: 0.35355474118185987 and parameters: {'num_leaves': 76, 'max_depth': 10, 'learning_rate': 0.06781604808025478, 'n_estimators': 231, 'min_child_samples': 9, 'subsample': 0.5992408483712687, 'colsample_bytree': 0.604460571182802, 'reg_alpha': 0.532821003468243, 'reg_lambda': 0.8337735011256029, 'scale_pos_weight': 4.340736071245455}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:36,262] Trial 36 finished with value: 0.0 and parameters: {'num_leaves': 54, 'max_depth': 13, 'learning_rate': 0.2161512504601447, 'n_estimators': 274, 'min_child_samples': 13, 'subsample': 0.5696572654888066, 'colsample_bytree': 0.677400041266957, 'reg_alpha': 0.3614975728875632, 'reg_lambda': 0.6296074957904141, 'scale_pos_weight': 12.975435139306848}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:37,670] Trial 37 finished with value: 0.4340485940485941 and parameters: {'num_leaves': 92, 'max_depth': 15, 'learning_rate': 0.04590482043194967, 'n_estimators': 147, 'min_child_samples': 17, 'subsample': 0.5275970017937563, 'colsample_bytree': 0.7736571427460628, 'reg_alpha': 0.7381092253864201, 'reg_lambda': 0.9479449221242247, 'scale_pos_weight': 9.72113150566279}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:38,129] Trial 38 finished with value: 0.0 and parameters: {'num_leaves': 23, 'max_depth': 3, 'learning_rate': 0.12303794290689846, 'n_estimators': 259, 'min_child_samples': 24, 'subsample': 0.971689757492779, 'colsample_bytree': 0.622476821937966, 'reg_alpha': 0.1281120357783581, 'reg_lambda': 0.7166559424252785, 'scale_pos_weight': 6.77669420528033}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:38,475] Trial 39 finished with value: 0.5421030405405406 and parameters: {'num_leaves': 34, 'max_depth': 12, 'learning_rate': 0.03393255687030986, 'n_estimators': 125, 'min_child_samples': 19, 'subsample': 0.6667609890621176, 'colsample_bytree': 0.5740901566347043, 'reg_alpha': 0.019568026616011702, 'reg_lambda': 0.6746452288283652, 'scale_pos_weight': 2.7677089953361875}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:38,836] Trial 40 finished with value: 0.5421030405405406 and parameters: {'num_leaves': 31, 'max_depth': 11, 'learning_rate': 0.03411848281158049, 'n_estimators': 125, 'min_child_samples': 18, 'subsample': 0.7284276000846592, 'colsample_bytree': 0.5709351957557292, 'reg_alpha': 0.018825163478298823, 'reg_lambda': 0.5551259916805066, 'scale_pos_weight': 2.7435613707077504}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:39,347] Trial 41 finished with value: 0.5421278421278422 and parameters: {'num_leaves': 30, 'max_depth': 11, 'learning_rate': 0.03404224786779101, 'n_estimators': 123, 'min_child_samples': 18, 'subsample': 0.7272656930308874, 'colsample_bytree': 0.5801505704777049, 'reg_alpha': 0.03902915714367031, 'reg_lambda': 0.5688730990564459, 'scale_pos_weight': 2.552667901962992}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:39,738] Trial 42 finished with value: 0.5421153436901469 and parameters: {'num_leaves': 31, 'max_depth': 11, 'learning_rate': 0.0351328554881622, 'n_estimators': 123, 'min_child_samples': 18, 'subsample': 0.748184960868157, 'colsample_bytree': 0.5709200363447873, 'reg_alpha': 0.014207115916532058, 'reg_lambda': 0.5401135579934899, 'scale_pos_weight': 2.4987573798901304}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:40,009] Trial 43 finished with value: 0.569100414282896 and parameters: {'num_leaves': 31, 'max_depth': 10, 'learning_rate': 0.02528965448769717, 'n_estimators': 124, 'min_child_samples': 17, 'subsample': 0.7452710623927852, 'colsample_bytree': 0.576215510668159, 'reg_alpha': 0.05798993271056116, 'reg_lambda': 0.5236412346430923, 'scale_pos_weight': 2.4898974903471043}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:40,276] Trial 44 finished with value: 0.5421030405405406 and parameters: {'num_leaves': 30, 'max_depth': 9, 'learning_rate': 0.024461599877553992, 'n_estimators': 119, 'min_child_samples': 16, 'subsample': 0.8096251145129255, 'colsample_bytree': 0.5350008237896245, 'reg_alpha': 0.012413701441233743, 'reg_lambda': 0.6505880422987022, 'scale_pos_weight': 1.8748933963929146}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:41,869] Trial 45 finished with value: 0.32594594594594595 and parameters: {'num_leaves': 39, 'max_depth': 10, 'learning_rate': 0.02533593842665175, 'n_estimators': 104, 'min_child_samples': 26, 'subsample': 0.7608263084448027, 'colsample_bytree': 0.5866540246007171, 'reg_alpha': 0.11347854678144276, 'reg_lambda': 0.5698858257989183, 'scale_pos_weight': 1.127573805330581}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:42,295] Trial 46 finished with value: 0.0 and parameters: {'num_leaves': 34, 'max_depth': 12, 'learning_rate': 0.016393144960377935, 'n_estimators': 131, 'min_child_samples': 20, 'subsample': 0.8490842131649265, 'colsample_bytree': 0.5466587991152873, 'reg_alpha': 0.06121833244965761, 'reg_lambda': 0.5102178592503206, 'scale_pos_weight': 3.6722175209938706}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:42,813] Trial 47 finished with value: 0.542193433102524 and parameters: {'num_leaves': 124, 'max_depth': 8, 'learning_rate': 0.033405197163714956, 'n_estimators': 85, 'min_child_samples': 12, 'subsample': 0.7837866217078879, 'colsample_bytree': 0.5660963981983227, 'reg_alpha': 0.16281835825658605, 'reg_lambda': 0.38408420979267355, 'scale_pos_weight': 2.6099085068429373}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:43,112] Trial 48 finished with value: 0.0 and parameters: {'num_leaves': 124, 'max_depth': 8, 'learning_rate': 0.02959876312306308, 'n_estimators': 78, 'min_child_samples': 7, 'subsample': 0.9070404313749388, 'colsample_bytree': 0.6343651378102166, 'reg_alpha': 0.15073852930435594, 'reg_lambda': 0.39486817291985177, 'scale_pos_weight': 4.955360905773517}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:43,573] Trial 49 finished with value: 0.48842197035745427 and parameters: {'num_leaves': 101, 'max_depth': 8, 'learning_rate': 0.021227874088491215, 'n_estimators': 153, 'min_child_samples': 13, 'subsample': 0.7820369166895483, 'colsample_bytree': 0.5550625219824463, 'reg_alpha': 0.18624837531408878, 'reg_lambda': 0.3065270862505612, 'scale_pos_weight': 1.9392086704491553}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:43,982] Trial 50 finished with value: 0.3528629792583281 and parameters: {'num_leaves': 118, 'max_depth': 9, 'learning_rate': 0.03867521252467244, 'n_estimators': 94, 'min_child_samples': 12, 'subsample': 0.7419961131673167, 'colsample_bytree': 0.6474722014647971, 'reg_alpha': 0.06924796234575797, 'reg_lambda': 0.2327866840977036, 'scale_pos_weight': 2.0671306378772485}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:44,426] Trial 51 finished with value: 0.5423423423423424 and parameters: {'num_leaves': 89, 'max_depth': 10, 'learning_rate': 0.033581879069217065, 'n_estimators': 109, 'min_child_samples': 16, 'subsample': 0.6694348621192001, 'colsample_bytree': 0.5839350642932696, 'reg_alpha': 0.043599332309468816, 'reg_lambda': 0.4950497447763238, 'scale_pos_weight': 2.87651747636599}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:44,690] Trial 52 finished with value: 0.0 and parameters: {'num_leaves': 88, 'max_depth': 7, 'learning_rate': 0.025984095694983982, 'n_estimators': 111, 'min_child_samples': 16, 'subsample': 0.695162145811796, 'colsample_bytree': 0.5279166927450685, 'reg_alpha': 0.24150402891735714, 'reg_lambda': 0.473849608882294, 'scale_pos_weight': 3.293008024269998}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:44,909] Trial 53 finished with value: 0.0 and parameters: {'num_leaves': 65, 'max_depth': 9, 'learning_rate': 0.03466226037841809, 'n_estimators': 52, 'min_child_samples': 6, 'subsample': 0.815866920875401, 'colsample_bytree': 0.6062665126486873, 'reg_alpha': 0.0690454481687485, 'reg_lambda': 0.4119354811809948, 'scale_pos_weight': 5.000508918496315}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:45,412] Trial 54 finished with value: 0.0 and parameters: {'num_leaves': 105, 'max_depth': 7, 'learning_rate': 0.04538713088192211, 'n_estimators': 73, 'min_child_samples': 9, 'subsample': 0.7304660916396523, 'colsample_bytree': 0.5875545482391697, 'reg_alpha': 0.15819545759251696, 'reg_lambda': 0.3198996899822124, 'scale_pos_weight': 3.8241967971590842}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:45,805] Trial 55 finished with value: 0.35318233726684434 and parameters: {'num_leaves': 80, 'max_depth': 10, 'learning_rate': 0.016516745793884735, 'n_estimators': 95, 'min_child_samples': 11, 'subsample': 0.7701592242341998, 'colsample_bytree': 0.558174090337325, 'reg_alpha': 0.09275024720863564, 'reg_lambda': 0.5206266795662524, 'scale_pos_weight': 1.0988132013520877}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:46,255] Trial 56 finished with value: 0.5152099420849421 and parameters: {'num_leaves': 95, 'max_depth': 8, 'learning_rate': 0.028822485585238186, 'n_estimators': 136, 'min_child_samples': 15, 'subsample': 0.74771644678187, 'colsample_bytree': 0.6213619717781171, 'reg_alpha': 0.04933558221531933, 'reg_lambda': 0.4503902729441486, 'scale_pos_weight': 2.683405480185581}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:46,775] Trial 57 finished with value: 0.0 and parameters: {'num_leaves': 127, 'max_depth': 5, 'learning_rate': 0.02288417606213529, 'n_estimators': 88, 'min_child_samples': 17, 'subsample': 0.6905454561954517, 'colsample_bytree': 0.5206032168718246, 'reg_alpha': 0.2565891493002227, 'reg_lambda': 0.3522199058222238, 'scale_pos_weight': 4.8976122517596625}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:47,152] Trial 58 finished with value: 0.5421798848028356 and parameters: {'num_leaves': 108, 'max_depth': 10, 'learning_rate': 0.01816060978883848, 'n_estimators': 113, 'min_child_samples': 23, 'subsample': 0.7112000698179675, 'colsample_bytree': 0.5867827926401128, 'reg_alpha': 0.11451890760804141, 'reg_lambda': 0.5845687379962702, 'scale_pos_weight': 2.1404305323648196}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:47,385] Trial 59 finished with value: 0.515165687426557 and parameters: {'num_leaves': 113, 'max_depth': 10, 'learning_rate': 0.014428264696518367, 'n_estimators': 66, 'min_child_samples': 22, 'subsample': 0.7198064280058223, 'colsample_bytree': 0.5896460450992319, 'reg_alpha': 0.21340304898710424, 'reg_lambda': 0.08683150976415727, 'scale_pos_weight': 1.6032683152807186}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:47,603] Trial 60 finished with value: 0.0 and parameters: {'num_leaves': 118, 'max_depth': 6, 'learning_rate': 0.01241313553849135, 'n_estimators': 112, 'min_child_samples': 23, 'subsample': 0.6579627298626283, 'colsample_bytree': 0.6811636421428469, 'reg_alpha': 0.1570226258757606, 'reg_lambda': 0.582694949213039, 'scale_pos_weight': 3.4330830221883417}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:48,057] Trial 61 finished with value: 0.5153059663437022 and parameters: {'num_leaves': 105, 'max_depth': 11, 'learning_rate': 0.01879788643588461, 'n_estimators': 156, 'min_child_samples': 20, 'subsample': 0.7850171779285062, 'colsample_bytree': 0.6413602470129242, 'reg_alpha': 0.00022383456775193836, 'reg_lambda': 0.603623973549622, 'scale_pos_weight': 2.3801024758130245}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:48,345] Trial 62 finished with value: 0.5421798848028356 and parameters: {'num_leaves': 113, 'max_depth': 9, 'learning_rate': 0.04105824733212766, 'n_estimators': 107, 'min_child_samples': 18, 'subsample': 0.7584768541834221, 'colsample_bytree': 0.5395073724943141, 'reg_alpha': 0.0404419483754468, 'reg_lambda': 0.5173472379248396, 'scale_pos_weight': 3.0368714343643872}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:48,625] Trial 63 finished with value: 0.0 and parameters: {'num_leaves': 116, 'max_depth': 9, 'learning_rate': 0.043183390327076514, 'n_estimators': 110, 'min_child_samples': 25, 'subsample': 0.7601985677182724, 'colsample_bytree': 0.5403572184279721, 'reg_alpha': 0.11141468108975151, 'reg_lambda': 0.4936725878805716, 'scale_pos_weight': 4.033912284532814}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:48,887] Trial 64 finished with value: 0.5151514445479962 and parameters: {'num_leaves': 110, 'max_depth': 10, 'learning_rate': 0.05392856088044313, 'n_estimators': 101, 'min_child_samples': 28, 'subsample': 0.7038369898339507, 'colsample_bytree': 0.509678393789664, 'reg_alpha': 0.04472271790289038, 'reg_lambda': 0.4270234728416309, 'scale_pos_weight': 3.2287122760132156}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:49,319] Trial 65 finished with value: 0.0 and parameters: {'num_leaves': 124, 'max_depth': 8, 'learning_rate': 0.032278536627184336, 'n_estimators': 86, 'min_child_samples': 13, 'subsample': 0.6822595125213984, 'colsample_bytree': 0.6145659111338868, 'reg_alpha': 0.09667404704664895, 'reg_lambda': 0.34935258053460255, 'scale_pos_weight': 4.632778326075531}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:49,729] Trial 66 finished with value: 0.0 and parameters: {'num_leaves': 109, 'max_depth': 9, 'learning_rate': 0.027916106104897493, 'n_estimators': 131, 'min_child_samples': 15, 'subsample': 0.8337226898151098, 'colsample_bytree': 0.5842163814623326, 'reg_alpha': 0.12002819907821066, 'reg_lambda': 0.6439191691931605, 'scale_pos_weight': 5.3812684037699015}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:49,955] Trial 67 finished with value: 0.4880936293436294 and parameters: {'num_leaves': 85, 'max_depth': 7, 'learning_rate': 0.01914943570791092, 'n_estimators': 98, 'min_child_samples': 21, 'subsample': 0.6480075445863602, 'colsample_bytree': 0.5578341104420618, 'reg_alpha': 0.1759179288691693, 'reg_lambda': 0.4527420588699913, 'scale_pos_weight': 1.5262561232815846}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:50,547] Trial 68 finished with value: 0.0 and parameters: {'num_leaves': 99, 'max_depth': 10, 'learning_rate': 0.048536551723025116, 'n_estimators': 172, 'min_child_samples': 10, 'subsample': 0.8013074169021092, 'colsample_bytree': 0.9923834344614579, 'reg_alpha': 0.30358519833885167, 'reg_lambda': 0.47645789736559074, 'scale_pos_weight': 6.277759063424963}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:50,756] Trial 69 finished with value: 0.0 and parameters: {'num_leaves': 121, 'max_depth': 9, 'learning_rate': 0.03897353281136035, 'n_estimators': 65, 'min_child_samples': 18, 'subsample': 0.6155659485480542, 'colsample_bytree': 0.5353405209125118, 'reg_alpha': 0.04950721607650382, 'reg_lambda': 0.2750098975931355, 'scale_pos_weight': 3.2135944926407736}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:51,032] Trial 70 finished with value: 0.40730413958262063 and parameters: {'num_leaves': 114, 'max_depth': 8, 'learning_rate': 0.06418727797044106, 'n_estimators': 114, 'min_child_samples': 11, 'subsample': 0.734649108618779, 'colsample_bytree': 0.5173157834113807, 'reg_alpha': 0.2213487102716753, 'reg_lambda': 0.585086239606065, 'scale_pos_weight': 2.159715432864226}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:51,249] Trial 71 finished with value: 0.5691954745443117 and parameters: {'num_leaves': 27, 'max_depth': 11, 'learning_rate': 0.03701788014004773, 'n_estimators': 121, 'min_child_samples': 18, 'subsample': 0.7168066474055651, 'colsample_bytree': 0.5645374601185754, 'reg_alpha': 0.08463679288349461, 'reg_lambda': 0.5356688388687401, 'scale_pos_weight': 2.62671816460967}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:51,575] Trial 72 finished with value: 0.5690893066980023 and parameters: {'num_leaves': 25, 'max_depth': 11, 'learning_rate': 0.04183353600314141, 'n_estimators': 139, 'min_child_samples': 22, 'subsample': 0.716888082719508, 'colsample_bytree': 0.6031229744134333, 'reg_alpha': 0.08345521444363455, 'reg_lambda': 0.526276322135773, 'scale_pos_weight': 3.7990081655711414}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:51,842] Trial 73 finished with value: 0.0 and parameters: {'num_leaves': 25, 'max_depth': 10, 'learning_rate': 0.05651599259835747, 'n_estimators': 136, 'min_child_samples': 21, 'subsample': 0.6809120054764958, 'colsample_bytree': 0.6017170571515765, 'reg_alpha': 0.08274513482192451, 'reg_lambda': 0.5162141030857752, 'scale_pos_weight': 19.676532199648943}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:52,091] Trial 74 finished with value: 0.0 and parameters: {'num_leaves': 19, 'max_depth': 12, 'learning_rate': 0.04030663040155051, 'n_estimators': 147, 'min_child_samples': 24, 'subsample': 0.7616073364721636, 'colsample_bytree': 0.5554751045870324, 'reg_alpha': 0.14103390503982377, 'reg_lambda': 0.39312316484407445, 'scale_pos_weight': 3.9639223652889033}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:52,297] Trial 75 finished with value: 0.5424096994190453 and parameters: {'num_leaves': 26, 'max_depth': 9, 'learning_rate': 0.030892348233533675, 'n_estimators': 108, 'min_child_samples': 14, 'subsample': 0.7109946648643312, 'colsample_bytree': 0.6316098280191476, 'reg_alpha': 0.09200373356871636, 'reg_lambda': 0.5292142366956175, 'scale_pos_weight': 1.6124665607681825}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:52,480] Trial 76 finished with value: 0.4071295433364399 and parameters: {'num_leaves': 18, 'max_depth': 11, 'learning_rate': 0.02285362782415172, 'n_estimators': 116, 'min_child_samples': 14, 'subsample': 0.7126294239051995, 'colsample_bytree': 0.6316969146190369, 'reg_alpha': 0.10162082047973699, 'reg_lambda': 0.4241841225928773, 'scale_pos_weight': 1.1301310644182803}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:52,751] Trial 77 finished with value: 0.4884864864864865 and parameters: {'num_leaves': 26, 'max_depth': 10, 'learning_rate': 0.030589034059611615, 'n_estimators': 188, 'min_child_samples': 12, 'subsample': 0.6983803040793072, 'colsample_bytree': 0.5977323531491113, 'reg_alpha': 0.17742368643770084, 'reg_lambda': 0.61045561490939, 'scale_pos_weight': 1.6526707128566656}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:52,964] Trial 78 finished with value: 0.4612120367790471 and parameters: {'num_leaves': 27, 'max_depth': 11, 'learning_rate': 0.05017843001915722, 'n_estimators': 130, 'min_child_samples': 8, 'subsample': 0.7179116984001105, 'colsample_bytree': 0.6665173123905778, 'reg_alpha': 0.30203876561439147, 'reg_lambda': 0.5417562833925139, 'scale_pos_weight': 2.326290511513162}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:53,147] Trial 79 finished with value: 0.5693031047576502 and parameters: {'num_leaves': 20, 'max_depth': 12, 'learning_rate': 0.0728027999694149, 'n_estimators': 103, 'min_child_samples': 5, 'subsample': 0.6530824891602124, 'colsample_bytree': 0.653084233088513, 'reg_alpha': 0.1274848715728299, 'reg_lambda': 0.46687683919800455, 'scale_pos_weight': 3.6169959331142536}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:53,309] Trial 80 finished with value: 0.5961223723723724 and parameters: {'num_leaves': 20, 'max_depth': 12, 'learning_rate': 0.07807958076729811, 'n_estimators': 80, 'min_child_samples': 5, 'subsample': 0.6781411164248381, 'colsample_bytree': 0.7196766873056911, 'reg_alpha': 0.08230336561806302, 'reg_lambda': 0.4778791090007422, 'scale_pos_weight': 4.4404129197334115}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:53,457] Trial 81 finished with value: 0.5961660231660232 and parameters: {'num_leaves': 20, 'max_depth': 12, 'learning_rate': 0.07960891364089875, 'n_estimators': 73, 'min_child_samples': 5, 'subsample': 0.6763223646174747, 'colsample_bytree': 0.7146093153797122, 'reg_alpha': 0.14077745433403915, 'reg_lambda': 0.473717590967342, 'scale_pos_weight': 4.287649107065169}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:53,641] Trial 82 finished with value: 0.5690675675675675 and parameters: {'num_leaves': 20, 'max_depth': 12, 'learning_rate': 0.07992072021396271, 'n_estimators': 73, 'min_child_samples': 5, 'subsample': 0.6777380810328277, 'colsample_bytree': 0.7319814794471303, 'reg_alpha': 0.07932216454206437, 'reg_lambda': 0.46788050852657365, 'scale_pos_weight': 4.201770931617572}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:53,846] Trial 83 finished with value: 0.0 and parameters: {'num_leaves': 21, 'max_depth': 13, 'learning_rate': 0.0800592816688163, 'n_estimators': 62, 'min_child_samples': 5, 'subsample': 0.6497529612027607, 'colsample_bytree': 0.7176965267833075, 'reg_alpha': 0.08189927941801786, 'reg_lambda': 0.464571270907144, 'scale_pos_weight': 4.422485536365329}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:53,993] Trial 84 finished with value: 0.0 and parameters: {'num_leaves': 19, 'max_depth': 12, 'learning_rate': 0.08913262039046575, 'n_estimators': 59, 'min_child_samples': 6, 'subsample': 0.6750756215146038, 'colsample_bytree': 0.7410838489812104, 'reg_alpha': 0.13535520221304984, 'reg_lambda': 0.5351111747062902, 'scale_pos_weight': 5.288852982226275}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:54,157] Trial 85 finished with value: 0.0 and parameters: {'num_leaves': 24, 'max_depth': 12, 'learning_rate': 0.07896247122454714, 'n_estimators': 72, 'min_child_samples': 6, 'subsample': 0.6220746637752874, 'colsample_bytree': 0.689482456128859, 'reg_alpha': 0.13165442663765556, 'reg_lambda': 0.4354037418582, 'scale_pos_weight': 5.893486118919565}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:54,337] Trial 86 finished with value: 0.5420790020790021 and parameters: {'num_leaves': 17, 'max_depth': 13, 'learning_rate': 0.11166375517405258, 'n_estimators': 77, 'min_child_samples': 7, 'subsample': 0.6396295373969052, 'colsample_bytree': 0.7556864670374743, 'reg_alpha': 0.08896639219843401, 'reg_lambda': 0.48810947188882164, 'scale_pos_weight': 3.572479501830757}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:54,626] Trial 87 finished with value: 0.0 and parameters: {'num_leaves': 22, 'max_depth': 14, 'learning_rate': 0.06967185058225064, 'n_estimators': 71, 'min_child_samples': 5, 'subsample': 0.6559328891135139, 'colsample_bytree': 0.7260106181240035, 'reg_alpha': 0.20224441512049512, 'reg_lambda': 0.4153711105626389, 'scale_pos_weight': 4.318160156931361}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:54,817] Trial 88 finished with value: 0.5421030405405406 and parameters: {'num_leaves': 28, 'max_depth': 12, 'learning_rate': 0.09073285675024194, 'n_estimators': 93, 'min_child_samples': 8, 'subsample': 0.6090764213452059, 'colsample_bytree': 0.7740158784815963, 'reg_alpha': 0.026408640537050478, 'reg_lambda': 0.5592264708624856, 'scale_pos_weight': 8.085706841761107}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:55,001] Trial 89 finished with value: 0.0 and parameters: {'num_leaves': 36, 'max_depth': 13, 'learning_rate': 0.07280760336662069, 'n_estimators': 80, 'min_child_samples': 9, 'subsample': 0.6947009661734339, 'colsample_bytree': 0.7013391703564824, 'reg_alpha': 0.6530683294649147, 'reg_lambda': 0.45968401006661597, 'scale_pos_weight': 6.3089499196843555}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:55,228] Trial 90 finished with value: 0.0 and parameters: {'num_leaves': 20, 'max_depth': 11, 'learning_rate': 0.05819231274601482, 'n_estimators': 201, 'min_child_samples': 6, 'subsample': 0.6325149056280563, 'colsample_bytree': 0.6600264836345127, 'reg_alpha': 0.06868580078870642, 'reg_lambda': 0.5055905981249369, 'scale_pos_weight': 6.958678308280359}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:55,387] Trial 91 finished with value: 0.0 and parameters: {'num_leaves': 15, 'max_depth': 11, 'learning_rate': 0.06262372162955944, 'n_estimators': 98, 'min_child_samples': 8, 'subsample': 0.6706108089153915, 'colsample_bytree': 0.6777196958389755, 'reg_alpha': 0.004260297314882741, 'reg_lambda': 0.49574099707619607, 'scale_pos_weight': 3.823418768791435}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:55,599] Trial 92 finished with value: 0.5152099420849421 and parameters: {'num_leaves': 24, 'max_depth': 12, 'learning_rate': 0.09700483425189528, 'n_estimators': 105, 'min_child_samples': 5, 'subsample': 0.6672750634465989, 'colsample_bytree': 0.7234245361004521, 'reg_alpha': 0.03455573115214705, 'reg_lambda': 0.5302908824659004, 'scale_pos_weight': 4.936379224717617}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:55,960] Trial 93 finished with value: 0.21775467775467777 and parameters: {'num_leaves': 32, 'max_depth': 12, 'learning_rate': 0.08397407194043749, 'n_estimators': 283, 'min_child_samples': 7, 'subsample': 0.6791758539927614, 'colsample_bytree': 0.651455074520058, 'reg_alpha': 0.49783665160826895, 'reg_lambda': 0.36741786392308917, 'scale_pos_weight': 3.062352427121021}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:56,488] Trial 94 finished with value: 0.5691954745443117 and parameters: {'num_leaves': 28, 'max_depth': 11, 'learning_rate': 0.036888448012938606, 'n_estimators': 264, 'min_child_samples': 10, 'subsample': 0.7014859972811309, 'colsample_bytree': 0.7333146084478256, 'reg_alpha': 0.9561418563749142, 'reg_lambda': 0.4742564275408692, 'scale_pos_weight': 8.892872949772618}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:56,913] Trial 95 finished with value: 0.5421153436901469 and parameters: {'num_leaves': 29, 'max_depth': 11, 'learning_rate': 0.03708887427385078, 'n_estimators': 260, 'min_child_samples': 9, 'subsample': 0.7402904985797032, 'colsample_bytree': 0.7669498777770413, 'reg_alpha': 0.9723679249998525, 'reg_lambda': 0.4045525564033581, 'scale_pos_weight': 10.126116219363903}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:57,317] Trial 96 finished with value: 0.3258827658827659 and parameters: {'num_leaves': 39, 'max_depth': 13, 'learning_rate': 0.0712129109915711, 'n_estimators': 271, 'min_child_samples': 10, 'subsample': 0.7230592603965292, 'colsample_bytree': 0.7054425479736581, 'reg_alpha': 0.8924080762374709, 'reg_lambda': 0.7709423914290241, 'scale_pos_weight': 9.377760800741166}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:57,695] Trial 97 finished with value: 0.4612874164487068 and parameters: {'num_leaves': 33, 'max_depth': 11, 'learning_rate': 0.06631685938498287, 'n_estimators': 245, 'min_child_samples': 6, 'subsample': 0.7040410778117049, 'colsample_bytree': 0.7462524209959649, 'reg_alpha': 0.9528635169160832, 'reg_lambda': 0.11959619768615681, 'scale_pos_weight': 10.933955683128682}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:57,890] Trial 98 finished with value: 0.40692055692055695 and parameters: {'num_leaves': 26, 'max_depth': 12, 'learning_rate': 0.07498618172987175, 'n_estimators': 119, 'min_child_samples': 7, 'subsample': 0.6847680942682687, 'colsample_bytree': 0.7338499536273332, 'reg_alpha': 0.06614674976433067, 'reg_lambda': 0.4756293343914948, 'scale_pos_weight': 3.616590839606456}. Best is trial 14 with value: 0.5962363856393708.
# [I 2026-01-19 14:04:58,019] Trial 99 finished with value: 0.0 and parameters: {'num_leaves': 17, 'max_depth': 13, 'learning_rate': 0.04569678549747556, 'n_estimators': 55, 'min_child_samples': 5, 'subsample': 0.6899154754883704, 'colsample_bytree': 0.6924399489483147, 'reg_alpha': 0.8513279758281787, 'reg_lambda': 0.4390618256038975, 'scale_pos_weight': 8.482119645002346}. Best is trial 14 with value: 0.5962363856393708.

# %%
# best_params_lgbm = grid_lgbm.best_params_

# %%
best_params_lgbm = study_lgbm.best_params

# %%
print(best_params_lgbm)
# Out:
# {'num_leaves': 18, 'max_depth': 14, 'learning_rate': 0.052102913140168634, 'n_estimators': 238, 'min_child_samples': 7, 'subsample': 0.584199775295691, 'colsample_bytree': 0.6896868765954901, 'reg_alpha': 0.969269852048718, 'reg_lambda': 0.937561159366022, 'scale_pos_weight': 7.678911504531028}

# %%
final_classifier = lgb.LGBMClassifier(**best_params_lgbm, random_state=42, verbose=-1)

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# LGBMClassifier(colsample_bytree=0.6896868765954901,
#                learning_rate=0.052102913140168634, max_depth=14,
#                min_child_samples=7, n_estimators=238, num_leaves=18,
#                random_state=42, reg_alpha=0.969269852048718,
#                reg_lambda=0.937561159366022, scale_pos_weight=7.678911504531028,
#                subsample=0.584199775295691, verbose=-1)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[617 112]
#  [ 15  22]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.8342036553524804

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.16417910447761194

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.5945945945945946

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.3900709219858156

# %% [markdown]
# ### Threshold tuning

# %%
best_threshold = 0.5

# %%
best_precision_score = 0

# %%
best_recall_score = 0

# %%
best_f2_score = 0

# %%
for threshold in np.arange(0.1, 0.95, 0.05):
    y_pred_val_threshold = (y_proba_val >= threshold).astype(int)
    recall = recall_score(y_val, y_pred_val_threshold)
    precision = precision_score(y_val, y_pred_val_threshold)
    f2_score = fbeta_score(y_val, y_pred_val_threshold, beta=2)
    
    print(f'Threshold {threshold} has recall score {f2_score}')
    
    if precision >= 0.15:
        current_recall_score = recall
        if current_recall_score > best_recall_score:
            best_recall_score = current_recall_score
            best_precision_score = precision
            best_threshold = threshold
        elif current_recall_score == best_recall_score and precision > best_precision_score:
            best_precision_score = precision
            best_threshold = threshold
        
        # current_f2_score = f2_score
        # if current_f2_score > best_f2_score:
        #     best_f2_score = current_f2_score
        #     best_threshold = threshold
# Out:
# Threshold 0.1 has recall score 0.34444444444444444
# Threshold 0.15000000000000002 has recall score 0.36729857819905215
# Threshold 0.20000000000000004 has recall score 0.358974358974359
# Threshold 0.25000000000000006 has recall score 0.37735849056603776
# Threshold 0.30000000000000004 has recall score 0.3448275862068966
# Threshold 0.3500000000000001 has recall score 0.3463855421686747
# Threshold 0.40000000000000013 has recall score 0.3639240506329114
# Threshold 0.45000000000000007 has recall score 0.3728813559322034
# Threshold 0.5000000000000001 has recall score 0.3900709219858156
# Threshold 0.5500000000000002 has recall score 0.38181818181818183
# Threshold 0.6000000000000002 has recall score 0.3584905660377358
# Threshold 0.6500000000000001 has recall score 0.37109375
# Threshold 0.7000000000000002 has recall score 0.35269709543568467
# Threshold 0.7500000000000002 has recall score 0.3508771929824561
# Threshold 0.8000000000000002 has recall score 0.2644230769230769
# Threshold 0.8500000000000002 has recall score 0.20100502512562815
# Threshold 0.9000000000000002 has recall score 0.16042780748663102

# %%
print(best_threshold)
# Out:
# 0.5000000000000001

# %%
print(best_recall_score)
# Out:
# 0.5945945945945946

# %% [markdown]
# ### Retrain on training + validation set

# %%
X_train_full = pd.concat([X_train_res_retained, X_val_retained], axis=0, ignore_index=True)
y_train_full = pd.concat([y_train_res, y_val], axis=0, ignore_index=True)

# %%
final_classifier.fit(X_train_full, y_train_full)
# Out:
# LGBMClassifier(colsample_bytree=0.6896868765954901,
#                learning_rate=0.052102913140168634, max_depth=14,
#                min_child_samples=7, n_estimators=238, num_leaves=18,
#                random_state=42, reg_alpha=0.969269852048718,
#                reg_lambda=0.937561159366022, scale_pos_weight=7.678911504531028,
#                subsample=0.584199775295691, verbose=-1)

# %% [markdown]
# ### Evaluate on test set

# %%
X_test_retained = X_test[retained_columns]

# %%
y_pred_test = final_classifier.predict(X_test_retained)

# %%
y_pred_test = final_classifier.predict(X_test_retained)

# %%
y_proba_test = final_classifier.predict_proba(X_test_retained)[:, 1]

# %%
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[608 121]
#  [ 18  20]]

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.81877444589309

# %%
print(precision_score(y_test, y_pred_test))
# Out:
# 0.14184397163120568

# %%
print(recall_score(y_test, y_pred_test))
# Out:
# 0.5263157894736842

# %%
print(fbeta_score(y_test, y_pred_test, beta=2))
# Out:
# 0.3412969283276451
