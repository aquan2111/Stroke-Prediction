# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.under_sampling import NearMiss
import lightgbm as lgb 
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20352\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20352\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### ADASYN Oversampling on Training Data

# %%
resampler = NearMiss()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = lgb.LGBMClassifier(random_state=42, verbose=-1)

# %% [markdown]
# ### Create grid for hyperparameter tuning

# %%
param_grid_lgbm = {
    'num_leaves': [15, 31, 63, 127],
    'max_depth': [3, 5, 7, 10, -1], 
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 300],
    'min_child_samples': [5, 10, 20, 30],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha': [0, 0.1, 0.5, 1], 
    'reg_lambda': [0, 0.1, 0.5, 1],  
    'scale_pos_weight': [1, 3, 5, 10, 15, 20]  
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_lgbm = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_lgbm,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# LGBMClassifier(random_state=42, verbose=-1)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Importance': importances}).sort_values(
    'Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Importance
# 5                              bmi         351
# 4                avg_glucose_level         299
# 0                              age         183
# 20                age_ever_married         125
# 7                            urban          62
# 13               work_type_private          35
# 6                             male          35
# 18     smoking_status_never_smoked          33
# 1                     hypertension          29
# 8                            smoke          25
# 10   hypertension_or_heart_disease          24
# 14         work_type_self_employed          16
# 16          smoking_status_unknown          13
# 19           smoking_status_smokes          13
# 11              work_type_govt_job           7
# 17  smoking_status_formerly_smoked           7
# 2                    heart_disease           4
# 21                           obese           1
# 22          high_avg_glucose_level           0
# 23                         log_bmi           0
# 12          work_type_never_worked           0
# 15              work_type_children           0
# 9                        have_work           0
# 3                     ever_married           0
# 24           log_avg_glucose_level           0

# %%
retained_columns = ['bmi', 'avg_glucose_level', 'age', 'urban', 'work_type_private', 'male', 'smoking_status_never_smoked', 'hypertension', 'smoke', 'work_type_self_employed']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.1

# %%
def objective_lgbm(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 15, 127),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 50),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 20),
        'random_state': 42,
        'verbose': -1
    }
    
    model = lgb.LGBMClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    
    if precision < MIN_PRECISION:
        return 0
    return recall + (precision * 0.01)

# %%
# grid_lgbm.fit(X_train_res_retained, y_train_res)

# %%
study_lgbm = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_lgbm.optimize(objective_lgbm, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 13:35:04,649] A new study created in memory with name: no-name-2fdac1f0-c2d9-4f2e-ae9e-be6329170baf
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 13:35:04,796] Trial 0 finished with value: 0.0 and parameters: {'num_leaves': 57, 'max_depth': 15, 'learning_rate': 0.1205712628744377, 'n_estimators': 200, 'min_child_samples': 12, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 14.453378978124864}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:04,856] Trial 1 finished with value: 0.0 and parameters: {'num_leaves': 17, 'max_depth': 15, 'learning_rate': 0.16967533607196555, 'n_estimators': 103, 'min_child_samples': 13, 'subsample': 0.5917022549267169, 'colsample_bytree': 0.6521211214797689, 'reg_alpha': 0.5247564316322378, 'reg_lambda': 0.43194501864211576, 'scale_pos_weight': 6.533353663762797}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:04,905] Trial 2 finished with value: 0.0 and parameters: {'num_leaves': 84, 'max_depth': 4, 'learning_rate': 0.027010527749605478, 'n_estimators': 141, 'min_child_samples': 25, 'subsample': 0.8925879806965068, 'colsample_bytree': 0.5998368910791798, 'reg_alpha': 0.5142344384136116, 'reg_lambda': 0.5924145688620425, 'scale_pos_weight': 1.8825578416799567}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:04,992] Trial 3 finished with value: 0.0 and parameters: {'num_leaves': 83, 'max_depth': 5, 'learning_rate': 0.012476394272569451, 'n_estimators': 288, 'min_child_samples': 49, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'reg_alpha': 0.09767211400638387, 'reg_lambda': 0.6842330265121569, 'scale_pos_weight': 9.362897381052425}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,100] Trial 4 finished with value: 0.0 and parameters: {'num_leaves': 28, 'max_depth': 9, 'learning_rate': 0.011240768803005551, 'n_estimators': 278, 'min_child_samples': 16, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796, 'scale_pos_weight': 4.512234654985013}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,176] Trial 5 finished with value: 0.0 and parameters: {'num_leaves': 124, 'max_depth': 13, 'learning_rate': 0.24420460844911424, 'n_estimators': 274, 'min_child_samples': 32, 'subsample': 0.9609371175115584, 'colsample_bytree': 0.5442462510259598, 'reg_alpha': 0.1959828624191452, 'reg_lambda': 0.045227288910538066, 'scale_pos_weight': 7.181276284502022}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,227] Trial 6 finished with value: 0.0 and parameters: {'num_leaves': 58, 'max_depth': 6, 'learning_rate': 0.16755052359850303, 'n_estimators': 139, 'min_child_samples': 17, 'subsample': 0.7713480415791243, 'colsample_bytree': 0.5704621124873813, 'reg_alpha': 0.8021969807540397, 'reg_lambda': 0.07455064367977082, 'scale_pos_weight': 19.75085179540983}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,299] Trial 7 finished with value: 0.0 and parameters: {'num_leaves': 102, 'max_depth': 5, 'learning_rate': 0.010189592979395137, 'n_estimators': 254, 'min_child_samples': 37, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'reg_alpha': 0.07404465173409036, 'reg_lambda': 0.3584657285442726, 'scale_pos_weight': 3.2015121309774646}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,335] Trial 8 finished with value: 0.0 and parameters: {'num_leaves': 112, 'max_depth': 11, 'learning_rate': 0.030816017044468066, 'n_estimators': 65, 'min_child_samples': 19, 'subsample': 0.6625916610133735, 'colsample_bytree': 0.864803089169032, 'reg_alpha': 0.6375574713552131, 'reg_lambda': 0.8872127425763265, 'scale_pos_weight': 9.972083578077036}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,384] Trial 9 finished with value: 0.0 and parameters: {'num_leaves': 28, 'max_depth': 12, 'learning_rate': 0.13297554090738672, 'n_estimators': 190, 'min_child_samples': 40, 'subsample': 0.7468977981821954, 'colsample_bytree': 0.7613664146909971, 'reg_alpha': 0.42754101835854963, 'reg_lambda': 0.02541912674409519, 'scale_pos_weight': 3.049937112872785}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,515] Trial 10 finished with value: 0.0 and parameters: {'num_leaves': 57, 'max_depth': 15, 'learning_rate': 0.0749883856323417, 'n_estimators': 214, 'min_child_samples': 5, 'subsample': 0.5193625999805915, 'colsample_bytree': 0.97988537297271, 'reg_alpha': 0.9761398998579952, 'reg_lambda': 0.9469618763901493, 'scale_pos_weight': 15.029705349775393}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,584] Trial 11 finished with value: 0.0 and parameters: {'num_leaves': 16, 'max_depth': 15, 'learning_rate': 0.08486603434290381, 'n_estimators': 64, 'min_child_samples': 6, 'subsample': 0.5472666635128242, 'colsample_bytree': 0.5034392951693698, 'reg_alpha': 0.9940403736301033, 'reg_lambda': 0.31464503711868463, 'scale_pos_weight': 14.76054734445038}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,671] Trial 12 finished with value: 0.0 and parameters: {'num_leaves': 48, 'max_depth': 9, 'learning_rate': 0.2947927028325085, 'n_estimators': 118, 'min_child_samples': 12, 'subsample': 0.609303657185796, 'colsample_bytree': 0.730179771771769, 'reg_alpha': 0.742347534737023, 'reg_lambda': 0.3568935701127543, 'scale_pos_weight': 13.817629527305492}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,805] Trial 13 finished with value: 0.0 and parameters: {'num_leaves': 37, 'max_depth': 14, 'learning_rate': 0.12626689958632767, 'n_estimators': 221, 'min_child_samples': 24, 'subsample': 0.6511020710303068, 'colsample_bytree': 0.6654564209034075, 'reg_alpha': 0.33171814206359374, 'reg_lambda': 0.7583635489314875, 'scale_pos_weight': 17.970040157414644}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,867] Trial 14 finished with value: 0.0 and parameters: {'num_leaves': 72, 'max_depth': 11, 'learning_rate': 0.04779944309421829, 'n_estimators': 92, 'min_child_samples': 10, 'subsample': 0.5785932138359383, 'colsample_bytree': 0.5065672694180388, 'reg_alpha': 0.7946453641120889, 'reg_lambda': 0.43200028731684337, 'scale_pos_weight': 6.521846951644682}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:05,937] Trial 15 finished with value: 0.0 and parameters: {'num_leaves': 45, 'max_depth': 13, 'learning_rate': 0.1906306420081584, 'n_estimators': 175, 'min_child_samples': 21, 'subsample': 0.6966713259977332, 'colsample_bytree': 0.7423578866620044, 'reg_alpha': 0.6732717907646599, 'reg_lambda': 0.2550570692138962, 'scale_pos_weight': 11.962034303903877}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,001] Trial 16 finished with value: 0.0 and parameters: {'num_leaves': 15, 'max_depth': 7, 'learning_rate': 0.09650592102088115, 'n_estimators': 157, 'min_child_samples': 30, 'subsample': 0.511847705752916, 'colsample_bytree': 0.6008964335081206, 'reg_alpha': 0.389664524207145, 'reg_lambda': 0.7163755998306335, 'scale_pos_weight': 7.086454969900423}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,067] Trial 17 finished with value: 0.0 and parameters: {'num_leaves': 67, 'max_depth': 15, 'learning_rate': 0.046419036087664504, 'n_estimators': 114, 'min_child_samples': 13, 'subsample': 0.6123467940735869, 'colsample_bytree': 0.6879515056982495, 'reg_alpha': 0.8956049237047359, 'reg_lambda': 0.17747344841110274, 'scale_pos_weight': 12.23175086121507}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,165] Trial 18 finished with value: 0.0 and parameters: {'num_leaves': 94, 'max_depth': 9, 'learning_rate': 0.06508953869274123, 'n_estimators': 233, 'min_child_samples': 10, 'subsample': 0.7201273557961427, 'colsample_bytree': 0.7902929748954253, 'reg_alpha': 0.2415834261767888, 'reg_lambda': 0.49221563552671455, 'scale_pos_weight': 17.33858749501863}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,233] Trial 19 finished with value: 0.0 and parameters: {'num_leaves': 35, 'max_depth': 13, 'learning_rate': 0.11981197100109081, 'n_estimators': 191, 'min_child_samples': 21, 'subsample': 0.5666077607075912, 'colsample_bytree': 0.6214160406561196, 'reg_alpha': 0.5864640754480753, 'reg_lambda': 0.5963089090685653, 'scale_pos_weight': 8.249148061478863}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,294] Trial 20 finished with value: 0.0 and parameters: {'num_leaves': 75, 'max_depth': 10, 'learning_rate': 0.1955365590981143, 'n_estimators': 89, 'min_child_samples': 14, 'subsample': 0.6427023912763987, 'colsample_bytree': 0.5528355205298704, 'reg_alpha': 0.878627006583033, 'reg_lambda': 0.8624808991805704, 'scale_pos_weight': 5.194511414669494}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,348] Trial 21 finished with value: 0.0 and parameters: {'num_leaves': 79, 'max_depth': 4, 'learning_rate': 0.02406878281440383, 'n_estimators': 134, 'min_child_samples': 26, 'subsample': 0.9987349142404867, 'colsample_bytree': 0.5756100246396195, 'reg_alpha': 0.5699054756297403, 'reg_lambda': 0.619330480889154, 'scale_pos_weight': 1.2650211042008035}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,415] Trial 22 finished with value: 0.0 and parameters: {'num_leaves': 92, 'max_depth': 8, 'learning_rate': 0.028326278670085792, 'n_estimators': 165, 'min_child_samples': 8, 'subsample': 0.8170064962868606, 'colsample_bytree': 0.6211260858961597, 'reg_alpha': 0.43523619548996173, 'reg_lambda': 0.4984172041931467, 'scale_pos_weight': 1.714720988499083}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,484] Trial 23 finished with value: 0.0 and parameters: {'num_leaves': 62, 'max_depth': 3, 'learning_rate': 0.017947587419652782, 'n_estimators': 91, 'min_child_samples': 35, 'subsample': 0.9280029567477267, 'colsample_bytree': 0.6856502617064631, 'reg_alpha': 0.6898576129152496, 'reg_lambda': 0.7973378203494244, 'scale_pos_weight': 5.068099230947219}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,560] Trial 24 finished with value: 0.0 and parameters: {'num_leaves': 90, 'max_depth': 14, 'learning_rate': 0.035980758134127336, 'n_estimators': 142, 'min_child_samples': 24, 'subsample': 0.8050213718606852, 'colsample_bytree': 0.6031074154579784, 'reg_alpha': 0.48481890068854183, 'reg_lambda': 0.654364235383882, 'scale_pos_weight': 11.592835379883343}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,625] Trial 25 finished with value: 0.0 and parameters: {'num_leaves': 106, 'max_depth': 3, 'learning_rate': 0.018461963570372456, 'n_estimators': 115, 'min_child_samples': 17, 'subsample': 0.6916721404977116, 'colsample_bytree': 0.5455621528427093, 'reg_alpha': 0.2452016505767063, 'reg_lambda': 0.42975581329342616, 'scale_pos_weight': 3.323560934454812}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,713] Trial 26 finished with value: 0.0 and parameters: {'num_leaves': 46, 'max_depth': 12, 'learning_rate': 0.09630469589936787, 'n_estimators': 198, 'min_child_samples': 43, 'subsample': 0.6174798275951675, 'colsample_bytree': 0.7083329397447957, 'reg_alpha': 0.5227968940126628, 'reg_lambda': 0.5931372159164537, 'scale_pos_weight': 8.60470793835623}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,767] Trial 27 finished with value: 0.0 and parameters: {'num_leaves': 52, 'max_depth': 7, 'learning_rate': 0.060108949100555434, 'n_estimators': 151, 'min_child_samples': 28, 'subsample': 0.8839468442608407, 'colsample_bytree': 0.8045242984991502, 'reg_alpha': 0.2978070889826723, 'reg_lambda': 0.4416836166131589, 'scale_pos_weight': 16.220122653535483}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,849] Trial 28 finished with value: 0.0 and parameters: {'num_leaves': 83, 'max_depth': 14, 'learning_rate': 0.14381192322177383, 'n_estimators': 247, 'min_child_samples': 21, 'subsample': 0.7723543022392799, 'colsample_bytree': 0.5246368140348497, 'reg_alpha': 0.5943749537281457, 'reg_lambda': 0.5423712182276632, 'scale_pos_weight': 13.063425735423989}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,902] Trial 29 finished with value: 0.0 and parameters: {'num_leaves': 37, 'max_depth': 11, 'learning_rate': 0.020241592544518253, 'n_estimators': 125, 'min_child_samples': 50, 'subsample': 0.9154724933789339, 'colsample_bytree': 0.6480542236247291, 'reg_alpha': 0.18271365535206224, 'reg_lambda': 0.6622672567826405, 'scale_pos_weight': 10.684825788657765}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:06,993] Trial 30 finished with value: 0.0 and parameters: {'num_leaves': 65, 'max_depth': 5, 'learning_rate': 0.0398649623792408, 'n_estimators': 299, 'min_child_samples': 14, 'subsample': 0.5472987942580846, 'colsample_bytree': 0.5851046733160638, 'reg_alpha': 0.7541088348288341, 'reg_lambda': 0.2370088886214864, 'scale_pos_weight': 6.0491170967446815}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,050] Trial 31 finished with value: 0.0 and parameters: {'num_leaves': 84, 'max_depth': 4, 'learning_rate': 0.013908945829988006, 'n_estimators': 295, 'min_child_samples': 50, 'subsample': 0.8653207917124405, 'colsample_bytree': 0.6407756737756548, 'reg_alpha': 0.021891514820133573, 'reg_lambda': 0.6964867909872028, 'scale_pos_weight': 9.337302790238667}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,130] Trial 32 finished with value: 0.0 and parameters: {'num_leaves': 117, 'max_depth': 5, 'learning_rate': 0.01265798937182387, 'n_estimators': 271, 'min_child_samples': 44, 'subsample': 0.9598482300597748, 'colsample_bytree': 0.6697376142616047, 'reg_alpha': 0.1139534584726818, 'reg_lambda': 0.5534966207562758, 'scale_pos_weight': 8.634603177226374}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,183] Trial 33 finished with value: 0.0 and parameters: {'num_leaves': 88, 'max_depth': 6, 'learning_rate': 0.014841414833760048, 'n_estimators': 102, 'min_child_samples': 32, 'subsample': 0.8420697677008246, 'colsample_bytree': 0.6290720820902892, 'reg_alpha': 0.5082677359152044, 'reg_lambda': 0.7747897038141311, 'scale_pos_weight': 7.5874001351548}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,281] Trial 34 finished with value: 0.0 and parameters: {'num_leaves': 100, 'max_depth': 4, 'learning_rate': 0.20166478423273865, 'n_estimators': 260, 'min_child_samples': 17, 'subsample': 0.9170493802452836, 'colsample_bytree': 0.5633862729668965, 'reg_alpha': 0.3606032092822813, 'reg_lambda': 0.531814722612808, 'scale_pos_weight': 10.585378570928082}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,351] Trial 35 finished with value: 0.0 and parameters: {'num_leaves': 22, 'max_depth': 6, 'learning_rate': 0.25994036028906087, 'n_estimators': 74, 'min_child_samples': 35, 'subsample': 0.9963252442894389, 'colsample_bytree': 0.7114019843530437, 'reg_alpha': 0.8719966273016766, 'reg_lambda': 0.472168090817362, 'scale_pos_weight': 4.245195071461804}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,465] Trial 36 finished with value: 0.0 and parameters: {'num_leaves': 125, 'max_depth': 7, 'learning_rate': 0.010438499616584433, 'n_estimators': 280, 'min_child_samples': 47, 'subsample': 0.7766726777775903, 'colsample_bytree': 0.532087302542294, 'reg_alpha': 0.13342292081136484, 'reg_lambda': 0.8491251209281683, 'scale_pos_weight': 2.4894135695522825}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,548] Trial 37 finished with value: 0.0 and parameters: {'num_leaves': 77, 'max_depth': 3, 'learning_rate': 0.023092375391614135, 'n_estimators': 175, 'min_child_samples': 38, 'subsample': 0.8434718425145458, 'colsample_bytree': 0.5949730686967667, 'reg_alpha': 0.4547514833554062, 'reg_lambda': 0.37052625840845455, 'scale_pos_weight': 19.176465295616286}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,667] Trial 38 finished with value: 0.0 and parameters: {'num_leaves': 101, 'max_depth': 13, 'learning_rate': 0.1587348992205482, 'n_estimators': 200, 'min_child_samples': 8, 'subsample': 0.7378700370812161, 'colsample_bytree': 0.9879570879719038, 'reg_alpha': 0.6470872887336561, 'reg_lambda': 0.697165810520577, 'scale_pos_weight': 9.673098503266857}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,783] Trial 39 finished with value: 0.0 and parameters: {'num_leaves': 56, 'max_depth': 15, 'learning_rate': 0.030470725454987066, 'n_estimators': 235, 'min_child_samples': 18, 'subsample': 0.8878972101534367, 'colsample_bytree': 0.7824865803817456, 'reg_alpha': 0.010447734008491971, 'reg_lambda': 0.9386408426081372, 'scale_pos_weight': 3.975213514932504}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,834] Trial 40 finished with value: 0.0 and parameters: {'num_leaves': 26, 'max_depth': 8, 'learning_rate': 0.10567810438876753, 'n_estimators': 75, 'min_child_samples': 41, 'subsample': 0.9646942991694355, 'colsample_bytree': 0.9550200187953906, 'reg_alpha': 0.7225632578719812, 'reg_lambda': 0.10523860989743106, 'scale_pos_weight': 5.760886550379041}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:07,965] Trial 41 finished with value: 0.0 and parameters: {'num_leaves': 23, 'max_depth': 10, 'learning_rate': 0.010511361499184881, 'n_estimators': 278, 'min_child_samples': 15, 'subsample': 0.8144208173352626, 'colsample_bytree': 0.6574551790998729, 'reg_alpha': 0.5407771822091715, 'reg_lambda': 0.6376140242933288, 'scale_pos_weight': 2.552667901962992}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,084] Trial 42 finished with value: 0.0 and parameters: {'num_leaves': 32, 'max_depth': 5, 'learning_rate': 0.01610390756480988, 'n_estimators': 289, 'min_child_samples': 11, 'subsample': 0.889612847708508, 'colsample_bytree': 0.7038213551567769, 'reg_alpha': 0.4026065762763772, 'reg_lambda': 0.5615706907021569, 'scale_pos_weight': 4.277889028538844}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,203] Trial 43 finished with value: 0.0 and parameters: {'num_leaves': 19, 'max_depth': 10, 'learning_rate': 0.01123541709189758, 'n_estimators': 264, 'min_child_samples': 7, 'subsample': 0.5830758856154384, 'colsample_bytree': 0.6136147860926751, 'reg_alpha': 0.619731842478561, 'reg_lambda': 0.3682147326998184, 'scale_pos_weight': 7.217378915795393}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,286] Trial 44 finished with value: 0.0 and parameters: {'num_leaves': 28, 'max_depth': 12, 'learning_rate': 0.012098357192876368, 'n_estimators': 220, 'min_child_samples': 23, 'subsample': 0.9485898346132119, 'colsample_bytree': 0.8447716486344699, 'reg_alpha': 0.9334159012892634, 'reg_lambda': 0.724439516940762, 'scale_pos_weight': 14.004357802029954}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,437] Trial 45 finished with value: 0.0 and parameters: {'num_leaves': 43, 'max_depth': 14, 'learning_rate': 0.07548765489227117, 'n_estimators': 249, 'min_child_samples': 5, 'subsample': 0.6772158673081285, 'colsample_bytree': 0.5778953513942386, 'reg_alpha': 0.8247480368863458, 'reg_lambda': 0.5814093952920381, 'scale_pos_weight': 4.9898671627545825}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,532] Trial 46 finished with value: 0.0 and parameters: {'num_leaves': 69, 'max_depth': 8, 'learning_rate': 0.22439215563012474, 'n_estimators': 131, 'min_child_samples': 19, 'subsample': 0.8498908602378278, 'colsample_bytree': 0.5143700170556725, 'reg_alpha': 0.31465090530232964, 'reg_lambda': 0.2928591365969716, 'scale_pos_weight': 1.816716753323207}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,617] Trial 47 finished with value: 0.0 and parameters: {'num_leaves': 73, 'max_depth': 6, 'learning_rate': 0.023166320097700373, 'n_estimators': 149, 'min_child_samples': 12, 'subsample': 0.6324879829877151, 'colsample_bytree': 0.7548083442200373, 'reg_alpha': 0.4757556078867084, 'reg_lambda': 0.407093993963048, 'scale_pos_weight': 6.636644437890211}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,738] Trial 48 finished with value: 0.0 and parameters: {'num_leaves': 97, 'max_depth': 15, 'learning_rate': 0.16954945134518648, 'n_estimators': 236, 'min_child_samples': 15, 'subsample': 0.5379023106760519, 'colsample_bytree': 0.6696663057787872, 'reg_alpha': 0.5578825840923461, 'reg_lambda': 0.5109518464562459, 'scale_pos_weight': 15.908655268174885}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,835] Trial 49 finished with value: 0.0 and parameters: {'num_leaves': 40, 'max_depth': 4, 'learning_rate': 0.05137529654176404, 'n_estimators': 173, 'min_child_samples': 27, 'subsample': 0.5050155788141772, 'colsample_bytree': 0.6392314429518854, 'reg_alpha': 0.3586403297298141, 'reg_lambda': 0.47504209460854685, 'scale_pos_weight': 3.412332759346572}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:08,918] Trial 50 finished with value: 0.0 and parameters: {'num_leaves': 61, 'max_depth': 13, 'learning_rate': 0.03826162718581155, 'n_estimators': 53, 'min_child_samples': 9, 'subsample': 0.7944446139623412, 'colsample_bytree': 0.7353043966310453, 'reg_alpha': 0.26242354172807925, 'reg_lambda': 0.6110268876502016, 'scale_pos_weight': 1.015119931437205}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,039] Trial 51 finished with value: 0.0 and parameters: {'num_leaves': 107, 'max_depth': 14, 'learning_rate': 0.29577122109804704, 'n_estimators': 286, 'min_child_samples': 29, 'subsample': 0.9423721394492406, 'colsample_bytree': 0.5390090282968824, 'reg_alpha': 0.08607779346666294, 'reg_lambda': 0.16327056337489082, 'scale_pos_weight': 7.7752941617369284}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,133] Trial 52 finished with value: 0.0 and parameters: {'num_leaves': 15, 'max_depth': 15, 'learning_rate': 0.23155631421582587, 'n_estimators': 274, 'min_child_samples': 31, 'subsample': 0.8946342778368916, 'colsample_bytree': 0.5625134137810821, 'reg_alpha': 0.06707949399380081, 'reg_lambda': 0.014117513645384105, 'scale_pos_weight': 6.396783714472349}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,252] Trial 53 finished with value: 0.0 and parameters: {'num_leaves': 123, 'max_depth': 14, 'learning_rate': 0.17117774602977484, 'n_estimators': 263, 'min_child_samples': 16, 'subsample': 0.9729067559222064, 'colsample_bytree': 0.5967727919468028, 'reg_alpha': 0.1995150678200393, 'reg_lambda': 0.6639581298254219, 'scale_pos_weight': 11.382040275846844}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,367] Trial 54 finished with value: 0.0 and parameters: {'num_leaves': 52, 'max_depth': 12, 'learning_rate': 0.11280417087676607, 'n_estimators': 253, 'min_child_samples': 34, 'subsample': 0.5873855864222522, 'colsample_bytree': 0.5520978630401577, 'reg_alpha': 0.4139473633145524, 'reg_lambda': 0.735841114766941, 'scale_pos_weight': 9.187166152097147}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,456] Trial 55 finished with value: 0.0 and parameters: {'num_leaves': 33, 'max_depth': 13, 'learning_rate': 0.14034055852832336, 'n_estimators': 102, 'min_child_samples': 21, 'subsample': 0.8668351259090606, 'colsample_bytree': 0.5001624757788677, 'reg_alpha': 0.1705538949632084, 'reg_lambda': 0.791840220453422, 'scale_pos_weight': 5.5089998773564695}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,566] Trial 56 finished with value: 0.0 and parameters: {'num_leaves': 115, 'max_depth': 9, 'learning_rate': 0.2429013482087388, 'n_estimators': 211, 'min_child_samples': 25, 'subsample': 0.9148190418680525, 'colsample_bytree': 0.6102934096480968, 'reg_alpha': 0.6253916064546046, 'reg_lambda': 0.6300298150568213, 'scale_pos_weight': 12.641040943948747}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,650] Trial 57 finished with value: 0.0 and parameters: {'num_leaves': 85, 'max_depth': 15, 'learning_rate': 0.017131871886585447, 'n_estimators': 104, 'min_child_samples': 39, 'subsample': 0.9357363902921597, 'colsample_bytree': 0.6870249957698258, 'reg_alpha': 0.6736070107309176, 'reg_lambda': 0.06633657274313334, 'scale_pos_weight': 8.255341490784405}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,767] Trial 58 finished with value: 0.0 and parameters: {'num_leaves': 79, 'max_depth': 11, 'learning_rate': 0.019791004539865608, 'n_estimators': 159, 'min_child_samples': 11, 'subsample': 0.8271492710828734, 'colsample_bytree': 0.5716356342581133, 'reg_alpha': 0.7893650875624196, 'reg_lambda': 0.20320497197278428, 'scale_pos_weight': 4.766055116431197}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:09,883] Trial 59 finished with value: 0.0 and parameters: {'num_leaves': 109, 'max_depth': 5, 'learning_rate': 0.013199652615038852, 'n_estimators': 185, 'min_child_samples': 23, 'subsample': 0.7244982207237002, 'colsample_bytree': 0.5295938188596735, 'reg_alpha': 0.4484702528434814, 'reg_lambda': 0.3149469549968126, 'scale_pos_weight': 9.996787352071559}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,036] Trial 60 finished with value: 0.0 and parameters: {'num_leaves': 28, 'max_depth': 14, 'learning_rate': 0.08622037128698104, 'n_estimators': 290, 'min_child_samples': 20, 'subsample': 0.9048881830287946, 'colsample_bytree': 0.628821550815742, 'reg_alpha': 0.045530600129577214, 'reg_lambda': 0.5231513247503518, 'scale_pos_weight': 2.8742493696468125}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,130] Trial 61 finished with value: 0.0 and parameters: {'num_leaves': 58, 'max_depth': 6, 'learning_rate': 0.200789887696236, 'n_estimators': 141, 'min_child_samples': 13, 'subsample': 0.7864289933500633, 'colsample_bytree': 0.5850673534546759, 'reg_alpha': 0.959101803367184, 'reg_lambda': 0.02519448152245185, 'scale_pos_weight': 18.053514845571335}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,201] Trial 62 finished with value: 0.0 and parameters: {'num_leaves': 50, 'max_depth': 4, 'learning_rate': 0.1273776410779823, 'n_estimators': 116, 'min_child_samples': 16, 'subsample': 0.7454074353951752, 'colsample_bytree': 0.5475589275746572, 'reg_alpha': 0.8504582432210853, 'reg_lambda': 0.11108705635572343, 'scale_pos_weight': 16.44507998684941}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,287] Trial 63 finished with value: 0.0 and parameters: {'num_leaves': 65, 'max_depth': 3, 'learning_rate': 0.17769237057111842, 'n_estimators': 126, 'min_child_samples': 13, 'subsample': 0.5328065911717674, 'colsample_bytree': 0.5211523271005981, 'reg_alpha': 0.9974342005408586, 'reg_lambda': 0.08253770207508748, 'scale_pos_weight': 19.96867361466695}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,369] Trial 64 finished with value: 0.0 and parameters: {'num_leaves': 95, 'max_depth': 7, 'learning_rate': 0.15877189933188093, 'n_estimators': 140, 'min_child_samples': 18, 'subsample': 0.8723625507142793, 'colsample_bytree': 0.6536696103510036, 'reg_alpha': 0.9310168880499717, 'reg_lambda': 0.6820052112108576, 'scale_pos_weight': 15.445240713802445}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,454] Trial 65 finished with value: 0.0 and parameters: {'num_leaves': 70, 'max_depth': 5, 'learning_rate': 0.2581648687798181, 'n_estimators': 166, 'min_child_samples': 47, 'subsample': 0.9779398755334614, 'colsample_bytree': 0.5616822897907321, 'reg_alpha': 0.7109930061667491, 'reg_lambda': 0.13375315468733012, 'scale_pos_weight': 14.125628395382856}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,548] Trial 66 finished with value: 0.0 and parameters: {'num_leaves': 20, 'max_depth': 4, 'learning_rate': 0.014806848130624996, 'n_estimators': 241, 'min_child_samples': 10, 'subsample': 0.7554995543948265, 'colsample_bytree': 0.5894682554482308, 'reg_alpha': 0.7556104374710458, 'reg_lambda': 0.8371975624882191, 'scale_pos_weight': 16.930838269922297}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,650] Trial 67 finished with value: 0.0 and parameters: {'num_leaves': 43, 'max_depth': 8, 'learning_rate': 0.2162555252756012, 'n_estimators': 267, 'min_child_samples': 33, 'subsample': 0.5600284578348128, 'colsample_bytree': 0.6141983894462294, 'reg_alpha': 0.5045414155115758, 'reg_lambda': 0.5801019874883537, 'scale_pos_weight': 18.032585414009713}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,768] Trial 68 finished with value: 0.0 and parameters: {'num_leaves': 81, 'max_depth': 12, 'learning_rate': 0.02765920962203911, 'n_estimators': 300, 'min_child_samples': 22, 'subsample': 0.6590375142550173, 'colsample_bytree': 0.6768553194483523, 'reg_alpha': 0.5989245877861689, 'reg_lambda': 0.0456087279116427, 'scale_pos_weight': 7.113269629669668}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,849] Trial 69 finished with value: 0.0 and parameters: {'num_leaves': 75, 'max_depth': 15, 'learning_rate': 0.04508897913783728, 'n_estimators': 81, 'min_child_samples': 19, 'subsample': 0.7069897903193029, 'colsample_bytree': 0.7216249819409108, 'reg_alpha': 0.1367099066998907, 'reg_lambda': 0.20756071991726652, 'scale_pos_weight': 8.93459350210306}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:10,940] Trial 70 finished with value: 0.0 and parameters: {'num_leaves': 89, 'max_depth': 9, 'learning_rate': 0.1513222638629288, 'n_estimators': 153, 'min_child_samples': 14, 'subsample': 0.591727370534469, 'colsample_bytree': 0.6331464538182433, 'reg_alpha': 0.5354348086620837, 'reg_lambda': 0.9847579735405627, 'scale_pos_weight': 7.813681374194474}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:11,426] Trial 71 finished with value: 0.0 and parameters: {'num_leaves': 99, 'max_depth': 5, 'learning_rate': 0.010036305139407644, 'n_estimators': 256, 'min_child_samples': 37, 'subsample': 0.8345178170217014, 'colsample_bytree': 0.9247001386902708, 'reg_alpha': 0.09963359330643386, 'reg_lambda': 0.4125683687481292, 'scale_pos_weight': 3.6672317888241035}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:11,550] Trial 72 finished with value: 0.0 and parameters: {'num_leaves': 104, 'max_depth': 6, 'learning_rate': 0.01167881119738003, 'n_estimators': 273, 'min_child_samples': 36, 'subsample': 0.8695256016743248, 'colsample_bytree': 0.9142678703177429, 'reg_alpha': 0.049224505605033275, 'reg_lambda': 0.4620866442751006, 'scale_pos_weight': 1.6783336394601456}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:11,663] Trial 73 finished with value: 0.0 and parameters: {'num_leaves': 122, 'max_depth': 4, 'learning_rate': 0.014684518384447637, 'n_estimators': 283, 'min_child_samples': 43, 'subsample': 0.849983372959537, 'colsample_bytree': 0.8543874944226745, 'reg_alpha': 0.17289986576589964, 'reg_lambda': 0.32655497116351156, 'scale_pos_weight': 11.045720434913706}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:11,762] Trial 74 finished with value: 0.0 and parameters: {'num_leaves': 116, 'max_depth': 10, 'learning_rate': 0.05921354492036958, 'n_estimators': 186, 'min_child_samples': 29, 'subsample': 0.9264174533315551, 'colsample_bytree': 0.8299918944589711, 'reg_alpha': 0.21524629836220263, 'reg_lambda': 0.5002202644954783, 'scale_pos_weight': 4.5562144907062905}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:11,837] Trial 75 finished with value: 0.0 and parameters: {'num_leaves': 93, 'max_depth': 3, 'learning_rate': 0.013246427497175658, 'n_estimators': 107, 'min_child_samples': 41, 'subsample': 0.7650814207784951, 'colsample_bytree': 0.7025576726875306, 'reg_alpha': 0.2748536270168155, 'reg_lambda': 0.5689840811714673, 'scale_pos_weight': 2.2300264945922628}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:11,949] Trial 76 finished with value: 0.0 and parameters: {'num_leaves': 112, 'max_depth': 7, 'learning_rate': 0.011066800954650756, 'n_estimators': 294, 'min_child_samples': 46, 'subsample': 0.8003876288366606, 'colsample_bytree': 0.7716366648127386, 'reg_alpha': 0.13787396901969762, 'reg_lambda': 0.6075359254566933, 'scale_pos_weight': 6.091336027033807}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,058] Trial 77 finished with value: 0.0 and parameters: {'num_leaves': 56, 'max_depth': 5, 'learning_rate': 0.26150811809957103, 'n_estimators': 280, 'min_child_samples': 31, 'subsample': 0.8164114862568372, 'colsample_bytree': 0.5164773371054366, 'reg_alpha': 0.7903110508753951, 'reg_lambda': 0.4006137405759115, 'scale_pos_weight': 5.4039327923776685}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,156] Trial 78 finished with value: 0.0 and parameters: {'num_leaves': 18, 'max_depth': 6, 'learning_rate': 0.18403919394962331, 'n_estimators': 225, 'min_child_samples': 26, 'subsample': 0.902594113316476, 'colsample_bytree': 0.8843544499346638, 'reg_alpha': 0.3746800126299998, 'reg_lambda': 0.2797666618532465, 'scale_pos_weight': 3.0269541946189564}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,291] Trial 79 finished with value: 0.0 and parameters: {'num_leaves': 85, 'max_depth': 15, 'learning_rate': 0.016287624567373187, 'n_estimators': 207, 'min_child_samples': 7, 'subsample': 0.609911048318764, 'colsample_bytree': 0.6023952560642952, 'reg_alpha': 0.47344392288553416, 'reg_lambda': 0.7523934955869798, 'scale_pos_weight': 3.923829468096179}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,392] Trial 80 finished with value: 0.0 and parameters: {'num_leaves': 24, 'max_depth': 5, 'learning_rate': 0.10133682049253467, 'n_estimators': 245, 'min_child_samples': 12, 'subsample': 0.951643790591922, 'colsample_bytree': 0.6500760159676947, 'reg_alpha': 0.5626326661603267, 'reg_lambda': 0.4462506229210011, 'scale_pos_weight': 14.693352366673649}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,466] Trial 81 finished with value: 0.0 and parameters: {'num_leaves': 121, 'max_depth': 11, 'learning_rate': 0.026729690685805406, 'n_estimators': 61, 'min_child_samples': 18, 'subsample': 0.6307124987095372, 'colsample_bytree': 0.8122614929710763, 'reg_alpha': 0.5208147062550009, 'reg_lambda': 0.943395329253638, 'scale_pos_weight': 10.009779536463801}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,554] Trial 82 finished with value: 0.0 and parameters: {'num_leaves': 118, 'max_depth': 13, 'learning_rate': 0.03160338842592516, 'n_estimators': 91, 'min_child_samples': 15, 'subsample': 0.8815946688197376, 'colsample_bytree': 0.8810198916280956, 'reg_alpha': 0.893143136687355, 'reg_lambda': 0.534299577342279, 'scale_pos_weight': 10.062598528007694}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,629] Trial 83 finished with value: 0.0 and parameters: {'num_leaves': 103, 'max_depth': 11, 'learning_rate': 0.02190398549645499, 'n_estimators': 71, 'min_child_samples': 16, 'subsample': 0.562142134300233, 'colsample_bytree': 0.9561663068485768, 'reg_alpha': 0.6516490961302087, 'reg_lambda': 0.64518067522773, 'scale_pos_weight': 12.112515300409873}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,709] Trial 84 finished with value: 0.0 and parameters: {'num_leaves': 126, 'max_depth': 14, 'learning_rate': 0.04347503904435165, 'n_estimators': 83, 'min_child_samples': 20, 'subsample': 0.6236730844178947, 'colsample_bytree': 0.8678119804905647, 'reg_alpha': 0.0009587832449938771, 'reg_lambda': 0.8318478552123724, 'scale_pos_weight': 13.31104208459163}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,795] Trial 85 finished with value: 0.0 and parameters: {'num_leaves': 112, 'max_depth': 12, 'learning_rate': 0.06892677420441795, 'n_estimators': 96, 'min_child_samples': 28, 'subsample': 0.8550906990676761, 'colsample_bytree': 0.571154966640967, 'reg_alpha': 0.8412402198800478, 'reg_lambda': 0.8758868589591218, 'scale_pos_weight': 11.635501517090924}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,903] Trial 86 finished with value: 0.0 and parameters: {'num_leaves': 61, 'max_depth': 14, 'learning_rate': 0.03307067129694599, 'n_estimators': 268, 'min_child_samples': 24, 'subsample': 0.6828986045143759, 'colsample_bytree': 0.8985816004040661, 'reg_alpha': 0.42442095015604864, 'reg_lambda': 0.34827711574119147, 'scale_pos_weight': 8.336722494921009}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:12,998] Trial 87 finished with value: 0.0 and parameters: {'num_leaves': 110, 'max_depth': 10, 'learning_rate': 0.13979559124813462, 'n_estimators': 132, 'min_child_samples': 17, 'subsample': 0.6425198154734315, 'colsample_bytree': 0.5384917274265528, 'reg_alpha': 0.5868866065536631, 'reg_lambda': 0.8828386071552328, 'scale_pos_weight': 6.674401716914345}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:13,145] Trial 88 finished with value: 0.0 and parameters: {'num_leaves': 91, 'max_depth': 13, 'learning_rate': 0.012431790487544798, 'n_estimators': 123, 'min_child_samples': 14, 'subsample': 0.5952919081767137, 'colsample_bytree': 0.7458962242907261, 'reg_alpha': 0.50011694564489, 'reg_lambda': 0.6880871113390686, 'scale_pos_weight': 18.76895925406618}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:13,314] Trial 89 finished with value: 0.0 and parameters: {'num_leaves': 47, 'max_depth': 4, 'learning_rate': 0.02569375137557908, 'n_estimators': 109, 'min_child_samples': 33, 'subsample': 0.5749027623265409, 'colsample_bytree': 0.6614095315200411, 'reg_alpha': 0.03807250127433677, 'reg_lambda': 0.5466750289320149, 'scale_pos_weight': 1.9050095683759116}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:13,591] Trial 90 finished with value: 0.0 and parameters: {'num_leaves': 119, 'max_depth': 15, 'learning_rate': 0.01824234124276692, 'n_estimators': 259, 'min_child_samples': 11, 'subsample': 0.9851753185285479, 'colsample_bytree': 0.618756426575168, 'reg_alpha': 0.8182566636117423, 'reg_lambda': 0.000446262849625588, 'scale_pos_weight': 3.288984466250143}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:13,746] Trial 91 finished with value: 0.0 and parameters: {'num_leaves': 37, 'max_depth': 12, 'learning_rate': 0.12269371908837991, 'n_estimators': 199, 'min_child_samples': 40, 'subsample': 0.6645037308309937, 'colsample_bytree': 0.6969392856088029, 'reg_alpha': 0.33566452623826354, 'reg_lambda': 0.05444421327960787, 'scale_pos_weight': 2.8699160077047585}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:13,878] Trial 92 finished with value: 0.0 and parameters: {'num_leaves': 30, 'max_depth': 13, 'learning_rate': 0.08890630399440758, 'n_estimators': 183, 'min_child_samples': 49, 'subsample': 0.7869827219840289, 'colsample_bytree': 0.5072889290341234, 'reg_alpha': 0.5511002033772532, 'reg_lambda': 0.13889490884870684, 'scale_pos_weight': 1.4416593921698349}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:13,959] Trial 93 finished with value: 0.0 and parameters: {'num_leaves': 35, 'max_depth': 11, 'learning_rate': 0.1137195636837425, 'n_estimators': 52, 'min_child_samples': 44, 'subsample': 0.7289440558445104, 'colsample_bytree': 0.7630037441026564, 'reg_alpha': 0.6149524124180725, 'reg_lambda': 0.08327224389297423, 'scale_pos_weight': 2.1983112080760634}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:14,061] Trial 94 finished with value: 0.0 and parameters: {'num_leaves': 66, 'max_depth': 12, 'learning_rate': 0.19422814071526678, 'n_estimators': 194, 'min_child_samples': 35, 'subsample': 0.6031571355305828, 'colsample_bytree': 0.8159319344201607, 'reg_alpha': 0.4620958840933809, 'reg_lambda': 0.48054075653763423, 'scale_pos_weight': 4.401322848204956}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:14,167] Trial 95 finished with value: 0.0 and parameters: {'num_leaves': 25, 'max_depth': 11, 'learning_rate': 0.13359918301058146, 'n_estimators': 177, 'min_child_samples': 38, 'subsample': 0.5232747019665247, 'colsample_bytree': 0.5553260292881088, 'reg_alpha': 0.07046955489356685, 'reg_lambda': 0.04320762418398115, 'scale_pos_weight': 9.586631979070473}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:14,266] Trial 96 finished with value: 0.0 and parameters: {'num_leaves': 40, 'max_depth': 9, 'learning_rate': 0.15586322554725718, 'n_estimators': 147, 'min_child_samples': 41, 'subsample': 0.7143324580464682, 'colsample_bytree': 0.6761780830253042, 'reg_alpha': 0.7650962646323348, 'reg_lambda': 0.3820623356308145, 'scale_pos_weight': 10.47957113800974}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:14,356] Trial 97 finished with value: 0.0 and parameters: {'num_leaves': 17, 'max_depth': 4, 'learning_rate': 0.011139692266914763, 'n_estimators': 158, 'min_child_samples': 10, 'subsample': 0.829804425005131, 'colsample_bytree': 0.7275432558586211, 'reg_alpha': 0.7271914642273605, 'reg_lambda': 0.5961316814495188, 'scale_pos_weight': 4.96075504961854}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:14,460] Trial 98 finished with value: 0.0 and parameters: {'num_leaves': 73, 'max_depth': 14, 'learning_rate': 0.010024352743078063, 'n_estimators': 165, 'min_child_samples': 26, 'subsample': 0.8969410663483214, 'colsample_bytree': 0.9489040712420866, 'reg_alpha': 0.48919249851844954, 'reg_lambda': 0.027335021882709823, 'scale_pos_weight': 7.473925288575179}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 13:35:14,586] Trial 99 finished with value: 0.0 and parameters: {'num_leaves': 127, 'max_depth': 13, 'learning_rate': 0.2103814394350398, 'n_estimators': 228, 'min_child_samples': 36, 'subsample': 0.5449895326265931, 'colsample_bytree': 0.5803796271409568, 'reg_alpha': 0.6948915256846262, 'reg_lambda': 0.09273033048855113, 'scale_pos_weight': 8.7338819362075}. Best is trial 0 with value: 0.0.

# %%
# best_params_lgbm = grid_lgbm.best_params_

# %%
best_params_lgbm = study_lgbm.best_params

# %%
print(best_params_lgbm)
# Out:
# {'num_leaves': 57, 'max_depth': 15, 'learning_rate': 0.1205712628744377, 'n_estimators': 200, 'min_child_samples': 12, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 14.453378978124864}

# %%
final_classifier = lgb.LGBMClassifier(**best_params_lgbm, random_state=42, verbose=-1)

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# LGBMClassifier(colsample_bytree=0.5290418060840998,
#                learning_rate=0.1205712628744377, max_depth=15,
#                min_child_samples=12, n_estimators=200, num_leaves=57,
#                random_state=42, reg_alpha=0.8661761457749352,
#                reg_lambda=0.6011150117432088,
#                scale_pos_weight=14.453378978124864,
#                subsample=0.5779972601681014, verbose=-1)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[ 49 680]
#  [  4  33]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.10704960835509138

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.04628330995792426

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.8918918918918919

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.1916376306620209
