# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_360\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_360\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### Random Oversampling on Training Data

# %%
resampler = RandomOverSampler()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Gini Importance': importances}).sort_values(
    'Gini Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Gini Importance
# 0                              age         0.223655
# 20                age_ever_married         0.164834
# 5                              bmi         0.096801
# 4                avg_glucose_level         0.095611
# 23                         log_bmi         0.093148
# 24           log_avg_glucose_level         0.091993
# 10   hypertension_or_heart_disease         0.033025
# 3                     ever_married         0.023963
# 7                            urban         0.015788
# 6                             male         0.015056
# 1                     hypertension         0.014000
# 18     smoking_status_never_smoked         0.013399
# 14         work_type_self_employed         0.012925
# 8                            smoke         0.011553
# 13               work_type_private         0.011175
# 22          high_avg_glucose_level         0.010823
# 19           smoking_status_smokes         0.010801
# 2                    heart_disease         0.010005
# 21                           obese         0.009651
# 16          smoking_status_unknown         0.009117
# 11              work_type_govt_job         0.008844
# 17  smoking_status_formerly_smoked         0.008628
# 9                        have_work         0.007930
# 15              work_type_children         0.007265
# 12          work_type_never_worked         0.000010

# %% [markdown]
# ### Feature selection

# %%
retained_columns = ['age', 'log_bmi', 'avg_glucose_level', 'hypertension_or_heart_disease', 'male', 'urban', 'work_type_self_employed', 'smoking_status_never_smoked', 'work_type_private', 'smoking_status_smokes']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create grid for hyperparameter tuning using GridSearchCV

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'class_weight': ['balanced', 'balanced_subsample']
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_rf = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_rf,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.15

# %%
def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample']),
        'random_state': 42
    }
    
    model = RandomForestClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    f2_score = fbeta_score(y_val, y_pred_val, beta=2)
    
    if precision < MIN_PRECISION:
        return 0
    return recall + (precision * 0.01)
    # return f2_score

# %% [markdown]
# ### Hyperparameter tuning

# %%
# grid_rf.fit(X_train_res_retained, y_train_res)

# %%
study_rf = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_rf.optimize(objective_rf, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 17:34:27,307] A new study created in memory with name: no-name-0c5b1dee-4b35-4b68-aed7-ab11e62017bc
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 17:34:28,272] Trial 0 finished with value: 0.29913063063063067 and parameters: {'n_estimators': 144, 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.29913063063063067.
# [I 2026-01-19 17:34:29,336] Trial 1 finished with value: 0.0 and parameters: {'n_estimators': 227, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.29913063063063067.
# [I 2026-01-19 17:34:30,804] Trial 2 finished with value: 0.6503877790834313 and parameters: {'n_estimators': 158, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.6503877790834313.
# [I 2026-01-19 17:34:32,888] Trial 3 finished with value: 0.4346546546546547 and parameters: {'n_estimators': 179, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.6503877790834313.
# [I 2026-01-19 17:34:33,469] Trial 4 finished with value: 0.0 and parameters: {'n_estimators': 126, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 2 with value: 0.6503877790834313.
# [I 2026-01-19 17:34:34,545] Trial 5 finished with value: 0.7044958061509786 and parameters: {'n_estimators': 216, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:38,137] Trial 6 finished with value: 0.16403716216216216 and parameters: {'n_estimators': 200, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:39,972] Trial 7 finished with value: 0.6774742368267548 and parameters: {'n_estimators': 139, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:40,406] Trial 8 finished with value: 0.461483268983269 and parameters: {'n_estimators': 51, 'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:41,594] Trial 9 finished with value: 0.6232644787644788 and parameters: {'n_estimators': 206, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:44,351] Trial 10 finished with value: 0.569801610120759 and parameters: {'n_estimators': 291, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:45,071] Trial 11 finished with value: 0.6233253253253253 and parameters: {'n_estimators': 94, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:48,526] Trial 12 finished with value: 0.5153404365904366 and parameters: {'n_estimators': 254, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:49,612] Trial 13 finished with value: 0.0 and parameters: {'n_estimators': 106, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:51,446] Trial 14 finished with value: 0.4073790896159317 and parameters: {'n_estimators': 258, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:53,383] Trial 15 finished with value: 0.0 and parameters: {'n_estimators': 175, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:54,288] Trial 16 finished with value: 0.43443243243243246 and parameters: {'n_estimators': 78, 'max_depth': 16, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:34:57,009] Trial 17 finished with value: 0.0 and parameters: {'n_estimators': 239, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:00,095] Trial 18 finished with value: 0.4071911196911197 and parameters: {'n_estimators': 285, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:01,081] Trial 19 finished with value: 0.4074601999259534 and parameters: {'n_estimators': 130, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:03,831] Trial 20 finished with value: 0.6505534105534105 and parameters: {'n_estimators': 206, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:07,701] Trial 21 finished with value: 0.6505534105534105 and parameters: {'n_estimators': 211, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:10,558] Trial 22 finished with value: 0.0 and parameters: {'n_estimators': 175, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:14,180] Trial 23 finished with value: 0.6772782397782398 and parameters: {'n_estimators': 186, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:17,616] Trial 24 finished with value: 0.6772579541566883 and parameters: {'n_estimators': 156, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:19,765] Trial 25 finished with value: 0.0 and parameters: {'n_estimators': 227, 'max_depth': 3, 'min_samples_split': 17, 'min_samples_leaf': 1, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:24,980] Trial 26 finished with value: 0.4077130977130977 and parameters: {'n_estimators': 185, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:26,328] Trial 27 finished with value: 0.0 and parameters: {'n_estimators': 122, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:27,297] Trial 28 finished with value: 0.32611536910044375 and parameters: {'n_estimators': 153, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 5 with value: 0.7044958061509786.
# [I 2026-01-19 17:35:28,221] Trial 29 finished with value: 0.7582702702702703 and parameters: {'n_estimators': 140, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 29 with value: 0.7582702702702703.
# [I 2026-01-19 17:35:29,100] Trial 30 finished with value: 0.6775987525987526 and parameters: {'n_estimators': 143, 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 29 with value: 0.7582702702702703.
# [I 2026-01-19 17:35:30,133] Trial 31 finished with value: 0.6235543947308653 and parameters: {'n_estimators': 144, 'max_depth': 9, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 29 with value: 0.7582702702702703.
# [I 2026-01-19 17:35:31,356] Trial 32 finished with value: 0.0 and parameters: {'n_estimators': 141, 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 29 with value: 0.7582702702702703.
# [I 2026-01-19 17:35:32,111] Trial 33 finished with value: 0.6505534105534105 and parameters: {'n_estimators': 106, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 29 with value: 0.7582702702702703.
# [I 2026-01-19 17:35:33,490] Trial 34 finished with value: 0.7586110613925184 and parameters: {'n_estimators': 162, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 34 with value: 0.7586110613925184.
# [I 2026-01-19 17:35:34,531] Trial 35 finished with value: 0.0 and parameters: {'n_estimators': 164, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 34 with value: 0.7586110613925184.
# [I 2026-01-19 17:35:36,322] Trial 36 finished with value: 0.5696887796887796 and parameters: {'n_estimators': 115, 'max_depth': 12, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 34 with value: 0.7586110613925184.
# [I 2026-01-19 17:35:38,069] Trial 37 finished with value: 0.7586234234234235 and parameters: {'n_estimators': 166, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:39,822] Trial 38 finished with value: 0.0 and parameters: {'n_estimators': 193, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:42,713] Trial 39 finished with value: 0.7582784958871915 and parameters: {'n_estimators': 223, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:44,359] Trial 40 finished with value: 0.0 and parameters: {'n_estimators': 166, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:46,494] Trial 41 finished with value: 0.7315178091999284 and parameters: {'n_estimators': 227, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:48,325] Trial 42 finished with value: 0.0 and parameters: {'n_estimators': 223, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 10, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:50,261] Trial 43 finished with value: 0.0 and parameters: {'n_estimators': 248, 'max_depth': 4, 'min_samples_split': 16, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:52,806] Trial 44 finished with value: 0.7314067483632701 and parameters: {'n_estimators': 272, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:54,711] Trial 45 finished with value: 0.7582702702702703 and parameters: {'n_estimators': 191, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:56,428] Trial 46 finished with value: 0.5426458036984353 and parameters: {'n_estimators': 197, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:57,415] Trial 47 finished with value: 0.0 and parameters: {'n_estimators': 164, 'max_depth': 3, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:58,911] Trial 48 finished with value: 0.7582952182952183 and parameters: {'n_estimators': 181, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:35:59,899] Trial 49 finished with value: 0.0 and parameters: {'n_estimators': 129, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:01,394] Trial 50 finished with value: 0.6778308480894688 and parameters: {'n_estimators': 176, 'max_depth': 10, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:03,623] Trial 51 finished with value: 0.7582784958871915 and parameters: {'n_estimators': 193, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:05,609] Trial 52 finished with value: 0.7314716652136006 and parameters: {'n_estimators': 152, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:08,621] Trial 53 finished with value: 0.0 and parameters: {'n_estimators': 217, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:10,669] Trial 54 finished with value: 0.758329790464622 and parameters: {'n_estimators': 170, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:13,435] Trial 55 finished with value: 0.0 and parameters: {'n_estimators': 204, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:17,135] Trial 56 finished with value: 0.704573206299825 and parameters: {'n_estimators': 238, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:19,261] Trial 57 finished with value: 0.0 and parameters: {'n_estimators': 165, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:21,289] Trial 58 finished with value: 0.6232528272953805 and parameters: {'n_estimators': 181, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:24,815] Trial 59 finished with value: 0.4887649674991447 and parameters: {'n_estimators': 198, 'max_depth': 15, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:27,117] Trial 60 finished with value: 0.0 and parameters: {'n_estimators': 173, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:28,480] Trial 61 finished with value: 0.0 and parameters: {'n_estimators': 152, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:29,871] Trial 62 finished with value: 0.7582868114015655 and parameters: {'n_estimators': 187, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:31,667] Trial 63 finished with value: 0.6235382882882883 and parameters: {'n_estimators': 186, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:33,543] Trial 64 finished with value: 0.7315178091999284 and parameters: {'n_estimators': 206, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:35,094] Trial 65 finished with value: 0.0 and parameters: {'n_estimators': 211, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:36,523] Trial 66 finished with value: 0.7582868114015655 and parameters: {'n_estimators': 173, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:37,632] Trial 67 finished with value: 0.0 and parameters: {'n_estimators': 171, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:39,125] Trial 68 finished with value: 0.40732848232848234 and parameters: {'n_estimators': 181, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:41,385] Trial 69 finished with value: 0.4070907986638324 and parameters: {'n_estimators': 160, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:42,491] Trial 70 finished with value: 0.6504531599268442 and parameters: {'n_estimators': 147, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:45,226] Trial 71 finished with value: 0.7582784958871915 and parameters: {'n_estimators': 192, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:47,814] Trial 72 finished with value: 0.7582868114015655 and parameters: {'n_estimators': 168, 'max_depth': 7, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:49,576] Trial 73 finished with value: 0.7315060455192034 and parameters: {'n_estimators': 170, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:51,644] Trial 74 finished with value: 0.6773648648648648 and parameters: {'n_estimators': 178, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:52,986] Trial 75 finished with value: 0.0 and parameters: {'n_estimators': 136, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:54,442] Trial 76 finished with value: 0.0 and parameters: {'n_estimators': 158, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:55,127] Trial 77 finished with value: 0.35329164985881406 and parameters: {'n_estimators': 53, 'max_depth': 18, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:56,615] Trial 78 finished with value: 0.0 and parameters: {'n_estimators': 184, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:36:59,062] Trial 79 finished with value: 0.6506486486486487 and parameters: {'n_estimators': 150, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:00,136] Trial 80 finished with value: 0.7583037180827237 and parameters: {'n_estimators': 135, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:01,160] Trial 81 finished with value: 0.7583037180827237 and parameters: {'n_estimators': 136, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:02,213] Trial 82 finished with value: 0.7044714101856959 and parameters: {'n_estimators': 132, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:03,105] Trial 83 finished with value: 0.7583386776607116 and parameters: {'n_estimators': 120, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:04,058] Trial 84 finished with value: 0.0 and parameters: {'n_estimators': 105, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:05,146] Trial 85 finished with value: 0.677353528024669 and parameters: {'n_estimators': 120, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:06,180] Trial 86 finished with value: 0.0 and parameters: {'n_estimators': 92, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:07,488] Trial 87 finished with value: 0.0 and parameters: {'n_estimators': 121, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 37 with value: 0.7586234234234235.
# [I 2026-01-19 17:37:09,025] Trial 88 finished with value: 0.7853021083911136 and parameters: {'n_estimators': 114, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:10,441] Trial 89 finished with value: 0.7046286286286286 and parameters: {'n_estimators': 110, 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:13,996] Trial 90 finished with value: 0.5965588803088804 and parameters: {'n_estimators': 135, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:14,979] Trial 91 finished with value: 0.0 and parameters: {'n_estimators': 99, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:16,008] Trial 92 finished with value: 0.0 and parameters: {'n_estimators': 159, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:16,608] Trial 93 finished with value: 0.6502172760996291 and parameters: {'n_estimators': 83, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:17,684] Trial 94 finished with value: 0.0 and parameters: {'n_estimators': 143, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:18,507] Trial 95 finished with value: 0.0 and parameters: {'n_estimators': 115, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:19,555] Trial 96 finished with value: 0.6773423423423424 and parameters: {'n_estimators': 125, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:20,445] Trial 97 finished with value: 0.0 and parameters: {'n_estimators': 126, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:21,487] Trial 98 finished with value: 0.7852942004504504 and parameters: {'n_estimators': 139, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.
# [I 2026-01-19 17:37:22,538] Trial 99 finished with value: 0.0 and parameters: {'n_estimators': 139, 'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 88 with value: 0.7853021083911136.

# %%
# best_params_rf = grid_rf.best_params_

# %%
best_params_rf = study_rf.best_params

# %%
print(best_params_rf)
# Out:
# {'n_estimators': 114, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced'}

# %%
final_classifier = RandomForestClassifier(**best_params_rf, random_state=42)

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=7,
#                        max_features='log2', min_samples_leaf=9,
#                        min_samples_split=18, n_estimators=114, random_state=42)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[567 162]
#  [  8  29]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.7780678851174935

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.1518324607329843

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.7837837837837838

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.4277286135693215

# %% [markdown]
# ### Threshold tuning

# %%
best_threshold = 0.5

# %%
best_precision_score = 0

# %%
best_recall_score = 0

# %%
best_f2_score = 0

# %%
for threshold in np.arange(0.1, 0.9, 0.05):
    y_pred_val_threshold = (y_proba_val >= threshold).astype(int)
    recall = recall_score(y_val, y_pred_val_threshold)
    precision = precision_score(y_val, y_pred_val_threshold)
    f2_score = fbeta_score(y_val, y_pred_val_threshold, beta=2)
    
    print(f'Threshold {threshold} has F2 score {f2_score}')
    
    if precision >= 0.15:
        current_recall_score = recall
        if current_recall_score > best_recall_score:
            best_recall_score = current_recall_score
            best_precision_score = precision
            best_threshold = threshold
        elif current_recall_score == best_recall_score and precision > best_precision_score:
            best_precision_score = precision
            best_threshold = threshold
        
        # current_f2_score = f2_score
        # if current_f2_score > best_f2_score:
        #     best_f2_score = current_f2_score
        #     best_threshold = threshold
# Out:
# Threshold 0.1 has F2 score 0.3159851301115242
# Threshold 0.15000000000000002 has F2 score 0.3273809523809524
# Threshold 0.20000000000000004 has F2 score 0.34232365145228216
# Threshold 0.25000000000000006 has F2 score 0.3525641025641026
# Threshold 0.30000000000000004 has F2 score 0.3579175704989154
# Threshold 0.3500000000000001 has F2 score 0.367816091954023
# Threshold 0.40000000000000013 has F2 score 0.3762135922330097
# Threshold 0.45000000000000007 has F2 score 0.38461538461538464
# Threshold 0.5000000000000001 has F2 score 0.4277286135693215
# Threshold 0.5500000000000002 has F2 score 0.436241610738255
# Threshold 0.6000000000000002 has F2 score 0.4372623574144487
# Threshold 0.6500000000000001 has F2 score 0.37280701754385964
# Threshold 0.7000000000000002 has F2 score 0.275
# Threshold 0.7500000000000002 has F2 score 0.25
# Threshold 0.8000000000000002 has F2 score 0.09375
# Threshold 0.8500000000000002 has F2 score 0.03289473684210526

# %%
print(best_threshold)
# Out:
# 0.5000000000000001

# %%
print(best_recall_score)
# Out:
# 0.7837837837837838

# %% [markdown]
# ### Retrain on training + validation set

# %%
X_train_full = pd.concat([X_train_res_retained, X_val_retained], axis=0, ignore_index=True)
y_train_full = pd.concat([y_train_res, y_val], axis=0, ignore_index=True)

# %%
final_classifier.fit(X_train_full, y_train_full)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=7,
#                        max_features='log2', min_samples_leaf=9,
#                        min_samples_split=18, n_estimators=114, random_state=42)

# %% [markdown]
# ### Evaluate on test set

# %%
X_test_retained = X_test[retained_columns]

# %%
y_pred_test = final_classifier.predict(X_test_retained)

# %%
y_proba_test = final_classifier.predict_proba(X_test_retained)[:, 1]

# %%
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[557 172]
#  [ 10  28]]

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.7627118644067796

# %%
print(precision_score(y_test, y_pred_test))
# Out:
# 0.14

# %%
print(recall_score(y_test, y_pred_test))
# Out:
# 0.7368421052631579

# %%
print(fbeta_score(y_test, y_pred_test, beta=2))
# Out:
# 0.3977272727272727
