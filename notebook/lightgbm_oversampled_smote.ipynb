# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11448\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11448\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### SMOTE Oversampling on Training Data

# %%
resampler = SMOTE()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = lgb.LGBMClassifier(random_state=42, verbose=-1)

# %% [markdown]
# ### Create grid for hyperparameter tuning

# %%
param_grid_lgbm = {
    'num_leaves': [15, 31, 63, 127],
    'max_depth': [3, 5, 7, 10, -1], 
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 300],
    'min_child_samples': [5, 10, 20, 30],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha': [0, 0.1, 0.5, 1], 
    'reg_lambda': [0, 0.1, 0.5, 1],  
    'scale_pos_weight': [1, 3, 5, 10, 15, 20]  
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_lgbm = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_lgbm,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# LGBMClassifier(random_state=42, verbose=-1)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Importance': importances}).sort_values(
    'Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Importance
# 4                avg_glucose_level         647
# 0                              age         511
# 5                              bmi         429
# 20                age_ever_married         246
# 24           log_avg_glucose_level         128
# 23                         log_bmi         123
# 18     smoking_status_never_smoked         106
# 16          smoking_status_unknown          95
# 14         work_type_self_employed          82
# 13               work_type_private          76
# 17  smoking_status_formerly_smoked          68
# 6                             male          67
# 7                            urban          62
# 19           smoking_status_smokes          62
# 11              work_type_govt_job          62
# 8                            smoke          59
# 21                           obese          50
# 10   hypertension_or_heart_disease          31
# 1                     hypertension          30
# 2                    heart_disease          21
# 3                     ever_married          18
# 9                        have_work          16
# 15              work_type_children          11
# 22          high_avg_glucose_level           0
# 12          work_type_never_worked           0

# %%
retained_columns = ['avg_glucose_level', 'age', 'bmi', 'smoking_status_never_smoked', 'smoking_status_unknown', 'work_type_self_employed', 'work_type_private', 'smoking_status_formerly_smoked', 'male', 'urban']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %%
MIN_PRECISION = 0.15

# %%
def objective_lgbm(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 15, 127),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 50),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 20),
        'random_state': 42,
        'verbose': -1
    }
    
    model = lgb.LGBMClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    
    if precision < MIN_PRECISION:
        return 0
    return recall + (precision * 0.01)

# %%
# grid_lgbm.fit(X_train_res_retained, y_train_res)

# %%
study_lgbm = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_lgbm.optimize(objective_lgbm, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 14:15:28,157] A new study created in memory with name: no-name-6fd0a234-f64c-49f3-b6b4-0b53a4261442
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 14:15:28,644] Trial 0 finished with value: 0.0 and parameters: {'num_leaves': 57, 'max_depth': 15, 'learning_rate': 0.1205712628744377, 'n_estimators': 200, 'min_child_samples': 12, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 14.453378978124864}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:28,759] Trial 1 finished with value: 0.0 and parameters: {'num_leaves': 17, 'max_depth': 15, 'learning_rate': 0.16967533607196555, 'n_estimators': 103, 'min_child_samples': 13, 'subsample': 0.5917022549267169, 'colsample_bytree': 0.6521211214797689, 'reg_alpha': 0.5247564316322378, 'reg_lambda': 0.43194501864211576, 'scale_pos_weight': 6.533353663762797}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:28,904] Trial 2 finished with value: 0.0 and parameters: {'num_leaves': 84, 'max_depth': 4, 'learning_rate': 0.027010527749605478, 'n_estimators': 141, 'min_child_samples': 25, 'subsample': 0.8925879806965068, 'colsample_bytree': 0.5998368910791798, 'reg_alpha': 0.5142344384136116, 'reg_lambda': 0.5924145688620425, 'scale_pos_weight': 1.8825578416799567}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:29,245] Trial 3 finished with value: 0.0 and parameters: {'num_leaves': 83, 'max_depth': 5, 'learning_rate': 0.012476394272569451, 'n_estimators': 288, 'min_child_samples': 49, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'reg_alpha': 0.09767211400638387, 'reg_lambda': 0.6842330265121569, 'scale_pos_weight': 9.362897381052425}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:29,677] Trial 4 finished with value: 0.0 and parameters: {'num_leaves': 28, 'max_depth': 9, 'learning_rate': 0.011240768803005551, 'n_estimators': 278, 'min_child_samples': 16, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796, 'scale_pos_weight': 4.512234654985013}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:30,266] Trial 5 finished with value: 0.0 and parameters: {'num_leaves': 124, 'max_depth': 13, 'learning_rate': 0.24420460844911424, 'n_estimators': 274, 'min_child_samples': 32, 'subsample': 0.9609371175115584, 'colsample_bytree': 0.5442462510259598, 'reg_alpha': 0.1959828624191452, 'reg_lambda': 0.045227288910538066, 'scale_pos_weight': 7.181276284502022}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:30,455] Trial 6 finished with value: 0.0 and parameters: {'num_leaves': 58, 'max_depth': 6, 'learning_rate': 0.16755052359850303, 'n_estimators': 139, 'min_child_samples': 17, 'subsample': 0.7713480415791243, 'colsample_bytree': 0.5704621124873813, 'reg_alpha': 0.8021969807540397, 'reg_lambda': 0.07455064367977082, 'scale_pos_weight': 19.75085179540983}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:30,771] Trial 7 finished with value: 0.0 and parameters: {'num_leaves': 102, 'max_depth': 5, 'learning_rate': 0.010189592979395137, 'n_estimators': 254, 'min_child_samples': 37, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'reg_alpha': 0.07404465173409036, 'reg_lambda': 0.3584657285442726, 'scale_pos_weight': 3.2015121309774646}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:30,993] Trial 8 finished with value: 0.0 and parameters: {'num_leaves': 112, 'max_depth': 11, 'learning_rate': 0.030816017044468066, 'n_estimators': 65, 'min_child_samples': 19, 'subsample': 0.6625916610133735, 'colsample_bytree': 0.864803089169032, 'reg_alpha': 0.6375574713552131, 'reg_lambda': 0.8872127425763265, 'scale_pos_weight': 9.972083578077036}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:31,385] Trial 9 finished with value: 0.0 and parameters: {'num_leaves': 28, 'max_depth': 12, 'learning_rate': 0.13297554090738672, 'n_estimators': 190, 'min_child_samples': 40, 'subsample': 0.7468977981821954, 'colsample_bytree': 0.7613664146909971, 'reg_alpha': 0.42754101835854963, 'reg_lambda': 0.02541912674409519, 'scale_pos_weight': 3.049937112872785}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:32,063] Trial 10 finished with value: 0.0 and parameters: {'num_leaves': 57, 'max_depth': 15, 'learning_rate': 0.0749883856323417, 'n_estimators': 214, 'min_child_samples': 5, 'subsample': 0.5193625999805915, 'colsample_bytree': 0.97988537297271, 'reg_alpha': 0.9761398998579952, 'reg_lambda': 0.9469618763901493, 'scale_pos_weight': 15.029705349775393}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:32,190] Trial 11 finished with value: 0.0 and parameters: {'num_leaves': 16, 'max_depth': 15, 'learning_rate': 0.08486603434290381, 'n_estimators': 64, 'min_child_samples': 6, 'subsample': 0.5472666635128242, 'colsample_bytree': 0.5034392951693698, 'reg_alpha': 0.9940403736301033, 'reg_lambda': 0.31464503711868463, 'scale_pos_weight': 14.76054734445038}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:32,589] Trial 12 finished with value: 0.0 and parameters: {'num_leaves': 48, 'max_depth': 9, 'learning_rate': 0.2947927028325085, 'n_estimators': 118, 'min_child_samples': 12, 'subsample': 0.609303657185796, 'colsample_bytree': 0.730179771771769, 'reg_alpha': 0.742347534737023, 'reg_lambda': 0.3568935701127543, 'scale_pos_weight': 13.817629527305492}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:33,066] Trial 13 finished with value: 0.0 and parameters: {'num_leaves': 37, 'max_depth': 14, 'learning_rate': 0.12626689958632767, 'n_estimators': 221, 'min_child_samples': 24, 'subsample': 0.6511020710303068, 'colsample_bytree': 0.6654564209034075, 'reg_alpha': 0.33171814206359374, 'reg_lambda': 0.7583635489314875, 'scale_pos_weight': 17.970040157414644}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:33,399] Trial 14 finished with value: 0.0 and parameters: {'num_leaves': 72, 'max_depth': 11, 'learning_rate': 0.04779944309421829, 'n_estimators': 92, 'min_child_samples': 10, 'subsample': 0.5785932138359383, 'colsample_bytree': 0.5065672694180388, 'reg_alpha': 0.7946453641120889, 'reg_lambda': 0.43200028731684337, 'scale_pos_weight': 6.521846951644682}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:34,475] Trial 15 finished with value: 0.0 and parameters: {'num_leaves': 45, 'max_depth': 13, 'learning_rate': 0.1906306420081584, 'n_estimators': 175, 'min_child_samples': 21, 'subsample': 0.6966713259977332, 'colsample_bytree': 0.7423578866620044, 'reg_alpha': 0.6732717907646599, 'reg_lambda': 0.2550570692138962, 'scale_pos_weight': 11.962034303903877}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:34,695] Trial 16 finished with value: 0.0 and parameters: {'num_leaves': 15, 'max_depth': 7, 'learning_rate': 0.09650592102088115, 'n_estimators': 157, 'min_child_samples': 30, 'subsample': 0.511847705752916, 'colsample_bytree': 0.6008964335081206, 'reg_alpha': 0.389664524207145, 'reg_lambda': 0.7163755998306335, 'scale_pos_weight': 7.086454969900423}. Best is trial 0 with value: 0.0.
# [I 2026-01-19 14:15:35,104] Trial 17 finished with value: 0.6772579541566883 and parameters: {'num_leaves': 67, 'max_depth': 15, 'learning_rate': 0.046419036087664504, 'n_estimators': 114, 'min_child_samples': 13, 'subsample': 0.6123467940735869, 'colsample_bytree': 0.6879515056982495, 'reg_alpha': 0.8956049237047359, 'reg_lambda': 0.17747344841110274, 'scale_pos_weight': 12.23175086121507}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:36,067] Trial 18 finished with value: 0.0 and parameters: {'num_leaves': 70, 'max_depth': 11, 'learning_rate': 0.05195548649433324, 'n_estimators': 233, 'min_child_samples': 10, 'subsample': 0.715002977615156, 'colsample_bytree': 0.8510830797595692, 'reg_alpha': 0.868157974245565, 'reg_lambda': 0.1695815293877519, 'scale_pos_weight': 16.46428386988243}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:37,905] Trial 19 finished with value: 0.0 and parameters: {'num_leaves': 87, 'max_depth': 13, 'learning_rate': 0.026090404146842425, 'n_estimators': 191, 'min_child_samples': 21, 'subsample': 0.6392777710709958, 'colsample_bytree': 0.7868522161209082, 'reg_alpha': 0.9039561993330525, 'reg_lambda': 0.20927693584464424, 'scale_pos_weight': 11.902893464485542}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:38,216] Trial 20 finished with value: 0.0 and parameters: {'num_leaves': 68, 'max_depth': 8, 'learning_rate': 0.03585989617141364, 'n_estimators': 123, 'min_child_samples': 14, 'subsample': 0.5590721088257601, 'colsample_bytree': 0.7008393079205733, 'reg_alpha': 0.6247298758429561, 'reg_lambda': 0.6040542034314511, 'scale_pos_weight': 12.538631984113113}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:38,483] Trial 21 finished with value: 0.5961014439096631 and parameters: {'num_leaves': 58, 'max_depth': 15, 'learning_rate': 0.06512640452583675, 'n_estimators': 100, 'min_child_samples': 9, 'subsample': 0.5829713263888421, 'colsample_bytree': 0.6258091008759973, 'reg_alpha': 0.8930736509153779, 'reg_lambda': 0.46463750132739706, 'scale_pos_weight': 8.806084160054294}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:38,715] Trial 22 finished with value: 0.0 and parameters: {'num_leaves': 59, 'max_depth': 14, 'learning_rate': 0.06568303979233274, 'n_estimators': 87, 'min_child_samples': 8, 'subsample': 0.6217550058005971, 'colsample_bytree': 0.5988220790623976, 'reg_alpha': 0.8682706614086091, 'reg_lambda': 0.48001145451991417, 'scale_pos_weight': 8.494545520540367}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:39,083] Trial 23 finished with value: 0.0 and parameters: {'num_leaves': 49, 'max_depth': 14, 'learning_rate': 0.017947587419652782, 'n_estimators': 168, 'min_child_samples': 9, 'subsample': 0.6823870052518723, 'colsample_bytree': 0.5628983016769756, 'reg_alpha': 0.7242550314821125, 'reg_lambda': 0.7997784052270356, 'scale_pos_weight': 10.948730063430839}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:39,293] Trial 24 finished with value: 0.0 and parameters: {'num_leaves': 76, 'max_depth': 15, 'learning_rate': 0.04166199718960281, 'n_estimators': 50, 'min_child_samples': 5, 'subsample': 0.5001310561523566, 'colsample_bytree': 0.69375859887217, 'reg_alpha': 0.9333353604838937, 'reg_lambda': 0.13322821489567543, 'scale_pos_weight': 17.17782241742378}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:39,754] Trial 25 finished with value: 0.0 and parameters: {'num_leaves': 95, 'max_depth': 12, 'learning_rate': 0.11491183414999911, 'n_estimators': 146, 'min_child_samples': 15, 'subsample': 0.5466043308268627, 'colsample_bytree': 0.8041859363210639, 'reg_alpha': 0.805924636819424, 'reg_lambda': 0.6497956707597883, 'scale_pos_weight': 13.49486115651427}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:40,037] Trial 26 finished with value: 0.0 and parameters: {'num_leaves': 63, 'max_depth': 14, 'learning_rate': 0.05754764182865805, 'n_estimators': 115, 'min_child_samples': 19, 'subsample': 0.5872322005228996, 'colsample_bytree': 0.6145773566887293, 'reg_alpha': 0.8662782598914353, 'reg_lambda': 0.4996337325817175, 'scale_pos_weight': 15.594649700627457}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:40,391] Trial 27 finished with value: 0.0 and parameters: {'num_leaves': 39, 'max_depth': 12, 'learning_rate': 0.06763899672384734, 'n_estimators': 195, 'min_child_samples': 12, 'subsample': 0.7803382520025416, 'colsample_bytree': 0.5344614469116451, 'reg_alpha': 0.7270572122447523, 'reg_lambda': 0.8398384561816132, 'scale_pos_weight': 8.718390501118865}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:40,689] Trial 28 finished with value: 0.4879990915285033 and parameters: {'num_leaves': 77, 'max_depth': 13, 'learning_rate': 0.09697282294561632, 'n_estimators': 85, 'min_child_samples': 23, 'subsample': 0.6204125518626495, 'colsample_bytree': 0.7054982204000595, 'reg_alpha': 0.6042048127665711, 'reg_lambda': 0.27792998872049535, 'scale_pos_weight': 11.006546173852353}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:40,940] Trial 29 finished with value: 0.0 and parameters: {'num_leaves': 77, 'max_depth': 13, 'learning_rate': 0.020241592544518253, 'n_estimators': 78, 'min_child_samples': 27, 'subsample': 0.7307498610037165, 'colsample_bytree': 0.6918729946325445, 'reg_alpha': 0.2982451893646034, 'reg_lambda': 0.2713188940296675, 'scale_pos_weight': 10.95851128565026}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:41,233] Trial 30 finished with value: 0.0 and parameters: {'num_leaves': 92, 'max_depth': 10, 'learning_rate': 0.09424325632153585, 'n_estimators': 104, 'min_child_samples': 34, 'subsample': 0.6202452057773575, 'colsample_bytree': 0.8186566781726684, 'reg_alpha': 0.5993402374253344, 'reg_lambda': 0.1848709295698036, 'scale_pos_weight': 5.108534032325438}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:41,629] Trial 31 finished with value: 0.0 and parameters: {'num_leaves': 65, 'max_depth': 15, 'learning_rate': 0.09824954064421633, 'n_estimators': 100, 'min_child_samples': 14, 'subsample': 0.5786291195163276, 'colsample_bytree': 0.6225658394072078, 'reg_alpha': 0.9486975276773032, 'reg_lambda': 0.40587293641005234, 'scale_pos_weight': 13.301939707727737}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:42,145] Trial 32 finished with value: 0.0 and parameters: {'num_leaves': 54, 'max_depth': 15, 'learning_rate': 0.15876076913166345, 'n_estimators': 129, 'min_child_samples': 23, 'subsample': 0.6761560700881108, 'colsample_bytree': 0.7152899087858715, 'reg_alpha': 0.8218730645508355, 'reg_lambda': 0.11536675819631585, 'scale_pos_weight': 10.328564031167032}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:42,470] Trial 33 finished with value: 0.0 and parameters: {'num_leaves': 78, 'max_depth': 14, 'learning_rate': 0.04438720691285532, 'n_estimators': 67, 'min_child_samples': 18, 'subsample': 0.610689737496508, 'colsample_bytree': 0.6325761640656253, 'reg_alpha': 0.7498158893605538, 'reg_lambda': 0.5556126488034842, 'scale_pos_weight': 8.025417747083647}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:43,031] Trial 34 finished with value: 0.0 and parameters: {'num_leaves': 83, 'max_depth': 15, 'learning_rate': 0.07805139568901398, 'n_estimators': 105, 'min_child_samples': 12, 'subsample': 0.5392190775635367, 'colsample_bytree': 0.6692409967634324, 'reg_alpha': 0.0013598054318320063, 'reg_lambda': 0.4363285849175415, 'scale_pos_weight': 11.409725673773758}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:43,942] Trial 35 finished with value: 0.0 and parameters: {'num_leaves': 63, 'max_depth': 14, 'learning_rate': 0.059663456560834494, 'n_estimators': 84, 'min_child_samples': 46, 'subsample': 0.5740678690965678, 'colsample_bytree': 0.5726692848592032, 'reg_alpha': 0.49543180338508347, 'reg_lambda': 0.24255537320093026, 'scale_pos_weight': 9.779289174158446}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:44,440] Trial 36 finished with value: 0.0 and parameters: {'num_leaves': 54, 'max_depth': 13, 'learning_rate': 0.20584037287704138, 'n_estimators': 139, 'min_child_samples': 27, 'subsample': 0.6529948175638667, 'colsample_bytree': 0.6483049994792649, 'reg_alpha': 0.5688176998681455, 'reg_lambda': 0.6303687892655571, 'scale_pos_weight': 12.608561927718377}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:44,652] Trial 37 finished with value: 0.0 and parameters: {'num_leaves': 31, 'max_depth': 15, 'learning_rate': 0.13625844859035793, 'n_estimators': 50, 'min_child_samples': 8, 'subsample': 0.6049853422805369, 'colsample_bytree': 0.7736571427460628, 'reg_alpha': 0.6751376841209983, 'reg_lambda': 0.33644244669160905, 'scale_pos_weight': 18.68042289493841}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:45,024] Trial 38 finished with value: 0.0 and parameters: {'num_leaves': 102, 'max_depth': 3, 'learning_rate': 0.035760027900887524, 'n_estimators': 250, 'min_child_samples': 16, 'subsample': 0.971689757492779, 'colsample_bytree': 0.5377495981697534, 'reg_alpha': 0.8673236589170898, 'reg_lambda': 0.5470072541947382, 'scale_pos_weight': 14.247323565432723}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:45,806] Trial 39 finished with value: 0.0 and parameters: {'num_leaves': 41, 'max_depth': 12, 'learning_rate': 0.11198507671361098, 'n_estimators': 294, 'min_child_samples': 21, 'subsample': 0.7812239493269991, 'colsample_bytree': 0.6755095273383979, 'reg_alpha': 0.9177740245667338, 'reg_lambda': 0.11301875449996955, 'scale_pos_weight': 1.1763803780717517}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:46,836] Trial 40 finished with value: 0.2717854217854218 and parameters: {'num_leaves': 73, 'max_depth': 13, 'learning_rate': 0.15241647465283037, 'n_estimators': 168, 'min_child_samples': 17, 'subsample': 0.9327720995860396, 'colsample_bytree': 0.5842068913620494, 'reg_alpha': 0.46037547718100125, 'reg_lambda': 0.397547211180706, 'scale_pos_weight': 9.486755195482758}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:47,751] Trial 41 finished with value: 0.0 and parameters: {'num_leaves': 82, 'max_depth': 13, 'learning_rate': 0.15554777105225193, 'n_estimators': 174, 'min_child_samples': 17, 'subsample': 0.8370912120671969, 'colsample_bytree': 0.5944674392222203, 'reg_alpha': 0.1971480173088952, 'reg_lambda': 0.39370163478885895, 'scale_pos_weight': 9.443121871438526}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:48,314] Trial 42 finished with value: 0.0 and parameters: {'num_leaves': 72, 'max_depth': 14, 'learning_rate': 0.21103305619856624, 'n_estimators': 209, 'min_child_samples': 11, 'subsample': 0.913371977533779, 'colsample_bytree': 0.6398107842230112, 'reg_alpha': 0.4309794491325165, 'reg_lambda': 0.30232038434980485, 'scale_pos_weight': 8.060912573509318}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:48,762] Trial 43 finished with value: 0.0 and parameters: {'num_leaves': 61, 'max_depth': 15, 'learning_rate': 0.08294983892813099, 'n_estimators': 154, 'min_child_samples': 14, 'subsample': 0.999007865737431, 'colsample_bytree': 0.5728487120864835, 'reg_alpha': 0.4756437099780336, 'reg_lambda': 0.48741957326992896, 'scale_pos_weight': 6.00520797046784}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:49,032] Trial 44 finished with value: 0.43403243243243245 and parameters: {'num_leaves': 52, 'max_depth': 11, 'learning_rate': 0.14043217039881312, 'n_estimators': 113, 'min_child_samples': 7, 'subsample': 0.8178061842912481, 'colsample_bytree': 0.5195275445393102, 'reg_alpha': 0.5360669181483524, 'reg_lambda': 0.3737284380532918, 'scale_pos_weight': 12.652740863473486}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:49,486] Trial 45 finished with value: 0.0 and parameters: {'num_leaves': 55, 'max_depth': 10, 'learning_rate': 0.14562438110981174, 'n_estimators': 132, 'min_child_samples': 7, 'subsample': 0.9164417536098725, 'colsample_bytree': 0.5542666097603094, 'reg_alpha': 0.5681280275645936, 'reg_lambda': 0.37756292135077696, 'scale_pos_weight': 9.16246976013349}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:49,743] Trial 46 finished with value: 0.325990990990991 and parameters: {'num_leaves': 69, 'max_depth': 10, 'learning_rate': 0.27445677647673977, 'n_estimators': 113, 'min_child_samples': 25, 'subsample': 0.8063067651702059, 'colsample_bytree': 0.5175233217122917, 'reg_alpha': 0.3506332368207288, 'reg_lambda': 0.29678831611469225, 'scale_pos_weight': 10.39436625957025}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:49,956] Trial 47 finished with value: 0.0 and parameters: {'num_leaves': 49, 'max_depth': 10, 'learning_rate': 0.2594557907859226, 'n_estimators': 111, 'min_child_samples': 31, 'subsample': 0.8105540210141227, 'colsample_bytree': 0.519615245459788, 'reg_alpha': 0.27710496478681573, 'reg_lambda': 0.2216947949744465, 'scale_pos_weight': 12.5482014402338}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:50,189] Trial 48 finished with value: 0.0 and parameters: {'num_leaves': 66, 'max_depth': 9, 'learning_rate': 0.2881135032510307, 'n_estimators': 75, 'min_child_samples': 26, 'subsample': 0.8809949115967088, 'colsample_bytree': 0.9372392913612978, 'reg_alpha': 0.3916911446122282, 'reg_lambda': 0.31016498399945214, 'scale_pos_weight': 10.636334205152146}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:50,540] Trial 49 finished with value: 0.0 and parameters: {'num_leaves': 88, 'max_depth': 11, 'learning_rate': 0.19285806750593734, 'n_estimators': 96, 'min_child_samples': 36, 'subsample': 0.8468367663601494, 'colsample_bytree': 0.7273606116997899, 'reg_alpha': 0.3547740253719991, 'reg_lambda': 0.06692807055345262, 'scale_pos_weight': 11.641044709921967}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:50,836] Trial 50 finished with value: 0.0 and parameters: {'num_leaves': 127, 'max_depth': 8, 'learning_rate': 0.23888044213428272, 'n_estimators': 123, 'min_child_samples': 29, 'subsample': 0.8070828581339197, 'colsample_bytree': 0.7518360263455838, 'reg_alpha': 0.20805531204575506, 'reg_lambda': 0.29124140850944763, 'scale_pos_weight': 15.58621240233682}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:51,711] Trial 51 finished with value: 0.5691231231231231 and parameters: {'num_leaves': 75, 'max_depth': 12, 'learning_rate': 0.10761403636968365, 'n_estimators': 94, 'min_child_samples': 23, 'subsample': 0.7523323812408362, 'colsample_bytree': 0.503246315724112, 'reg_alpha': 0.4522636180855793, 'reg_lambda': 0.4561247037137355, 'scale_pos_weight': 10.147961684329369}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:52,039] Trial 52 finished with value: 0.0 and parameters: {'num_leaves': 79, 'max_depth': 11, 'learning_rate': 0.06994378028834997, 'n_estimators': 92, 'min_child_samples': 22, 'subsample': 0.7571696947674933, 'colsample_bytree': 0.5194087470616012, 'reg_alpha': 0.2655219590988041, 'reg_lambda': 0.4327273352427565, 'scale_pos_weight': 9.948547944840103}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:52,312] Trial 53 finished with value: 0.48805170387779084 and parameters: {'num_leaves': 67, 'max_depth': 10, 'learning_rate': 0.10430868374158425, 'n_estimators': 110, 'min_child_samples': 25, 'subsample': 0.8026870191010356, 'colsample_bytree': 0.5475160098315557, 'reg_alpha': 0.5436409370001513, 'reg_lambda': 0.4553740874525753, 'scale_pos_weight': 7.529751839892425}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:52,514] Trial 54 finished with value: 0.542193433102524 and parameters: {'num_leaves': 58, 'max_depth': 12, 'learning_rate': 0.10517852160273988, 'n_estimators': 77, 'min_child_samples': 29, 'subsample': 0.7385624650653859, 'colsample_bytree': 0.5523218348036169, 'reg_alpha': 0.5811439390826983, 'reg_lambda': 0.46989883744500477, 'scale_pos_weight': 5.63759051987441}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:52,677] Trial 55 finished with value: 0.0 and parameters: {'num_leaves': 59, 'max_depth': 12, 'learning_rate': 0.10408357865163137, 'n_estimators': 60, 'min_child_samples': 29, 'subsample': 0.7295326704094192, 'colsample_bytree': 0.538350163119682, 'reg_alpha': 0.5185633553398457, 'reg_lambda': 0.4624927920534882, 'scale_pos_weight': 4.92317833576503}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:52,895] Trial 56 finished with value: 0.5150457715780297 and parameters: {'num_leaves': 73, 'max_depth': 12, 'learning_rate': 0.08737103676474287, 'n_estimators': 73, 'min_child_samples': 40, 'subsample': 0.7122861546195166, 'colsample_bytree': 0.6091247104324323, 'reg_alpha': 0.606343546283467, 'reg_lambda': 0.5266441519867181, 'scale_pos_weight': 3.948553560798687}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:53,073] Trial 57 finished with value: 0.0 and parameters: {'num_leaves': 67, 'max_depth': 8, 'learning_rate': 0.08315182118376033, 'n_estimators': 72, 'min_child_samples': 44, 'subsample': 0.6982612177804028, 'colsample_bytree': 0.5554522637958478, 'reg_alpha': 0.6711901429804481, 'reg_lambda': 0.5278939934573995, 'scale_pos_weight': 3.5076848629457826}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:53,209] Trial 58 finished with value: 0.542055692055692 and parameters: {'num_leaves': 43, 'max_depth': 12, 'learning_rate': 0.12106016804885458, 'n_estimators': 60, 'min_child_samples': 37, 'subsample': 0.7578038483496037, 'colsample_bytree': 0.5002679314019978, 'reg_alpha': 0.42565860147754414, 'reg_lambda': 0.002371749867601386, 'scale_pos_weight': 3.8946306728630944}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:53,345] Trial 59 finished with value: 0.0 and parameters: {'num_leaves': 42, 'max_depth': 12, 'learning_rate': 0.047051713089012945, 'n_estimators': 60, 'min_child_samples': 42, 'subsample': 0.7535550658385988, 'colsample_bytree': 0.5065159696091373, 'reg_alpha': 0.43049283398438287, 'reg_lambda': 0.008112454689769528, 'scale_pos_weight': 2.568742638026947}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:53,506] Trial 60 finished with value: 0.0 and parameters: {'num_leaves': 35, 'max_depth': 12, 'learning_rate': 0.0633568821662471, 'n_estimators': 83, 'min_child_samples': 40, 'subsample': 0.7117324697362786, 'colsample_bytree': 0.60409557517799, 'reg_alpha': 0.9657748260654294, 'reg_lambda': 0.5772905333008822, 'scale_pos_weight': 5.9603368317978545}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:53,628] Trial 61 finished with value: 0.0 and parameters: {'num_leaves': 21, 'max_depth': 9, 'learning_rate': 0.12251973169179976, 'n_estimators': 71, 'min_child_samples': 38, 'subsample': 0.7714249738683148, 'colsample_bytree': 0.5460307963869149, 'reg_alpha': 0.5737984262281702, 'reg_lambda': 0.671080577339065, 'scale_pos_weight': 3.949771938477622}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:53,754] Trial 62 finished with value: 0.0 and parameters: {'num_leaves': 58, 'max_depth': 6, 'learning_rate': 0.05448697847912545, 'n_estimators': 58, 'min_child_samples': 50, 'subsample': 0.7900975502459714, 'colsample_bytree': 0.501063630542043, 'reg_alpha': 0.3889583590793373, 'reg_lambda': 0.5263508551668983, 'scale_pos_weight': 7.0878779141336725}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:53,986] Trial 63 finished with value: 0.0 and parameters: {'num_leaves': 74, 'max_depth': 11, 'learning_rate': 0.08912504052354639, 'n_estimators': 93, 'min_child_samples': 33, 'subsample': 0.7398411779895034, 'colsample_bytree': 0.5875309060098584, 'reg_alpha': 0.541430445354655, 'reg_lambda': 0.467890793029439, 'scale_pos_weight': 4.353368359052129}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:54,165] Trial 64 finished with value: 0.5422072072072073 and parameters: {'num_leaves': 46, 'max_depth': 12, 'learning_rate': 0.11511032993466909, 'n_estimators': 80, 'min_child_samples': 34, 'subsample': 0.7139793094308776, 'colsample_bytree': 0.6140095369160549, 'reg_alpha': 0.47312492909681175, 'reg_lambda': 0.6036483508366456, 'scale_pos_weight': 5.580894212264763}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:54,358] Trial 65 finished with value: 0.0 and parameters: {'num_leaves': 62, 'max_depth': 12, 'learning_rate': 0.0757487631929379, 'n_estimators': 80, 'min_child_samples': 34, 'subsample': 0.7080072002797321, 'colsample_bytree': 0.6154399071595538, 'reg_alpha': 0.46395659589892996, 'reg_lambda': 0.7324325708496968, 'scale_pos_weight': 1.8669077624499382}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:54,517] Trial 66 finished with value: 0.5420909281374398 and parameters: {'num_leaves': 44, 'max_depth': 14, 'learning_rate': 0.11911124685517352, 'n_estimators': 69, 'min_child_samples': 35, 'subsample': 0.6911110862195333, 'colsample_bytree': 0.6269628584167019, 'reg_alpha': 0.9990261538676284, 'reg_lambda': 0.5757670118535629, 'scale_pos_weight': 5.513278033469071}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:54,673] Trial 67 finished with value: 0.46096388423822054 and parameters: {'num_leaves': 45, 'max_depth': 14, 'learning_rate': 0.1779578398547195, 'n_estimators': 52, 'min_child_samples': 36, 'subsample': 0.674930753265781, 'colsample_bytree': 0.6752282499991007, 'reg_alpha': 0.9869608269079079, 'reg_lambda': 0.6027215926952504, 'scale_pos_weight': 6.236159883622655}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:54,866] Trial 68 finished with value: 0.0 and parameters: {'num_leaves': 34, 'max_depth': 14, 'learning_rate': 0.12444718000670864, 'n_estimators': 99, 'min_child_samples': 32, 'subsample': 0.6418856915811746, 'colsample_bytree': 0.6527315169134918, 'reg_alpha': 0.9040104567316443, 'reg_lambda': 0.6896856287468687, 'scale_pos_weight': 5.4619267643416975}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:55,078] Trial 69 finished with value: 0.4609773166023166 and parameters: {'num_leaves': 46, 'max_depth': 13, 'learning_rate': 0.1138924733204774, 'n_estimators': 88, 'min_child_samples': 35, 'subsample': 0.6918763728242114, 'colsample_bytree': 0.630159586498603, 'reg_alpha': 0.8258245033647773, 'reg_lambda': 0.620087258816291, 'scale_pos_weight': 5.38828255039625}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:55,204] Trial 70 finished with value: 0.0 and parameters: {'num_leaves': 24, 'max_depth': 15, 'learning_rate': 0.03320830388131536, 'n_estimators': 61, 'min_child_samples': 38, 'subsample': 0.7318165662184571, 'colsample_bytree': 0.5812597920545255, 'reg_alpha': 0.7650824012726497, 'reg_lambda': 0.5786917660966995, 'scale_pos_weight': 2.7127608668983094}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:55,370] Trial 71 finished with value: 0.0 and parameters: {'num_leaves': 50, 'max_depth': 12, 'learning_rate': 0.09048640082835659, 'n_estimators': 70, 'min_child_samples': 40, 'subsample': 0.7575698519338465, 'colsample_bytree': 0.6059292397681015, 'reg_alpha': 0.4940671864229154, 'reg_lambda': 0.5115864108054746, 'scale_pos_weight': 4.417672355916244}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:55,532] Trial 72 finished with value: 0.48802494802494806 and parameters: {'num_leaves': 42, 'max_depth': 14, 'learning_rate': 0.10606199802635352, 'n_estimators': 76, 'min_child_samples': 39, 'subsample': 0.7181734245307699, 'colsample_bytree': 0.5612327436132153, 'reg_alpha': 0.6511668228752524, 'reg_lambda': 0.5663734014510071, 'scale_pos_weight': 4.078815180020291}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:55,748] Trial 73 finished with value: 0.0 and parameters: {'num_leaves': 52, 'max_depth': 13, 'learning_rate': 0.13118371906057677, 'n_estimators': 104, 'min_child_samples': 32, 'subsample': 0.6607161296070488, 'colsample_bytree': 0.6609518086664429, 'reg_alpha': 0.4136361126609244, 'reg_lambda': 0.045475664048380264, 'scale_pos_weight': 3.524624691898908}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:55,909] Trial 74 finished with value: 0.48803821062441755 and parameters: {'num_leaves': 45, 'max_depth': 13, 'learning_rate': 0.07095047708805843, 'n_estimators': 80, 'min_child_samples': 42, 'subsample': 0.7677682646983979, 'colsample_bytree': 0.61697178258983, 'reg_alpha': 0.9897143029910853, 'reg_lambda': 0.1530806394902493, 'scale_pos_weight': 2.2926185881994963}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:56,060] Trial 75 finished with value: 0.0 and parameters: {'num_leaves': 38, 'max_depth': 11, 'learning_rate': 0.06137737025697475, 'n_estimators': 67, 'min_child_samples': 42, 'subsample': 0.7434851749581959, 'colsample_bytree': 0.6411515356296537, 'reg_alpha': 0.9308603931583218, 'reg_lambda': 0.9650101824276291, 'scale_pos_weight': 4.941715967154626}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:56,282] Trial 76 finished with value: 0.0 and parameters: {'num_leaves': 56, 'max_depth': 15, 'learning_rate': 0.040779530586687866, 'n_estimators': 88, 'min_child_samples': 37, 'subsample': 0.6354294095453631, 'colsample_bytree': 0.6822730520454262, 'reg_alpha': 0.9526065870534223, 'reg_lambda': 0.6403118695315311, 'scale_pos_weight': 6.992982471449149}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:56,427] Trial 77 finished with value: 0.0 and parameters: {'num_leaves': 31, 'max_depth': 12, 'learning_rate': 0.0519145541063754, 'n_estimators': 55, 'min_child_samples': 30, 'subsample': 0.684128612860973, 'colsample_bytree': 0.5281806985284705, 'reg_alpha': 0.7002911420659221, 'reg_lambda': 0.9094602032419226, 'scale_pos_weight': 6.619757889221187}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:56,631] Trial 78 finished with value: 0.0 and parameters: {'num_leaves': 70, 'max_depth': 14, 'learning_rate': 0.07915393574194421, 'n_estimators': 65, 'min_child_samples': 34, 'subsample': 0.5338331809553272, 'colsample_bytree': 0.5666246748105079, 'reg_alpha': 0.8469216562130589, 'reg_lambda': 0.5043234543570128, 'scale_pos_weight': 8.79554944284213}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:57,004] Trial 79 finished with value: 0.0 and parameters: {'num_leaves': 117, 'max_depth': 13, 'learning_rate': 0.16505053489963825, 'n_estimators': 120, 'min_child_samples': 28, 'subsample': 0.5940228281652904, 'colsample_bytree': 0.6227388143118472, 'reg_alpha': 0.8914525764881333, 'reg_lambda': 0.09303469173769821, 'scale_pos_weight': 3.238539187284033}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:57,615] Trial 80 finished with value: 0.0 and parameters: {'num_leaves': 81, 'max_depth': 11, 'learning_rate': 0.013207780077891609, 'n_estimators': 95, 'min_child_samples': 45, 'subsample': 0.7248990276896222, 'colsample_bytree': 0.5771997546101636, 'reg_alpha': 0.6189724778079123, 'reg_lambda': 0.4245508170412682, 'scale_pos_weight': 5.608264143225582}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:57,845] Trial 81 finished with value: 0.5151101521689757 and parameters: {'num_leaves': 75, 'max_depth': 10, 'learning_rate': 0.10257696019368746, 'n_estimators': 107, 'min_child_samples': 25, 'subsample': 0.7916866840805057, 'colsample_bytree': 0.5493635995720967, 'reg_alpha': 0.5562890315488418, 'reg_lambda': 0.34244416934509814, 'scale_pos_weight': 8.042141582492148}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:58,084] Trial 82 finished with value: 0.0 and parameters: {'num_leaves': 75, 'max_depth': 12, 'learning_rate': 0.11714384259578843, 'n_estimators': 102, 'min_child_samples': 20, 'subsample': 0.7909124108025385, 'colsample_bytree': 0.5303619797746895, 'reg_alpha': 0.4450171083143941, 'reg_lambda': 0.5387080219021908, 'scale_pos_weight': 8.230017549198127}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:58,374] Trial 83 finished with value: 0.4071295433364399 and parameters: {'num_leaves': 64, 'max_depth': 15, 'learning_rate': 0.09959569546374061, 'n_estimators': 128, 'min_child_samples': 10, 'subsample': 0.5686484952417322, 'colsample_bytree': 0.6373387987651665, 'reg_alpha': 0.49673579771409526, 'reg_lambda': 0.34865003945105044, 'scale_pos_weight': 7.745665370901362}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:58,565] Trial 84 finished with value: 0.6231347795163584 and parameters: {'num_leaves': 60, 'max_depth': 11, 'learning_rate': 0.09037433796317461, 'n_estimators': 76, 'min_child_samples': 23, 'subsample': 0.7406640190010184, 'colsample_bytree': 0.5960876392034024, 'reg_alpha': 0.7877855422870976, 'reg_lambda': 0.19201792515742921, 'scale_pos_weight': 8.93534678481947}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:58,783] Trial 85 finished with value: 0.5152252252252252 and parameters: {'num_leaves': 60, 'max_depth': 10, 'learning_rate': 0.13322635101677008, 'n_estimators': 88, 'min_child_samples': 23, 'subsample': 0.7664614245204587, 'colsample_bytree': 0.5928579637193337, 'reg_alpha': 0.7634908532933167, 'reg_lambda': 0.13894093192551932, 'scale_pos_weight': 9.105279644636871}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:59,015] Trial 86 finished with value: 0.0 and parameters: {'num_leaves': 60, 'max_depth': 11, 'learning_rate': 0.14156801513781325, 'n_estimators': 86, 'min_child_samples': 24, 'subsample': 0.7657356280237484, 'colsample_bytree': 0.594684498322058, 'reg_alpha': 0.7777588841540003, 'reg_lambda': 0.2013720544475385, 'scale_pos_weight': 6.6666802393808124}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:59,211] Trial 87 finished with value: 0.0 and parameters: {'num_leaves': 52, 'max_depth': 10, 'learning_rate': 0.17658689032198088, 'n_estimators': 78, 'min_child_samples': 23, 'subsample': 0.7416571975931349, 'colsample_bytree': 0.5841657692277176, 'reg_alpha': 0.8908403447652558, 'reg_lambda': 0.1579741583917117, 'scale_pos_weight': 9.040612330462071}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:15:59,458] Trial 88 finished with value: 0.0 and parameters: {'num_leaves': 57, 'max_depth': 11, 'learning_rate': 0.13044583500717508, 'n_estimators': 92, 'min_child_samples': 19, 'subsample': 0.697663624882776, 'colsample_bytree': 0.5662001256990066, 'reg_alpha': 0.843842635737451, 'reg_lambda': 0.039666606017003975, 'scale_pos_weight': 9.722118058286227}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:02,149] Trial 89 finished with value: 0.0 and parameters: {'num_leaves': 49, 'max_depth': 14, 'learning_rate': 0.11101803761545542, 'n_estimators': 64, 'min_child_samples': 31, 'subsample': 0.6649112786310019, 'colsample_bytree': 0.6257204394097898, 'reg_alpha': 0.7966305411880766, 'reg_lambda': 0.23748158135464675, 'scale_pos_weight': 12.096595114085996}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:02,721] Trial 90 finished with value: 0.0 and parameters: {'num_leaves': 55, 'max_depth': 11, 'learning_rate': 0.027896267685079124, 'n_estimators': 98, 'min_child_samples': 28, 'subsample': 0.8270681927775279, 'colsample_bytree': 0.6507890092038708, 'reg_alpha': 0.7120661389548572, 'reg_lambda': 0.08734883228790369, 'scale_pos_weight': 10.55756106558827}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:03,520] Trial 91 finished with value: 0.0 and parameters: {'num_leaves': 64, 'max_depth': 10, 'learning_rate': 0.09917180247369048, 'n_estimators': 106, 'min_child_samples': 22, 'subsample': 0.7519693410714174, 'colsample_bytree': 0.5143005114347079, 'reg_alpha': 0.39819246796999686, 'reg_lambda': 0.1340050837670498, 'scale_pos_weight': 8.428463955377712}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:04,836] Trial 92 finished with value: 0.0 and parameters: {'num_leaves': 85, 'max_depth': 12, 'learning_rate': 0.14452185256880656, 'n_estimators': 82, 'min_child_samples': 26, 'subsample': 0.7873148576674032, 'colsample_bytree': 0.5494984434584257, 'reg_alpha': 0.4766852179656301, 'reg_lambda': 0.18636189810390247, 'scale_pos_weight': 7.655494011973513}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:05,699] Trial 93 finished with value: 0.0 and parameters: {'num_leaves': 69, 'max_depth': 10, 'learning_rate': 0.09249537218716039, 'n_estimators': 88, 'min_child_samples': 26, 'subsample': 0.768298353483298, 'colsample_bytree': 0.5944448602639393, 'reg_alpha': 0.5850356628462818, 'reg_lambda': 0.2619486283077893, 'scale_pos_weight': 9.88886384385505}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:07,200] Trial 94 finished with value: 0.5962122416534181 and parameters: {'num_leaves': 60, 'max_depth': 10, 'learning_rate': 0.12179454670649678, 'n_estimators': 75, 'min_child_samples': 20, 'subsample': 0.7368474277125552, 'colsample_bytree': 0.5410446404567638, 'reg_alpha': 0.9292242170380609, 'reg_lambda': 0.33079511158264957, 'scale_pos_weight': 8.795142589710506}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:07,792] Trial 95 finished with value: 0.6502070902070902 and parameters: {'num_leaves': 61, 'max_depth': 9, 'learning_rate': 0.12242373459394472, 'n_estimators': 70, 'min_child_samples': 13, 'subsample': 0.7255169310034736, 'colsample_bytree': 0.5283627895055555, 'reg_alpha': 0.9430733666763386, 'reg_lambda': 0.006742544948969337, 'scale_pos_weight': 11.232490484743774}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:08,229] Trial 96 finished with value: 0.0 and parameters: {'num_leaves': 46, 'max_depth': 9, 'learning_rate': 0.11078700203787491, 'n_estimators': 68, 'min_child_samples': 15, 'subsample': 0.7243596113198748, 'colsample_bytree': 0.5103586810794849, 'reg_alpha': 0.9603327746865057, 'reg_lambda': 0.01416361166200116, 'scale_pos_weight': 11.125354218606626}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:08,524] Trial 97 finished with value: 0.0 and parameters: {'num_leaves': 53, 'max_depth': 8, 'learning_rate': 0.1184885104016828, 'n_estimators': 54, 'min_child_samples': 13, 'subsample': 0.7053518452773253, 'colsample_bytree': 0.5016393540229125, 'reg_alpha': 0.9993389099844083, 'reg_lambda': 0.06726578344209852, 'scale_pos_weight': 13.022687086513804}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:08,694] Trial 98 finished with value: 0.0 and parameters: {'num_leaves': 40, 'max_depth': 9, 'learning_rate': 0.15084829517138446, 'n_estimators': 73, 'min_child_samples': 9, 'subsample': 0.7337672367020069, 'colsample_bytree': 0.526422954406508, 'reg_alpha': 0.9269011257691286, 'reg_lambda': 0.3246909675747697, 'scale_pos_weight': 11.28465382782384}. Best is trial 17 with value: 0.6772579541566883.
# [I 2026-01-19 14:16:09,614] Trial 99 finished with value: 0.0 and parameters: {'num_leaves': 66, 'max_depth': 9, 'learning_rate': 0.08275962007645223, 'n_estimators': 271, 'min_child_samples': 11, 'subsample': 0.7184877621529223, 'colsample_bytree': 0.5393944072229169, 'reg_alpha': 0.9410164313508935, 'reg_lambda': 0.486761943534625, 'scale_pos_weight': 12.000001054798702}. Best is trial 17 with value: 0.6772579541566883.

# %%
# best_params_lgbm = grid_lgbm.best_params_

# %%
best_params_lgbm = study_lgbm.best_params

# %%
print(best_params_lgbm)
# Out:
# {'num_leaves': 67, 'max_depth': 15, 'learning_rate': 0.046419036087664504, 'n_estimators': 114, 'min_child_samples': 13, 'subsample': 0.6123467940735869, 'colsample_bytree': 0.6879515056982495, 'reg_alpha': 0.8956049237047359, 'reg_lambda': 0.17747344841110274, 'scale_pos_weight': 12.23175086121507}

# %%
final_classifier = lgb.LGBMClassifier(**best_params_lgbm, random_state=42, verbose=-1)

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# LGBMClassifier(colsample_bytree=0.6879515056982495,
#                learning_rate=0.046419036087664504, max_depth=15,
#                min_child_samples=13, n_estimators=114, num_leaves=67,
#                random_state=42, reg_alpha=0.8956049237047359,
#                reg_lambda=0.17747344841110274,
#                scale_pos_weight=12.23175086121507, subsample=0.6123467940735869,
#                verbose=-1)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[596 133]
#  [ 12  25]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.8107049608355091

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.15822784810126583

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.6756756756756757

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.4084967320261438

# %% [markdown]
# ### Threshold tuning

# %%
best_threshold = 0.5

# %%
best_precision_score = 0

# %%
best_recall_score = 0

# %%
best_f2_score = 0

# %%
for threshold in np.arange(0.1, 0.95, 0.05):
    y_pred_val_threshold = (y_proba_val >= threshold).astype(int)
    recall = recall_score(y_val, y_pred_val_threshold)
    precision = precision_score(y_val, y_pred_val_threshold)
    f2_score = fbeta_score(y_val, y_pred_val_threshold, beta=2)
    
    print(f'Threshold {threshold} has recall score {f2_score}')
    
    if precision >= 0.15:
        current_recall_score = recall
        if current_recall_score > best_recall_score:
            best_recall_score = current_recall_score
            best_precision_score = precision
            best_threshold = threshold
        elif current_recall_score == best_recall_score and precision > best_precision_score:
            best_precision_score = precision
            best_threshold = threshold
        
        # current_f2_score = f2_score
        # if current_f2_score > best_f2_score:
        #     best_f2_score = current_f2_score
        #     best_threshold = threshold
# Out:
# Threshold 0.1 has recall score 0.35560344827586204
# Threshold 0.15000000000000002 has recall score 0.3664302600472813
# Threshold 0.20000000000000004 has recall score 0.3778337531486146
# Threshold 0.25000000000000006 has recall score 0.38961038961038963
# Threshold 0.30000000000000004 has recall score 0.3835616438356164
# Threshold 0.3500000000000001 has recall score 0.4
# Threshold 0.40000000000000013 has recall score 0.40059347181008903
# Threshold 0.45000000000000007 has recall score 0.40625
# Threshold 0.5000000000000001 has recall score 0.4084967320261438
# Threshold 0.5500000000000002 has recall score 0.4280821917808219
# Threshold 0.6000000000000002 has recall score 0.4092526690391459
# Threshold 0.6500000000000001 has recall score 0.42592592592592593
# Threshold 0.7000000000000002 has recall score 0.33203125
# Threshold 0.7500000000000002 has recall score 0.24793388429752067
# Threshold 0.8000000000000002 has recall score 0.23504273504273504
# Threshold 0.8500000000000002 has recall score 0.2422907488986784
# Threshold 0.9000000000000002 has recall score 0.19607843137254902

# %%
print(best_threshold)
# Out:
# 0.45000000000000007

# %%
print(best_recall_score)
# Out:
# 0.7027027027027027

# %% [markdown]
# ### Retrain on training + validation set

# %%
X_train_full = pd.concat([X_train_res_retained, X_val_retained], axis=0, ignore_index=True)
y_train_full = pd.concat([y_train_res, y_val], axis=0, ignore_index=True)

# %%
final_classifier.fit(X_train_full, y_train_full)
# Out:
# LGBMClassifier(colsample_bytree=0.6879515056982495,
#                learning_rate=0.046419036087664504, max_depth=15,
#                min_child_samples=13, n_estimators=114, num_leaves=67,
#                random_state=42, reg_alpha=0.8956049237047359,
#                reg_lambda=0.17747344841110274,
#                scale_pos_weight=12.23175086121507, subsample=0.6123467940735869,
#                verbose=-1)

# %% [markdown]
# ### Evaluate on test set

# %%
X_test_retained = X_test[retained_columns]

# %%
y_pred_test = final_classifier.predict(X_test_retained)

# %%
y_proba_test = final_classifier.predict_proba(X_test_retained)[:, 1]

# %%
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[595 134]
#  [ 18  20]]

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.8018252933507171

# %%
print(precision_score(y_test, y_pred_test))
# Out:
# 0.12987012987012986

# %%
print(recall_score(y_test, y_pred_test))
# Out:
# 0.5263157894736842

# %%
print(fbeta_score(y_test, y_pred_test, beta=2))
# Out:
# 0.32679738562091504

# %% [markdown]
# ### Test with best threshold 0.45

# %%
y_pred_test_threshold = (y_proba_test >= best_threshold).astype(int)

# %%
print(confusion_matrix(y_test, y_pred_test_threshold))
# Out:
# [[590 139]
#  [ 17  21]]

# %%
print(accuracy_score(y_test, y_pred_test_threshold))
# Out:
# 0.7966101694915254

# %%
print(precision_score(y_test, y_pred_test_threshold))
# Out:
# 0.13125

# %%
print(recall_score(y_test, y_pred_test_threshold))
# Out:
# 0.5526315789473685

# %%
print(fbeta_score(y_test, y_pred_test_threshold, beta=2))
# Out:
# 0.33653846153846156
