# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.under_sampling import TomekLinks
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14016\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for age interaction features

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %%
df['age_hypertension'] = df['age'] * df['hypertension']

# %%
df['age_heart_disease'] = df['age'] * df['heart_disease']

# %%
df['age_bmi'] = df['age'] * df['bmi']

# %%
df['age_avg_glucose_level'] = df['age'] * df['avg_glucose_level']

# %%
df['bmi_avg_glucose_level'] = df['bmi'] * df['avg_glucose_level']

# %%
df['avg_glucose_level_hypertension'] = df['avg_glucose_level'] * df['hypertension']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %%
df['obese_high_avg_glucose_level'] = df['obese'] | df['high_avg_glucose_level']

# %% [markdown]
# ### Creating column representing high age

# %%
df['old'] = df['age'] >= 65

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %%
df['risk_count'] = df['obese'] + df['high_avg_glucose_level'] + df['old'] + df['hypertension'] + df['heart_disease']

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  age_hypertension  \
# 0                      0              67.0               0.0
# 1                      0              61.0               0.0
# 2                      0              80.0               0.0
# 3                      1              49.0               0.0
# 4                      0              79.0              79.0
#
#    age_heart_disease  age_bmi  age_avg_glucose_level  bmi_avg_glucose_level  \
# 0               67.0   2452.2               15322.23               8370.054
# 1                0.0   1714.1               12334.81               5682.101
# 2               80.0   2600.0                8473.60               3442.400
# 3                0.0   1685.6                8390.27               5890.312
# 4                0.0   1896.0               13755.48               4178.880
#
#    avg_glucose_level_hypertension  obese  high_avg_glucose_level  \
# 0                            0.00      1                       1
# 1                            0.00      0                       1
# 2                            0.00      1                       0
# 3                            0.00      1                       1
# 4                          174.12      0                       1
#
#    obese_high_avg_glucose_level  old  risk_count   log_bmi  \
# 0                             1    1           4  3.600048
# 1                             1    0           1  3.335770
# 2                             1    1           3  3.481240
# 3                             1    0           2  3.538057
# 4                             1    1           3  3.178054
#
#    log_avg_glucose_level
# 0               5.432367
# 1               5.309307
# 2               4.662684
# 3               5.143008
# 4               5.159745

# %%
df.shape
# Out:
# (5110, 36)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14016\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### ADASYN Oversampling on Training Data

# %%
resampler = TomekLinks()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = RandomForestClassifier(random_state=42)

# %% [markdown]
# ### Create grid for hyperparameter tuning

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'class_weight': ['balanced', 'balanced_subsample']
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_rf = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_rf,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Gini Importance': importances}).sort_values(
    'Gini Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Gini Importance
# 24           age_avg_glucose_level         0.094787
# 23                         age_bmi         0.090626
# 4                avg_glucose_level         0.086602
# 33           log_avg_glucose_level         0.084606
# 25           bmi_avg_glucose_level         0.080800
# 0                              age         0.079460
# 32                         log_bmi         0.077683
# 5                              bmi         0.070120
# 20                age_ever_married         0.066083
# 26  avg_glucose_level_hypertension         0.023199
# 21                age_hypertension         0.023178
# 22               age_heart_disease         0.020441
# 31                      risk_count         0.019727
# 7                            urban         0.015812
# 13               work_type_private         0.015092
# 6                             male         0.015044
# 14         work_type_self_employed         0.013913
# 30                             old         0.013907
# 18     smoking_status_never_smoked         0.012157
# 17  smoking_status_formerly_smoked         0.011866
# 8                            smoke         0.011174
# 19           smoking_status_smokes         0.010464
# 16          smoking_status_unknown         0.010087
# 11              work_type_govt_job         0.007585
# 2                    heart_disease         0.007407
# 3                     ever_married         0.007158
# 10   hypertension_or_heart_disease         0.007074
# 27                           obese         0.006734
# 1                     hypertension         0.006421
# 29    obese_high_avg_glucose_level         0.005685
# 28          high_avg_glucose_level         0.004799
# 9                        have_work         0.000199
# 15              work_type_children         0.000108
# 12          work_type_never_worked         0.000000

# %%
# retained_columns = ['age_avg_glucose_level', 'age_bmi', 'avg_glucose_level', 'bmi_avg_glucose_level', 'age', 'log_bmi', 'age_ever_married', 'avg_glucose_level_hypertension', 'age_hypertension']

# %%
# retained_columns = ['age_avg_glucose_level', 'age_bmi', 'avg_glucose_level', 'bmi_avg_glucose_level', 'age', 'log_bmi', 'age_ever_married', 'avg_glucose_level_hypertension', 'age_hypertension', 'age_heart_disease']

# %%
# retained_columns = ['age_avg_glucose_level', 'log_avg_glucose_level', 'bmi_avg_glucose_level', 'age_bmi', 'avg_glucose_level', 'age', 'log_bmi', 'age_ever_married', 'avg_glucose_level_hypertension', 'age_hypertension']

# %%
# retained_columns = ['log_avg_glucose_level', 'log_bmi', 'age', 'age_ever_married', 'age_hypertension', 'age_heart_disease', 'old', 'urban', 'male', 'work_type_private']

# %%
# retained_columns = ['age', 'avg_glucose_level', 'age_ever_married', 'log_bmi', 'urban', 'work_type_private', 'male', 'hypertension_or_heart_disease', 'smoking_status_never_smoked', 'heart_disease']

# %%
# retained_columns = ['age', 'avg_glucose_level', 'age_ever_married', 'log_bmi', 'urban', 'work_type_private', 'male', 'hypertension_or_heart_disease', 'smoking_status_never_smoked', 'heart_disease']

# %%
# retained_columns = ['age', 'avg_glucose_level', 'log_bmi', 'urban', 'work_type_private', 'male', 'hypertension_or_heart_disease', 'smoking_status_never_smoked', 'work_type_self_employed', 'smoking_status_smokes']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.15

# %%
def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 50),
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 50, 300),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 40),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 15),
        'min_weight_fraction_leaf': trial.suggest_float('min_weight_fraction_leaf', 0.0, 0.05),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', 0.5, 0.7]),
        'max_samples': trial.suggest_float('max_samples', 0.6, 1.0),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']), 
        'min_impurity_decrease': trial.suggest_float('min_impurity_decrease', 0.0, 0.005),
        'ccp_alpha': trial.suggest_float('ccp_alpha', 0.0, 0.005),
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample']),
        'random_state': 42,
        'n_jobs': -1
    }
    
    model = RandomForestClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    f2_score = fbeta_score(y_val, y_pred_val, beta=2)
    
    if precision < MIN_PRECISION:
        return 0
    # return recall + (precision * 0.01)
    return f2_score + recall * 0.001 + precision * 0.00001

# %%
study_rf = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_rf.optimize(objective_rf, n_trials=500, show_progress_bar=True)
# Out:
# [I 2026-01-22 15:18:52,121] A new study created in memory with name: no-name-45143605-d295-4512-aa30-5cfad3119947
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2026-01-22 15:18:53,387] Trial 0 finished with value: 0.41231659558338823 and parameters: {'n_estimators': 218, 'max_depth': 48, 'max_leaf_nodes': 233, 'min_samples_split': 25, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.007799726016810133, 'max_features': 'log2', 'max_samples': 0.608233797718321, 'criterion': 'gini', 'min_impurity_decrease': 0.0010616955533913808, 'ccp_alpha': 0.0009091248360355031, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.41231659558338823.
# [I 2026-01-22 15:18:55,048] Trial 1 finished with value: 0.0 and parameters: {'n_estimators': 286, 'max_depth': 23, 'max_leaf_nodes': 123, 'min_samples_split': 25, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.014607232426760909, 'max_features': 0.5, 'max_samples': 0.8056937753654446, 'criterion': 'gini', 'min_impurity_decrease': 0.003037724259507192, 'ccp_alpha': 0.0008526206184364576, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.41231659558338823.
# [I 2026-01-22 15:18:58,454] Trial 2 finished with value: 0.0 and parameters: {'n_estimators': 485, 'max_depth': 41, 'max_leaf_nodes': 126, 'min_samples_split': 5, 'min_samples_leaf': 11, 'min_weight_fraction_leaf': 0.022007624686980067, 'max_features': 0.7, 'max_samples': 0.7035119926400067, 'criterion': 'gini', 'min_impurity_decrease': 0.002600340105889054, 'ccp_alpha': 0.0027335513967163983, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.41231659558338823.
# [I 2026-01-22 15:19:01,501] Trial 3 finished with value: 0.4088135577903876 and parameters: {'n_estimators': 399, 'max_depth': 48, 'max_leaf_nodes': 274, 'min_samples_split': 25, 'min_samples_leaf': 14, 'min_weight_fraction_leaf': 0.004424625102595975, 'max_features': 0.7, 'max_samples': 0.7085396127095583, 'criterion': 'gini', 'min_impurity_decrease': 0.0014046725484369038, 'ccp_alpha': 0.0027134804157912425, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.41231659558338823.
# [I 2026-01-22 15:19:02,185] Trial 4 finished with value: 0.0 and parameters: {'n_estimators': 83, 'max_depth': 50, 'max_leaf_nodes': 243, 'min_samples_split': 9, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.04077307142274171, 'max_features': 0.5, 'max_samples': 0.7433862914177091, 'criterion': 'entropy', 'min_impurity_decrease': 0.0031164906341377896, 'ccp_alpha': 0.001654490124263246, 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.41231659558338823.
# [I 2026-01-22 15:19:03,685] Trial 5 finished with value: 0.4487062579077477 and parameters: {'n_estimators': 196, 'max_depth': 38, 'max_leaf_nodes': 210, 'min_samples_split': 36, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.005979712296915085, 'max_features': 0.7, 'max_samples': 0.7975182385457563, 'criterion': 'gini', 'min_impurity_decrease': 0.00012709563372047595, 'ccp_alpha': 0.0005394571349665222, 'class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.4487062579077477.
# [I 2026-01-22 15:19:05,214] Trial 6 finished with value: 0.0 and parameters: {'n_estimators': 191, 'max_depth': 27, 'max_leaf_nodes': 277, 'min_samples_split': 11, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.037777556927152435, 'max_features': 0.5, 'max_samples': 0.9718790609370292, 'criterion': 'gini', 'min_impurity_decrease': 0.004357302950938589, 'ccp_alpha': 0.004018360384495572, 'class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.4487062579077477.
# [I 2026-01-22 15:19:06,681] Trial 7 finished with value: 0.44520287784790774 and parameters: {'n_estimators': 293, 'max_depth': 41, 'max_leaf_nodes': 274, 'min_samples_split': 14, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.011396758127097084, 'max_features': 0.5, 'max_samples': 0.8042989210310263, 'criterion': 'gini', 'min_impurity_decrease': 0.000599326836668414, 'ccp_alpha': 0.0016880758570181399, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.4487062579077477.
# [I 2026-01-22 15:19:08,131] Trial 8 finished with value: 0.0 and parameters: {'n_estimators': 283, 'max_depth': 36, 'max_leaf_nodes': 141, 'min_samples_split': 39, 'min_samples_leaf': 15, 'min_weight_fraction_leaf': 0.01258911479126821, 'max_features': 'sqrt', 'max_samples': 0.8438257335919588, 'criterion': 'gini', 'min_impurity_decrease': 0.0013932323211830573, 'ccp_alpha': 0.004541329429833269, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.4487062579077477.
# [I 2026-01-22 15:19:10,138] Trial 9 finished with value: 0.0 and parameters: {'n_estimators': 270, 'max_depth': 50, 'max_leaf_nodes': 110, 'min_samples_split': 28, 'min_samples_leaf': 12, 'min_weight_fraction_leaf': 0.011881877199619984, 'max_features': 'sqrt', 'max_samples': 0.8143098736299034, 'criterion': 'entropy', 'min_impurity_decrease': 0.0016039003248586791, 'ccp_alpha': 0.0009325925519992712, 'class_weight': 'balanced_subsample'}. Best is trial 5 with value: 0.4487062579077477.
# [I 2026-01-22 15:19:10,554] Trial 10 finished with value: 0.0 and parameters: {'n_estimators': 66, 'max_depth': 3, 'max_leaf_nodes': 51, 'min_samples_split': 39, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.028760403340763633, 'max_features': 0.7, 'max_samples': 0.9349271445377154, 'criterion': 'entropy', 'min_impurity_decrease': 6.155584782468766e-05, 'ccp_alpha': 0.0001365681698735613, 'class_weight': 'balanced'}. Best is trial 5 with value: 0.4487062579077477.
# [I 2026-01-22 15:19:11,431] Trial 11 finished with value: 0.45855313355113353 and parameters: {'n_estimators': 166, 'max_depth': 34, 'max_leaf_nodes': 209, 'min_samples_split': 16, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.0004976597373873761, 'max_features': 'log2', 'max_samples': 0.8875622174156794, 'criterion': 'gini', 'min_impurity_decrease': 6.499203398580402e-05, 'ccp_alpha': 0.0021360725744575663, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:12,238] Trial 12 finished with value: 0.416115870538074 and parameters: {'n_estimators': 158, 'max_depth': 29, 'max_leaf_nodes': 188, 'min_samples_split': 17, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.00015151666938874406, 'max_features': 'log2', 'max_samples': 0.8954702873336231, 'criterion': 'gini', 'min_impurity_decrease': 0.00017941038596874648, 'ccp_alpha': 0.0034411475597509963, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:12,970] Trial 13 finished with value: 0.0 and parameters: {'n_estimators': 124, 'max_depth': 17, 'max_leaf_nodes': 211, 'min_samples_split': 33, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.021267114600976272, 'max_features': 'log2', 'max_samples': 0.8848541435297621, 'criterion': 'gini', 'min_impurity_decrease': 0.002127947321819143, 'ccp_alpha': 0.0018220301791089914, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:14,125] Trial 14 finished with value: 0.0 and parameters: {'n_estimators': 218, 'max_depth': 34, 'max_leaf_nodes': 171, 'min_samples_split': 19, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0488633232797539, 'max_features': 'log2', 'max_samples': 0.7467874116238973, 'criterion': 'entropy', 'min_impurity_decrease': 0.004898232498406144, 'ccp_alpha': 3.218379079909903e-05, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:16,211] Trial 15 finished with value: 0.42584745603165364 and parameters: {'n_estimators': 375, 'max_depth': 19, 'max_leaf_nodes': 171, 'min_samples_split': 32, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.000908166892765643, 'max_features': 0.7, 'max_samples': 0.8758697700847069, 'criterion': 'gini', 'min_impurity_decrease': 0.0007222335265086063, 'ccp_alpha': 0.003450231390215875, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:17,607] Trial 16 finished with value: 0.0 and parameters: {'n_estimators': 142, 'max_depth': 35, 'max_leaf_nodes': 225, 'min_samples_split': 2, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.017687261635391954, 'max_features': 'log2', 'max_samples': 0.9409695457750876, 'criterion': 'gini', 'min_impurity_decrease': 1.0419233651434114e-05, 'ccp_alpha': 0.002145139506750299, 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:19,498] Trial 17 finished with value: 0.0 and parameters: {'n_estimators': 354, 'max_depth': 41, 'max_leaf_nodes': 299, 'min_samples_split': 33, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.02876185140101277, 'max_features': 0.7, 'max_samples': 0.6327524619699703, 'criterion': 'gini', 'min_impurity_decrease': 0.0038614490776038538, 'ccp_alpha': 0.0011825302346369728, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:20,218] Trial 18 finished with value: 0.0 and parameters: {'n_estimators': 112, 'max_depth': 6, 'max_leaf_nodes': 194, 'min_samples_split': 16, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.006062312132549041, 'max_features': 'sqrt', 'max_samples': 0.9911481122198003, 'criterion': 'entropy', 'min_impurity_decrease': 0.0020124982770938237, 'ccp_alpha': 0.0004080456580947151, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:21,663] Trial 19 finished with value: 0.4229746621621622 and parameters: {'n_estimators': 184, 'max_depth': 31, 'max_leaf_nodes': 87, 'min_samples_split': 21, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0064530124305953495, 'max_features': 0.7, 'max_samples': 0.7591370979754566, 'criterion': 'gini', 'min_impurity_decrease': 0.0006652513106724712, 'ccp_alpha': 0.0032026506668281496, 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:23,503] Trial 20 finished with value: 0.0 and parameters: {'n_estimators': 253, 'max_depth': 13, 'max_leaf_nodes': 152, 'min_samples_split': 21, 'min_samples_leaf': 12, 'min_weight_fraction_leaf': 0.0014674051397175606, 'max_features': 'log2', 'max_samples': 0.8430713275297996, 'criterion': 'gini', 'min_impurity_decrease': 0.0009794481017464485, 'ccp_alpha': 0.002173977827786409, 'class_weight': 'balanced_subsample'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:25,381] Trial 21 finished with value: 0.44775135052615184 and parameters: {'n_estimators': 330, 'max_depth': 39, 'max_leaf_nodes': 248, 'min_samples_split': 11, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.009574670489905164, 'max_features': 0.5, 'max_samples': 0.7806927057375393, 'criterion': 'gini', 'min_impurity_decrease': 0.0004492013967316687, 'ccp_alpha': 0.0014125689876448412, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:26,854] Trial 22 finished with value: 0.4261823545870418 and parameters: {'n_estimators': 324, 'max_depth': 39, 'max_leaf_nodes': 245, 'min_samples_split': 9, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.007149065148652139, 'max_features': 0.5, 'max_samples': 0.7731716250009738, 'criterion': 'gini', 'min_impurity_decrease': 0.0004374679053290128, 'ccp_alpha': 0.0013745092280764307, 'class_weight': 'balanced'}. Best is trial 11 with value: 0.45855313355113353.
# [I 2026-01-22 15:19:28,746] Trial 23 finished with value: 0.46169755080262864 and parameters: {'n_estimators': 425, 'max_depth': 44, 'max_leaf_nodes': 206, 'min_samples_split': 13, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.009716056872661867, 'max_features': 0.5, 'max_samples': 0.6956834798310512, 'criterion': 'gini', 'min_impurity_decrease': 0.00037244724847514067, 'ccp_alpha': 0.0006173941849269865, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:30,788] Trial 24 finished with value: 0.0 and parameters: {'n_estimators': 497, 'max_depth': 43, 'max_leaf_nodes': 209, 'min_samples_split': 14, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.01692211702697834, 'max_features': 'log2', 'max_samples': 0.654880742741248, 'criterion': 'gini', 'min_impurity_decrease': 0.0010572071914555726, 'ccp_alpha': 0.000502285029895766, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:32,346] Trial 25 finished with value: 0.45893031923227573 and parameters: {'n_estimators': 423, 'max_depth': 45, 'max_leaf_nodes': 211, 'min_samples_split': 6, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.004248610845486856, 'max_features': 0.5, 'max_samples': 0.6840819260553908, 'criterion': 'gini', 'min_impurity_decrease': 0.0002955824764140834, 'ccp_alpha': 0.0004461568191201661, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:33,974] Trial 26 finished with value: 0.4441451816913688 and parameters: {'n_estimators': 436, 'max_depth': 45, 'max_leaf_nodes': 188, 'min_samples_split': 5, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.0036113957531492737, 'max_features': 0.5, 'max_samples': 0.6827910799936344, 'criterion': 'entropy', 'min_impurity_decrease': 0.0019867252209478303, 'ccp_alpha': 0.0020838075610755723, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:35,904] Trial 27 finished with value: 0.4396298675378893 and parameters: {'n_estimators': 438, 'max_depth': 45, 'max_leaf_nodes': 221, 'min_samples_split': 6, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.015523645348325201, 'max_features': 0.5, 'max_samples': 0.6632636309472303, 'criterion': 'gini', 'min_impurity_decrease': 0.0009254898473143655, 'ccp_alpha': 0.0006622197199150106, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:37,492] Trial 28 finished with value: 0.42922189540189537 and parameters: {'n_estimators': 429, 'max_depth': 32, 'max_leaf_nodes': 155, 'min_samples_split': 13, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.0024335953924824565, 'max_features': 0.5, 'max_samples': 0.7232156947861148, 'criterion': 'gini', 'min_impurity_decrease': 0.0016339595503376836, 'ccp_alpha': 0.000263674500646817, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:39,397] Trial 29 finished with value: 0.43386350550365665 and parameters: {'n_estimators': 466, 'max_depth': 45, 'max_leaf_nodes': 197, 'min_samples_split': 2, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.008810758776350722, 'max_features': 0.5, 'max_samples': 0.6073006529573675, 'criterion': 'gini', 'min_impurity_decrease': 0.00038845939982437875, 'ccp_alpha': 0.00103879904780187, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:41,023] Trial 30 finished with value: 0.0 and parameters: {'n_estimators': 401, 'max_depth': 23, 'max_leaf_nodes': 258, 'min_samples_split': 7, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.02688510191726569, 'max_features': 'log2', 'max_samples': 0.630721825503299, 'criterion': 'gini', 'min_impurity_decrease': 0.0013812038415208843, 'ccp_alpha': 0.004909270315731907, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:42,182] Trial 31 finished with value: 0.44236384108550875 and parameters: {'n_estimators': 223, 'max_depth': 38, 'max_leaf_nodes': 225, 'min_samples_split': 18, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.005015733719166121, 'max_features': 0.7, 'max_samples': 0.8410818481044704, 'criterion': 'gini', 'min_impurity_decrease': 0.00015295118957982267, 'ccp_alpha': 0.0006371107956418772, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:43,964] Trial 32 finished with value: 0.4229746621621622 and parameters: {'n_estimators': 234, 'max_depth': 47, 'max_leaf_nodes': 206, 'min_samples_split': 22, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.00888199125946467, 'max_features': 0.5, 'max_samples': 0.677953717734273, 'criterion': 'gini', 'min_impurity_decrease': 0.0008156161544933454, 'ccp_alpha': 0.0007668285212866396, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:45,566] Trial 33 finished with value: 0.0 and parameters: {'n_estimators': 179, 'max_depth': 36, 'max_leaf_nodes': 181, 'min_samples_split': 12, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.020740135086306934, 'max_features': 'sqrt', 'max_samples': 0.7172558392466961, 'criterion': 'gini', 'min_impurity_decrease': 0.0002585733624948313, 'ccp_alpha': 0.0012642890328177663, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:48,248] Trial 34 finished with value: 0.4276967165051226 and parameters: {'n_estimators': 468, 'max_depth': 42, 'max_leaf_nodes': 232, 'min_samples_split': 36, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.0035584244838233322, 'max_features': 0.7, 'max_samples': 0.9049972765509223, 'criterion': 'gini', 'min_impurity_decrease': 4.985797183389315e-06, 'ccp_alpha': 0.0024851140220656194, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:51,408] Trial 35 finished with value: 0.0 and parameters: {'n_estimators': 393, 'max_depth': 32, 'max_leaf_nodes': 167, 'min_samples_split': 28, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.012424325302440255, 'max_features': 0.5, 'max_samples': 0.6867440481858498, 'criterion': 'gini', 'min_impurity_decrease': 0.00307192569810801, 'ccp_alpha': 0.00037036421417710593, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:52,869] Trial 36 finished with value: 0.44293136750074247 and parameters: {'n_estimators': 198, 'max_depth': 47, 'max_leaf_nodes': 258, 'min_samples_split': 24, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.005461082382719331, 'max_features': 0.7, 'max_samples': 0.7301906662915154, 'criterion': 'gini', 'min_impurity_decrease': 0.0005308080196518986, 'ccp_alpha': 0.0009527457914918658, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:53,527] Trial 37 finished with value: 0.42371901188693023 and parameters: {'n_estimators': 104, 'max_depth': 24, 'max_leaf_nodes': 213, 'min_samples_split': 8, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.009606325429815026, 'max_features': 0.5, 'max_samples': 0.6983448562950793, 'criterion': 'gini', 'min_impurity_decrease': 0.002767158060889559, 'ccp_alpha': 6.57824601443172e-05, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:55,994] Trial 38 finished with value: 0.0 and parameters: {'n_estimators': 322, 'max_depth': 37, 'max_leaf_nodes': 236, 'min_samples_split': 15, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.014027244289804435, 'max_features': 'log2', 'max_samples': 0.8204158150928217, 'criterion': 'entropy', 'min_impurity_decrease': 0.003576348962682608, 'ccp_alpha': 0.001541249194185356, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:56,771] Trial 39 finished with value: 0.45194115156630893 and parameters: {'n_estimators': 136, 'max_depth': 50, 'max_leaf_nodes': 197, 'min_samples_split': 4, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.0001241890971908806, 'max_features': 0.5, 'max_samples': 0.7887423150948641, 'criterion': 'gini', 'min_impurity_decrease': 0.0011876308795310765, 'ccp_alpha': 0.0026310762982031995, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:57,217] Trial 40 finished with value: 0.0 and parameters: {'n_estimators': 51, 'max_depth': 50, 'max_leaf_nodes': 137, 'min_samples_split': 4, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.03420500672299005, 'max_features': 0.5, 'max_samples': 0.8662305535660647, 'criterion': 'gini', 'min_impurity_decrease': 0.0012587232605881932, 'ccp_alpha': 0.0029738407478073453, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:58,268] Trial 41 finished with value: 0.4313351648816222 and parameters: {'n_estimators': 150, 'max_depth': 44, 'max_leaf_nodes': 202, 'min_samples_split': 10, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.002828823142049383, 'max_features': 0.5, 'max_samples': 0.7726697625269675, 'criterion': 'gini', 'min_impurity_decrease': 0.00031211224072032857, 'ccp_alpha': 0.0026847045228426724, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:58,903] Trial 42 finished with value: 0.4069542143306097 and parameters: {'n_estimators': 85, 'max_depth': 48, 'max_leaf_nodes': 185, 'min_samples_split': 4, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.0002516880724716397, 'max_features': 0.5, 'max_samples': 0.922482734065261, 'criterion': 'gini', 'min_impurity_decrease': 0.0006610288074162494, 'ccp_alpha': 0.00397881057903895, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:19:59,984] Trial 43 finished with value: 0.44288135427291986 and parameters: {'n_estimators': 167, 'max_depth': 40, 'max_leaf_nodes': 217, 'min_samples_split': 19, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.003997791811689978, 'max_features': 0.5, 'max_samples': 0.7915987260228154, 'criterion': 'gini', 'min_impurity_decrease': 0.0012052861797186157, 'ccp_alpha': 0.002540477236547259, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:00,774] Trial 44 finished with value: 0.4419888438990461 and parameters: {'n_estimators': 129, 'max_depth': 47, 'max_leaf_nodes': 159, 'min_samples_split': 8, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.00012395087757356097, 'max_features': 'sqrt', 'max_samples': 0.7416013431091846, 'criterion': 'gini', 'min_impurity_decrease': 0.0016351212755550274, 'ccp_alpha': 0.0029734615911023547, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:01,986] Trial 45 finished with value: 0.4332034002824145 and parameters: {'n_estimators': 206, 'max_depth': 43, 'max_leaf_nodes': 203, 'min_samples_split': 27, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.007204007360700158, 'max_features': 0.7, 'max_samples': 0.8093439752609809, 'criterion': 'gini', 'min_impurity_decrease': 0.000781000108162207, 'ccp_alpha': 0.0018950777568931172, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:02,868] Trial 46 finished with value: 0.45091924625234786 and parameters: {'n_estimators': 95, 'max_depth': 49, 'max_leaf_nodes': 178, 'min_samples_split': 12, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.010764553107165582, 'max_features': 0.5, 'max_samples': 0.8610663355221734, 'criterion': 'entropy', 'min_impurity_decrease': 0.0002332152471385196, 'ccp_alpha': 0.0037962339415263746, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:03,496] Trial 47 finished with value: 0.43204127024672073 and parameters: {'n_estimators': 68, 'max_depth': 50, 'max_leaf_nodes': 178, 'min_samples_split': 12, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.010363407696191184, 'max_features': 0.5, 'max_samples': 0.8619969264559261, 'criterion': 'entropy', 'min_impurity_decrease': 0.00022383800320675332, 'ccp_alpha': 0.003937140381139806, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:04,380] Trial 48 finished with value: 0.0 and parameters: {'n_estimators': 100, 'max_depth': 50, 'max_leaf_nodes': 114, 'min_samples_split': 10, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.01905670133131107, 'max_features': 0.5, 'max_samples': 0.9133115379749912, 'criterion': 'entropy', 'min_impurity_decrease': 0.002321230959999289, 'ccp_alpha': 0.00433703251763293, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:05,117] Trial 49 finished with value: 0.4341948892644967 and parameters: {'n_estimators': 132, 'max_depth': 47, 'max_leaf_nodes': 190, 'min_samples_split': 16, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.013463090637690911, 'max_features': 0.5, 'max_samples': 0.9515645579924666, 'criterion': 'entropy', 'min_impurity_decrease': 0.0005760112467261805, 'ccp_alpha': 0.0035808356034015953, 'class_weight': 'balanced'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:07,279] Trial 50 finished with value: 0.0 and parameters: {'n_estimators': 413, 'max_depth': 29, 'max_leaf_nodes': 166, 'min_samples_split': 6, 'min_samples_leaf': 3, 'min_weight_fraction_leaf': 0.02385053515816902, 'max_features': 0.5, 'max_samples': 0.8266778916771886, 'criterion': 'entropy', 'min_impurity_decrease': 0.0011315246171790896, 'ccp_alpha': 0.00374913639002403, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:08,134] Trial 51 finished with value: 0.4354331323443008 and parameters: {'n_estimators': 152, 'max_depth': 41, 'max_leaf_nodes': 237, 'min_samples_split': 13, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.002607836134640975, 'max_features': 'log2', 'max_samples': 0.8810858802778679, 'criterion': 'entropy', 'min_impurity_decrease': 0.0002368502298850506, 'ccp_alpha': 0.003176406829603994, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:09,569] Trial 52 finished with value: 0.4069542143306097 and parameters: {'n_estimators': 263, 'max_depth': 45, 'max_leaf_nodes': 197, 'min_samples_split': 3, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.005247539441916915, 'max_features': 0.7, 'max_samples': 0.7900985616059731, 'criterion': 'gini', 'min_impurity_decrease': 3.146139584708074e-05, 'ccp_alpha': 0.004485100758830679, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:10,504] Trial 53 finished with value: 0.45348088860994523 and parameters: {'n_estimators': 172, 'max_depth': 35, 'max_leaf_nodes': 219, 'min_samples_split': 17, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.0075878911305254666, 'max_features': 0.5, 'max_samples': 0.6389184409511002, 'criterion': 'entropy', 'min_impurity_decrease': 0.00043219231906445907, 'ccp_alpha': 0.0011164797733457068, 'class_weight': 'balanced_subsample'}. Best is trial 23 with value: 0.46169755080262864.
# [I 2026-01-22 15:20:11,448] Trial 54 finished with value: 0.46464914361481374 and parameters: {'n_estimators': 168, 'max_depth': 28, 'max_leaf_nodes': 219, 'min_samples_split': 19, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.011557542732050577, 'max_features': 0.5, 'max_samples': 0.6302254327186754, 'criterion': 'entropy', 'min_impurity_decrease': 0.0008560622922114843, 'ccp_alpha': 0.002312510662017114, 'class_weight': 'balanced_subsample'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:12,435] Trial 55 finished with value: 0.43295439784183315 and parameters: {'n_estimators': 173, 'max_depth': 26, 'max_leaf_nodes': 229, 'min_samples_split': 19, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.007807894659109263, 'max_features': 0.5, 'max_samples': 0.6273135680117949, 'criterion': 'entropy', 'min_impurity_decrease': 0.0008939072426061147, 'ccp_alpha': 0.0023874598530034246, 'class_weight': 'balanced_subsample'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:13,877] Trial 56 finished with value: 0.4334236837635009 and parameters: {'n_estimators': 377, 'max_depth': 30, 'max_leaf_nodes': 257, 'min_samples_split': 23, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.015524000494154241, 'max_features': 0.5, 'max_samples': 0.6503821183545145, 'criterion': 'entropy', 'min_impurity_decrease': 0.0005256106038297592, 'ccp_alpha': 0.0018622608525681967, 'class_weight': 'balanced'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:15,528] Trial 57 finished with value: 0.4391395317686107 and parameters: {'n_estimators': 301, 'max_depth': 26, 'max_leaf_nodes': 219, 'min_samples_split': 17, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0013752838068123883, 'max_features': 0.5, 'max_samples': 0.6433208873945093, 'criterion': 'entropy', 'min_impurity_decrease': 0.0017799650103094075, 'ccp_alpha': 0.0022428227745807943, 'class_weight': 'balanced_subsample'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:17,914] Trial 58 finished with value: 0.0 and parameters: {'n_estimators': 462, 'max_depth': 33, 'max_leaf_nodes': 246, 'min_samples_split': 19, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.04250377266313175, 'max_features': 'log2', 'max_samples': 0.6691921139517912, 'criterion': 'entropy', 'min_impurity_decrease': 0.0007843197809374858, 'ccp_alpha': 0.0016313570824595365, 'class_weight': 'balanced'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:19,291] Trial 59 finished with value: 0.4354331323443008 and parameters: {'n_estimators': 238, 'max_depth': 28, 'max_leaf_nodes': 270, 'min_samples_split': 15, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 0.006337215307500265, 'max_features': 'sqrt', 'max_samples': 0.6175268063529313, 'criterion': 'entropy', 'min_impurity_decrease': 0.0003635956742651105, 'ccp_alpha': 0.0011471475222263171, 'class_weight': 'balanced'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:20,641] Trial 60 finished with value: 0.44775135052615184 and parameters: {'n_estimators': 162, 'max_depth': 35, 'max_leaf_nodes': 213, 'min_samples_split': 20, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.011854396750639647, 'max_features': 0.5, 'max_samples': 0.6928789603239678, 'criterion': 'entropy', 'min_impurity_decrease': 0.0014227140832505068, 'ccp_alpha': 0.0008165740413718136, 'class_weight': 'balanced_subsample'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:22,125] Trial 61 finished with value: 0.42318562462213666 and parameters: {'n_estimators': 118, 'max_depth': 20, 'max_leaf_nodes': 176, 'min_samples_split': 17, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.010816584737232592, 'max_features': 0.5, 'max_samples': 0.6064139745275426, 'criterion': 'entropy', 'min_impurity_decrease': 0.0004415227865217531, 'ccp_alpha': 0.0002955728596176046, 'class_weight': 'balanced_subsample'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:23,539] Trial 62 finished with value: 0.45194115156630893 and parameters: {'n_estimators': 135, 'max_depth': 49, 'max_leaf_nodes': 198, 'min_samples_split': 14, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.007885626797838578, 'max_features': 0.5, 'max_samples': 0.7044395941558611, 'criterion': 'entropy', 'min_impurity_decrease': 0.0010011978838236281, 'ccp_alpha': 0.00276315963121753, 'class_weight': 'balanced_subsample'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:25,024] Trial 63 finished with value: 0.4334433830795276 and parameters: {'n_estimators': 140, 'max_depth': 43, 'max_leaf_nodes': 196, 'min_samples_split': 15, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.0020929825973208076, 'max_features': 0.5, 'max_samples': 0.712961125368058, 'criterion': 'entropy', 'min_impurity_decrease': 0.0009960637731306636, 'ccp_alpha': 0.002801539609648414, 'class_weight': 'balanced_subsample'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:26,653] Trial 64 finished with value: 0.42318562462213666 and parameters: {'n_estimators': 189, 'max_depth': 46, 'max_leaf_nodes': 206, 'min_samples_split': 17, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.008424477213989413, 'max_features': 0.5, 'max_samples': 0.6662733493999777, 'criterion': 'entropy', 'min_impurity_decrease': 0.0013235581757218766, 'ccp_alpha': 0.0020328094806509123, 'class_weight': 'balanced_subsample'}. Best is trial 54 with value: 0.46464914361481374.
# [I 2026-01-22 15:20:29,426] Trial 65 finished with value: 0.4670956694567702 and parameters: {'n_estimators': 344, 'max_depth': 34, 'max_leaf_nodes': 223, 'min_samples_split': 14, 'min_samples_leaf': 14, 'min_weight_fraction_leaf': 0.004726622098265915, 'max_features': 0.5, 'max_samples': 0.6408173676832962, 'criterion': 'entropy', 'min_impurity_decrease': 0.0007161184343391566, 'ccp_alpha': 0.0027890840606104757, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:31,332] Trial 66 finished with value: 0.0 and parameters: {'n_estimators': 377, 'max_depth': 34, 'max_leaf_nodes': 225, 'min_samples_split': 22, 'min_samples_leaf': 15, 'min_weight_fraction_leaf': 0.0043728139307136135, 'max_features': 'log2', 'max_samples': 0.6430961078165526, 'criterion': 'gini', 'min_impurity_decrease': 0.0006641971833240619, 'ccp_alpha': 0.0023278225024344944, 'class_weight': 'balanced'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:33,496] Trial 67 finished with value: 0.4234175941073901 and parameters: {'n_estimators': 415, 'max_depth': 37, 'max_leaf_nodes': 239, 'min_samples_split': 10, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.0042696950805794715, 'max_features': 0.5, 'max_samples': 0.6192575721623552, 'criterion': 'gini', 'min_impurity_decrease': 0.0005617645364721107, 'ccp_alpha': 0.003091539333717373, 'class_weight': 'balanced'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:36,027] Trial 68 finished with value: 0.4313351648816222 and parameters: {'n_estimators': 354, 'max_depth': 30, 'max_leaf_nodes': 221, 'min_samples_split': 6, 'min_samples_leaf': 14, 'min_weight_fraction_leaf': 0.0015265135990323929, 'max_features': 0.5, 'max_samples': 0.6752692598916843, 'criterion': 'entropy', 'min_impurity_decrease': 8.80313876982005e-05, 'ccp_alpha': 0.0025834182684631446, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:37,717] Trial 69 finished with value: 0.416115870538074 and parameters: {'n_estimators': 340, 'max_depth': 11, 'max_leaf_nodes': 70, 'min_samples_split': 8, 'min_samples_leaf': 12, 'min_weight_fraction_leaf': 0.006155782390276852, 'max_features': 'log2', 'max_samples': 0.6549467634541601, 'criterion': 'gini', 'min_impurity_decrease': 0.0007787513618522781, 'ccp_alpha': 0.0005077217428303263, 'class_weight': 'balanced'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:41,103] Trial 70 finished with value: 0.4395549368754049 and parameters: {'n_estimators': 442, 'max_depth': 39, 'max_leaf_nodes': 228, 'min_samples_split': 20, 'min_samples_leaf': 13, 'min_weight_fraction_leaf': 0.0026881100748766015, 'max_features': 0.5, 'max_samples': 0.6433649558099588, 'criterion': 'gini', 'min_impurity_decrease': 0.0004054254562657726, 'ccp_alpha': 0.00016919694789582648, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:42,721] Trial 71 finished with value: 0.45008886770256235 and parameters: {'n_estimators': 205, 'max_depth': 32, 'max_leaf_nodes': 211, 'min_samples_split': 14, 'min_samples_leaf': 1, 'min_weight_fraction_leaf': 0.007201944520751898, 'max_features': 0.5, 'max_samples': 0.700583111357455, 'criterion': 'entropy', 'min_impurity_decrease': 0.0009377767012579046, 'ccp_alpha': 0.0027721356738824336, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:44,178] Trial 72 finished with value: 0.4370141747760645 and parameters: {'n_estimators': 142, 'max_depth': 48, 'max_leaf_nodes': 201, 'min_samples_split': 14, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.008483699905746201, 'max_features': 0.5, 'max_samples': 0.6000186108786478, 'criterion': 'entropy', 'min_impurity_decrease': 0.001122423999465817, 'ccp_alpha': 0.0033628245382639156, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:46,406] Trial 73 finished with value: 0.4418270547207549 and parameters: {'n_estimators': 305, 'max_depth': 35, 'max_leaf_nodes': 188, 'min_samples_split': 16, 'min_samples_leaf': 11, 'min_weight_fraction_leaf': 0.005148948634495197, 'max_features': 0.5, 'max_samples': 0.7510905194666202, 'criterion': 'entropy', 'min_impurity_decrease': 0.0007036341799439862, 'ccp_alpha': 0.0028875797433496777, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:47,173] Trial 74 finished with value: 0.0 and parameters: {'n_estimators': 113, 'max_depth': 41, 'max_leaf_nodes': 216, 'min_samples_split': 18, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.031343388574973166, 'max_features': 0.5, 'max_samples': 0.7285266166141847, 'criterion': 'entropy', 'min_impurity_decrease': 0.0010519642115161612, 'ccp_alpha': 0.000654092983455002, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:49,648] Trial 75 finished with value: 0.3259618632794544 and parameters: {'n_estimators': 450, 'max_depth': 27, 'max_leaf_nodes': 192, 'min_samples_split': 13, 'min_samples_leaf': 4, 'min_weight_fraction_leaf': 2.3832526913224314e-05, 'max_features': 'sqrt', 'max_samples': 0.6874503384535516, 'criterion': 'entropy', 'min_impurity_decrease': 0.00015578571363872786, 'ccp_alpha': 0.0024468963205933857, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:50,383] Trial 76 finished with value: 0.0 and parameters: {'n_estimators': 183, 'max_depth': 24, 'max_leaf_nodes': 252, 'min_samples_split': 16, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.009836943402198595, 'max_features': 0.5, 'max_samples': 0.624096406757727, 'criterion': 'gini', 'min_impurity_decrease': 0.00426156020972329, 'ccp_alpha': 0.002609755075927064, 'class_weight': 'balanced'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:52,191] Trial 77 finished with value: 0.3799259820158504 and parameters: {'n_estimators': 487, 'max_depth': 44, 'max_leaf_nodes': 207, 'min_samples_split': 11, 'min_samples_leaf': 2, 'min_weight_fraction_leaf': 0.0035369975283829156, 'max_features': 0.5, 'max_samples': 0.7070785070314658, 'criterion': 'entropy', 'min_impurity_decrease': 0.00032415859885041377, 'ccp_alpha': 0.0020415806431990442, 'class_weight': 'balanced'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:53,431] Trial 78 finished with value: 0.4275875806049952 and parameters: {'n_estimators': 218, 'max_depth': 49, 'max_leaf_nodes': 232, 'min_samples_split': 18, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.015402811112585067, 'max_features': 0.5, 'max_samples': 0.6592101796242116, 'criterion': 'gini', 'min_impurity_decrease': 0.0014673913280908017, 'ccp_alpha': 0.0022487371697749972, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:54,988] Trial 79 finished with value: 0.0 and parameters: {'n_estimators': 418, 'max_depth': 38, 'max_leaf_nodes': 184, 'min_samples_split': 2, 'min_samples_leaf': 5, 'min_weight_fraction_leaf': 0.013002166583455155, 'max_features': 'log2', 'max_samples': 0.6381272548679959, 'criterion': 'gini', 'min_impurity_decrease': 0.000862335239737662, 'ccp_alpha': 0.0010303050735563683, 'class_weight': 'balanced'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:56,778] Trial 80 finished with value: 0.45348088860994523 and parameters: {'n_estimators': 284, 'max_depth': 46, 'max_leaf_nodes': 198, 'min_samples_split': 5, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.006831325936120287, 'max_features': 0.5, 'max_samples': 0.6741570956533618, 'criterion': 'entropy', 'min_impurity_decrease': 0.0005173015660042647, 'ccp_alpha': 0.0015119337423117525, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:20:58,764] Trial 81 finished with value: 0.45177850209582593 and parameters: {'n_estimators': 284, 'max_depth': 46, 'max_leaf_nodes': 201, 'min_samples_split': 4, 'min_samples_leaf': 6, 'min_weight_fraction_leaf': 0.00739397731557743, 'max_features': 0.5, 'max_samples': 0.6769553499034807, 'criterion': 'entropy', 'min_impurity_decrease': 0.0005181754763701979, 'ccp_alpha': 0.0014264108863910846, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:21:01,113] Trial 82 finished with value: 0.45697303950928947 and parameters: {'n_estimators': 355, 'max_depth': 49, 'max_leaf_nodes': 221, 'min_samples_split': 5, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.005323610684940147, 'max_features': 0.5, 'max_samples': 0.668963661816901, 'criterion': 'entropy', 'min_impurity_decrease': 0.0006290967248307681, 'ccp_alpha': 0.0012268152329187934, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:21:03,743] Trial 83 finished with value: 0.46397127413127415 and parameters: {'n_estimators': 355, 'max_depth': 42, 'max_leaf_nodes': 222, 'min_samples_split': 7, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.00579601920874802, 'max_features': 0.5, 'max_samples': 0.6524289635741126, 'criterion': 'entropy', 'min_impurity_decrease': 0.0006380030505176717, 'ccp_alpha': 0.0013097751855646583, 'class_weight': 'balanced_subsample'}. Best is trial 65 with value: 0.4670956694567702.
# [I 2026-01-22 15:21:06,107] Trial 84 finished with value: 0.46757692052242156 and parameters: {'n_estimators': 361, 'max_depth': 42, 'max_leaf_nodes': 223, 'min_samples_split': 7, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.005814155089056204, 'max_features': 0.5, 'max_samples': 0.6346966809256905, 'criterion': 'entropy', 'min_impurity_decrease': 0.00033697408297202967, 'ccp_alpha': 0.0012342477465690136, 'class_weight': 'balanced_subsample'}. Best is trial 84 with value: 0.46757692052242156.
# [I 2026-01-22 15:21:08,627] Trial 85 finished with value: 0.46576710953659795 and parameters: {'n_estimators': 362, 'max_depth': 42, 'max_leaf_nodes': 223, 'min_samples_split': 7, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.0054014433180781295, 'max_features': 0.5, 'max_samples': 0.6331142631280824, 'criterion': 'entropy', 'min_impurity_decrease': 0.0003369590161553762, 'ccp_alpha': 0.0017239736866894507, 'class_weight': 'balanced_subsample'}. Best is trial 84 with value: 0.46757692052242156.
# [I 2026-01-22 15:21:11,015] Trial 86 finished with value: 0.44293136750074247 and parameters: {'n_estimators': 363, 'max_depth': 42, 'max_leaf_nodes': 238, 'min_samples_split': 7, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.005211147582347361, 'max_features': 0.5, 'max_samples': 0.6512952801582288, 'criterion': 'entropy', 'min_impurity_decrease': 0.0001331844242869134, 'ccp_alpha': 0.0017162860705568453, 'class_weight': 'balanced_subsample'}. Best is trial 84 with value: 0.46757692052242156.
# [I 2026-01-22 15:21:13,608] Trial 87 finished with value: 0.4662109893883578 and parameters: {'n_estimators': 395, 'max_depth': 40, 'max_leaf_nodes': 242, 'min_samples_split': 9, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.0036250875561975827, 'max_features': 0.5, 'max_samples': 0.6178393133659278, 'criterion': 'entropy', 'min_impurity_decrease': 0.0002638719171819647, 'ccp_alpha': 0.00130177650553023, 'class_weight': 'balanced_subsample'}. Best is trial 84 with value: 0.46757692052242156.
# [I 2026-01-22 15:21:15,704] Trial 88 finished with value: 0.44984250125125125 and parameters: {'n_estimators': 335, 'max_depth': 40, 'max_leaf_nodes': 270, 'min_samples_split': 9, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.002991767286029649, 'max_features': 'log2', 'max_samples': 0.6116470781614276, 'criterion': 'entropy', 'min_impurity_decrease': 3.080630313882703e-06, 'ccp_alpha': 0.0012843268587083862, 'class_weight': 'balanced_subsample'}. Best is trial 84 with value: 0.46757692052242156.
# [I 2026-01-22 15:21:17,764] Trial 89 finished with value: 0.4370141747760645 and parameters: {'n_estimators': 399, 'max_depth': 40, 'max_leaf_nodes': 254, 'min_samples_split': 9, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.009385869844933354, 'max_features': 0.5, 'max_samples': 0.6297286193886159, 'criterion': 'entropy', 'min_impurity_decrease': 0.0002952606920764292, 'ccp_alpha': 0.0017111083451795753, 'class_weight': 'balanced_subsample'}. Best is trial 84 with value: 0.46757692052242156.
# [I 2026-01-22 15:21:19,888] Trial 90 finished with value: 0.44984250125125125 and parameters: {'n_estimators': 393, 'max_depth': 42, 'max_leaf_nodes': 284, 'min_samples_split': 7, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.0017721271852397394, 'max_features': 'sqrt', 'max_samples': 0.6160856993957684, 'criterion': 'entropy', 'min_impurity_decrease': 0.00016951352089306267, 'ccp_alpha': 0.0019664628660352027, 'class_weight': 'balanced_subsample'}. Best is trial 84 with value: 0.46757692052242156.
# [I 2026-01-22 15:21:21,792] Trial 91 finished with value: 0.4297280159002286 and parameters: {'n_estimators': 364, 'max_depth': 44, 'max_leaf_nodes': 241, 'min_samples_split': 5, 'min_samples_leaf': 13, 'min_weight_fraction_leaf': 0.004380407298779032, 'max_features': 0.5, 'max_samples': 0.6616205869997627, 'criterion': 'entropy', 'min_impurity_decrease': 0.0006081596005681026, 'ccp_alpha': 0.0015478601932191456, 'class_weight': 'balanced_subsample'}. Best is trial 84 with value: 0.46757692052242156.
# [I 2026-01-22 15:21:23,866] Trial 92 finished with value: 0.4694008708708709 and parameters: {'n_estimators': 385, 'max_depth': 43, 'max_leaf_nodes': 223, 'min_samples_split': 7, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.005434865361122539, 'max_features': 0.5, 'max_samples': 0.6490478726099026, 'criterion': 'entropy', 'min_impurity_decrease': 0.0003175839398434227, 'ccp_alpha': 0.0009023946115710025, 'class_weight': 'balanced_subsample'}. Best is trial 92 with value: 0.4694008708708709.
# [I 2026-01-22 15:21:25,947] Trial 93 finished with value: 0.4514165583924088 and parameters: {'n_estimators': 387, 'max_depth': 37, 'max_leaf_nodes': 232, 'min_samples_split': 7, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0034665087062129593, 'max_features': 0.5, 'max_samples': 0.6344970761914026, 'criterion': 'entropy', 'min_impurity_decrease': 0.000327728156147326, 'ccp_alpha': 0.0008929408728518596, 'class_weight': 'balanced_subsample'}. Best is trial 92 with value: 0.4694008708708709.
# [I 2026-01-22 15:21:29,020] Trial 94 finished with value: 0.4450950603062078 and parameters: {'n_estimators': 425, 'max_depth': 43, 'max_leaf_nodes': 225, 'min_samples_split': 11, 'min_samples_leaf': 11, 'min_weight_fraction_leaf': 0.006245746314722926, 'max_features': 0.5, 'max_samples': 0.6507916944253854, 'criterion': 'entropy', 'min_impurity_decrease': 0.00020168054920240136, 'ccp_alpha': 0.0007677869191010636, 'class_weight': 'balanced_subsample'}. Best is trial 92 with value: 0.4694008708708709.
# [I 2026-01-22 15:21:31,351] Trial 95 finished with value: 0.42170303205241355 and parameters: {'n_estimators': 345, 'max_depth': 39, 'max_leaf_nodes': 247, 'min_samples_split': 8, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.011237677715620824, 'max_features': 0.5, 'max_samples': 0.6037583577935097, 'criterion': 'entropy', 'min_impurity_decrease': 0.00046218254846655885, 'ccp_alpha': 0.0013480806547822802, 'class_weight': 'balanced_subsample'}. Best is trial 92 with value: 0.4694008708708709.
# ...
# [I 2026-01-22 15:32:53,116] Trial 469 finished with value: 0.45337969694475333 and parameters: {'n_estimators': 286, 'max_depth': 20, 'max_leaf_nodes': 105, 'min_samples_split': 4, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.005418240939816873, 'max_features': 0.7, 'max_samples': 0.6578837780586868, 'criterion': 'entropy', 'min_impurity_decrease': 0.0006186371069825053, 'ccp_alpha': 0.002628224935919259, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:32:55,032] Trial 470 finished with value: 0.47001174785768307 and parameters: {'n_estimators': 259, 'max_depth': 27, 'max_leaf_nodes': 112, 'min_samples_split': 3, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0031806296062196174, 'max_features': 0.5, 'max_samples': 0.6668114741941553, 'criterion': 'entropy', 'min_impurity_decrease': 0.00019479434786652717, 'ccp_alpha': 0.00250689974980833, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:32:56,571] Trial 471 finished with value: 0.4417463714891362 and parameters: {'n_estimators': 266, 'max_depth': 21, 'max_leaf_nodes': 113, 'min_samples_split': 2, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0018487303146227574, 'max_features': 0.5, 'max_samples': 0.6799304509347698, 'criterion': 'entropy', 'min_impurity_decrease': 0.0004941155471338024, 'ccp_alpha': 0.0023396022480862266, 'class_weight': 'balanced'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:32:58,627] Trial 472 finished with value: 0.4249777350827562 and parameters: {'n_estimators': 296, 'max_depth': 28, 'max_leaf_nodes': 122, 'min_samples_split': 4, 'min_samples_leaf': 7, 'min_weight_fraction_leaf': 0.0008509669822255627, 'max_features': 0.5, 'max_samples': 0.6940805046277513, 'criterion': 'gini', 'min_impurity_decrease': 0.00024465786008802355, 'ccp_alpha': 0.0032863062435017605, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:00,354] Trial 473 finished with value: 0.0 and parameters: {'n_estimators': 243, 'max_depth': 26, 'max_leaf_nodes': 129, 'min_samples_split': 2, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.02799898325996881, 'max_features': 0.5, 'max_samples': 0.6747051818475673, 'criterion': 'entropy', 'min_impurity_decrease': 0.00038659298335906546, 'ccp_alpha': 0.0022298775095539076, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:01,529] Trial 474 finished with value: 0.4215527744034456 and parameters: {'n_estimators': 204, 'max_depth': 31, 'max_leaf_nodes': 118, 'min_samples_split': 38, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.003908158800873837, 'max_features': 'log2', 'max_samples': 0.6832349672101744, 'criterion': 'entropy', 'min_impurity_decrease': 0.00016573503156421757, 'ccp_alpha': 0.002109068009213455, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:03,088] Trial 475 finished with value: 0.4249777350827562 and parameters: {'n_estimators': 278, 'max_depth': 23, 'max_leaf_nodes': 135, 'min_samples_split': 5, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.0017822197239286668, 'max_features': 0.5, 'max_samples': 0.8424947170511901, 'criterion': 'entropy', 'min_impurity_decrease': 0.002098321598995186, 'ccp_alpha': 0.0021762492799575987, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:04,360] Trial 476 finished with value: 0.45327180750340984 and parameters: {'n_estimators': 215, 'max_depth': 17, 'max_leaf_nodes': 128, 'min_samples_split': 3, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0027102209991038315, 'max_features': 0.5, 'max_samples': 0.6398972031367433, 'criterion': 'entropy', 'min_impurity_decrease': 0.00028873404921163815, 'ccp_alpha': 0.0023897884536118958, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:05,725] Trial 477 finished with value: 0.40048882414882414 and parameters: {'n_estimators': 231, 'max_depth': 27, 'max_leaf_nodes': 107, 'min_samples_split': 3, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.0007900247413917508, 'max_features': 0.5, 'max_samples': 0.7040328214015126, 'criterion': 'entropy', 'min_impurity_decrease': 4.3485896779896444e-08, 'ccp_alpha': 0.001996668906310369, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:07,310] Trial 478 finished with value: 0.4514165583924088 and parameters: {'n_estimators': 252, 'max_depth': 24, 'max_leaf_nodes': 122, 'min_samples_split': 4, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.0023471202177778724, 'max_features': 0.5, 'max_samples': 0.6514168298359367, 'criterion': 'entropy', 'min_impurity_decrease': 0.00014443783107980006, 'ccp_alpha': 0.0020845726388710054, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:09,390] Trial 479 finished with value: 0.44293136750074247 and parameters: {'n_estimators': 284, 'max_depth': 25, 'max_leaf_nodes': 134, 'min_samples_split': 2, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.004729237302958383, 'max_features': 0.5, 'max_samples': 0.6706974493446973, 'criterion': 'entropy', 'min_impurity_decrease': 0.00025144871317913514, 'ccp_alpha': 0.002271091169912573, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:11,523] Trial 480 finished with value: 0.44360790180167364 and parameters: {'n_estimators': 271, 'max_depth': 22, 'max_leaf_nodes': 141, 'min_samples_split': 5, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0009855268540919185, 'max_features': 0.5, 'max_samples': 0.692467713519015, 'criterion': 'entropy', 'min_impurity_decrease': 0.00055898546423754, 'ccp_alpha': 0.0019073751677261908, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:13,785] Trial 481 finished with value: 0.46433359904097643 and parameters: {'n_estimators': 314, 'max_depth': 19, 'max_leaf_nodes': 115, 'min_samples_split': 3, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0035776530960415797, 'max_features': 0.5, 'max_samples': 0.6621036175271663, 'criterion': 'entropy', 'min_impurity_decrease': 0.0007058067986965142, 'ccp_alpha': 0.002049325917420103, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:15,962] Trial 482 finished with value: 0.43458585158453084 and parameters: {'n_estimators': 296, 'max_depth': 26, 'max_leaf_nodes': 132, 'min_samples_split': 35, 'min_samples_leaf': 11, 'min_weight_fraction_leaf': 0.0017683809700131856, 'max_features': 0.5, 'max_samples': 0.6837901708610721, 'criterion': 'entropy', 'min_impurity_decrease': 0.0003771258674336475, 'ccp_alpha': 0.0018451352720256192, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:17,884] Trial 483 finished with value: 0.45327180750340984 and parameters: {'n_estimators': 261, 'max_depth': 24, 'max_leaf_nodes': 290, 'min_samples_split': 4, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.0007669650351049037, 'max_features': 0.5, 'max_samples': 0.6741306729537705, 'criterion': 'entropy', 'min_impurity_decrease': 9.099963561841954e-05, 'ccp_alpha': 0.0021744783472839434, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:19,670] Trial 484 finished with value: 0.45893031923227573 and parameters: {'n_estimators': 239, 'max_depth': 23, 'max_leaf_nodes': 127, 'min_samples_split': 2, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 5.182476098396975e-05, 'max_features': 0.5, 'max_samples': 0.6982520135389896, 'criterion': 'entropy', 'min_impurity_decrease': 0.00022810320590097087, 'ccp_alpha': 0.0026810712495452787, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:21,886] Trial 485 finished with value: 0.41723625346500354 and parameters: {'n_estimators': 289, 'max_depth': 25, 'max_leaf_nodes': 272, 'min_samples_split': 6, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.0028977199067054355, 'max_features': 'sqrt', 'max_samples': 0.7147719440265075, 'criterion': 'entropy', 'min_impurity_decrease': 0.00014076736679884765, 'ccp_alpha': 0.0019639946375775846, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:24,274] Trial 486 finished with value: 0.46433359904097643 and parameters: {'n_estimators': 306, 'max_depth': 27, 'max_leaf_nodes': 138, 'min_samples_split': 3, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.0018998068542101258, 'max_features': 0.5, 'max_samples': 0.6883850220439768, 'criterion': 'entropy', 'min_impurity_decrease': 0.00047818082594634325, 'ccp_alpha': 0.00309556441343226, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:26,464] Trial 487 finished with value: 0.45337969694475333 and parameters: {'n_estimators': 273, 'max_depth': 21, 'max_leaf_nodes': 123, 'min_samples_split': 4, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.003905058019252207, 'max_features': 0.5, 'max_samples': 0.6666210834784443, 'criterion': 'entropy', 'min_impurity_decrease': 0.0008536950640625713, 'ccp_alpha': 0.0024615564163587423, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:28,494] Trial 488 finished with value: 0.4608480582021168 and parameters: {'n_estimators': 250, 'max_depth': 29, 'max_leaf_nodes': 99, 'min_samples_split': 2, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0022706469956685583, 'max_features': 0.5, 'max_samples': 0.7693419649988491, 'criterion': 'entropy', 'min_impurity_decrease': 0.00033569123223527257, 'ccp_alpha': 0.0023017337810374147, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:30,979] Trial 489 finished with value: 0.4297280159002286 and parameters: {'n_estimators': 323, 'max_depth': 26, 'max_leaf_nodes': 131, 'min_samples_split': 5, 'min_samples_leaf': 14, 'min_weight_fraction_leaf': 0.0010118383859326271, 'max_features': 0.5, 'max_samples': 0.6802366162169551, 'criterion': 'entropy', 'min_impurity_decrease': 6.558131954611215e-05, 'ccp_alpha': 0.002073540204297838, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:32,419] Trial 490 finished with value: 0.45160416331119463 and parameters: {'n_estimators': 264, 'max_depth': 24, 'max_leaf_nodes': 119, 'min_samples_split': 3, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.003155867447577915, 'max_features': 0.5, 'max_samples': 0.6596159848889959, 'criterion': 'gini', 'min_impurity_decrease': 0.00020246780031450042, 'ccp_alpha': 0.0019342513865070517, 'class_weight': 'balanced'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:34,596] Trial 491 finished with value: 0.446747286394816 and parameters: {'n_estimators': 282, 'max_depth': 28, 'max_leaf_nodes': 109, 'min_samples_split': 2, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.005889521032220239, 'max_features': 0.5, 'max_samples': 0.67293937314244, 'criterion': 'entropy', 'min_impurity_decrease': 0.0013659987793733983, 'ccp_alpha': 0.0018011149218042728, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:36,510] Trial 492 finished with value: 0.45008886770256235 and parameters: {'n_estimators': 225, 'max_depth': 22, 'max_leaf_nodes': 142, 'min_samples_split': 3, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.004898195700203433, 'max_features': 0.5, 'max_samples': 0.6880238410476736, 'criterion': 'entropy', 'min_impurity_decrease': 0.0002831584619127961, 'ccp_alpha': 0.0021859212289425034, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:38,747] Trial 493 finished with value: 0.4606238765235824 and parameters: {'n_estimators': 302, 'max_depth': 25, 'max_leaf_nodes': 136, 'min_samples_split': 4, 'min_samples_leaf': 11, 'min_weight_fraction_leaf': 0.0014802046843398644, 'max_features': 0.5, 'max_samples': 0.7062972992702311, 'criterion': 'entropy', 'min_impurity_decrease': 0.00043783778921354006, 'ccp_alpha': 0.002008890667205134, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:40,616] Trial 494 finished with value: 0.0 and parameters: {'n_estimators': 253, 'max_depth': 5, 'max_leaf_nodes': 129, 'min_samples_split': 5, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 2.4605050158136134e-05, 'max_features': 0.7, 'max_samples': 0.6961231690702724, 'criterion': 'entropy', 'min_impurity_decrease': 0.00010150305368355011, 'ccp_alpha': 0.0018702543333628501, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:42,538] Trial 495 finished with value: 0.4450950603062078 and parameters: {'n_estimators': 243, 'max_depth': 23, 'max_leaf_nodes': 125, 'min_samples_split': 4, 'min_samples_leaf': 15, 'min_weight_fraction_leaf': 0.002316765488464579, 'max_features': 0.5, 'max_samples': 0.6794126728858599, 'criterion': 'entropy', 'min_impurity_decrease': 0.0001935808877954565, 'ccp_alpha': 0.0017157629527634296, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:44,683] Trial 496 finished with value: 0.47193549286479103 and parameters: {'n_estimators': 291, 'max_depth': 27, 'max_leaf_nodes': 113, 'min_samples_split': 2, 'min_samples_leaf': 10, 'min_weight_fraction_leaf': 0.0012036371575168017, 'max_features': 0.5, 'max_samples': 0.6508905220285869, 'criterion': 'entropy', 'min_impurity_decrease': 0.000324030646788015, 'ccp_alpha': 0.002123554982835518, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:46,672] Trial 497 finished with value: 0.4758306800003802 and parameters: {'n_estimators': 274, 'max_depth': 26, 'max_leaf_nodes': 138, 'min_samples_split': 3, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.0035673973645009064, 'max_features': 0.5, 'max_samples': 0.6675014731720307, 'criterion': 'entropy', 'min_impurity_decrease': 0.00010929286921837993, 'ccp_alpha': 0.0023496803027644214, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:48,309] Trial 498 finished with value: 0.45697303950928947 and parameters: {'n_estimators': 271, 'max_depth': 26, 'max_leaf_nodes': 144, 'min_samples_split': 3, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.00432236220692088, 'max_features': 0.5, 'max_samples': 0.6662670416873145, 'criterion': 'entropy', 'min_impurity_decrease': 0.0005438856181652681, 'ccp_alpha': 0.002525942351550588, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.
# [I 2026-01-22 15:33:49,353] Trial 499 finished with value: 0.4408183589813923 and parameters: {'n_estimators': 181, 'max_depth': 30, 'max_leaf_nodes': 139, 'min_samples_split': 2, 'min_samples_leaf': 8, 'min_weight_fraction_leaf': 0.005033801784075385, 'max_features': 'log2', 'max_samples': 0.6567611279555762, 'criterion': 'entropy', 'min_impurity_decrease': 0.0002485175047908534, 'ccp_alpha': 0.0023355366847323525, 'class_weight': 'balanced_subsample'}. Best is trial 255 with value: 0.4817956972113039.

# %%
# grid_rf.fit(X_train_res_retained, y_train_res)

# %%
# best_params_rf = grid_rf.best_params_

# %%
best_params_rf = study_rf.best_params

# %%
print(best_params_rf)
# Out:
# {'n_estimators': 271, 'max_depth': 24, 'max_leaf_nodes': 122, 'min_samples_split': 4, 'min_samples_leaf': 9, 'min_weight_fraction_leaf': 0.0018487948653081016, 'max_features': 0.5, 'max_samples': 0.6809917393397245, 'criterion': 'entropy', 'min_impurity_decrease': 0.00015835760860691516, 'ccp_alpha': 0.0021445873205053296, 'class_weight': 'balanced_subsample'}

# %%
final_classifier = RandomForestClassifier(**best_params_rf, random_state=42)

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# RandomForestClassifier(ccp_alpha=0.0021445873205053296,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=24, max_features=0.5, max_leaf_nodes=122,
#                        max_samples=0.6809917393397245,
#                        min_impurity_decrease=0.00015835760860691516,
#                        min_samples_leaf=9, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0018487948653081016,
#                        n_estimators=271, random_state=42)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[661  68]
#  [ 14  23]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.8929503916449086

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.25274725274725274

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.6216216216216216

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.4811715481171548

# %% [markdown]
# ### Threshold tuning

# %%
best_threshold = 0.5

# %%
best_precision_score = 0

# %%
best_recall_score = 0

# %%
best_f2_score = 0

# %%
for threshold in np.arange(0.1, 0.95, 0.05):
    y_pred_val_threshold = (y_proba_val >= threshold).astype(int)
    recall = recall_score(y_val, y_pred_val_threshold)
    precision = precision_score(y_val, y_pred_val_threshold)
    f2_score = fbeta_score(y_val, y_pred_val_threshold, beta=2)
    
    print(f'Threshold {threshold} has recall score {f2_score}')
    
    if precision >= 0.15:
        current_recall_score = recall
        if current_recall_score > best_recall_score:
            best_recall_score = current_recall_score
            best_precision_score = precision
            best_threshold = threshold
        elif current_recall_score == best_recall_score and precision > best_precision_score:
            best_precision_score = precision
            best_threshold = threshold
        
        # current_f2_score = f2_score
        # if current_f2_score > best_f2_score:
        #     best_f2_score = current_f2_score
        #     best_threshold = threshold
# Out:
# Threshold 0.1 has recall score 0.3382663847780127
# Threshold 0.15000000000000002 has recall score 0.36556603773584906
# Threshold 0.20000000000000004 has recall score 0.39845758354755784
# Threshold 0.25000000000000006 has recall score 0.4132231404958678
# Threshold 0.30000000000000004 has recall score 0.39755351681957185
# Threshold 0.3500000000000001 has recall score 0.4166666666666667
# Threshold 0.40000000000000013 has recall score 0.44964028776978415
# Threshold 0.45000000000000007 has recall score 0.4669260700389105
# Threshold 0.5000000000000001 has recall score 0.4811715481171548
# Threshold 0.5500000000000002 has recall score 0.3472222222222222
# Threshold 0.6000000000000002 has recall score 0.3015075376884422
# Threshold 0.6500000000000001 has recall score 0.2459016393442623
# Threshold 0.7000000000000002 has recall score 0.23255813953488372
# Threshold 0.7500000000000002 has recall score 0.125
# Threshold 0.8000000000000002 has recall score 0.09740259740259741
# Threshold 0.8500000000000002 has recall score 0.03355704697986577
# Threshold 0.9000000000000002 has recall score 0.0
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(best_threshold)
# Out:
# 0.40000000000000013

# %%
print(best_recall_score)
# Out:
# 0.6756756756756757

# %% [markdown]
# ### Retrain on training + validation set

# %%
X_train_full = pd.concat([X_train_res_retained, X_val_retained], axis=0, ignore_index=True)
y_train_full = pd.concat([y_train_res, y_val], axis=0, ignore_index=True)

# %%
final_classifier.fit(X_train_full, y_train_full)
# Out:
# RandomForestClassifier(ccp_alpha=0.0021445873205053296,
#                        class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=24, max_features=0.5, max_leaf_nodes=122,
#                        max_samples=0.6809917393397245,
#                        min_impurity_decrease=0.00015835760860691516,
#                        min_samples_leaf=9, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0018487948653081016,
#                        n_estimators=271, random_state=42)

# %% [markdown]
# ### Evaluate on test set

# %%
X_test_retained = X_test[retained_columns]

# %%
y_pred_test = final_classifier.predict(X_test_retained)

# %%
y_proba_test = final_classifier.predict_proba(X_test_retained)[:, 1]

# %%
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[658  71]
#  [ 21  17]]

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.8800521512385919

# %%
print(precision_score(y_test, y_pred_test))
# Out:
# 0.19318181818181818

# %%
print(recall_score(y_test, y_pred_test))
# Out:
# 0.4473684210526316

# %%
print(fbeta_score(y_test, y_pred_test, beta=2))
# Out:
# 0.3541666666666667

# %% [markdown]
# ### Test with best threshold 0.35

# %%
y_pred_test_threshold = (y_proba_test >= best_threshold).astype(int)

# %%
print(confusion_matrix(y_test, y_pred_test_threshold))
# Out:
# [[616 113]
#  [ 12  26]]

# %%
print(accuracy_score(y_test, y_pred_test_threshold))
# Out:
# 0.8370273794002607

# %%
print(precision_score(y_test, y_pred_test_threshold))
# Out:
# 0.18705035971223022

# %%
print(recall_score(y_test, y_pred_test_threshold))
# Out:
# 0.6842105263157895

# %%
print(fbeta_score(y_test, y_pred_test_threshold, beta=2))
# Out:
# 0.44673539518900346
