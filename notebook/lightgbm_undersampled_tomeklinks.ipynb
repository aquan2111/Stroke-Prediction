# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.under_sampling import TomekLinks
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_29412\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_29412\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### ADASYN Oversampling on Training Data

# %%
resampler = TomekLinks()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = lgb.LGBMClassifier(random_state=42, verbose=-1)

# %% [markdown]
# ### Create grid for hyperparameter tuning

# %%
param_grid_lgbm = {
    'num_leaves': [15, 31, 63, 127],
    'max_depth': [3, 5, 7, 10, -1], 
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200, 300],
    'min_child_samples': [5, 10, 20, 30],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'reg_alpha': [0, 0.1, 0.5, 1], 
    'reg_lambda': [0, 0.1, 0.5, 1],  
    'scale_pos_weight': [1, 3, 5, 10, 15, 20]  
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_lgbm = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_lgbm,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# LGBMClassifier(random_state=42, verbose=-1)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Gini Importance': importances}).sort_values(
    'Gini Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Gini Importance
# 4                avg_glucose_level              952
# 5                              bmi              818
# 0                              age              434
# 20                age_ever_married              219
# 7                            urban               68
# 13               work_type_private               66
# 6                             male               65
# 1                     hypertension               60
# 14         work_type_self_employed               49
# 18     smoking_status_never_smoked               45
# 8                            smoke               38
# 17  smoking_status_formerly_smoked               38
# 10   hypertension_or_heart_disease               28
# 11              work_type_govt_job               26
# 19           smoking_status_smokes               26
# 3                     ever_married               23
# 2                    heart_disease               21
# 16          smoking_status_unknown               21
# 22          high_avg_glucose_level                2
# 21                           obese                1
# 23                         log_bmi                0
# 12          work_type_never_worked                0
# 15              work_type_children                0
# 9                        have_work                0
# 24           log_avg_glucose_level                0

# %%
retained_columns = ['avg_glucose_level', 'bmi', 'age', 'urban', 'work_type_private', 'male', 'hypertension', 'work_type_self_employed', 'smoking_status_never_smoked', 'smoke']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.15

# %%
def objective_lgbm(trial):
    params = {
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 80),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.001, 5, log=True), 
        'min_split_gain': trial.suggest_float('min_split_gain', 0, 3), 
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.2, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 7),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.001, 10, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.001, 10, log=True),
        'max_delta_step': trial.suggest_float('max_delta_step', 0, 5),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 5, 25),
        'boosting_type': 'gbdt',  
        'max_bin': trial.suggest_int('max_bin', 200, 400),
        'random_state': 42,
        'verbose': -1,
    }
    
    model = lgb.LGBMClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    f2_score = fbeta_score(y_val, y_pred_val, beta=2)
    
    if precision < MIN_PRECISION:
        return 0
    return recall + (precision * 0.01)
    # return f2_score + recall * 0.001 + precision * 0.00001

# %%
# grid_lgbm.fit(X_train_res_retained, y_train_res)

# %%
study_lgbm = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_lgbm.optimize(objective_lgbm, n_trials=300, show_progress_bar=True)
# Out:
# [I 2026-01-19 13:54:46,749] A new study created in memory with name: no-name-8e3c0c6d-02a8-402b-9928-0bc404f24a6d
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 13:54:47,118] Trial 0 finished with value: 0.27297297297297296 and parameters: {'num_leaves': 57, 'max_depth': 15, 'learning_rate': 0.1205712628744377, 'n_estimators': 200, 'min_child_samples': 12, 'subsample': 0.5779972601681014, 'colsample_bytree': 0.5290418060840998, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 14.453378978124864}. Best is trial 0 with value: 0.27297297297297296.
# [I 2026-01-19 13:54:47,229] Trial 1 finished with value: 0.32667726550079496 and parameters: {'num_leaves': 17, 'max_depth': 15, 'learning_rate': 0.16967533607196555, 'n_estimators': 103, 'min_child_samples': 13, 'subsample': 0.5917022549267169, 'colsample_bytree': 0.6521211214797689, 'reg_alpha': 0.5247564316322378, 'reg_lambda': 0.43194501864211576, 'scale_pos_weight': 6.533353663762797}. Best is trial 1 with value: 0.32667726550079496.
# [I 2026-01-19 13:54:47,324] Trial 2 finished with value: 0.08708108108108109 and parameters: {'num_leaves': 84, 'max_depth': 4, 'learning_rate': 0.027010527749605478, 'n_estimators': 141, 'min_child_samples': 25, 'subsample': 0.8925879806965068, 'colsample_bytree': 0.5998368910791798, 'reg_alpha': 0.5142344384136116, 'reg_lambda': 0.5924145688620425, 'scale_pos_weight': 1.8825578416799567}. Best is trial 1 with value: 0.32667726550079496.
# [I 2026-01-19 13:54:47,525] Trial 3 finished with value: 0.5695675675675675 and parameters: {'num_leaves': 83, 'max_depth': 5, 'learning_rate': 0.012476394272569451, 'n_estimators': 288, 'min_child_samples': 49, 'subsample': 0.9041986740582306, 'colsample_bytree': 0.6523068845866853, 'reg_alpha': 0.09767211400638387, 'reg_lambda': 0.6842330265121569, 'scale_pos_weight': 9.362897381052425}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:47,773] Trial 4 finished with value: 0.27283437283437284 and parameters: {'num_leaves': 28, 'max_depth': 9, 'learning_rate': 0.011240768803005551, 'n_estimators': 278, 'min_child_samples': 16, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796, 'scale_pos_weight': 4.512234654985013}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:48,103] Trial 5 finished with value: 0.21879686137750656 and parameters: {'num_leaves': 124, 'max_depth': 13, 'learning_rate': 0.24420460844911424, 'n_estimators': 274, 'min_child_samples': 32, 'subsample': 0.9609371175115584, 'colsample_bytree': 0.5442462510259598, 'reg_alpha': 0.1959828624191452, 'reg_lambda': 0.045227288910538066, 'scale_pos_weight': 7.181276284502022}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:48,279] Trial 6 finished with value: 0.3807512597343106 and parameters: {'num_leaves': 58, 'max_depth': 6, 'learning_rate': 0.16755052359850303, 'n_estimators': 139, 'min_child_samples': 17, 'subsample': 0.7713480415791243, 'colsample_bytree': 0.5704621124873813, 'reg_alpha': 0.8021969807540397, 'reg_lambda': 0.07455064367977082, 'scale_pos_weight': 19.75085179540983}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:48,525] Trial 7 finished with value: 0.13846846846846847 and parameters: {'num_leaves': 102, 'max_depth': 5, 'learning_rate': 0.010189592979395137, 'n_estimators': 254, 'min_child_samples': 37, 'subsample': 0.8645035840204937, 'colsample_bytree': 0.8856351733429728, 'reg_alpha': 0.07404465173409036, 'reg_lambda': 0.3584657285442726, 'scale_pos_weight': 3.2015121309774646}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:48,692] Trial 8 finished with value: 0.43471814671814674 and parameters: {'num_leaves': 112, 'max_depth': 11, 'learning_rate': 0.030816017044468066, 'n_estimators': 65, 'min_child_samples': 19, 'subsample': 0.6625916610133735, 'colsample_bytree': 0.864803089169032, 'reg_alpha': 0.6375574713552131, 'reg_lambda': 0.8872127425763265, 'scale_pos_weight': 9.972083578077036}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:48,886] Trial 9 finished with value: 0.1644698544698545 and parameters: {'num_leaves': 28, 'max_depth': 12, 'learning_rate': 0.13297554090738672, 'n_estimators': 190, 'min_child_samples': 40, 'subsample': 0.7468977981821954, 'colsample_bytree': 0.7613664146909971, 'reg_alpha': 0.42754101835854963, 'reg_lambda': 0.02541912674409519, 'scale_pos_weight': 3.049937112872785}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:49,112] Trial 10 finished with value: 0.4075482625482626 and parameters: {'num_leaves': 81, 'max_depth': 8, 'learning_rate': 0.0582376318110375, 'n_estimators': 228, 'min_child_samples': 50, 'subsample': 0.9538323976412588, 'colsample_bytree': 0.97988537297271, 'reg_alpha': 0.2762860195555519, 'reg_lambda': 0.9506149249776015, 'scale_pos_weight': 13.230541995852649}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:49,385] Trial 11 finished with value: 0.4077130977130977 and parameters: {'num_leaves': 112, 'max_depth': 11, 'learning_rate': 0.024915737267353112, 'n_estimators': 62, 'min_child_samples': 50, 'subsample': 0.6867771857270699, 'colsample_bytree': 0.7866454888256146, 'reg_alpha': 0.7116574996731307, 'reg_lambda': 0.8863027948095235, 'scale_pos_weight': 10.636122896218275}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:49,507] Trial 12 finished with value: 0.46178822658274715 and parameters: {'num_leaves': 97, 'max_depth': 7, 'learning_rate': 0.022584683707525987, 'n_estimators': 71, 'min_child_samples': 23, 'subsample': 0.6400016021035824, 'colsample_bytree': 0.8613574115870757, 'reg_alpha': 0.9960165317474352, 'reg_lambda': 0.7563062039527706, 'scale_pos_weight': 9.91739052503912}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:50,471] Trial 13 finished with value: 0.48842197035745427 and parameters: {'num_leaves': 86, 'max_depth': 7, 'learning_rate': 0.016790036723716078, 'n_estimators': 300, 'min_child_samples': 26, 'subsample': 0.5262605355069299, 'colsample_bytree': 0.6911897857229801, 'reg_alpha': 0.965337946065455, 'reg_lambda': 0.7812874114500199, 'scale_pos_weight': 10.585064786331003}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:50,626] Trial 14 finished with value: 0.0 and parameters: {'num_leaves': 63, 'max_depth': 3, 'learning_rate': 0.018310523128318497, 'n_estimators': 299, 'min_child_samples': 42, 'subsample': 0.5125336489219637, 'colsample_bytree': 0.6898306742313617, 'reg_alpha': 0.0033331972121352083, 'reg_lambda': 0.7110189753164403, 'scale_pos_weight': 14.334363356066525}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:50,871] Trial 15 finished with value: 0.3531081081081081 and parameters: {'num_leaves': 77, 'max_depth': 6, 'learning_rate': 0.04973792606366414, 'n_estimators': 238, 'min_child_samples': 5, 'subsample': 0.510456783241702, 'colsample_bytree': 0.7122199242440835, 'reg_alpha': 0.3239947121630833, 'reg_lambda': 0.7443801416541335, 'scale_pos_weight': 17.333347628715472}. Best is trial 3 with value: 0.5695675675675675.
# [I 2026-01-19 13:54:51,056] Trial 16 finished with value: 0.5968626358317081 and parameters: {'num_leaves': 49, 'max_depth': 3, 'learning_rate': 0.014480577875920799, 'n_estimators': 298, 'min_child_samples': 31, 'subsample': 0.7745410636167176, 'colsample_bytree': 0.6008964335081206, 'reg_alpha': 0.12232570955761565, 'reg_lambda': 0.30087379330197245, 'scale_pos_weight': 7.086454969900423}. Best is trial 16 with value: 0.5968626358317081.
# [I 2026-01-19 13:54:51,205] Trial 17 finished with value: 0.5699009009009008 and parameters: {'num_leaves': 44, 'max_depth': 3, 'learning_rate': 0.04358218506746621, 'n_estimators': 217, 'min_child_samples': 34, 'subsample': 0.7917670580202939, 'colsample_bytree': 0.6223752669714424, 'reg_alpha': 0.15795130006005614, 'reg_lambda': 0.24919458696803146, 'scale_pos_weight': 7.420928278855839}. Best is trial 16 with value: 0.5968626358317081.
# [I 2026-01-19 13:54:51,327] Trial 18 finished with value: 0.43445774888812866 and parameters: {'num_leaves': 44, 'max_depth': 3, 'learning_rate': 0.05202114322877145, 'n_estimators': 219, 'min_child_samples': 32, 'subsample': 0.7858819748428905, 'colsample_bytree': 0.5043581615346939, 'reg_alpha': 0.2041829863603956, 'reg_lambda': 0.2344780743619249, 'scale_pos_weight': 6.402843550192247}. Best is trial 16 with value: 0.5968626358317081.
# [I 2026-01-19 13:54:51,424] Trial 19 finished with value: 0.4343836519446276 and parameters: {'num_leaves': 47, 'max_depth': 3, 'learning_rate': 0.07581437852594107, 'n_estimators': 164, 'min_child_samples': 32, 'subsample': 0.7045005355351618, 'colsample_bytree': 0.6036313034851821, 'reg_alpha': 0.36249389957804273, 'reg_lambda': 0.23288977788076004, 'scale_pos_weight': 7.846508664700782}. Best is trial 16 with value: 0.5968626358317081.
# [I 2026-01-19 13:54:51,628] Trial 20 finished with value: 0.2999802241265656 and parameters: {'num_leaves': 44, 'max_depth': 9, 'learning_rate': 0.039865095460191395, 'n_estimators': 258, 'min_child_samples': 36, 'subsample': 0.8054692012755708, 'colsample_bytree': 0.5948794157853438, 'reg_alpha': 0.17217919490235667, 'reg_lambda': 0.2553073923827313, 'scale_pos_weight': 5.026946931859594}. Best is trial 16 with value: 0.5968626358317081.
# [I 2026-01-19 13:54:51,805] Trial 21 finished with value: 0.5155347901092582 and parameters: {'num_leaves': 69, 'max_depth': 5, 'learning_rate': 0.014587927677347078, 'n_estimators': 278, 'min_child_samples': 45, 'subsample': 0.9079219245745126, 'colsample_bytree': 0.6423130331925699, 'reg_alpha': 0.07945925583020445, 'reg_lambda': 0.4254381624049008, 'scale_pos_weight': 8.538329501268711}. Best is trial 16 with value: 0.5968626358317081.
# [I 2026-01-19 13:54:51,940] Trial 22 finished with value: 0.6773648648648648 and parameters: {'num_leaves': 36, 'max_depth': 4, 'learning_rate': 0.013058986333465491, 'n_estimators': 256, 'min_child_samples': 44, 'subsample': 0.8406615500056063, 'colsample_bytree': 0.7311213963056294, 'reg_alpha': 0.0015184173187385297, 'reg_lambda': 0.1409243800309793, 'scale_pos_weight': 12.319432336091385}. Best is trial 22 with value: 0.6773648648648648.
# [I 2026-01-19 13:54:52,078] Trial 23 finished with value: 0.6232300132300133 and parameters: {'num_leaves': 34, 'max_depth': 4, 'learning_rate': 0.019703742258497053, 'n_estimators': 244, 'min_child_samples': 29, 'subsample': 0.8360315643870019, 'colsample_bytree': 0.8078980831754887, 'reg_alpha': 0.03267333943540196, 'reg_lambda': 0.15580596841785488, 'scale_pos_weight': 12.1406593277218}. Best is trial 22 with value: 0.6773648648648648.
# [I 2026-01-19 13:54:52,229] Trial 24 finished with value: 0.6774117867867868 and parameters: {'num_leaves': 31, 'max_depth': 4, 'learning_rate': 0.0181139716982351, 'n_estimators': 245, 'min_child_samples': 28, 'subsample': 0.7355683828241563, 'colsample_bytree': 0.813781650830506, 'reg_alpha': 0.0026277244029793353, 'reg_lambda': 0.13439363352672695, 'scale_pos_weight': 12.26921134780506}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:52,365] Trial 25 finished with value: 0.6774117867867868 and parameters: {'num_leaves': 32, 'max_depth': 4, 'learning_rate': 0.021363196314674777, 'n_estimators': 250, 'min_child_samples': 22, 'subsample': 0.7244278109981884, 'colsample_bytree': 0.8041859363210639, 'reg_alpha': 0.00032535730348314754, 'reg_lambda': 0.13583114059131457, 'scale_pos_weight': 12.387367077279961}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:52,501] Trial 26 finished with value: 0.5965244191559982 and parameters: {'num_leaves': 15, 'max_depth': 6, 'learning_rate': 0.034000431380307325, 'n_estimators': 202, 'min_child_samples': 6, 'subsample': 0.7284077574259675, 'colsample_bytree': 0.8157917401480089, 'reg_alpha': 0.2647171998046792, 'reg_lambda': 0.12473611341654359, 'scale_pos_weight': 15.955328616961733}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:52,656] Trial 27 finished with value: 0.6233509449298923 and parameters: {'num_leaves': 34, 'max_depth': 4, 'learning_rate': 0.020684308657287605, 'n_estimators': 266, 'min_child_samples': 22, 'subsample': 0.6272353029327429, 'colsample_bytree': 0.9436807524388049, 'reg_alpha': 0.004526127790874541, 'reg_lambda': 0.15514121618479357, 'scale_pos_weight': 11.821985571162768}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:52,832] Trial 28 finished with value: 0.6505236486486486 and parameters: {'num_leaves': 24, 'max_depth': 7, 'learning_rate': 0.014199017805486283, 'n_estimators': 176, 'min_child_samples': 44, 'subsample': 0.7417902398612948, 'colsample_bytree': 0.759359978569621, 'reg_alpha': 0.21844613843673463, 'reg_lambda': 0.12777652556662134, 'scale_pos_weight': 16.263126896887275}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:52,995] Trial 29 finished with value: 0.40790540540540543 and parameters: {'num_leaves': 34, 'max_depth': 5, 'learning_rate': 0.0848028474401187, 'n_estimators': 210, 'min_child_samples': 10, 'subsample': 0.9992483437747102, 'colsample_bytree': 0.7311054721082171, 'reg_alpha': 0.067299924302136, 'reg_lambda': 0.36044185678267476, 'scale_pos_weight': 14.403265806195158}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:53,612] Trial 30 finished with value: 0.5429795649307845 and parameters: {'num_leaves': 55, 'max_depth': 9, 'learning_rate': 0.010112577527344707, 'n_estimators': 240, 'min_child_samples': 20, 'subsample': 0.7023358302225919, 'colsample_bytree': 0.9077005426941609, 'reg_alpha': 0.40494192310848587, 'reg_lambda': 0.0032573346706889217, 'scale_pos_weight': 12.53528202496771}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:53,828] Trial 31 finished with value: 0.6233908523908523 and parameters: {'num_leaves': 23, 'max_depth': 7, 'learning_rate': 0.014267811053713416, 'n_estimators': 180, 'min_child_samples': 46, 'subsample': 0.7331523455707596, 'colsample_bytree': 0.7616780579422507, 'reg_alpha': 0.24188061070604955, 'reg_lambda': 0.10835861427058545, 'scale_pos_weight': 16.309579648562394}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:53,995] Trial 32 finished with value: 0.0 and parameters: {'num_leaves': 20, 'max_depth': 4, 'learning_rate': 0.016210700041665162, 'n_estimators': 154, 'min_child_samples': 42, 'subsample': 0.8287606604535994, 'colsample_bytree': 0.8194265552505005, 'reg_alpha': 0.12380887276623409, 'reg_lambda': 0.15736172945283605, 'scale_pos_weight': 18.462294018449075}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:54,187] Trial 33 finished with value: 0.6504004734661669 and parameters: {'num_leaves': 26, 'max_depth': 6, 'learning_rate': 0.027568511411374116, 'n_estimators': 118, 'min_child_samples': 39, 'subsample': 0.5976034029519438, 'colsample_bytree': 0.7820149048212641, 'reg_alpha': 0.02071431816239347, 'reg_lambda': 0.08651694061907794, 'scale_pos_weight': 15.346453849239724}. Best is trial 24 with value: 0.6774117867867868.
# [I 2026-01-19 13:54:54,406] Trial 34 finished with value: 0.7044132290184922 and parameters: {'num_leaves': 38, 'max_depth': 4, 'learning_rate': 0.011976229057575054, 'n_estimators': 192, 'min_child_samples': 45, 'subsample': 0.6730863784184444, 'colsample_bytree': 0.847751553561685, 'reg_alpha': 0.1284344250227612, 'reg_lambda': 0.195850939058209, 'scale_pos_weight': 13.720270295264479}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:54,632] Trial 35 finished with value: 0.6773423423423424 and parameters: {'num_leaves': 38, 'max_depth': 4, 'learning_rate': 0.01171765812020166, 'n_estimators': 226, 'min_child_samples': 12, 'subsample': 0.6591183288671048, 'colsample_bytree': 0.8426546179687204, 'reg_alpha': 0.11980832940318414, 'reg_lambda': 0.4698016324154841, 'scale_pos_weight': 13.128596475628322}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:54,922] Trial 36 finished with value: 0.6233908523908523 and parameters: {'num_leaves': 53, 'max_depth': 5, 'learning_rate': 0.01284813235015189, 'n_estimators': 194, 'min_child_samples': 27, 'subsample': 0.5721388480032987, 'colsample_bytree': 0.9147881548617374, 'reg_alpha': 0.05948263229340736, 'reg_lambda': 0.1971215238684212, 'scale_pos_weight': 11.559196722988922}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:55,112] Trial 37 finished with value: 0.6501486486486486 and parameters: {'num_leaves': 38, 'max_depth': 4, 'learning_rate': 0.020887166642046262, 'n_estimators': 253, 'min_child_samples': 47, 'subsample': 0.8722502690702904, 'colsample_bytree': 0.7249813318271341, 'reg_alpha': 0.1588921348881619, 'reg_lambda': 0.3095281572678297, 'scale_pos_weight': 13.842856816124767}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:55,365] Trial 38 finished with value: 0.5153059663437022 and parameters: {'num_leaves': 61, 'max_depth': 5, 'learning_rate': 0.025224736461410494, 'n_estimators': 267, 'min_child_samples': 17, 'subsample': 0.6867755339810767, 'colsample_bytree': 0.8286660127265221, 'reg_alpha': 0.0019446422161161147, 'reg_lambda': 0.6057231434032369, 'scale_pos_weight': 11.370297102918514}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:55,752] Trial 39 finished with value: 0.4883812233285918 and parameters: {'num_leaves': 38, 'max_depth': 14, 'learning_rate': 0.011696901768855718, 'n_estimators': 239, 'min_child_samples': 24, 'subsample': 0.7189803265504475, 'colsample_bytree': 0.7893545713870994, 'reg_alpha': 0.6314397764009776, 'reg_lambda': 0.05805645285272988, 'scale_pos_weight': 15.389038335270845}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:55,925] Trial 40 finished with value: 0.5425607425607426 and parameters: {'num_leaves': 18, 'max_depth': 4, 'learning_rate': 0.03327812127695397, 'n_estimators': 209, 'min_child_samples': 36, 'subsample': 0.770159265437759, 'colsample_bytree': 0.939383110947198, 'reg_alpha': 0.08947697758703874, 'reg_lambda': 0.397547211180706, 'scale_pos_weight': 8.958355902495686}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:56,101] Trial 41 finished with value: 0.6773648648648648 and parameters: {'num_leaves': 29, 'max_depth': 4, 'learning_rate': 0.01162027844217466, 'n_estimators': 222, 'min_child_samples': 10, 'subsample': 0.6590751891013801, 'colsample_bytree': 0.84901119031828, 'reg_alpha': 0.13138770615108764, 'reg_lambda': 0.5060443377038555, 'scale_pos_weight': 13.13835264631667}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:56,316] Trial 42 finished with value: 0.650439693424768 and parameters: {'num_leaves': 30, 'max_depth': 5, 'learning_rate': 0.016382907336396905, 'n_estimators': 229, 'min_child_samples': 14, 'subsample': 0.6667502482457707, 'colsample_bytree': 0.8540382423858224, 'reg_alpha': 0.04718556276508387, 'reg_lambda': 0.5601475525332594, 'scale_pos_weight': 13.088216237657917}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:56,585] Trial 43 finished with value: 0.5965244191559982 and parameters: {'num_leaves': 31, 'max_depth': 6, 'learning_rate': 0.010041408417133727, 'n_estimators': 252, 'min_child_samples': 10, 'subsample': 0.6188973894581795, 'colsample_bytree': 0.8820577988892473, 'reg_alpha': 0.3077014142603987, 'reg_lambda': 0.49283480781122646, 'scale_pos_weight': 13.739740046168901}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:56,725] Trial 44 finished with value: 0.6504133545310016 and parameters: {'num_leaves': 21, 'max_depth': 3, 'learning_rate': 0.012264958478759172, 'n_estimators': 187, 'min_child_samples': 48, 'subsample': 0.6829881639769495, 'colsample_bytree': 0.8800184195847193, 'reg_alpha': 0.13862021105259073, 'reg_lambda': 0.6234853835149645, 'scale_pos_weight': 10.811475407942417}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:56,902] Trial 45 finished with value: 0.677353528024669 and parameters: {'num_leaves': 39, 'max_depth': 4, 'learning_rate': 0.017866873690177285, 'n_estimators': 282, 'min_child_samples': 20, 'subsample': 0.5732145676492318, 'colsample_bytree': 0.7983893715325104, 'reg_alpha': 0.10660578274805262, 'reg_lambda': 0.3077676105916832, 'scale_pos_weight': 12.48565994968601}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:57,123] Trial 46 finished with value: 0.1917817817817818 and parameters: {'num_leaves': 49, 'max_depth': 5, 'learning_rate': 0.27445677647673977, 'n_estimators': 200, 'min_child_samples': 8, 'subsample': 0.6445230770323658, 'colsample_bytree': 0.8430859578736559, 'reg_alpha': 0.18253069674616845, 'reg_lambda': 0.04720821153417308, 'scale_pos_weight': 9.720533779373334}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:57,410] Trial 47 finished with value: 0.5694259746472136 and parameters: {'num_leaves': 27, 'max_depth': 10, 'learning_rate': 0.012621870180250962, 'n_estimators': 268, 'min_child_samples': 40, 'subsample': 0.711121870306973, 'colsample_bytree': 0.6791212183152906, 'reg_alpha': 0.4668765883920406, 'reg_lambda': 0.21728206262393185, 'scale_pos_weight': 15.100846346046954}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:57,783] Trial 48 finished with value: 0.48857950974230047 and parameters: {'num_leaves': 41, 'max_depth': 15, 'learning_rate': 0.022466225191798528, 'n_estimators': 230, 'min_child_samples': 29, 'subsample': 0.7514628049689627, 'colsample_bytree': 0.7738227244834323, 'reg_alpha': 0.06062504835378362, 'reg_lambda': 0.1965890895033118, 'scale_pos_weight': 17.303656478486847}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:58,083] Trial 49 finished with value: 0.5422072072072073 and parameters: {'num_leaves': 15, 'max_depth': 8, 'learning_rate': 0.016442696004042964, 'n_estimators': 250, 'min_child_samples': 43, 'subsample': 0.6026971402954406, 'colsample_bytree': 0.7390955497368943, 'reg_alpha': 0.8210920308576761, 'reg_lambda': 0.5218726397461465, 'scale_pos_weight': 11.157129886919682}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:58,308] Trial 50 finished with value: 0.7042880685563613 and parameters: {'num_leaves': 127, 'max_depth': 3, 'learning_rate': 0.02820657442057664, 'n_estimators': 216, 'min_child_samples': 15, 'subsample': 0.55206479610992, 'colsample_bytree': 0.9988249011828504, 'reg_alpha': 0.5598692971713617, 'reg_lambda': 0.2753258645556037, 'scale_pos_weight': 13.686287066925619}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:58,480] Trial 51 finished with value: 0.7043587536581167 and parameters: {'num_leaves': 126, 'max_depth': 3, 'learning_rate': 0.02955001388261717, 'n_estimators': 219, 'min_child_samples': 14, 'subsample': 0.5476624977680937, 'colsample_bytree': 0.992675265509229, 'reg_alpha': 0.614448183625057, 'reg_lambda': 0.2719422234840675, 'scale_pos_weight': 13.548702566385563}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:58,650] Trial 52 finished with value: 0.0 and parameters: {'num_leaves': 118, 'max_depth': 3, 'learning_rate': 0.028477650838095, 'n_estimators': 207, 'min_child_samples': 14, 'subsample': 0.5350284977357571, 'colsample_bytree': 0.9674297599306966, 'reg_alpha': 0.5598944284952081, 'reg_lambda': 0.2827629895974982, 'scale_pos_weight': 14.05271311359169}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:58,816] Trial 53 finished with value: 0.677353528024669 and parameters: {'num_leaves': 125, 'max_depth': 3, 'learning_rate': 0.03789963001219966, 'n_estimators': 234, 'min_child_samples': 18, 'subsample': 0.5648788085601677, 'colsample_bytree': 0.9976640108068452, 'reg_alpha': 0.5631278570577032, 'reg_lambda': 0.3475606915019501, 'scale_pos_weight': 12.527543919120808}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:58,951] Trial 54 finished with value: 0.7042321144674086 and parameters: {'num_leaves': 102, 'max_depth': 3, 'learning_rate': 0.02467859810871733, 'n_estimators': 164, 'min_child_samples': 15, 'subsample': 0.7587625611264937, 'colsample_bytree': 0.9629633846261009, 'reg_alpha': 0.6892148896746085, 'reg_lambda': 0.16884492533493184, 'scale_pos_weight': 13.532368040681057}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:59,088] Trial 55 finished with value: 0.0 and parameters: {'num_leaves': 102, 'max_depth': 3, 'learning_rate': 0.023192824866986556, 'n_estimators': 164, 'min_child_samples': 15, 'subsample': 0.557408930848084, 'colsample_bytree': 0.9612714155397951, 'reg_alpha': 0.7294925631200231, 'reg_lambda': 0.186762842134427, 'scale_pos_weight': 14.887933466913278}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:59,253] Trial 56 finished with value: 0.0 and parameters: {'num_leaves': 119, 'max_depth': 3, 'learning_rate': 0.02844111206149961, 'n_estimators': 133, 'min_child_samples': 16, 'subsample': 0.5385451492619577, 'colsample_bytree': 0.9955092565499444, 'reg_alpha': 0.6527222854292721, 'reg_lambda': 0.0922666515506643, 'scale_pos_weight': 1.2245001694502307}. Best is trial 34 with value: 0.7044132290184922.
# [I 2026-01-19 13:54:59,403] Trial 57 finished with value: 0.7313562357538261 and parameters: {'num_leaves': 110, 'max_depth': 3, 'learning_rate': 0.04446640803681436, 'n_estimators': 160, 'min_child_samples': 12, 'subsample': 0.7638049499688528, 'colsample_bytree': 0.9226878621150694, 'reg_alpha': 0.7317575458078548, 'reg_lambda': 0.27116820333190483, 'scale_pos_weight': 13.724103802090282}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:54:59,606] Trial 58 finished with value: 0.7044020491079315 and parameters: {'num_leaves': 113, 'max_depth': 3, 'learning_rate': 0.0668503368258554, 'n_estimators': 162, 'min_child_samples': 11, 'subsample': 0.7887978859370014, 'colsample_bytree': 0.9161936227613665, 'reg_alpha': 0.7325852636699689, 'reg_lambda': 0.2701451496517951, 'scale_pos_weight': 13.705409539889326}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:54:59,796] Trial 59 finished with value: 0.0 and parameters: {'num_leaves': 110, 'max_depth': 3, 'learning_rate': 0.06302984941561803, 'n_estimators': 148, 'min_child_samples': 12, 'subsample': 0.8104540968813594, 'colsample_bytree': 0.9155290035592066, 'reg_alpha': 0.738294655661222, 'reg_lambda': 0.2812148538791999, 'scale_pos_weight': 17.388731580384334}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:54:59,935] Trial 60 finished with value: 0.7042977947272426 and parameters: {'num_leaves': 108, 'max_depth': 3, 'learning_rate': 0.04684999488320001, 'n_estimators': 162, 'min_child_samples': 12, 'subsample': 0.7532890289856988, 'colsample_bytree': 0.9410216367901412, 'reg_alpha': 0.6864013946577466, 'reg_lambda': 0.3465035155864542, 'scale_pos_weight': 14.54124027584862}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:00,059] Trial 61 finished with value: 0.6501580826109128 and parameters: {'num_leaves': 91, 'max_depth': 3, 'learning_rate': 0.0459307069461769, 'n_estimators': 167, 'min_child_samples': 7, 'subsample': 0.776669715480639, 'colsample_bytree': 0.9418829461949193, 'reg_alpha': 0.673645349320817, 'reg_lambda': 0.34417175827091095, 'scale_pos_weight': 13.67233425058729}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:00,197] Trial 62 finished with value: 0.0 and parameters: {'num_leaves': 108, 'max_depth': 3, 'learning_rate': 0.06644362508248643, 'n_estimators': 132, 'min_child_samples': 12, 'subsample': 0.7589585432118374, 'colsample_bytree': 0.9766861127465917, 'reg_alpha': 0.597616345025728, 'reg_lambda': 0.39406344158854356, 'scale_pos_weight': 16.88173579766844}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:00,327] Trial 63 finished with value: 0.6234184966216216 and parameters: {'num_leaves': 120, 'max_depth': 3, 'learning_rate': 0.09060961462450125, 'n_estimators': 184, 'min_child_samples': 10, 'subsample': 0.7987002903045033, 'colsample_bytree': 0.9573932069439568, 'reg_alpha': 0.781291897954179, 'reg_lambda': 0.25454547375807113, 'scale_pos_weight': 14.481785841296233}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:00,436] Trial 64 finished with value: 0.5421665568007031 and parameters: {'num_leaves': 115, 'max_depth': 3, 'learning_rate': 0.11048138475552094, 'n_estimators': 169, 'min_child_samples': 8, 'subsample': 0.818817751686393, 'colsample_bytree': 0.8976480930735009, 'reg_alpha': 0.6980121269984381, 'reg_lambda': 0.27855785599748834, 'scale_pos_weight': 15.79196887731527}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:00,535] Trial 65 finished with value: 0.5964127764127765 and parameters: {'num_leaves': 127, 'max_depth': 4, 'learning_rate': 0.05600475195509409, 'n_estimators': 149, 'min_child_samples': 13, 'subsample': 0.7603258729795159, 'colsample_bytree': 0.92758182209641, 'reg_alpha': 0.8586295244111253, 'reg_lambda': 0.33799860501551443, 'scale_pos_weight': 14.728423016916596}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:00,659] Trial 66 finished with value: 0.6775696150696151 and parameters: {'num_leaves': 104, 'max_depth': 4, 'learning_rate': 0.040678951725207656, 'n_estimators': 157, 'min_child_samples': 16, 'subsample': 0.7817888988304482, 'colsample_bytree': 0.9838300298748814, 'reg_alpha': 0.7628713151072324, 'reg_lambda': 0.3896619069828783, 'scale_pos_weight': 13.477238530043083}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:00,766] Trial 67 finished with value: 0.0 and parameters: {'num_leaves': 96, 'max_depth': 3, 'learning_rate': 0.03217304337419845, 'n_estimators': 112, 'min_child_samples': 19, 'subsample': 0.5050269761741197, 'colsample_bytree': 0.929041149991192, 'reg_alpha': 0.48774746088033094, 'reg_lambda': 0.4540639713038987, 'scale_pos_weight': 14.323877214381092}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:00,901] Trial 68 finished with value: 0.4887364864864865 and parameters: {'num_leaves': 122, 'max_depth': 5, 'learning_rate': 0.04701100320588472, 'n_estimators': 174, 'min_child_samples': 5, 'subsample': 0.8571430397911264, 'colsample_bytree': 0.9575246541127627, 'reg_alpha': 0.9251523162964923, 'reg_lambda': 0.22621228106549596, 'scale_pos_weight': 12.89427209117626}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,001] Trial 69 finished with value: 0.5428132678132679 and parameters: {'num_leaves': 115, 'max_depth': 11, 'learning_rate': 0.03543029828079374, 'n_estimators': 81, 'min_child_samples': 14, 'subsample': 0.5439073131338975, 'colsample_bytree': 0.9809669444981384, 'reg_alpha': 0.6859546425787819, 'reg_lambda': 0.17590110536074788, 'scale_pos_weight': 16.62897852142933}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,101] Trial 70 finished with value: 0.4885554520037279 and parameters: {'num_leaves': 105, 'max_depth': 4, 'learning_rate': 0.07399668380035918, 'n_estimators': 193, 'min_child_samples': 8, 'subsample': 0.7459710837139308, 'colsample_bytree': 0.895093587987137, 'reg_alpha': 0.6216616411134595, 'reg_lambda': 0.25542197617927076, 'scale_pos_weight': 15.478658280700895}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,201] Trial 71 finished with value: 0.6504133545310016 and parameters: {'num_leaves': 100, 'max_depth': 4, 'learning_rate': 0.04106648093729994, 'n_estimators': 154, 'min_child_samples': 16, 'subsample': 0.7830917185308522, 'colsample_bytree': 0.9839698857621094, 'reg_alpha': 0.7971375471382172, 'reg_lambda': 0.3986894327203153, 'scale_pos_weight': 13.560150549156642}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,284] Trial 72 finished with value: 0.6233253253253253 and parameters: {'num_leaves': 115, 'max_depth': 3, 'learning_rate': 0.053358999261222846, 'n_estimators': 159, 'min_child_samples': 11, 'subsample': 0.7903223703045064, 'colsample_bytree': 0.9473884071294165, 'reg_alpha': 0.7787707596852651, 'reg_lambda': 0.3793294363268159, 'scale_pos_weight': 11.73375115003024}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,368] Trial 73 finished with value: 0.0 and parameters: {'num_leaves': 107, 'max_depth': 3, 'learning_rate': 0.041858124920077795, 'n_estimators': 142, 'min_child_samples': 15, 'subsample': 0.7641474273222517, 'colsample_bytree': 0.9721478145375979, 'reg_alpha': 0.7533482926617867, 'reg_lambda': 0.3233371511347975, 'scale_pos_weight': 14.898143251405573}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,467] Trial 74 finished with value: 0.6233253253253253 and parameters: {'num_leaves': 94, 'max_depth': 4, 'learning_rate': 0.0360817406278643, 'n_estimators': 174, 'min_child_samples': 18, 'subsample': 0.5889007271901545, 'colsample_bytree': 0.9980575269034838, 'reg_alpha': 0.5802310961646227, 'reg_lambda': 0.4268133640369734, 'scale_pos_weight': 13.522630661298612}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,549] Trial 75 finished with value: 0.7042503217503218 and parameters: {'num_leaves': 112, 'max_depth': 4, 'learning_rate': 0.04828741870067467, 'n_estimators': 126, 'min_child_samples': 13, 'subsample': 0.5197346265109131, 'colsample_bytree': 0.925838893152296, 'reg_alpha': 0.6646092665128581, 'reg_lambda': 0.2139049787299283, 'scale_pos_weight': 18.533293374113942}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,634] Trial 76 finished with value: 0.5964590013742557 and parameters: {'num_leaves': 112, 'max_depth': 5, 'learning_rate': 0.06172862844570531, 'n_estimators': 126, 'min_child_samples': 13, 'subsample': 0.5086162337645839, 'colsample_bytree': 0.9263192231124544, 'reg_alpha': 0.5288552457838149, 'reg_lambda': 0.20526860678104103, 'scale_pos_weight': 19.536579581231173}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,897] Trial 77 finished with value: 0.32785373608903023 and parameters: {'num_leaves': 74, 'max_depth': 12, 'learning_rate': 0.06859884079332479, 'n_estimators': 199, 'min_child_samples': 9, 'subsample': 0.5474872158462951, 'colsample_bytree': 0.9051744545449684, 'reg_alpha': 0.6509171566347512, 'reg_lambda': 0.17310433427429076, 'scale_pos_weight': 19.312639620984015}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:01,976] Trial 78 finished with value: 0.6233127980922099 and parameters: {'num_leaves': 123, 'max_depth': 3, 'learning_rate': 0.04871864704700732, 'n_estimators': 91, 'min_child_samples': 11, 'subsample': 0.5316446690196344, 'colsample_bytree': 0.878984977622084, 'reg_alpha': 0.7176561464760326, 'reg_lambda': 0.2493533745753196, 'scale_pos_weight': 10.283678396326646}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:02,106] Trial 79 finished with value: 0.7042784602784603 and parameters: {'num_leaves': 86, 'max_depth': 4, 'learning_rate': 0.030306230437585728, 'n_estimators': 217, 'min_child_samples': 21, 'subsample': 0.5860354556122827, 'colsample_bytree': 0.8633764923788376, 'reg_alpha': 0.6762477942717176, 'reg_lambda': 0.2714261212843705, 'scale_pos_weight': 18.154935043380178}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:02,254] Trial 80 finished with value: 0.3270515970515971 and parameters: {'num_leaves': 126, 'max_depth': 5, 'learning_rate': 0.20613432480065713, 'n_estimators': 215, 'min_child_samples': 22, 'subsample': 0.5218415193251372, 'colsample_bytree': 0.922613796320431, 'reg_alpha': 0.6131626009334944, 'reg_lambda': 0.2886558916022114, 'scale_pos_weight': 18.38565834754654}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:02,358] Trial 81 finished with value: 0.0 and parameters: {'num_leaves': 87, 'max_depth': 3, 'learning_rate': 0.031209551113001825, 'n_estimators': 179, 'min_child_samples': 20, 'subsample': 0.6130516540650724, 'colsample_bytree': 0.9413254225668007, 'reg_alpha': 0.6652590786401906, 'reg_lambda': 0.23290375864512883, 'scale_pos_weight': 18.768743135839014}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:02,472] Trial 82 finished with value: 0.0 and parameters: {'num_leaves': 99, 'max_depth': 4, 'learning_rate': 0.025192101140639245, 'n_estimators': 146, 'min_child_samples': 15, 'subsample': 0.5536736329753016, 'colsample_bytree': 0.8737779340463573, 'reg_alpha': 0.8309436248734354, 'reg_lambda': 0.32379834407317093, 'scale_pos_weight': 18.8240807586193}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:02,581] Trial 83 finished with value: 0.6502486486486487 and parameters: {'num_leaves': 117, 'max_depth': 4, 'learning_rate': 0.04485436697625924, 'n_estimators': 214, 'min_child_samples': 17, 'subsample': 0.5199190770541383, 'colsample_bytree': 0.955715813795501, 'reg_alpha': 0.7029031013756412, 'reg_lambda': 0.26787769906658115, 'scale_pos_weight': 19.919736150633966}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:02,670] Trial 84 finished with value: 0.0 and parameters: {'num_leaves': 111, 'max_depth': 3, 'learning_rate': 0.030139789437768467, 'n_estimators': 183, 'min_child_samples': 11, 'subsample': 0.5870428515665238, 'colsample_bytree': 0.8598251333719178, 'reg_alpha': 0.5888808236988698, 'reg_lambda': 0.21775099937696601, 'scale_pos_weight': 17.996756229327318}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:02,761] Trial 85 finished with value: 0.5425607425607426 and parameters: {'num_leaves': 80, 'max_depth': 4, 'learning_rate': 0.05158082606848788, 'n_estimators': 191, 'min_child_samples': 14, 'subsample': 0.6943675506171962, 'colsample_bytree': 0.9072328962939806, 'reg_alpha': 0.5308260156901172, 'reg_lambda': 0.3094876225685933, 'scale_pos_weight': 11.986450534314255}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:02,893] Trial 86 finished with value: 0.3808783783783784 and parameters: {'num_leaves': 122, 'max_depth': 5, 'learning_rate': 0.0857152980972399, 'n_estimators': 203, 'min_child_samples': 13, 'subsample': 0.7152743274392708, 'colsample_bytree': 0.8904087863447024, 'reg_alpha': 0.4441649365416984, 'reg_lambda': 0.3658901429172264, 'scale_pos_weight': 14.08706917012855}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:03,345] Trial 87 finished with value: 0.0 and parameters: {'num_leaves': 69, 'max_depth': 3, 'learning_rate': 0.0376144922780151, 'n_estimators': 222, 'min_child_samples': 26, 'subsample': 0.6395224939935916, 'colsample_bytree': 0.9380396280826667, 'reg_alpha': 0.6369526735688886, 'reg_lambda': 0.1116760106086962, 'scale_pos_weight': 16.041270762367994}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:03,425] Trial 88 finished with value: 0.7042503217503218 and parameters: {'num_leaves': 91, 'max_depth': 4, 'learning_rate': 0.0592778312557439, 'n_estimators': 103, 'min_child_samples': 18, 'subsample': 0.5620879271298778, 'colsample_bytree': 0.8297839346072087, 'reg_alpha': 0.6807296067933603, 'reg_lambda': 0.1698433509413768, 'scale_pos_weight': 17.795154720197857}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:03,522] Trial 89 finished with value: 0.5152252252252252 and parameters: {'num_leaves': 90, 'max_depth': 6, 'learning_rate': 0.05692526239065367, 'n_estimators': 106, 'min_child_samples': 18, 'subsample': 0.5527801265694581, 'colsample_bytree': 0.9030399201509034, 'reg_alpha': 0.551964130231466, 'reg_lambda': 0.19940505568606803, 'scale_pos_weight': 18.118986126582723}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:03,602] Trial 90 finished with value: 0.5422072072072073 and parameters: {'num_leaves': 109, 'max_depth': 4, 'learning_rate': 0.10106919742196012, 'n_estimators': 99, 'min_child_samples': 21, 'subsample': 0.5789657539560112, 'colsample_bytree': 0.8708191868946766, 'reg_alpha': 0.7357952444437048, 'reg_lambda': 0.23286057487742973, 'scale_pos_weight': 16.747124837645284}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:03,684] Trial 91 finished with value: 0.5961438903692425 and parameters: {'num_leaves': 106, 'max_depth': 4, 'learning_rate': 0.07674261264574213, 'n_estimators': 121, 'min_child_samples': 17, 'subsample': 0.5606635179712223, 'colsample_bytree': 0.8357787578374857, 'reg_alpha': 0.6811568711261726, 'reg_lambda': 0.15197879714044593, 'scale_pos_weight': 17.70399631143503}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:03,770] Trial 92 finished with value: 0.650292484265087 and parameters: {'num_leaves': 113, 'max_depth': 3, 'learning_rate': 0.06235291191163958, 'n_estimators': 137, 'min_child_samples': 12, 'subsample': 0.7346582406021377, 'colsample_bytree': 0.9682767369871148, 'reg_alpha': 0.604059805135838, 'reg_lambda': 0.17586850511617155, 'scale_pos_weight': 12.907390618873357}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:03,828] Trial 93 finished with value: 0.0 and parameters: {'num_leaves': 104, 'max_depth': 3, 'learning_rate': 0.026127679149833934, 'n_estimators': 52, 'min_child_samples': 24, 'subsample': 0.518035212262141, 'colsample_bytree': 0.9503006516743426, 'reg_alpha': 0.7078429558693351, 'reg_lambda': 0.29631269229634394, 'scale_pos_weight': 19.102988508185206}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:03,913] Trial 94 finished with value: 0.5691954745443117 and parameters: {'num_leaves': 94, 'max_depth': 5, 'learning_rate': 0.023025338702140335, 'n_estimators': 89, 'min_child_samples': 15, 'subsample': 0.6058295652637514, 'colsample_bytree': 0.8291532545215459, 'reg_alpha': 0.6514489535076178, 'reg_lambda': 0.27105048069823884, 'scale_pos_weight': 15.386072141139035}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:04,068] Trial 95 finished with value: 0.5428393911152533 and parameters: {'num_leaves': 102, 'max_depth': 8, 'learning_rate': 0.018814181037160812, 'n_estimators': 163, 'min_child_samples': 9, 'subsample': 0.577844203916621, 'colsample_bytree': 0.9194064430506825, 'reg_alpha': 0.6731678949645827, 'reg_lambda': 0.0651654599226375, 'scale_pos_weight': 17.247234512796688}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:04,167] Trial 96 finished with value: 0.6504531599268442 and parameters: {'num_leaves': 86, 'max_depth': 4, 'learning_rate': 0.05021990418955577, 'n_estimators': 173, 'min_child_samples': 19, 'subsample': 0.6730069988042645, 'colsample_bytree': 0.9890239748952049, 'reg_alpha': 0.7439258705330046, 'reg_lambda': 0.8352250891337847, 'scale_pos_weight': 14.526014113505383}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:04,256] Trial 97 finished with value: 0.6504004734661669 and parameters: {'num_leaves': 121, 'max_depth': 3, 'learning_rate': 0.033369687267734434, 'n_estimators': 207, 'min_child_samples': 14, 'subsample': 0.8112739310129581, 'colsample_bytree': 0.9311024916884795, 'reg_alpha': 0.507672183158312, 'reg_lambda': 0.11381224065525868, 'scale_pos_weight': 10.933955683128682}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:04,353] Trial 98 finished with value: 0.6232300132300133 and parameters: {'num_leaves': 97, 'max_depth': 4, 'learning_rate': 0.028894233597528653, 'n_estimators': 169, 'min_child_samples': 11, 'subsample': 0.7521149330357533, 'colsample_bytree': 0.8654125339454655, 'reg_alpha': 0.6254202961572318, 'reg_lambda': 0.14258127055549774, 'scale_pos_weight': 14.0756376565701}. Best is trial 57 with value: 0.7313562357538261.
# [I 2026-01-19 13:55:04,443] Trial 99 finished with value: 0.7043587536581167 and parameters: {'num_leaves': 82, 'max_depth': 3, 'learning_rate': 0.07103467911658534, 'n_estimators': 198, 'min_child_samples': 13, 'subsample': 0.5680478918658953, 'colsample_bytree': 0.9656720913275707, 'reg_alpha': 0.7169521374889061, 'reg_lambda': 0.20939210861272822, 'scale_pos_weight': 15.707560702730444}. Best is trial 57 with value: 0.7313562357538261.

# %%
# best_params_lgbm = grid_lgbm.best_params_

# %%
best_params_lgbm = study_lgbm.best_params

# %%
print(best_params_lgbm)
# Out:
# {'num_leaves': 110, 'max_depth': 3, 'learning_rate': 0.04446640803681436, 'n_estimators': 160, 'min_child_samples': 12, 'subsample': 0.7638049499688528, 'colsample_bytree': 0.9226878621150694, 'reg_alpha': 0.7317575458078548, 'reg_lambda': 0.27116820333190483, 'scale_pos_weight': 13.724103802090282}

# %%
final_classifier = lgb.LGBMClassifier(**best_params_lgbm, random_state=42, verbose=-1)

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# LGBMClassifier(colsample_bytree=0.9226878621150694,
#                learning_rate=0.04446640803681436, max_depth=3,
#                min_child_samples=12, n_estimators=160, num_leaves=110,
#                random_state=42, reg_alpha=0.7317575458078548,
#                reg_lambda=0.27116820333190483,
#                scale_pos_weight=13.724103802090282,
#                subsample=0.7638049499688528, verbose=-1)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[590 139]
#  [ 10  27]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.8054830287206266

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.16265060240963855

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.7297297297297297

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.4299363057324841

# %% [markdown]
# ### Threshold tuning

# %%
best_threshold = 0.5

# %%
best_precision_score = 0

# %%
best_recall_score = 0

# %%
best_f2_score = 0

# %%
for threshold in np.arange(0.1, 0.95, 0.05):
    y_pred_val_threshold = (y_proba_val >= threshold).astype(int)
    recall = recall_score(y_val, y_pred_val_threshold)
    precision = precision_score(y_val, y_pred_val_threshold)
    f2_score = fbeta_score(y_val, y_pred_val_threshold, beta=2)
    
    print(f'Threshold {threshold} has recall score {f2_score}')
    
    if precision >= 0.15:
        current_recall_score = recall
        if current_recall_score > best_recall_score:
            best_recall_score = current_recall_score
            best_precision_score = precision
            best_threshold = threshold
        elif current_recall_score == best_recall_score and precision > best_precision_score:
            best_precision_score = precision
            best_threshold = threshold
        
        # current_f2_score = f2_score
        # if current_f2_score > best_f2_score:
        #     best_f2_score = current_f2_score
        #     best_threshold = threshold
# Out:
# Threshold 0.1 has recall score 0.3248031496062992
# Threshold 0.15000000000000002 has recall score 0.32563025210084034
# Threshold 0.20000000000000004 has recall score 0.33916849015317285
# Threshold 0.25000000000000006 has recall score 0.3464203233256351
# Threshold 0.30000000000000004 has recall score 0.3588516746411483
# Threshold 0.3500000000000001 has recall score 0.35714285714285715
# Threshold 0.40000000000000013 has recall score 0.3835616438356164
# Threshold 0.45000000000000007 has recall score 0.4017857142857143
# Threshold 0.5000000000000001 has recall score 0.4299363057324841
# Threshold 0.5500000000000002 has recall score 0.43252595155709345
# Threshold 0.6000000000000002 has recall score 0.41509433962264153
# Threshold 0.6500000000000001 has recall score 0.425531914893617
# Threshold 0.7000000000000002 has recall score 0.4460093896713615
# Threshold 0.7500000000000002 has recall score 0.34574468085106386
# Threshold 0.8000000000000002 has recall score 0.20114942528735633
# Threshold 0.8500000000000002 has recall score 0.0949367088607595
# Threshold 0.9000000000000002 has recall score 0.03333333333333333

# %%
print(best_threshold)
# Out:
# 0.5000000000000001

# %%
print(best_recall_score)
# Out:
# 0.7297297297297297

# %% [markdown]
# ### Retrain on training + validation set

# %%
X_train_full = pd.concat([X_train_res_retained, X_val_retained], axis=0, ignore_index=True)
y_train_full = pd.concat([y_train_res, y_val], axis=0, ignore_index=True)

# %%
final_classifier.fit(X_train_full, y_train_full)
# Out:
# LGBMClassifier(colsample_bytree=0.9226878621150694,
#                learning_rate=0.04446640803681436, max_depth=3,
#                min_child_samples=12, n_estimators=160, num_leaves=110,
#                random_state=42, reg_alpha=0.7317575458078548,
#                reg_lambda=0.27116820333190483,
#                scale_pos_weight=13.724103802090282,
#                subsample=0.7638049499688528, verbose=-1)

# %% [markdown]
# ### Evaluate on test set

# %%
X_test_retained = X_test[retained_columns]

# %%
y_pred_test = final_classifier.predict(X_test_retained)

# %%
y_proba_test = final_classifier.predict_proba(X_test_retained)[:, 1]

# %%
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[589 140]
#  [ 10  28]]

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.8044328552803129

# %%
print(precision_score(y_test, y_pred_test))
# Out:
# 0.16666666666666666

# %%
print(recall_score(y_test, y_pred_test))
# Out:
# 0.7368421052631579

# %%
print(fbeta_score(y_test, y_pred_test, beta=2))
# Out:
# 0.4375
