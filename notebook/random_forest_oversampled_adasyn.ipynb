# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_26096\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_26096\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### ADASYN Oversampling on Training Data

# %%
resampler = ADASYN()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = RandomForestClassifier(random_state=42)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Gini Importance': importances}).sort_values(
    'Gini Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Gini Importance
# 0                              age         0.202335
# 20                age_ever_married         0.155914
# 18     smoking_status_never_smoked         0.064717
# 4                avg_glucose_level         0.058891
# 16          smoking_status_unknown         0.056230
# 24           log_avg_glucose_level         0.055505
# 5                              bmi         0.054453
# 23                         log_bmi         0.049607
# 13               work_type_private         0.031365
# 8                            smoke         0.030005
# 14         work_type_self_employed         0.028518
# 11              work_type_govt_job         0.027577
# 21                           obese         0.026781
# 17  smoking_status_formerly_smoked         0.026389
# 7                            urban         0.026085
# 19           smoking_status_smokes         0.022534
# 3                     ever_married         0.021526
# 6                             male         0.020043
# 22          high_avg_glucose_level         0.008964
# 15              work_type_children         0.008006
# 1                     hypertension         0.007955
# 10   hypertension_or_heart_disease         0.007591
# 2                    heart_disease         0.005324
# 9                        have_work         0.003509
# 12          work_type_never_worked         0.000174

# %% [markdown]
# ### Feature selection

# %%
retained_columns = ['age', 'smoking_status_never_smoked', 'avg_glucose_level', 'smoking_status_unknown', 'bmi', 'work_type_private', 'work_type_self_employed', 'smoking_status_formerly_smoked', 'work_type_govt_job', 'urban']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create grid for hyperparameter tuning with GridSearchCV

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'class_weight': ['balanced', 'balanced_subsample']
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_rf = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_rf,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.15

# %%
def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample']),
        'random_state': 42
    }
    
    model = RandomForestClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    f2_score = fbeta_score(y_val, y_pred_val, beta=2)
    
    if precision < MIN_PRECISION:
        return 0
    # return recall + (precision * 0.01)
    return f2_score

# %% [markdown]
# ### Hyperparameter tuning

# %%
# grid_rf.fit(X_train_res_retained, y_train_res)

# %%
study_rf = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_rf.optimize(objective_rf, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 17:10:30,788] A new study created in memory with name: no-name-72c3044e-941b-4a98-af22-92fcea32eb9e
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 17:10:32,126] Trial 0 finished with value: 0.21951219512195122 and parameters: {'n_estimators': 144, 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.21951219512195122.
# [I 2026-01-19 17:10:33,488] Trial 1 finished with value: 0.0 and parameters: {'n_estimators': 227, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.21951219512195122.
# [I 2026-01-19 17:10:35,711] Trial 2 finished with value: 0.0 and parameters: {'n_estimators': 158, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.21951219512195122.
# [I 2026-01-19 17:10:38,404] Trial 3 finished with value: 0.0 and parameters: {'n_estimators': 179, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 0 with value: 0
 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 39 with value: 0.33472803347280333.
# [I 2026-01-19 17:12:38,471] Trial 71 finished with value: 0.3333333333333333 and parameters: {'n_estimators': 229, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 39 with value: 0.33472803347280333.
# [I 2026-01-19 17:12:40,514] Trial 72 finished with value: 0.3138075313807531 and parameters: {'n_estimators': 232, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 39 with value: 0.33472803347280333.
# [I 2026-01-19 17:12:42,247] Trial 73 finished with value: 0.0 and parameters: {'n_estimators': 246, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 39 with value: 0.33472803347280333.
# [I 2026-01-19 17:12:43,574] Trial 74 finished with value: 0.35587188612099646 and parameters: {'n_estimators': 202, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:45,087] Trial 75 finished with value: 0.35587188612099646 and parameters: {'n_estimators': 204, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:46,450] Trial 76 finished with value: 0.0 and parameters: {'n_estimators': 202, 'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:51,133] Trial 77 finished with value: 0.0 and parameters: {'n_estimators': 261, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:52,335] Trial 78 finished with value: 0.0 and parameters: {'n_estimators': 224, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:53,193] Trial 79 finished with value: 0.0 and parameters: {'n_estimators': 167, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:54,504] Trial 80 finished with value: 0.0 and parameters: {'n_estimators': 229, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:55,676] Trial 81 finished with value: 0.0 and parameters: {'n_estimators': 210, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:56,799] Trial 82 finished with value: 0.0 and parameters: {'n_estimators': 199, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:57,920] Trial 83 finished with value: 0.3305785123966942 and parameters: {'n_estimators': 187, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:12:59,866] Trial 84 finished with value: 0.0 and parameters: {'n_estimators': 300, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:00,886] Trial 85 finished with value: 0.0 and parameters: {'n_estimators': 185, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:02,190] Trial 86 finished with value: 0.0 and parameters: {'n_estimators': 220, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:02,927] Trial 87 finished with value: 0.0 and parameters: {'n_estimators': 158, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:04,623] Trial 88 finished with value: 0.2928870292887029 and parameters: {'n_estimators': 195, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:06,464] Trial 89 finished with value: 0.2558139534883721 and parameters: {'n_estimators': 239, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:07,281] Trial 90 finished with value: 0.0 and parameters: {'n_estimators': 61, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:08,711] Trial 91 finished with value: 0.32786885245901637 and parameters: {'n_estimators': 207, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:10,218] Trial 92 finished with value: 0.3056768558951965 and parameters: {'n_estimators': 213, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:12,065] Trial 93 finished with value: 0.2511415525114155 and parameters: {'n_estimators': 203, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:13,638] Trial 94 finished with value: 0.32786885245901637 and parameters: {'n_estimators': 189, 'max_depth': 7, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:14,872] Trial 95 finished with value: 0.0 and parameters: {'n_estimators': 180, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:16,342] Trial 96 finished with value: 0.32388663967611336 and parameters: {'n_estimators': 195, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:17,455] Trial 97 finished with value: 0.28761061946902655 and parameters: {'n_estimators': 87, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:18,932] Trial 98 finished with value: 0.0 and parameters: {'n_estimators': 215, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.
# [I 2026-01-19 17:13:20,535] Trial 99 finished with value: 0.0 and parameters: {'n_estimators': 224, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 74 with value: 0.35587188612099646.

# %%
# best_params_rf = grid_rf.best_params_

# %%
best_params_rf = study_rf.best_params

# %%
print(best_params_rf)
# Out:
# {'n_estimators': 202, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced'}

# %%
final_classifier = RandomForestClassifier(**best_params_rf, random_state=42)

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=5, min_samples_leaf=8,
#                        min_samples_split=17, n_estimators=202, random_state=42)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[616 113]
#  [ 17  20]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.8302872062663186

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.15037593984962405

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.5405405405405406

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.35587188612099646
