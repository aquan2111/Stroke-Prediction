# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_30456\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_30456\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### Random Oversampling on Training Data

# %%
resampler = RandomOverSampler()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = xgb.XGBClassifier(random_state=42, eval_metric='logloss')

# %% [markdown]
# ### Create grid for hyperparameter tuning

# %%
param_grid_xgb = {
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'scale_pos_weight': [1, 3, 5, 10, 15, 20]
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_xgb = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_xgb,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Importance': importances}).sort_values(
    'Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Importance
# 0                              age    0.226049
# 10   hypertension_or_heart_disease    0.083619
# 3                     ever_married    0.062250
# 11              work_type_govt_job    0.061575
# 5                              bmi    0.056118
# 1                     hypertension    0.054868
# 19           smoking_status_smokes    0.048406
# 4                avg_glucose_level    0.047120
# 2                    heart_disease    0.047007
# 20                age_ever_married    0.046953
# 14         work_type_self_employed    0.041129
# 17  smoking_status_formerly_smoked    0.038121
# 16          smoking_status_unknown    0.037818
# 7                            urban    0.037628
# 8                            smoke    0.037051
# 6                             male    0.028850
# 13               work_type_private    0.024394
# 18     smoking_status_never_smoked    0.021044
# 23                         log_bmi    0.000000
# 21                           obese    0.000000
# 22          high_avg_glucose_level    0.000000
# 12          work_type_never_worked    0.000000
# 15              work_type_children    0.000000
# 9                        have_work    0.000000
# 24           log_avg_glucose_level    0.000000

# %% [markdown]
# ### Feature selection

# %%
retained_columns = ['age', 'ever_married', 'hypertension_or_heart_disease', 'smoking_status_smokes', 'bmi', 'avg_glucose_level', 'smoking_status_formerly_smoked', 'smoking_status_unknown', 'work_type_self_employed', 'smoke']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.15

# %%
def objective_xgb(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 7),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 1),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 15),
        'random_state': 42,
        'eval_metric': 'logloss'
    }
    
    model = xgb.XGBClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    f2_score = fbeta_score(y_val, y_pred_val, beta=2)
    
    if precision < MIN_PRECISION:
        return 0
    return recall + (precision * 0.01)
    # return f2_score

# %%
study_xgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_xgb.optimize(objective_xgb, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 23:46:53,996] A new study created in memory with name: no-name-3aeb8687-e39d-4ed4-933d-06b2eba784d3
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 23:46:54,294] Trial 0 finished with value: 0.3534148434148434 and parameters: {'max_depth': 9, 'learning_rate': 0.2536999076681772, 'n_estimators': 233, 'min_child_weight': 5, 'subsample': 0.5780093202212182, 'colsample_bytree': 0.5779972601681014, 'gamma': 0.05808361216819946, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 10.913016089144637}. Best is trial 0 with value: 0.3534148434148434.
# [I 2026-01-19 23:46:54,482] Trial 1 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.2708160864249968, 'n_estimators': 258, 'min_child_weight': 2, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'gamma': 0.3042422429595377, 'reg_alpha': 0.5247564316322378, 'reg_lambda': 0.43194501864211576, 'scale_pos_weight': 5.077207962772587}. Best is trial 0 with value: 0.3534148434148434.
# [I 2026-01-19 23:46:54,820] Trial 2 finished with value: 0.5154926801801801 and parameters: {'max_depth': 14, 'learning_rate': 0.01607123851203988, 'n_estimators': 123, 'min_child_weight': 3, 'subsample': 0.728034992108518, 'colsample_bytree': 0.8925879806965068, 'gamma': 0.19967378215835974, 'reg_alpha': 0.5142344384136116, 'reg_lambda': 0.5924145688620425, 'scale_pos_weight': 1.6503057780799681}. Best is trial 2 with value: 0.5154926801801801.
# [I 2026-01-19 23:46:55,054] Trial 3 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.0178601378893971, 'n_estimators': 66, 'min_child_weight': 7, 'subsample': 0.9828160165372797, 'colsample_bytree': 0.9041986740582306, 'gamma': 0.3046137691733707, 'reg_alpha': 0.09767211400638387, 'reg_lambda': 0.6842330265121569, 'scale_pos_weight': 7.162134912354418}. Best is trial 2 with value: 0.5154926801801801.
# [I 2026-01-19 23:46:55,134] Trial 4 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.05388108577817234, 'n_estimators': 58, 'min_child_weight': 7, 'subsample': 0.6293899908000085, 'colsample_bytree': 0.831261142176991, 'gamma': 0.31171107608941095, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796, 'scale_pos_weight': 3.5879623773573783}. Best is trial 2 with value: 0.5154926801801801.
# [I 2026-01-19 23:46:55,511] Trial 5 finished with value: 0.2451997649823737 and parameters: {'max_depth': 20, 'learning_rate': 0.13962563737015762, 'n_estimators': 285, 'min_child_weight': 7, 'subsample': 0.7989499894055425, 'colsample_bytree': 0.9609371175115584, 'gamma': 0.0884925020519195, 'reg_alpha': 0.1959828624191452, 'reg_lambda': 0.045227288910538066, 'scale_pos_weight': 5.554624630685701}. Best is trial 2 with value: 0.5154926801801801.
# [I 2026-01-19 23:46:55,962] Trial 6 finished with value: 0.5962869022869023 and parameters: {'max_depth': 9, 'learning_rate': 0.02516607127550297, 'n_estimators': 258, 'min_child_weight': 3, 'subsample': 0.6404672548436904, 'colsample_bytree': 0.7713480415791243, 'gamma': 0.14092422497476265, 'reg_alpha': 0.8021969807540397, 'reg_lambda': 0.07455064367977082, 'scale_pos_weight': 14.816417112407242}. Best is trial 6 with value: 0.5962869022869023.
# [I 2026-01-19 23:46:56,097] Trial 7 finished with value: 0.70422317053896 and parameters: {'max_depth': 16, 'learning_rate': 0.019657448966046126, 'n_estimators': 51, 'min_child_weight': 6, 'subsample': 0.8534286719238086, 'colsample_bytree': 0.8645035840204937, 'gamma': 0.7712703466859457, 'reg_alpha': 0.07404465173409036, 'reg_lambda': 0.3584657285442726, 'scale_pos_weight': 2.622166833351816}. Best is trial 7 with value: 0.70422317053896.
# [I 2026-01-19 23:46:56,329] Trial 8 finished with value: 0.4077863577863578 and parameters: {'max_depth': 18, 'learning_rate': 0.08330803890301997, 'n_estimators': 133, 'min_child_weight': 1, 'subsample': 0.6554911608578311, 'colsample_bytree': 0.6625916610133735, 'gamma': 0.7296061783380641, 'reg_alpha': 0.6375574713552131, 'reg_lambda': 0.8872127425763265, 'scale_pos_weight': 7.61100895226729}. Best is trial 7 with value: 0.70422317053896.
# [I 2026-01-19 23:46:56,518] Trial 9 finished with value: 0.3804073638856248 and parameters: {'max_depth': 5, 'learning_rate': 0.1131225105716033, 'n_estimators': 240, 'min_child_weight': 4, 'subsample': 0.8854835899772805, 'colsample_bytree': 0.7468977981821954, 'gamma': 0.5227328293819941, 'reg_alpha': 0.42754101835854963, 'reg_lambda': 0.02541912674409519, 'scale_pos_weight': 2.5104799779062623}. Best is trial 7 with value: 0.70422317053896.
# [I 2026-01-19 23:46:56,918] Trial 10 finished with value: 0.7853345859228212 and parameters: {'max_depth': 16, 'learning_rate': 0.010206070557577008, 'n_estimators': 180, 'min_child_weight': 5, 'subsample': 0.8669883221005054, 'colsample_bytree': 0.6901464801259053, 'gamma': 0.9657008843759458, 'reg_alpha': 0.010922153829082418, 'reg_lambda': 0.3021984369842996, 'scale_pos_weight': 10.294192614408253}. Best is trial 10 with value: 0.7853345859228212.
# [I 2026-01-19 23:46:57,369] Trial 11 finished with value: 0.7583210025668127 and parameters: {'max_depth': 16, 'learning_rate': 0.01031754361271033, 'n_estimators': 180, 'min_child_weight': 5, 'subsample': 0.8665006740490948, 'colsample_bytree': 0.7058589507532047, 'gamma': 0.9946900761935068, 'reg_alpha': 0.004248209669097774, 'reg_lambda': 0.3110348593526827, 'scale_pos_weight': 10.863536600179074}. Best is trial 10 with value: 0.7853345859228212.
# [I 2026-01-19 23:46:57,791] Trial 12 finished with value: 0.758329790464622 and parameters: {'max_depth': 16, 'learning_rate': 0.010441783493626143, 'n_estimators': 181, 'min_child_weight': 5, 'subsample': 0.9714168349599798, 'colsample_bytree': 0.6730693287995818, 'gamma': 0.9920380497943113, 'reg_alpha': 0.22713901165087858, 'reg_lambda': 0.2647546873991115, 'scale_pos_weight': 11.428967871698166}. Best is trial 10 with value: 0.7853345859228212.
# [I 2026-01-19 23:46:58,315] Trial 13 finished with value: 0.7854409266409266 and parameters: {'max_depth': 20, 'learning_rate': 0.010154871435763517, 'n_estimators': 186, 'min_child_weight': 5, 'subsample': 0.9985129955349379, 'colsample_bytree': 0.6550186135528008, 'gamma': 0.987011647915453, 'reg_alpha': 0.30344630088855795, 'reg_lambda': 0.2166573503023841, 'scale_pos_weight': 11.162291834716905}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:46:58,707] Trial 14 finished with value: 0.4886551611852817 and parameters: {'max_depth': 20, 'learning_rate': 0.04200211318096981, 'n_estimators': 207, 'min_child_weight': 4, 'subsample': 0.9190518159198487, 'colsample_bytree': 0.5226696625381084, 'gamma': 0.7994491510456678, 'reg_alpha': 0.2879092994650642, 'reg_lambda': 0.19983046298953924, 'scale_pos_weight': 13.014257601337663}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:46:58,973] Trial 15 finished with value: 0.70422317053896 and parameters: {'max_depth': 18, 'learning_rate': 0.03214580136370649, 'n_estimators': 137, 'min_child_weight': 6, 'subsample': 0.5023700598265448, 'colsample_bytree': 0.6195356905949762, 'gamma': 0.8701557644685571, 'reg_alpha': 0.3558507159649593, 'reg_lambda': 0.17801390192299937, 'scale_pos_weight': 9.387782075370058}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:46:59,239] Trial 16 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.014690166512154278, 'n_estimators': 151, 'min_child_weight': 6, 'subsample': 0.7929841127845034, 'colsample_bytree': 0.511847705752916, 'gamma': 0.6052498869350371, 'reg_alpha': 0.16186496013429225, 'reg_lambda': 0.4360998335722802, 'scale_pos_weight': 8.955242459720562}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:46:59,595] Trial 17 finished with value: 0.6234470184470184 and parameters: {'max_depth': 18, 'learning_rate': 0.025694047513937654, 'n_estimators': 101, 'min_child_weight': 3, 'subsample': 0.938944366664203, 'colsample_bytree': 0.7956474358611872, 'gamma': 0.8925302191289418, 'reg_alpha': 0.6972447565686001, 'reg_lambda': 0.1893370949068336, 'scale_pos_weight': 12.982272783345161}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:00,095] Trial 18 finished with value: 0.758384663733501 and parameters: {'max_depth': 14, 'learning_rate': 0.010069201938260164, 'n_estimators': 212, 'min_child_weight': 5, 'subsample': 0.9965327158373527, 'colsample_bytree': 0.7179980556436268, 'gamma': 0.602022777786361, 'reg_alpha': 0.032480218395115036, 'reg_lambda': 0.7319970889891716, 'scale_pos_weight': 12.769721204825194}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:00,461] Trial 19 finished with value: 0.5966898326898328 and parameters: {'max_depth': 20, 'learning_rate': 0.03724758407777502, 'n_estimators': 164, 'min_child_weight': 4, 'subsample': 0.8116080709985092, 'colsample_bytree': 0.6351443165279888, 'gamma': 0.6980966400054011, 'reg_alpha': 0.9813130867582933, 'reg_lambda': 0.9938427850497087, 'scale_pos_weight': 9.10091006204129}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:00,881] Trial 20 finished with value: 0.0 and parameters: {'max_depth': 17, 'learning_rate': 0.014192869196794874, 'n_estimators': 194, 'min_child_weight': 6, 'subsample': 0.7263831575702958, 'colsample_bytree': 0.5672509330034889, 'gamma': 0.9117146279116282, 'reg_alpha': 0.33236764537473795, 'reg_lambda': 0.44677372941644855, 'scale_pos_weight': 14.574468093551545}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:01,481] Trial 21 finished with value: 0.6772680323635738 and parameters: {'max_depth': 13, 'learning_rate': 0.011589319080884038, 'n_estimators': 213, 'min_child_weight': 5, 'subsample': 0.9880132485249431, 'colsample_bytree': 0.7283588846648559, 'gamma': 0.637977736103486, 'reg_alpha': 0.02873721860276618, 'reg_lambda': 0.7470875994109166, 'scale_pos_weight': 12.589588848191092}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:02,146] Trial 22 finished with value: 0.5964749364749365 and parameters: {'max_depth': 14, 'learning_rate': 0.022510144612718143, 'n_estimators': 215, 'min_child_weight': 5, 'subsample': 0.9263803080437988, 'colsample_bytree': 0.6951071877368427, 'gamma': 0.46224279261125895, 'reg_alpha': 0.12022289464728603, 'reg_lambda': 0.8287592327595859, 'scale_pos_weight': 11.837658505040828}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:02,682] Trial 23 finished with value: 0.70422317053896 and parameters: {'max_depth': 11, 'learning_rate': 0.013435005198624998, 'n_estimators': 174, 'min_child_weight': 4, 'subsample': 0.9948503294499998, 'colsample_bytree': 0.7972167156086554, 'gamma': 0.47034073377667496, 'reg_alpha': 0.24285822491524472, 'reg_lambda': 0.3512786202203141, 'scale_pos_weight': 10.224042504819638}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:03,758] Trial 24 finished with value: 0.7582868114015655 and parameters: {'max_depth': 15, 'learning_rate': 0.010484032982955499, 'n_estimators': 197, 'min_child_weight': 5, 'subsample': 0.9000458037453889, 'colsample_bytree': 0.6507037967815212, 'gamma': 0.8284339058204298, 'reg_alpha': 0.0034306147028449266, 'reg_lambda': 0.12607863720009752, 'scale_pos_weight': 13.71650419792001}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:04,497] Trial 25 finished with value: 0.6235224480679026 and parameters: {'max_depth': 19, 'learning_rate': 0.018353476955812933, 'n_estimators': 233, 'min_child_weight': 6, 'subsample': 0.9561189456318635, 'colsample_bytree': 0.7244278109981884, 'gamma': 0.9525170582852733, 'reg_alpha': 0.14307612494406655, 'reg_lambda': 0.27023457266352807, 'scale_pos_weight': 9.908284442085082}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:04,837] Trial 26 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.013317814189940587, 'n_estimators': 153, 'min_child_weight': 4, 'subsample': 0.8409504714423914, 'colsample_bytree': 0.6156748180353262, 'gamma': 0.5749190780339266, 'reg_alpha': 0.4278684033465028, 'reg_lambda': 0.4996337325817175, 'scale_pos_weight': 12.019715823024436}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:05,481] Trial 27 finished with value: 0.5426238738738739 and parameters: {'max_depth': 12, 'learning_rate': 0.027525834373649465, 'n_estimators': 294, 'min_child_weight': 5, 'subsample': 0.9436754581175855, 'colsample_bytree': 0.7679046485962018, 'gamma': 0.7096167076742876, 'reg_alpha': 0.2605892153569775, 'reg_lambda': 0.7549840918750789, 'scale_pos_weight': 8.432193704005847}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:05,762] Trial 28 finished with value: 0.6503038210624418 and parameters: {'max_depth': 15, 'learning_rate': 0.05058799463236139, 'n_estimators': 85, 'min_child_weight': 6, 'subsample': 0.7583631087011907, 'colsample_bytree': 0.6933362944493492, 'gamma': 0.8437709129467452, 'reg_alpha': 0.07224852156127587, 'reg_lambda': 0.1255508569074461, 'scale_pos_weight': 10.400695161293239}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:06,088] Trial 29 finished with value: 0.3807921714818267 and parameters: {'max_depth': 17, 'learning_rate': 0.18802532698289026, 'n_estimators': 226, 'min_child_weight': 3, 'subsample': 0.8941106498974993, 'colsample_bytree': 0.9992483437747102, 'gamma': 0.3960304246300297, 'reg_alpha': 0.380716979197826, 'reg_lambda': 0.6531428041893119, 'scale_pos_weight': 6.612120423237481}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:06,637] Trial 30 finished with value: 0.0 and parameters: {'max_depth': 10, 'learning_rate': 0.012872816471027702, 'n_estimators': 252, 'min_child_weight': 5, 'subsample': 0.9992563864089731, 'colsample_bytree': 0.5529691308907545, 'gamma': 0.6547056403471195, 'reg_alpha': 0.5993402374253344, 'reg_lambda': 0.36629293337409957, 'scale_pos_weight': 13.772226190412884}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:07,204] Trial 31 finished with value: 0.7583386776607116 and parameters: {'max_depth': 16, 'learning_rate': 0.01038858424024555, 'n_estimators': 185, 'min_child_weight': 5, 'subsample': 0.9622598521342883, 'colsample_bytree': 0.6724982090168407, 'gamma': 0.9653181353214655, 'reg_alpha': 0.20143718982659203, 'reg_lambda': 0.2807476944659316, 'scale_pos_weight': 11.644484320244626}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:07,806] Trial 32 finished with value: 0.677353528024669 and parameters: {'max_depth': 15, 'learning_rate': 0.01948740159608966, 'n_estimators': 183, 'min_child_weight': 5, 'subsample': 0.9546923708722097, 'colsample_bytree': 0.5996397542582691, 'gamma': 0.9311914171398176, 'reg_alpha': 0.17774888664078645, 'reg_lambda': 0.2669047395493331, 'scale_pos_weight': 10.958911062336197}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:08,576] Trial 33 finished with value: 0.7582784958871915 and parameters: {'max_depth': 13, 'learning_rate': 0.010132686953552782, 'n_estimators': 196, 'min_child_weight': 4, 'subsample': 0.9072052432662387, 'colsample_bytree': 0.6652659926386739, 'gamma': 0.9484367862292905, 'reg_alpha': 0.06824080230841739, 'reg_lambda': 0.5254630341137738, 'scale_pos_weight': 12.01377985782494}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:09,270] Trial 34 finished with value: 0.7042977947272426 and parameters: {'max_depth': 17, 'learning_rate': 0.015541473049504848, 'n_estimators': 164, 'min_child_weight': 6, 'subsample': 0.9605374379650028, 'colsample_bytree': 0.7238704509187575, 'gamma': 0.9941155926265572, 'reg_alpha': 0.2990812573444706, 'reg_lambda': 0.39233640781372736, 'scale_pos_weight': 13.627026537673274}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:09,657] Trial 35 finished with value: 0.5159185768046527 and parameters: {'max_depth': 14, 'learning_rate': 0.07135052613549166, 'n_estimators': 119, 'min_child_weight': 4, 'subsample': 0.9991403039555717, 'colsample_bytree': 0.6841787747408874, 'gamma': 0.7765719946645362, 'reg_alpha': 0.12394829678105035, 'reg_lambda': 0.2240400862263036, 'scale_pos_weight': 10.838224238217695}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:10,515] Trial 36 finished with value: 0.4346546546546547 and parameters: {'max_depth': 19, 'learning_rate': 0.016681149854528187, 'n_estimators': 272, 'min_child_weight': 2, 'subsample': 0.8342744191531065, 'colsample_bytree': 0.6407020167636455, 'gamma': 0.8774471901422191, 'reg_alpha': 0.04595801927288462, 'reg_lambda': 0.5924991803588647, 'scale_pos_weight': 9.721763226522745}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:11,148] Trial 37 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.013609353701531724, 'n_estimators': 207, 'min_child_weight': 7, 'subsample': 0.9311493133753258, 'colsample_bytree': 0.5887663591658137, 'gamma': 0.0014500117927535028, 'reg_alpha': 0.20934823212179532, 'reg_lambda': 0.11150534839078288, 'scale_pos_weight': 8.277140850753355}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:11,526] Trial 38 finished with value: 0.0 and parameters: {'max_depth': 7, 'learning_rate': 0.022068061822075883, 'n_estimators': 228, 'min_child_weight': 5, 'subsample': 0.8777051321923496, 'colsample_bytree': 0.8137766917498691, 'gamma': 0.36840378089084647, 'reg_alpha': 0.1212599396904124, 'reg_lambda': 0.4852578446736177, 'scale_pos_weight': 12.626882855124764}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:11,945] Trial 39 finished with value: 0.0 and parameters: {'max_depth': 12, 'learning_rate': 0.012072121492579246, 'n_estimators': 150, 'min_child_weight': 5, 'subsample': 0.9660200686836317, 'colsample_bytree': 0.7515103103472637, 'gamma': 0.21286635221015604, 'reg_alpha': 0.4196419142368217, 'reg_lambda': 0.3220571496488857, 'scale_pos_weight': 11.495691559769295}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:12,411] Trial 40 finished with value: 0.32667726550079496 and parameters: {'max_depth': 19, 'learning_rate': 0.2720527950991961, 'n_estimators': 242, 'min_child_weight': 6, 'subsample': 0.6760140488592352, 'colsample_bytree': 0.7058375785455119, 'gamma': 0.22686142252995373, 'reg_alpha': 0.1928206616354733, 'reg_lambda': 0.0019540570082597353, 'scale_pos_weight': 6.8640517176284}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:13,084] Trial 41 finished with value: 0.7583386776607116 and parameters: {'max_depth': 16, 'learning_rate': 0.010264301066643026, 'n_estimators': 185, 'min_child_weight': 5, 'subsample': 0.9692187034163856, 'colsample_bytree': 0.6719936585568064, 'gamma': 0.9836954797149442, 'reg_alpha': 0.22823676035329274, 'reg_lambda': 0.27159556506742627, 'scale_pos_weight': 11.442889720659997}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:13,621] Trial 42 finished with value: 0.7583752538665834 and parameters: {'max_depth': 16, 'learning_rate': 0.01163360123742478, 'n_estimators': 170, 'min_child_weight': 5, 'subsample': 0.9766281282385324, 'colsample_bytree': 0.6252654853607664, 'gamma': 0.9316633156936057, 'reg_alpha': 0.2970968395754674, 'reg_lambda': 0.2395957091644096, 'scale_pos_weight': 11.251412303750444}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:14,117] Trial 43 finished with value: 0.7583476658476659 and parameters: {'max_depth': 15, 'learning_rate': 0.011635103984251162, 'n_estimators': 171, 'min_child_weight': 5, 'subsample': 0.9213330583941948, 'colsample_bytree': 0.620951340823109, 'gamma': 0.8279624097623578, 'reg_alpha': 0.3064556799783448, 'reg_lambda': 0.15275247447820733, 'scale_pos_weight': 10.526299532660843}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:14,537] Trial 44 finished with value: 0.7042880685563613 and parameters: {'max_depth': 14, 'learning_rate': 0.01674578893993, 'n_estimators': 163, 'min_child_weight': 4, 'subsample': 0.9193133667413164, 'colsample_bytree': 0.5479739640111136, 'gamma': 0.8226440647570759, 'reg_alpha': 0.47694699310913, 'reg_lambda': 0.07758281813172178, 'scale_pos_weight': 10.40697451334419}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:14,929] Trial 45 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.012033272025139848, 'n_estimators': 142, 'min_child_weight': 6, 'subsample': 0.8690952445205096, 'colsample_bytree': 0.6033830353878624, 'gamma': 0.7492184188149538, 'reg_alpha': 0.5588393612195044, 'reg_lambda': 0.1512202063419152, 'scale_pos_weight': 12.445751599735095}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:15,297] Trial 46 finished with value: 0.6504133545310016 and parameters: {'max_depth': 15, 'learning_rate': 0.015813408903424832, 'n_estimators': 120, 'min_child_weight': 4, 'subsample': 0.9804578355243124, 'colsample_bytree': 0.636808447279407, 'gamma': 0.8871295106680307, 'reg_alpha': 0.47511120581059185, 'reg_lambda': 0.21968735231360417, 'scale_pos_weight': 4.796871664175855}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:15,761] Trial 47 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.020596798424009955, 'n_estimators': 169, 'min_child_weight': 7, 'subsample': 0.5780732260013026, 'colsample_bytree': 0.5728950699921006, 'gamma': 0.9194073431246874, 'reg_alpha': 0.3159296995346732, 'reg_lambda': 0.07090528739068673, 'scale_pos_weight': 10.943143957325697}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:16,350] Trial 48 finished with value: 0.7045466743339084 and parameters: {'max_depth': 17, 'learning_rate': 0.012162973928377393, 'n_estimators': 199, 'min_child_weight': 5, 'subsample': 0.9349342181554309, 'colsample_bytree': 0.8809949115967088, 'gamma': 0.8530710473645805, 'reg_alpha': 0.38282284501019975, 'reg_lambda': 0.9501202093357981, 'scale_pos_weight': 7.747378969766229}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:16,604] Trial 49 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.21721161726640364, 'n_estimators': 219, 'min_child_weight': 1, 'subsample': 0.9046818134538201, 'colsample_bytree': 0.6155563255339965, 'gamma': 0.5419188917609379, 'reg_alpha': 0.6879237170681584, 'reg_lambda': 0.1686013542626733, 'scale_pos_weight': 8.753859993465188}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:16,948] Trial 50 finished with value: 0.46163894663894667 and parameters: {'max_depth': 16, 'learning_rate': 0.11760743995513974, 'n_estimators': 176, 'min_child_weight': 3, 'subsample': 0.9813139917208573, 'colsample_bytree': 0.5382050194779807, 'gamma': 0.6747664115909455, 'reg_alpha': 0.8386720040896887, 'reg_lambda': 0.41103651411328157, 'scale_pos_weight': 14.379872364159764}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:17,840] Trial 51 finished with value: 0.758329790464622 and parameters: {'max_depth': 16, 'learning_rate': 0.011293524743675787, 'n_estimators': 185, 'min_child_weight': 5, 'subsample': 0.9496968228813318, 'colsample_bytree': 0.6558639897531244, 'gamma': 0.9496104521769931, 'reg_alpha': 0.2722593766560898, 'reg_lambda': 0.3246179966720376, 'scale_pos_weight': 13.1457684346126}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:19,452] Trial 52 finished with value: 0.7583567567567568 and parameters: {'max_depth': 15, 'learning_rate': 0.010079529065496067, 'n_estimators': 157, 'min_child_weight': 5, 'subsample': 0.9796955825416365, 'colsample_bytree': 0.7455947688900741, 'gamma': 0.7977158308098903, 'reg_alpha': 0.35099214482592456, 'reg_lambda': 0.23369289084398212, 'scale_pos_weight': 9.398902899875239}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:20,085] Trial 53 finished with value: 0.758384663733501 and parameters: {'max_depth': 15, 'learning_rate': 0.014379436689677954, 'n_estimators': 132, 'min_child_weight': 6, 'subsample': 0.9740510436375763, 'colsample_bytree': 0.745010367449913, 'gamma': 0.7941809951320924, 'reg_alpha': 0.34885068686301035, 'reg_lambda': 0.22503320567319238, 'scale_pos_weight': 9.337403765351441}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:20,806] Trial 54 finished with value: 0.7853345859228212 and parameters: {'max_depth': 13, 'learning_rate': 0.01446146812026164, 'n_estimators': 128, 'min_child_weight': 6, 'subsample': 0.9786561886462755, 'colsample_bytree': 0.7569091188638949, 'gamma': 0.7783621153654044, 'reg_alpha': 0.34182767545798903, 'reg_lambda': 0.22772364637927744, 'scale_pos_weight': 9.855937425880413}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:21,404] Trial 55 finished with value: 0.0 and parameters: {'max_depth': 12, 'learning_rate': 0.01504046006926798, 'n_estimators': 105, 'min_child_weight': 7, 'subsample': 0.9999725593022748, 'colsample_bytree': 0.8467214000702917, 'gamma': 0.7512580651206854, 'reg_alpha': 0.40388792139775065, 'reg_lambda': 0.3108213384707843, 'scale_pos_weight': 9.720450890308133}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:22,142] Trial 56 finished with value: 0.48860413354531 and parameters: {'max_depth': 14, 'learning_rate': 0.017378351317341098, 'n_estimators': 136, 'min_child_weight': 6, 'subsample': 0.9411157159826529, 'colsample_bytree': 0.7686491356080057, 'gamma': 0.900410114336916, 'reg_alpha': 0.5181280475164616, 'reg_lambda': 0.1995931985573287, 'scale_pos_weight': 1.1654211774896446}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:22,618] Trial 57 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.013893685651748158, 'n_estimators': 101, 'min_child_weight': 6, 'subsample': 0.7811816973346488, 'colsample_bytree': 0.7823081548435188, 'gamma': 0.6299902967760791, 'reg_alpha': 0.45394142554133327, 'reg_lambda': 0.2423966726813626, 'scale_pos_weight': 8.817844888620296}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:23,515] Trial 58 finished with value: 0.731246583662314 and parameters: {'max_depth': 10, 'learning_rate': 0.025659234503945423, 'n_estimators': 125, 'min_child_weight': 6, 'subsample': 0.8546854263078302, 'colsample_bytree': 0.7385053515816902, 'gamma': 0.7039946664644118, 'reg_alpha': 0.3477334938139782, 'reg_lambda': 0.46792406392026564, 'scale_pos_weight': 9.993083047903927}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:24,091] Trial 59 finished with value: 0.6501871101871102 and parameters: {'max_depth': 18, 'learning_rate': 0.03329333541712587, 'n_estimators': 143, 'min_child_weight': 6, 'subsample': 0.5359053986477897, 'colsample_bytree': 0.7136736147469706, 'gamma': 0.7919574986167487, 'reg_alpha': 0.027258606227867185, 'reg_lambda': 0.6483688576579123, 'scale_pos_weight': 12.258472424667811}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:24,531] Trial 60 finished with value: 0.0 and parameters: {'max_depth': 20, 'learning_rate': 0.014743999142182046, 'n_estimators': 91, 'min_child_weight': 7, 'subsample': 0.97618852259759, 'colsample_bytree': 0.691655276881707, 'gamma': 0.571826483628138, 'reg_alpha': 0.15905699226954895, 'reg_lambda': 0.7984714913735456, 'scale_pos_weight': 11.202401514830774}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:26,314] Trial 61 finished with value: 0.7583476658476659 and parameters: {'max_depth': 13, 'learning_rate': 0.011313731940540516, 'n_estimators': 157, 'min_child_weight': 5, 'subsample': 0.9795773500397801, 'colsample_bytree': 0.7494029543648723, 'gamma': 0.8012890142477215, 'reg_alpha': 0.3474310445710642, 'reg_lambda': 0.22720907291408876, 'scale_pos_weight': 9.363278491158557}. Best is trial 13 with value: 0.7854409266409266.
# [I 2026-01-19 23:47:30,633] Trial 62 finished with value: 0.8124237140366173 and parameters: {'max_depth': 15, 'learning_rate': 0.012893533916898767, 'n_estimators': 134, 'min_child_weight': 6, 'subsample': 0.9822634135008492, 'colsample_bytree': 0.7863016340536831, 'gamma': 0.8616265540211223, 'reg_alpha': 0.37705101017059434, 'reg_lambda': 0.29186765334001574, 'scale_pos_weight': 9.11072558855006}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:33,540] Trial 63 finished with value: 0.7044714101856959 and parameters: {'max_depth': 17, 'learning_rate': 0.018470647730186213, 'n_estimators': 128, 'min_child_weight': 6, 'subsample': 0.950987327515295, 'colsample_bytree': 0.9225423382714222, 'gamma': 0.8740176634158813, 'reg_alpha': 0.2735281038520121, 'reg_lambda': 0.3719975422615471, 'scale_pos_weight': 8.112938362443423}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:34,186] Trial 64 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.0129775023310955, 'n_estimators': 113, 'min_child_weight': 7, 'subsample': 0.9124035085986435, 'colsample_bytree': 0.818817751686393, 'gamma': 0.9395778657272869, 'reg_alpha': 0.09088221882847743, 'reg_lambda': 0.32041052319577346, 'scale_pos_weight': 7.182615284102241}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:34,765] Trial 65 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.012705686088429565, 'n_estimators': 144, 'min_child_weight': 6, 'subsample': 0.7037797028638126, 'colsample_bytree': 0.7968811699942213, 'gamma': 0.909058600625995, 'reg_alpha': 0.38474216085016266, 'reg_lambda': 0.18803976247415455, 'scale_pos_weight': 10.671515659755789}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:35,332] Trial 66 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.011113133853121874, 'n_estimators': 133, 'min_child_weight': 6, 'subsample': 0.8209971212259914, 'colsample_bytree': 0.7805805967805604, 'gamma': 0.8541681033769473, 'reg_alpha': 0.24434078674755721, 'reg_lambda': 0.5609251023673472, 'scale_pos_weight': 9.274495083225984}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:35,860] Trial 67 finished with value: 0.7313464961967956 and parameters: {'max_depth': 18, 'learning_rate': 0.022108758726981946, 'n_estimators': 84, 'min_child_weight': 6, 'subsample': 0.9891355360088014, 'colsample_bytree': 0.7606839793754628, 'gamma': 0.7259754735185335, 'reg_alpha': 0.5506919729652444, 'reg_lambda': 0.2965199506500247, 'scale_pos_weight': 6.037859669826515}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:36,743] Trial 68 finished with value: 0.4883812233285918 and parameters: {'max_depth': 12, 'learning_rate': 0.07038462555334005, 'n_estimators': 204, 'min_child_weight': 5, 'subsample': 0.8907696734242935, 'colsample_bytree': 0.7115264067978391, 'gamma': 0.9707229435540123, 'reg_alpha': 0.3204875032148732, 'reg_lambda': 0.2472789587143773, 'scale_pos_weight': 10.083524037737163}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:37,726] Trial 69 finished with value: 0.6505384124281762 and parameters: {'max_depth': 16, 'learning_rate': 0.014826641321180094, 'n_estimators': 193, 'min_child_weight': 4, 'subsample': 0.9621818887034176, 'colsample_bytree': 0.7266238989426627, 'gamma': 0.7574638080485026, 'reg_alpha': 0.9613465498894438, 'reg_lambda': 0.34747078207380083, 'scale_pos_weight': 8.610576292812775}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:38,533] Trial 70 finished with value: 0.5964590013742557 and parameters: {'max_depth': 14, 'learning_rate': 0.029524594798822454, 'n_estimators': 191, 'min_child_weight': 7, 'subsample': 0.9358416411816404, 'colsample_bytree': 0.6782456847875415, 'gamma': 0.9181653291092213, 'reg_alpha': 0.44669839306891057, 'reg_lambda': 0.09423844977052753, 'scale_pos_weight': 11.166819762447236}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:39,256] Trial 71 finished with value: 0.7583386776607116 and parameters: {'max_depth': 15, 'learning_rate': 0.010199101788743592, 'n_estimators': 156, 'min_child_weight': 5, 'subsample': 0.9841222841367505, 'colsample_bytree': 0.7393049109863371, 'gamma': 0.8100121997568271, 'reg_alpha': 0.35672611947609423, 'reg_lambda': 0.14612204891382785, 'scale_pos_weight': 9.714457321909409}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:40,386] Trial 72 finished with value: 0.7313760711931443 and parameters: {'max_depth': 15, 'learning_rate': 0.01113655483403894, 'n_estimators': 163, 'min_child_weight': 5, 'subsample': 0.9683521314445267, 'colsample_bytree': 0.7815535112313533, 'gamma': 0.8553983159482257, 'reg_alpha': 0.2831481028508359, 'reg_lambda': 0.20951878444031366, 'scale_pos_weight': 9.251337575964085}. Best is trial 62 with value: 0.8124237140366173.
# [I 2026-01-19 23:47:41,330] Trial 73 finished with value: 0.8393801263950518 and parameters: {'max_depth': 16, 'learning_rate': 0.010030914888874592, 'n_estimators': 148, 'min_child_weight': 6, 'subsample': 0.9979181798896652, 'colsample_bytree': 0.7036441742892015, 'gamma': 0.670358813731746, 'reg_alpha': 0.3702006503548862, 'reg_lambda': 0.28641543248993034, 'scale_pos_weight': 10.200182172707299}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:41,990] Trial 74 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.013379208013992847, 'n_estimators': 113, 'min_child_weight': 6, 'subsample': 0.9916155969124636, 'colsample_bytree': 0.6989754957678077, 'gamma': 0.6754056467318738, 'reg_alpha': 0.4005457486897353, 'reg_lambda': 0.4118173235611763, 'scale_pos_weight': 11.894032688047826}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:42,710] Trial 75 finished with value: 0.839357445680975 and parameters: {'max_depth': 17, 'learning_rate': 0.012638016914688778, 'n_estimators': 131, 'min_child_weight': 6, 'subsample': 0.9539443932664022, 'colsample_bytree': 0.6553561881411472, 'gamma': 0.6093864338802631, 'reg_alpha': 0.03162832947115364, 'reg_lambda': 0.2847862798028238, 'scale_pos_weight': 10.418232397714666}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:43,622] Trial 76 finished with value: 0.7582868114015655 and parameters: {'max_depth': 17, 'learning_rate': 0.015817799068717425, 'n_estimators': 132, 'min_child_weight': 6, 'subsample': 0.9473175742903664, 'colsample_bytree': 0.6543068004866563, 'gamma': 0.5987543516979982, 'reg_alpha': 0.05778159404281961, 'reg_lambda': 0.345620649444421, 'scale_pos_weight': 10.276053897816926}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:44,200] Trial 77 finished with value: 0.7042977947272426 and parameters: {'max_depth': 19, 'learning_rate': 0.013970613690905883, 'n_estimators': 147, 'min_child_weight': 6, 'subsample': 0.9988455922379751, 'colsample_bytree': 0.7151002795728038, 'gamma': 0.5076110657152979, 'reg_alpha': 0.002864887191112747, 'reg_lambda': 0.29399055619100123, 'scale_pos_weight': 9.71459086941083}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:44,621] Trial 78 finished with value: 0.7583210025668127 and parameters: {'max_depth': 17, 'learning_rate': 0.0189674714230028, 'n_estimators': 111, 'min_child_weight': 6, 'subsample': 0.9624010061694263, 'colsample_bytree': 0.685284723515053, 'gamma': 0.6223495319036804, 'reg_alpha': 0.050492230827018536, 'reg_lambda': 0.7160131547268198, 'scale_pos_weight': 7.7620221301319745}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:45,499] Trial 79 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.012588931142544807, 'n_estimators': 126, 'min_child_weight': 7, 'subsample': 0.9480895400677449, 'colsample_bytree': 0.8084431217406179, 'gamma': 0.671225891397905, 'reg_alpha': 0.10041343004024912, 'reg_lambda': 0.2672825917321471, 'scale_pos_weight': 9.028275003499111}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:46,031] Trial 80 finished with value: 0.7043801220575414 and parameters: {'max_depth': 20, 'learning_rate': 0.016783082057262033, 'n_estimators': 139, 'min_child_weight': 6, 'subsample': 0.9294097367972217, 'colsample_bytree': 0.8436806114966345, 'gamma': 0.5577162277800574, 'reg_alpha': 0.015892094461238366, 'reg_lambda': 0.387235360410364, 'scale_pos_weight': 10.726253296200015}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:46,598] Trial 81 finished with value: 0.7583476658476659 and parameters: {'max_depth': 16, 'learning_rate': 0.011204821005026596, 'n_estimators': 174, 'min_child_weight': 5, 'subsample': 0.9719370956570685, 'colsample_bytree': 0.6362406882576919, 'gamma': 0.5992507007277753, 'reg_alpha': 0.23931802091133328, 'reg_lambda': 0.24477462749573864, 'scale_pos_weight': 11.145443930132725}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:47,137] Trial 82 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.012337047568948793, 'n_estimators': 152, 'min_child_weight': 5, 'subsample': 0.9905339803618927, 'colsample_bytree': 0.6461510795430994, 'gamma': 0.7258267062120894, 'reg_alpha': 0.4935597092936962, 'reg_lambda': 0.1765994604474378, 'scale_pos_weight': 11.60657623041776}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:47,842] Trial 83 finished with value: 0.5423104520449653 and parameters: {'max_depth': 17, 'learning_rate': 0.04387646719679271, 'n_estimators': 120, 'min_child_weight': 6, 'subsample': 0.9699337924118425, 'colsample_bytree': 0.6674749689632646, 'gamma': 0.9905186509025001, 'reg_alpha': 0.14403889041503798, 'reg_lambda': 0.2873419219839801, 'scale_pos_weight': 10.379588506255123}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:48,527] Trial 84 finished with value: 0.7313963963963964 and parameters: {'max_depth': 15, 'learning_rate': 0.010707926805374385, 'n_estimators': 214, 'min_child_weight': 6, 'subsample': 0.9526832862000508, 'colsample_bytree': 0.7601267930785092, 'gamma': 0.4811256698968342, 'reg_alpha': 0.4318933276042682, 'reg_lambda': 0.2586813262819417, 'scale_pos_weight': 10.031892308155335}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:49,105] Trial 85 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.010001553817841152, 'n_estimators': 169, 'min_child_weight': 5, 'subsample': 0.9214935758931946, 'colsample_bytree': 0.6222294166645769, 'gamma': 0.6499055896230574, 'reg_alpha': 0.2969660142697574, 'reg_lambda': 0.863410325418123, 'scale_pos_weight': 13.299230938998315}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:49,970] Trial 86 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.012148962208269744, 'n_estimators': 138, 'min_child_weight': 6, 'subsample': 0.9846976356125874, 'colsample_bytree': 0.731401340613571, 'gamma': 0.7786238378999242, 'reg_alpha': 0.32795090994986464, 'reg_lambda': 0.3365310544021766, 'scale_pos_weight': 12.2179571108434}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:50,599] Trial 87 finished with value: 0.0 and parameters: {'max_depth': 14, 'learning_rate': 0.014082193806033674, 'n_estimators': 177, 'min_child_weight': 5, 'subsample': 0.6086128405775875, 'colsample_bytree': 0.7000651037266188, 'gamma': 0.43249784090539584, 'reg_alpha': 0.3671168773369258, 'reg_lambda': 0.21616297576666538, 'scale_pos_weight': 12.635630278995274}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:51,495] Trial 88 finished with value: 0.6504668304668305 and parameters: {'max_depth': 19, 'learning_rate': 0.011541838497622418, 'n_estimators': 221, 'min_child_weight': 4, 'subsample': 0.9994778586600243, 'colsample_bytree': 0.6606443218471177, 'gamma': 0.8335438342639044, 'reg_alpha': 0.09970951156503868, 'reg_lambda': 0.1256118466148956, 'scale_pos_weight': 9.56025384622484}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:52,080] Trial 89 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.015624570307472873, 'n_estimators': 161, 'min_child_weight': 7, 'subsample': 0.9603249084362848, 'colsample_bytree': 0.5854550113105024, 'gamma': 0.9343790656732723, 'reg_alpha': 0.17600031859074702, 'reg_lambda': 0.16635557331534168, 'scale_pos_weight': 10.645699933239557}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:53,053] Trial 90 finished with value: 0.7853684832373357 and parameters: {'max_depth': 16, 'learning_rate': 0.013284340747220702, 'n_estimators': 148, 'min_child_weight': 6, 'subsample': 0.9367763525410804, 'colsample_bytree': 0.6781930887950874, 'gamma': 0.9724383428799488, 'reg_alpha': 0.2121605810072977, 'reg_lambda': 0.2017461331029602, 'scale_pos_weight': 8.451726509425084}. Best is trial 73 with value: 0.8393801263950518.
# [I 2026-01-19 23:47:53,672] Trial 91 finished with value: 0.8393878378378379 and parameters: {'max_depth': 16, 'learning_rate': 0.012780395740489277, 'n_estimators': 128, 'min_child_weight': 6, 'subsample': 0.9404638299026308, 'colsample_bytree': 0.6850306580582279, 'gamma': 0.9653733009988429, 'reg_alpha': 0.21493784253530226, 'reg_lambda': 0.19707028008492108, 'scale_pos_weight': 8.394797601478162}. Best is trial 91 with value: 0.8393878378378379.
# [I 2026-01-19 23:47:54,311] Trial 92 finished with value: 0.839419470490899 and parameters: {'max_depth': 16, 'learning_rate': 0.013124634465700174, 'n_estimators': 128, 'min_child_weight': 6, 'subsample': 0.9397473160350994, 'colsample_bytree': 0.6814190625491517, 'gamma': 0.9702505707960093, 'reg_alpha': 0.2596968067719325, 'reg_lambda': 0.19968491212289435, 'scale_pos_weight': 8.290791869962101}. Best is trial 92 with value: 0.839419470490899.
# [I 2026-01-19 23:47:55,020] Trial 93 finished with value: 0.7853684832373357 and parameters: {'max_depth': 17, 'learning_rate': 0.013165661866775737, 'n_estimators': 147, 'min_child_weight': 6, 'subsample': 0.8826770434780491, 'colsample_bytree': 0.6821404366005783, 'gamma': 0.998640364394283, 'reg_alpha': 0.22414433184050725, 'reg_lambda': 0.2980924124206197, 'scale_pos_weight': 7.386043706515832}. Best is trial 92 with value: 0.839419470490899.
# [I 2026-01-19 23:47:55,755] Trial 94 finished with value: 0.758517763046065 and parameters: {'max_depth': 17, 'learning_rate': 0.017491945956297838, 'n_estimators': 148, 'min_child_weight': 6, 'subsample': 0.8980647056945811, 'colsample_bytree': 0.6824242577891052, 'gamma': 0.9683273450522047, 'reg_alpha': 0.2571790432854042, 'reg_lambda': 0.19047376003366778, 'scale_pos_weight': 7.157521439651829}. Best is trial 92 with value: 0.839419470490899.
# [I 2026-01-19 23:47:57,040] Trial 95 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.013111296744919891, 'n_estimators': 117, 'min_child_weight': 6, 'subsample': 0.8790283611902799, 'colsample_bytree': 0.6698838908431733, 'gamma': 0.9625927080153296, 'reg_alpha': 0.1695010821401376, 'reg_lambda': 0.051460368951003976, 'scale_pos_weight': 8.441180458073548}. Best is trial 92 with value: 0.839419470490899.
# [I 2026-01-19 23:47:57,972] Trial 96 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.010942653993118964, 'n_estimators': 128, 'min_child_weight': 7, 'subsample': 0.9092474553441977, 'colsample_bytree': 0.6905057860241841, 'gamma': 0.9846399140627985, 'reg_alpha': 0.21628925061559287, 'reg_lambda': 0.29872437653994105, 'scale_pos_weight': 7.451510852680842}. Best is trial 92 with value: 0.839419470490899.
# [I 2026-01-19 23:47:58,653] Trial 97 finished with value: 0.0 and parameters: {'max_depth': 17, 'learning_rate': 0.012610537680206027, 'n_estimators': 106, 'min_child_weight': 6, 'subsample': 0.8634387216010797, 'colsample_bytree': 0.6482611691060305, 'gamma': 0.9990410591874493, 'reg_alpha': 0.2050625488241523, 'reg_lambda': 0.27656117074784403, 'scale_pos_weight': 6.527840445230597}. Best is trial 92 with value: 0.839419470490899.
# [I 2026-01-19 23:47:59,260] Trial 98 finished with value: 0.0 and parameters: {'max_depth': 18, 'learning_rate': 0.016145347447400232, 'n_estimators': 97, 'min_child_weight': 6, 'subsample': 0.9407967300189611, 'colsample_bytree': 0.6072101522426372, 'gamma': 0.9017908245212998, 'reg_alpha': 0.25648132590286626, 'reg_lambda': 0.14258127055549774, 'scale_pos_weight': 8.00597925344691}. Best is trial 92 with value: 0.839419470490899.
# [I 2026-01-19 23:48:00,715] Trial 99 finished with value: 0.7044132290184922 and parameters: {'max_depth': 16, 'learning_rate': 0.01999369790548058, 'n_estimators': 141, 'min_child_weight': 6, 'subsample': 0.9252435365666779, 'colsample_bytree': 0.6749468659761871, 'gamma': 0.9507715419893643, 'reg_alpha': 0.13653697366440537, 'reg_lambda': 0.10369503315336304, 'scale_pos_weight': 8.295510358249908}. Best is trial 92 with value: 0.839419470490899.

# %%
# grid_xgb.fit(X_train_res_retained, y_train_res)

# %%
# best_params_xgb = grid_xgb.best_params_

# %%
best_params_xgb = study_xgb.best_params

# %%
print(best_params_xgb)
# Out:
# {'max_depth': 16, 'learning_rate': 0.013124634465700174, 'n_estimators': 128, 'min_child_weight': 6, 'subsample': 0.9397473160350994, 'colsample_bytree': 0.6814190625491517, 'gamma': 0.9702505707960093, 'reg_alpha': 0.2596968067719325, 'reg_lambda': 0.19968491212289435, 'scale_pos_weight': 8.290791869962101}

# %%
final_classifier = xgb.XGBClassifier(**best_params_xgb, random_state=42, eval_metric='logloss')

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6814190625491517, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=0.9702505707960093, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.013124634465700174,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=16, max_leaves=None,
#               min_child_weight=6, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=128, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[564 165]
#  [  6  31]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.7767624020887729

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.15816326530612246

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.8378378378378378

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.45058139534883723

# %% [markdown]
# ### Threshold tuning

# %%
best_threshold = 0.5

# %%
best_precision_score = 0

# %%
best_recall_score = 0

# %%
best_f2_score = 0

# %%
for threshold in np.arange(0.1, 0.95, 0.05):
    y_pred_val_threshold = (y_proba_val >= threshold).astype(int)
    recall = recall_score(y_val, y_pred_val_threshold)
    precision = precision_score(y_val, y_pred_val_threshold)
    f2_score = fbeta_score(y_val, y_pred_val_threshold, beta=2)
    
    print(f'Threshold {threshold} has F2 score {f2_score}')
    
    if precision >= 0.15:
        current_recall_score = recall
        if current_recall_score > best_recall_score:
            best_recall_score = current_recall_score
            best_precision_score = precision
            best_threshold = threshold
        elif current_recall_score == best_recall_score and precision > best_precision_score:
            best_precision_score = precision
            best_threshold = threshold
        
        # current_f2_score = f2_score
        # if current_f2_score > best_f2_score:
        #     best_f2_score = current_f2_score
        #     best_threshold = threshold
# Out:
# Threshold 0.1 has F2 score 0.2024070021881838
# Threshold 0.15000000000000002 has F2 score 0.22981366459627328
# Threshold 0.20000000000000004 has F2 score 0.3005008347245409
# Threshold 0.25000000000000006 has F2 score 0.3258845437616387
# Threshold 0.30000000000000004 has F2 score 0.3503184713375796
# Threshold 0.3500000000000001 has F2 score 0.382830626450116
# Threshold 0.40000000000000013 has F2 score 0.4084158415841584
# Threshold 0.45000000000000007 has F2 score 0.4144385026737968
# Threshold 0.5000000000000001 has F2 score 0.45058139534883723
# Threshold 0.5500000000000002 has F2 score 0.4434250764525994
# Threshold 0.6000000000000002 has F2 score 0.4272151898734177
# Threshold 0.6500000000000001 has F2 score 0.4406779661016949
# Threshold 0.7000000000000002 has F2 score 0.4227941176470588
# Threshold 0.7500000000000002 has F2 score 0.37549407114624506
# Threshold 0.8000000000000002 has F2 score 0.41125541125541126
# Threshold 0.8500000000000002 has F2 score 0.39906103286384975
# Threshold 0.9000000000000002 has F2 score 0.14367816091954022

# %%
print(best_threshold)
# Out:
# 0.5000000000000001

# %%
print(best_recall_score)
# Out:
# 0.8378378378378378

# %% [markdown]
# ### Retrain on training + validation set

# %%
X_train_full = pd.concat([X_train_res_retained, X_val_retained], axis=0, ignore_index=True)
y_train_full = pd.concat([y_train_res, y_val], axis=0, ignore_index=True)

# %%
final_classifier.fit(X_train_full, y_train_full)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6814190625491517, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=0.9702505707960093, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.013124634465700174,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=16, max_leaves=None,
#               min_child_weight=6, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=128, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ### Evaluate on test set

# %%
X_test_retained = X_test[retained_columns]

# %%
y_pred_test = final_classifier.predict(X_test_retained)

# %%
y_proba_test = final_classifier.predict_proba(X_test_retained)[:, 1]

# %%
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[556 173]
#  [ 10  28]]

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.7614080834419817

# %%
print(precision_score(y_test, y_pred_test))
# Out:
# 0.13930348258706468

# %%
print(recall_score(y_test, y_pred_test))
# Out:
# 0.7368421052631579

# %%
print(fbeta_score(y_test, y_pred_test, beta=2))
# Out:
# 0.39660056657223797
