# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_364\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_364\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### ADASYN Oversampling on Training Data

# %%
resampler = ADASYN()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = xgb.XGBClassifier(random_state=42, eval_metric='logloss')

# %% [markdown]
# ### Create grid for hyperparameter tuning

# %%
param_grid_xgb = {
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [50, 100, 200],
    'min_child_weight': [1, 3, 5],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'scale_pos_weight': [1, 3, 5, 10, 15, 20]
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_xgb = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_xgb,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Importance': importances}).sort_values(
    'Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Importance
# 16          smoking_status_unknown    0.122834
# 8                            smoke    0.119763
# 11              work_type_govt_job    0.106980
# 0                              age    0.084440
# 18     smoking_status_never_smoked    0.072567
# 15              work_type_children    0.069775
# 14         work_type_self_employed    0.066703
# 21                           obese    0.050234
# 13               work_type_private    0.047196
# 12          work_type_never_worked    0.045933
# 17  smoking_status_formerly_smoked    0.042058
# 19           smoking_status_smokes    0.034735
# 7                            urban    0.022613
# 6                             male    0.021152
# 3                     ever_married    0.019435
# 20                age_ever_married    0.011631
# 4                avg_glucose_level    0.010501
# 5                              bmi    0.010316
# 23                         log_bmi    0.008860
# 10   hypertension_or_heart_disease    0.008692
# 1                     hypertension    0.008669
# 24           log_avg_glucose_level    0.006463
# 2                    heart_disease    0.005619
# 9                        have_work    0.002831
# 22          high_avg_glucose_level    0.000000

# %% [markdown]
# ### Feature selection

# %%
retained_columns = ['smoking_status_smokes', 'smoking_status_unknown', 'work_type_govt_job', 'age', 'smoking_status_never_smoked', 'obese', 'work_type_children', 'work_type_private', 'work_type_self_employed', 'smoking_status_formerly_smoked']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.15

# %%
def objective_xgb(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 7),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 1),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 15),
        'random_state': 42,
        'eval_metric': 'logloss'
    }
    
    model = xgb.XGBClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    f2_score = fbeta_score(y_val, y_pred_val, beta=2)
    
    if precision < MIN_PRECISION:
        return 0
    # return recall + (precision * 0.01)
    return f2_score

# %%
# grid_xgb.fit(X_train_res_retained, y_train_res)

# %%
study_xgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_xgb.optimize(objective_xgb, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 19:22:02,281] A new study created in memory with name: no-name-c9a2c3b1-9efb-4bcb-bdcf-209bfe7e2620
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 19:22:02,664] Trial 0 finished with value: 0.37542662116040953 and parameters: {'max_depth': 9, 'learning_rate': 0.2536999076681772, 'n_estimators': 233, 'min_child_weight': 5, 'subsample': 0.5780093202212182, 'colsample_bytree': 0.5779972601681014, 'gamma': 0.05808361216819946, 'reg_alpha': 0.8661761457749352, 'reg_lambda': 0.6011150117432088, 'scale_pos_weight': 10.913016089144637}. Best is trial 0 with value: 0.37542662116040953.
# [I 2026-01-19 19:22:02,889] Trial 1 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.2708160864249968, 'n_estimators': 258, 'min_child_weight': 2, 'subsample': 0.5909124836035503, 'colsample_bytree': 0.5917022549267169, 'gamma': 0.3042422429595377, 'reg_alpha': 0.5247564316322378, 'reg_lambda': 0.43194501864211576, 'scale_pos_weight': 5.077207962772587}. Best is trial 0 with value: 0.37542662116040953.
# [I 2026-01-19 19:22:03,223] Trial 2 finished with value: 0.35864978902953587 and parameters: {'max_depth': 14, 'learning_rate': 0.01607123851203988, 'n_estimators': 123, 'min_child_weight': 3, 'subsample': 0.728034992108518, 'colsample_bytree': 0.8925879806965068, 'gamma': 0.19967378215835974, 'reg_alpha': 0.5142344384136116, 'reg_lambda': 0.5924145688620425, 'scale_pos_weight': 1.6503057780799681}. Best is trial 0 with value: 0.37542662116040953.
# [I 2026-01-19 19:22:03,391] Trial 3 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.0178601378893971, 'n_estimators': 66, 'min_child_weight': 7, 'subsample': 0.9828160165372797, 'colsample_bytree': 0.9041986740582306, 'gamma': 0.3046137691733707, 'reg_alpha': 0.09767211400638387, 'reg_lambda': 0.6842330265121569, 'scale_pos_weight': 7.162134912354418}. Best is trial 0 with value: 0.37542662116040953.
# [I 2026-01-19 19:22:03,508] Trial 4 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.05388108577817234, 'n_estimators': 58, 'min_child_weight': 7, 'subsample': 0.6293899908000085, 'colsample_bytree': 0.831261142176991, 'gamma': 0.31171107608941095, 'reg_alpha': 0.5200680211778108, 'reg_lambda': 0.5467102793432796, 'scale_pos_weight': 3.5879623773573783}. Best is trial 0 with value: 0.37542662116040953.
# [I 2026-01-19 19:22:04,060] Trial 5 finished with value: 0.0 and parameters: {'max_depth': 20, 'learning_rate': 0.13962563737015762, 'n_estimators': 285, 'min_child_weight': 7, 'subsample': 0.7989499894055425, 'colsample_bytree': 0.9609371175115584, 'gamma': 0.0884925020519195, 'reg_alpha': 0.1959828624191452, 'reg_lambda': 0.045227288910538066, 'scale_pos_weight': 5.554624630685701}. Best is trial 0 with value: 0.37542662116040953.
# [I 2026-01-19 19:22:04,649] Trial 6 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.02516607127550297, 'n_estimators': 258, 'min_child_weight': 3, 'subsample': 0.6404672548436904, 'colsample_bytree': 0.7713480415791243, 'gamma': 0.14092422497476265, 'reg_alpha': 0.8021969807540397, 'reg_lambda': 0.07455064367977082, 'scale_pos_weight': 14.816417112407242}. Best is trial 0 with value: 0.37542662116040953.
# [I 2026-01-19 19:22:04,779] Trial 7 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.019657448966046126, 'n_estimators': 51, 'min_child_weight': 6, 'subsample': 0.8534286719238086, 'colsample_bytree': 0.8645035840204937, 'gamma': 0.7712703466859457, 'reg_alpha': 0.07404465173409036, 'reg_lambda': 0.3584657285442726, 'scale_pos_weight': 2.622166833351816}. Best is trial 0 with value: 0.37542662116040953.
# [I 2026-01-19 19:22:05,013] Trial 8 finished with value: 0.3763440860215054 and parameters: {'max_depth': 18, 'learning_rate': 0.08330803890301997, 'n_estimators': 133, 'min_child_weight': 1, 'subsample': 0.6554911608578311, 'colsample_bytree': 0.6625916610133735, 'gamma': 0.7296061783380641, 'reg_alpha': 0.6375574713552131, 'reg_lambda': 0.8872127425763265, 'scale_pos_weight': 7.61100895226729}. Best is trial 8 with value: 0.3763440860215054.
# [I 2026-01-19 19:22:05,248] Trial 9 finished with value: 0.3648068669527897 and parameters: {'max_depth': 5, 'learning_rate': 0.1131225105716033, 'n_estimators': 240, 'min_child_weight': 4, 'subsample': 0.8854835899772805, 'colsample_bytree': 0.7468977981821954, 'gamma': 0.5227328293819941, 'reg_alpha': 0.42754101835854963, 'reg_lambda': 0.02541912674409519, 'scale_pos_weight': 2.5104799779062623}. Best is trial 8 with value: 0.3763440860215054.
# [I 2026-01-19 19:22:05,579] Trial 10 finished with value: 0.0 and parameters: {'max_depth': 20, 'learning_rate': 0.04728771970423099, 'n_estimators': 174, 'min_child_weight': 1, 'subsample': 0.5122235210501648, 'colsample_bytree': 0.6719337720565075, 'gamma': 0.9610860157784141, 'reg_alpha': 0.6899748066581108, 'reg_lambda': 0.9697901717337378, 'scale_pos_weight': 10.01197831273353}. Best is trial 8 with value: 0.3763440860215054.
# [I 2026-01-19 19:22:05,819] Trial 11 finished with value: 0.0 and parameters: {'max_depth': 9, 'learning_rate': 0.24950292438859467, 'n_estimators': 179, 'min_child_weight': 5, 'subsample': 0.6950726952619702, 'colsample_bytree': 0.5199150427655417, 'gamma': 0.6071842740332256, 'reg_alpha': 0.9949150289767864, 'reg_lambda': 0.8863027948095235, 'scale_pos_weight': 11.139350674858177}. Best is trial 8 with value: 0.3763440860215054.
# [I 2026-01-19 19:22:06,106] Trial 12 finished with value: 0.39473684210526316 and parameters: {'max_depth': 10, 'learning_rate': 0.10435882230584723, 'n_estimators': 202, 'min_child_weight': 5, 'subsample': 0.5245823841543481, 'colsample_bytree': 0.6400016021035824, 'gamma': 0.7227148231741514, 'reg_alpha': 0.8555101314960508, 'reg_lambda': 0.730100777331755, 'scale_pos_weight': 10.34143854670089}. Best is trial 12 with value: 0.39473684210526316.
# [I 2026-01-19 19:22:06,481] Trial 13 finished with value: 0.0 and parameters: {'max_depth': 17, 'learning_rate': 0.10058661290807135, 'n_estimators': 162, 'min_child_weight': 1, 'subsample': 0.5394721233299107, 'colsample_bytree': 0.6799045630890553, 'gamma': 0.7298348295317014, 'reg_alpha': 0.6884995851139852, 'reg_lambda': 0.802571195817036, 'scale_pos_weight': 8.450009271544443}. Best is trial 12 with value: 0.39473684210526316.
# [I 2026-01-19 19:22:06,700] Trial 14 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.07627118921087536, 'n_estimators': 127, 'min_child_weight': 4, 'subsample': 0.6604250893099085, 'colsample_bytree': 0.6622651830816499, 'gamma': 0.9227602132677906, 'reg_alpha': 0.969269852048718, 'reg_lambda': 0.7832047086267959, 'scale_pos_weight': 13.401066043586056}. Best is trial 12 with value: 0.39473684210526316.
# [I 2026-01-19 19:22:07,023] Trial 15 finished with value: 0.0 and parameters: {'max_depth': 16, 'learning_rate': 0.03743982382453581, 'n_estimators': 202, 'min_child_weight': 5, 'subsample': 0.5023700598265448, 'colsample_bytree': 0.6099144574274531, 'gamma': 0.7652941911525005, 'reg_alpha': 0.6732717907646599, 'reg_lambda': 0.9664268050771169, 'scale_pos_weight': 8.433546252612746}. Best is trial 12 with value: 0.39473684210526316.
# [I 2026-01-19 19:22:07,241] Trial 16 finished with value: 0.0 and parameters: {'max_depth': 11, 'learning_rate': 0.16403439120253901, 'n_estimators': 114, 'min_child_weight': 2, 'subsample': 0.7542767371594747, 'colsample_bytree': 0.7457265639467195, 'gamma': 0.6257574067942783, 'reg_alpha': 0.33531078148632737, 'reg_lambda': 0.7653911951852361, 'scale_pos_weight': 12.395911878089642}. Best is trial 12 with value: 0.39473684210526316.
# [I 2026-01-19 19:22:07,786] Trial 17 finished with value: 0.40540540540540543 and parameters: {'max_depth': 7, 'learning_rate': 0.0742708334836405, 'n_estimators': 210, 'min_child_weight': 3, 'subsample': 0.5916526779070379, 'colsample_bytree': 0.5004283205469727, 'gamma': 0.8534387602871257, 'reg_alpha': 0.8127374348677748, 'reg_lambda': 0.34022982219356357, 'scale_pos_weight': 6.6884896311189825}. Best is trial 17 with value: 0.40540540540540543.
# [I 2026-01-19 19:22:08,106] Trial 18 finished with value: 0.0 and parameters: {'max_depth': 7, 'learning_rate': 0.011781989741722088, 'n_estimators': 211, 'min_child_weight': 3, 'subsample': 0.5765230465577171, 'colsample_bytree': 0.5270619558742974, 'gamma': 0.8969434354375037, 'reg_alpha': 0.8183568576198857, 'reg_lambda': 0.27379703851638004, 'scale_pos_weight': 6.096213938254964}. Best is trial 17 with value: 0.40540540540540543.
# [I 2026-01-19 19:22:08,536] Trial 19 finished with value: 0.0 and parameters: {'max_depth': 7, 'learning_rate': 0.03288119586765661, 'n_estimators': 300, 'min_child_weight': 4, 'subsample': 0.5531696010617887, 'colsample_bytree': 0.553344488531144, 'gamma': 0.8565281553255162, 'reg_alpha': 0.8731424285218723, 'reg_lambda': 0.20793234122003798, 'scale_pos_weight': 9.81795923365503}. Best is trial 17 with value: 0.40540540540540543.
# [I 2026-01-19 19:22:09,047] Trial 20 finished with value: 0.4092526690391459 and parameters: {'max_depth': 7, 'learning_rate': 0.06814372806101829, 'n_estimators': 208, 'min_child_weight': 6, 'subsample': 0.608192016285199, 'colsample_bytree': 0.5021041382015146, 'gamma': 0.457417335034527, 'reg_alpha': 0.7611983209859814, 'reg_lambda': 0.44677372941644855, 'scale_pos_weight': 4.29513132312521}. Best is trial 20 with value: 0.4092526690391459.
# [I 2026-01-19 19:22:09,298] Trial 21 finished with value: 0.4092526690391459 and parameters: {'max_depth': 7, 'learning_rate': 0.06566772969011805, 'n_estimators': 205, 'min_child_weight': 6, 'subsample': 0.6126807563321386, 'colsample_bytree': 0.5043099917879914, 'gamma': 0.5410216404946695, 'reg_alpha': 0.7327363025807675, 'reg_lambda': 0.42397360062573713, 'scale_pos_weight': 4.283109079260925}. Best is trial 20 with value: 0.4092526690391459.
# [I 2026-01-19 19:22:09,573] Trial 22 finished with value: 0.4136690647482014 and parameters: {'max_depth': 7, 'learning_rate': 0.0681208323835571, 'n_estimators': 223, 'min_child_weight': 6, 'subsample': 0.6223751209834899, 'colsample_bytree': 0.5162057802617684, 'gamma': 0.4332668216800014, 'reg_alpha': 0.7363244881344181, 'reg_lambda': 0.44104192921060503, 'scale_pos_weight': 4.24738889268549}. Best is trial 22 with value: 0.4136690647482014.
# [I 2026-01-19 19:22:09,771] Trial 23 finished with value: 0.0 and parameters: {'max_depth': 3, 'learning_rate': 0.0615666005067566, 'n_estimators': 231, 'min_child_weight': 6, 'subsample': 0.7104614857848673, 'colsample_bytree': 0.5032186151772239, 'gamma': 0.41973691982813455, 'reg_alpha': 0.6061243028185093, 'reg_lambda': 0.41508275061609357, 'scale_pos_weight': 4.428984026663098}. Best is trial 22 with value: 0.4136690647482014.
# [I 2026-01-19 19:22:09,969] Trial 24 finished with value: 0.0 and parameters: {'max_depth': 5, 'learning_rate': 0.03930010295474171, 'n_estimators': 155, 'min_child_weight': 6, 'subsample': 0.6285753620738819, 'colsample_bytree': 0.5460597644400536, 'gamma': 0.4513558997096444, 'reg_alpha': 0.7435406788097801, 'reg_lambda': 0.4866926275405754, 'scale_pos_weight': 3.9394471457401177}. Best is trial 22 with value: 0.4136690647482014.
# [I 2026-01-19 19:22:10,229] Trial 25 finished with value: 0.3440366972477064 and parameters: {'max_depth': 6, 'learning_rate': 0.06432954671561175, 'n_estimators': 184, 'min_child_weight': 6, 'subsample': 0.676907943936125, 'colsample_bytree': 0.5684915304489463, 'gamma': 0.5564640959718928, 'reg_alpha': 0.3945504784587912, 'reg_lambda': 0.16482620337310067, 'scale_pos_weight': 1.431392119647148}. Best is trial 22 with value: 0.4136690647482014.
# [I 2026-01-19 19:22:10,550] Trial 26 finished with value: 0.379746835443038 and parameters: {'max_depth': 8, 'learning_rate': 0.15103132889464044, 'n_estimators': 255, 'min_child_weight': 6, 'subsample': 0.7881288918205039, 'colsample_bytree': 0.6166502714980224, 'gamma': 0.39082007074161595, 'reg_alpha': 0.5971321392414645, 'reg_lambda': 0.49145527400334593, 'scale_pos_weight': 3.274906161453856}. Best is trial 22 with value: 0.4136690647482014.
# [I 2026-01-19 19:22:10,900] Trial 27 finished with value: 0.43478260869565216 and parameters: {'max_depth': 13, 'learning_rate': 0.028238736300234574, 'n_estimators': 220, 'min_child_weight': 7, 'subsample': 0.612259199753213, 'colsample_bytree': 0.7098663740528182, 'gamma': 0.6149744177336061, 'reg_alpha': 0.9322800425479881, 'reg_lambda': 0.31818708052321143, 'scale_pos_weight': 4.832108028707547}. Best is trial 27 with value: 0.43478260869565216.
# [I 2026-01-19 19:22:11,323] Trial 28 finished with value: 0.4318936877076412 and parameters: {'max_depth': 13, 'learning_rate': 0.027700138237710926, 'n_estimators': 272, 'min_child_weight': 7, 'subsample': 0.56254022349847, 'colsample_bytree': 0.7949866834933749, 'gamma': 0.6620764640698122, 'reg_alpha': 0.9292234767141191, 'reg_lambda': 0.2934293610476625, 'scale_pos_weight': 5.338788908437797}. Best is trial 27 with value: 0.43478260869565216.
# [I 2026-01-19 19:22:11,785] Trial 29 finished with value: 0.0 and parameters: {'max_depth': 13, 'learning_rate': 0.010900709612868579, 'n_estimators': 279, 'min_child_weight': 7, 'subsample': 0.5610056705358516, 'colsample_bytree': 0.8012123192154237, 'gamma': 0.6214742337504002, 'reg_alpha': 0.9366763247617457, 'reg_lambda': 0.2667713947190713, 'scale_pos_weight': 5.61832693547166}. Best is trial 27 with value: 0.43478260869565216.
# [I 2026-01-19 19:22:12,231] Trial 30 finished with value: 0.40716612377850164 and parameters: {'max_depth': 14, 'learning_rate': 0.026518142017116306, 'n_estimators': 232, 'min_child_weight': 7, 'subsample': 0.7471142800935557, 'colsample_bytree': 0.7132594721588975, 'gamma': 0.6606822580522761, 'reg_alpha': 0.9193227192171467, 'reg_lambda': 0.14944717648068617, 'scale_pos_weight': 6.1084820793996455}. Best is trial 27 with value: 0.43478260869565216.
# [I 2026-01-19 19:22:12,857] Trial 31 finished with value: 0.4107142857142857 and parameters: {'max_depth': 12, 'learning_rate': 0.04577924127225635, 'n_estimators': 224, 'min_child_weight': 7, 'subsample': 0.5993636108361037, 'colsample_bytree': 0.8028400347037994, 'gamma': 0.489252985849217, 'reg_alpha': 0.8969039069670688, 'reg_lambda': 0.2827316388528156, 'scale_pos_weight': 4.8626472773330764}. Best is trial 27 with value: 0.43478260869565216.
# [I 2026-01-19 19:22:13,358] Trial 32 finished with value: 0.42955326460481097 and parameters: {'max_depth': 12, 'learning_rate': 0.029698791907311093, 'n_estimators': 245, 'min_child_weight': 7, 'subsample': 0.57142513052311, 'colsample_bytree': 0.8074487626160937, 'gamma': 0.39160449020917687, 'reg_alpha': 0.9039161072087555, 'reg_lambda': 0.3295013197902037, 'scale_pos_weight': 4.850713351453047}. Best is trial 27 with value: 0.43478260869565216.
# [I 2026-01-19 19:22:13,765] Trial 33 finished with value: 0.37254901960784315 and parameters: {'max_depth': 14, 'learning_rate': 0.026603450540844256, 'n_estimators': 248, 'min_child_weight': 7, 'subsample': 0.5601714989351141, 'colsample_bytree': 0.8454241134116108, 'gamma': 0.2512450763122462, 'reg_alpha': 0.9829897310876816, 'reg_lambda': 0.3801804265345252, 'scale_pos_weight': 2.7460167200326544}. Best is trial 27 with value: 0.43478260869565216.
# [I 2026-01-19 19:22:14,192] Trial 34 finished with value: 0.40498442367601245 and parameters: {'max_depth': 12, 'learning_rate': 0.022339238126214432, 'n_estimators': 271, 'min_child_weight': 7, 'subsample': 0.5814714071405475, 'colsample_bytree': 0.718454424547255, 'gamma': 0.39401030438093865, 'reg_alpha': 0.8621824795056949, 'reg_lambda': 0.3205934914113061, 'scale_pos_weight': 6.542418884404464}. Best is trial 27 with value: 0.43478260869565216.
# [I 2026-01-19 19:22:14,752] Trial 35 finished with value: 0.4416961130742049 and parameters: {'max_depth': 15, 'learning_rate': 0.032820664271631314, 'n_estimators': 267, 'min_child_weight': 7, 'subsample': 0.5364568758057406, 'colsample_bytree': 0.9349167349891595, 'gamma': 0.3539046850838074, 'reg_alpha': 0.919769808816028, 'reg_lambda': 0.6124406217138116, 'scale_pos_weight': 5.14338858326586}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:15,222] Trial 36 finished with value: 0.3980891719745223 and parameters: {'max_depth': 15, 'learning_rate': 0.015485189966472976, 'n_estimators': 268, 'min_child_weight': 7, 'subsample': 0.5341049899670598, 'colsample_bytree': 0.9443758393583563, 'gamma': 0.32175024295340315, 'reg_alpha': 0.942515073758268, 'reg_lambda': 0.6182970405405374, 'scale_pos_weight': 5.190601610120829}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:15,791] Trial 37 finished with value: 0.40492957746478875 and parameters: {'max_depth': 13, 'learning_rate': 0.031717804449439495, 'n_estimators': 300, 'min_child_weight': 5, 'subsample': 0.5324591190565963, 'colsample_bytree': 0.9251862456387177, 'gamma': 0.0014500117927535028, 'reg_alpha': 0.9184757702399524, 'reg_lambda': 0.21519959053844767, 'scale_pos_weight': 7.633768392116394}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:16,292] Trial 38 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.01578775640331864, 'n_estimators': 285, 'min_child_weight': 7, 'subsample': 0.5039531506768749, 'colsample_bytree': 0.9975999525453063, 'gamma': 0.2122577781352722, 'reg_alpha': 0.1833253634659049, 'reg_lambda': 0.5720443460425575, 'scale_pos_weight': 9.076444514059428}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:16,688] Trial 39 finished with value: 0.3917910447761194 and parameters: {'max_depth': 18, 'learning_rate': 0.02053045889934503, 'n_estimators': 244, 'min_child_weight': 7, 'subsample': 0.5738120168279119, 'colsample_bytree': 0.8845283691698157, 'gamma': 0.3625053545845965, 'reg_alpha': 0.7915177651135886, 'reg_lambda': 0.6429926312005168, 'scale_pos_weight': 3.192262589950266}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:17,188] Trial 40 finished with value: 0.2981651376146789 and parameters: {'max_depth': 10, 'learning_rate': 0.03150172693004775, 'n_estimators': 257, 'min_child_weight': 6, 'subsample': 0.941364635997169, 'colsample_bytree': 0.7832988882088849, 'gamma': 0.2669164904634753, 'reg_alpha': 0.018825163478298823, 'reg_lambda': 0.5212097129263259, 'scale_pos_weight': 1.8054431462113616}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:17,560] Trial 41 finished with value: 0.43010752688172044 and parameters: {'max_depth': 12, 'learning_rate': 0.04899597611713852, 'n_estimators': 219, 'min_child_weight': 7, 'subsample': 0.631689767419012, 'colsample_bytree': 0.8311473114524665, 'gamma': 0.5787111748352499, 'reg_alpha': 0.8559906172674876, 'reg_lambda': 0.3863568505353269, 'scale_pos_weight': 4.8461336753689475}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:18,071] Trial 42 finished with value: 0.39855072463768115 and parameters: {'max_depth': 12, 'learning_rate': 0.05082096221853265, 'n_estimators': 273, 'min_child_weight': 7, 'subsample': 0.645644055424162, 'colsample_bytree': 0.8433849486457925, 'gamma': 0.5857164345618703, 'reg_alpha': 0.847062102851655, 'reg_lambda': 0.38320229972344977, 'scale_pos_weight': 5.216930559719926}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:18,519] Trial 43 finished with value: 0.42105263157894735 and parameters: {'max_depth': 13, 'learning_rate': 0.04032466964837497, 'n_estimators': 262, 'min_child_weight': 7, 'subsample': 0.6770115316543104, 'colsample_bytree': 0.8748180639518397, 'gamma': 0.6689798955282759, 'reg_alpha': 0.9947666478909272, 'reg_lambda': 0.1028575256649425, 'scale_pos_weight': 5.850045511440128}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:19,569] Trial 44 finished with value: 0.4126984126984127 and parameters: {'max_depth': 14, 'learning_rate': 0.023438725223627353, 'n_estimators': 287, 'min_child_weight': 7, 'subsample': 0.5532924850747619, 'colsample_bytree': 0.8226605752186819, 'gamma': 0.4935627959094585, 'reg_alpha': 0.8877906015450928, 'reg_lambda': 0.30293116863227065, 'scale_pos_weight': 7.131322338554834}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:19,975] Trial 45 finished with value: 0.40492957746478875 and parameters: {'max_depth': 10, 'learning_rate': 0.02878173147065293, 'n_estimators': 242, 'min_child_weight': 6, 'subsample': 0.5882413050462532, 'colsample_bytree': 0.9120484784862791, 'gamma': 0.670190071291028, 'reg_alpha': 0.9480703749529248, 'reg_lambda': 0.23164217013365415, 'scale_pos_weight': 4.864554680804823}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:20,417] Trial 46 finished with value: 0.0 and parameters: {'max_depth': 15, 'learning_rate': 0.018902944815826044, 'n_estimators': 249, 'min_child_weight': 7, 'subsample': 0.6406840792895764, 'colsample_bytree': 0.7594509977335729, 'gamma': 0.35298838714545666, 'reg_alpha': 0.8274286769211272, 'reg_lambda': 0.6874404484865269, 'scale_pos_weight': 6.624549912971551}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:20,587] Trial 47 finished with value: 0.3736654804270463 and parameters: {'max_depth': 16, 'learning_rate': 0.04338244127333877, 'n_estimators': 77, 'min_child_weight': 5, 'subsample': 0.6660807373277763, 'colsample_bytree': 0.8158748828333549, 'gamma': 0.5849465652442186, 'reg_alpha': 0.7854325573898496, 'reg_lambda': 0.5524898348302623, 'scale_pos_weight': 3.6909686190792375}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:20,917] Trial 48 finished with value: 0.39215686274509803 and parameters: {'max_depth': 11, 'learning_rate': 0.034731637006212894, 'n_estimators': 222, 'min_child_weight': 7, 'subsample': 0.520604969848292, 'colsample_bytree': 0.7029842338291864, 'gamma': 0.14412211191792396, 'reg_alpha': 0.8996460443296401, 'reg_lambda': 0.35145048022783576, 'scale_pos_weight': 2.5239043212639887}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:21,302] Trial 49 finished with value: 0.3409090909090909 and parameters: {'max_depth': 18, 'learning_rate': 0.0541060964774081, 'n_estimators': 290, 'min_child_weight': 6, 'subsample': 0.7046322154329935, 'colsample_bytree': 0.7379047481298894, 'gamma': 0.5147919866498318, 'reg_alpha': 0.9671277114833734, 'reg_lambda': 0.16209371511632722, 'scale_pos_weight': 1.9597126078289864}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:21,658] Trial 50 finished with value: 0.0 and parameters: {'max_depth': 12, 'learning_rate': 0.013304022812950058, 'n_estimators': 185, 'min_child_weight': 7, 'subsample': 0.606907367094033, 'colsample_bytree': 0.7769056037604345, 'gamma': 0.8103459610405902, 'reg_alpha': 0.5598692971713618, 'reg_lambda': 0.24284771031364977, 'scale_pos_weight': 7.132045998652348}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:22,109] Trial 51 finished with value: 0.43859649122807015 and parameters: {'max_depth': 13, 'learning_rate': 0.0418127901541405, 'n_estimators': 265, 'min_child_weight': 7, 'subsample': 0.6844941201460917, 'colsample_bytree': 0.8759853256518522, 'gamma': 0.6912902090167785, 'reg_alpha': 0.9914002485308259, 'reg_lambda': 0.10868652288838959, 'scale_pos_weight': 5.730227248044979}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:22,635] Trial 52 finished with value: 0.42704626334519574 and parameters: {'max_depth': 13, 'learning_rate': 0.03797067053178784, 'n_estimators': 264, 'min_child_weight': 7, 'subsample': 0.543612737471566, 'colsample_bytree': 0.8631078152788638, 'gamma': 0.6996114651568858, 'reg_alpha': 0.9959175699594423, 'reg_lambda': 0.014117513645384105, 'scale_pos_weight': 4.8751124056481565}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:23,076] Trial 53 finished with value: 0.4391891891891892 and parameters: {'max_depth': 15, 'learning_rate': 0.02883313835517555, 'n_estimators': 233, 'min_child_weight': 7, 'subsample': 0.6278479588114493, 'colsample_bytree': 0.8974331761279658, 'gamma': 0.7608718542894691, 'reg_alpha': 0.852437053090046, 'reg_lambda': 0.09050863120954905, 'scale_pos_weight': 5.530625978770178}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:23,523] Trial 54 finished with value: 0.3924914675767918 and parameters: {'max_depth': 17, 'learning_rate': 0.02204715442360512, 'n_estimators': 233, 'min_child_weight': 6, 'subsample': 0.728211741930042, 'colsample_bytree': 0.97113059813327, 'gamma': 0.7700826386675725, 'reg_alpha': 0.8552598825242781, 'reg_lambda': 0.06440032509425446, 'scale_pos_weight': 5.522983441990499}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:23,926] Trial 55 finished with value: 0.4032258064516129 and parameters: {'max_depth': 14, 'learning_rate': 0.026847070127750897, 'n_estimators': 194, 'min_child_weight': 7, 'subsample': 0.6895788877118649, 'colsample_bytree': 0.9027942659729492, 'gamma': 0.8107535439569044, 'reg_alpha': 0.9454600395296221, 'reg_lambda': 0.10788375951769844, 'scale_pos_weight': 6.273867750427542}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:24,320] Trial 56 finished with value: 0.39603960396039606 and parameters: {'max_depth': 15, 'learning_rate': 0.03551160355651181, 'n_estimators': 217, 'min_child_weight': 6, 'subsample': 0.6528368887670942, 'colsample_bytree': 0.9306295712833768, 'gamma': 0.7095474220355555, 'reg_alpha': 0.8257146549352997, 'reg_lambda': 0.10784694637389226, 'scale_pos_weight': 8.071589962902038}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:24,993] Trial 57 finished with value: 0.3441295546558704 and parameters: {'max_depth': 16, 'learning_rate': 0.047269165361231685, 'n_estimators': 276, 'min_child_weight': 2, 'subsample': 0.6293695811449265, 'colsample_bytree': 0.8572425855015254, 'gamma': 0.6426580127080916, 'reg_alpha': 0.700608900727835, 'reg_lambda': 0.18842745187013865, 'scale_pos_weight': 3.72415020528355}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:25,527] Trial 58 finished with value: 0.4136690647482014 and parameters: {'max_depth': 17, 'learning_rate': 0.08914284278982046, 'n_estimators': 195, 'min_child_weight': 7, 'subsample': 0.5978554409249978, 'colsample_bytree': 0.8928290703752497, 'gamma': 0.9965344069268106, 'reg_alpha': 0.7747139853968015, 'reg_lambda': 0.1252696975847117, 'scale_pos_weight': 5.577931972043555}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:26,030] Trial 59 finished with value: 0.39094650205761317 and parameters: {'max_depth': 14, 'learning_rate': 0.058794731444279165, 'n_estimators': 259, 'min_child_weight': 5, 'subsample': 0.6157726559931676, 'colsample_bytree': 0.9676067758217599, 'gamma': 0.7469667680100469, 'reg_alpha': 0.877230873630989, 'reg_lambda': 0.04228955013223906, 'scale_pos_weight': 3.268688825658347}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:26,390] Trial 60 finished with value: 0.41118421052631576 and parameters: {'max_depth': 11, 'learning_rate': 0.017346736337505157, 'n_estimators': 163, 'min_child_weight': 6, 'subsample': 0.7249525225591764, 'colsample_bytree': 0.830123471159722, 'gamma': 0.5624907331344042, 'reg_alpha': 0.28244867368676485, 'reg_lambda': 0.449631177546976, 'scale_pos_weight': 4.423439367434744}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:26,807] Trial 61 finished with value: 0.42517006802721086 and parameters: {'max_depth': 13, 'learning_rate': 0.03169288585281224, 'n_estimators': 252, 'min_child_weight': 7, 'subsample': 0.5654397973863501, 'colsample_bytree': 0.790609649428947, 'gamma': 0.6931134074656021, 'reg_alpha': 0.9137373921269973, 'reg_lambda': 0.38510379722081056, 'scale_pos_weight': 4.824130781846565}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:27,593] Trial 62 finished with value: 0.42662116040955633 and parameters: {'max_depth': 12, 'learning_rate': 0.029863782357643226, 'n_estimators': 239, 'min_child_weight': 7, 'subsample': 0.5754789127204428, 'colsample_bytree': 0.8108990661201948, 'gamma': 0.6070734359016063, 'reg_alpha': 0.9673581428820478, 'reg_lambda': 0.3046905319882975, 'scale_pos_weight': 5.3395162033135755}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:28,109] Trial 63 finished with value: 0.42483660130718953 and parameters: {'max_depth': 13, 'learning_rate': 0.02393905165595793, 'n_estimators': 236, 'min_child_weight': 7, 'subsample': 0.6277343731752006, 'colsample_bytree': 0.8392684093959755, 'gamma': 0.7906084714296878, 'reg_alpha': 0.8359926146352296, 'reg_lambda': 0.2600648652055775, 'scale_pos_weight': 5.998819634613563}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:28,473] Trial 64 finished with value: 0.4227941176470588 and parameters: {'max_depth': 9, 'learning_rate': 0.04043117232792142, 'n_estimators': 223, 'min_child_weight': 7, 'subsample': 0.6679509814000981, 'colsample_bytree': 0.7612038605326443, 'gamma': 0.47205717538174824, 'reg_alpha': 0.8936656024867455, 'reg_lambda': 0.3353565950359969, 'scale_pos_weight': 3.9638920816305734}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:28,930] Trial 65 finished with value: 0.4222972972972973 and parameters: {'max_depth': 11, 'learning_rate': 0.028389158303893908, 'n_estimators': 280, 'min_child_weight': 6, 'subsample': 0.5942461679541264, 'colsample_bytree': 0.8844818722176417, 'gamma': 0.6401183240038253, 'reg_alpha': 0.9387479395568538, 'reg_lambda': 0.192929500423918, 'scale_pos_weight': 6.781180711595636}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:29,350] Trial 66 finished with value: 0.39325842696629215 and parameters: {'max_depth': 15, 'learning_rate': 0.05133657425080579, 'n_estimators': 213, 'min_child_weight': 7, 'subsample': 0.8316565979400624, 'colsample_bytree': 0.9160193853251636, 'gamma': 0.5336708520020667, 'reg_alpha': 0.9996575232925192, 'reg_lambda': 0.40179922622936437, 'scale_pos_weight': 4.335616840060659}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:29,737] Trial 67 finished with value: 0.4370629370629371 and parameters: {'max_depth': 14, 'learning_rate': 0.04328855989586704, 'n_estimators': 292, 'min_child_weight': 7, 'subsample': 0.5151357720288132, 'colsample_bytree': 0.6939708326550428, 'gamma': 0.7410370556374823, 'reg_alpha': 0.8721791021299201, 'reg_lambda': 0.47132853736277547, 'scale_pos_weight': 4.706737331457171}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:30,138] Trial 68 finished with value: 0.4406779661016949 and parameters: {'max_depth': 16, 'learning_rate': 0.04271338408699115, 'n_estimators': 295, 'min_child_weight': 6, 'subsample': 0.5138843204492825, 'colsample_bytree': 0.6934094011827782, 'gamma': 0.849164066386809, 'reg_alpha': 0.718964997604439, 'reg_lambda': 0.5172835021553945, 'scale_pos_weight': 6.353703093813298}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:30,562] Trial 69 finished with value: 0.42207792207792205 and parameters: {'max_depth': 16, 'learning_rate': 0.04279453255486715, 'n_estimators': 292, 'min_child_weight': 6, 'subsample': 0.5174529642439823, 'colsample_bytree': 0.6892829377898629, 'gamma': 0.9056423399533902, 'reg_alpha': 0.6562139112532231, 'reg_lambda': 0.47494940137126085, 'scale_pos_weight': 7.5225660249032025}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:31,049] Trial 70 finished with value: 0.43478260869565216 and parameters: {'max_depth': 14, 'learning_rate': 0.03606351198064792, 'n_estimators': 292, 'min_child_weight': 6, 'subsample': 0.5399923327414005, 'colsample_bytree': 0.628127757434927, 'gamma': 0.8665590138685046, 'reg_alpha': 0.46575586693967264, 'reg_lambda': 0.5224018642584538, 'scale_pos_weight': 6.164299589734453}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:31,573] Trial 71 finished with value: 0.4391891891891892 and parameters: {'max_depth': 14, 'learning_rate': 0.035488849968705556, 'n_estimators': 297, 'min_child_weight': 6, 'subsample': 0.5019406294599571, 'colsample_bytree': 0.6659263791029623, 'gamma': 0.8494002773805416, 'reg_alpha': 0.5015334409633989, 'reg_lambda': 0.5347190793513252, 'scale_pos_weight': 5.847143171799049}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:32,184] Trial 72 finished with value: 0.43333333333333335 and parameters: {'max_depth': 14, 'learning_rate': 0.033846355166096305, 'n_estimators': 292, 'min_child_weight': 5, 'subsample': 0.5070724208138936, 'colsample_bytree': 0.6406132169542645, 'gamma': 0.8552627564050106, 'reg_alpha': 0.4269411158534418, 'reg_lambda': 0.5253265719100944, 'scale_pos_weight': 6.384419452129204}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:32,698] Trial 73 finished with value: 0.42704626334519574 and parameters: {'max_depth': 15, 'learning_rate': 0.03719566326800037, 'n_estimators': 297, 'min_child_weight': 4, 'subsample': 0.5399509748692453, 'colsample_bytree': 0.6578698723175206, 'gamma': 0.8274177110960322, 'reg_alpha': 0.3408906615139366, 'reg_lambda': 0.6089744462737801, 'scale_pos_weight': 5.926260058114291}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:33,110] Trial 74 finished with value: 0.4151624548736462 and parameters: {'max_depth': 16, 'learning_rate': 0.2125866791858152, 'n_estimators': 280, 'min_child_weight': 6, 'subsample': 0.5001162474402711, 'colsample_bytree': 0.6297565479811557, 'gamma': 0.8790519014701798, 'reg_alpha': 0.4847481016351247, 'reg_lambda': 0.6546567765147404, 'scale_pos_weight': 6.988270934171185}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:33,539] Trial 75 finished with value: 0.38461538461538464 and parameters: {'max_depth': 14, 'learning_rate': 0.058492294824074864, 'n_estimators': 283, 'min_child_weight': 6, 'subsample': 0.5240403434761414, 'colsample_bytree': 0.728157346059317, 'gamma': 0.9478587127911615, 'reg_alpha': 0.5046375893404526, 'reg_lambda': 0.5602268725282964, 'scale_pos_weight': 7.681909065974972}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:33,964] Trial 76 finished with value: 0.0 and parameters: {'max_depth': 17, 'learning_rate': 0.043875558121434746, 'n_estimators': 267, 'min_child_weight': 5, 'subsample': 0.5470778390074135, 'colsample_bytree': 0.602022110608004, 'gamma': 0.7325434446938612, 'reg_alpha': 0.4685399713952211, 'reg_lambda': 0.5920278490518052, 'scale_pos_weight': 14.492506992274222}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:34,390] Trial 77 finished with value: 0.4180064308681672 and parameters: {'max_depth': 15, 'learning_rate': 0.025590052564723312, 'n_estimators': 300, 'min_child_weight': 6, 'subsample': 0.531110337266207, 'colsample_bytree': 0.6853034805714263, 'gamma': 0.833926223987475, 'reg_alpha': 0.6154135935597635, 'reg_lambda': 0.6731361557448564, 'scale_pos_weight': 5.838102992942376}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:34,809] Trial 78 finished with value: 0.40498442367601245 and parameters: {'max_depth': 14, 'learning_rate': 0.03505718032210126, 'n_estimators': 292, 'min_child_weight': 6, 'subsample': 0.5189479711327214, 'colsample_bytree': 0.6546022818743656, 'gamma': 0.9310209716311841, 'reg_alpha': 0.4406110218286572, 'reg_lambda': 0.5183284106504579, 'scale_pos_weight': 8.439613593887497}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:35,304] Trial 79 finished with value: 0.4013377926421405 and parameters: {'max_depth': 19, 'learning_rate': 0.04100368436830382, 'n_estimators': 271, 'min_child_weight': 3, 'subsample': 0.5500350123855313, 'colsample_bytree': 0.6693405108489067, 'gamma': 0.8845034729723598, 'reg_alpha': 0.5789385866855757, 'reg_lambda': 0.4652649204915069, 'scale_pos_weight': 9.111207756007015}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:35,731] Trial 80 finished with value: 0.41522491349480967 and parameters: {'max_depth': 16, 'learning_rate': 0.04778165546026774, 'n_estimators': 285, 'min_child_weight': 7, 'subsample': 0.5126210678613672, 'colsample_bytree': 0.7030635899436882, 'gamma': 0.7917501269180587, 'reg_alpha': 0.7183682324699471, 'reg_lambda': 0.8358973938472867, 'scale_pos_weight': 6.170755733730841}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:36,152] Trial 81 finished with value: 0.436241610738255 and parameters: {'max_depth': 13, 'learning_rate': 0.03238001177242956, 'n_estimators': 291, 'min_child_weight': 5, 'subsample': 0.5050694919700098, 'colsample_bytree': 0.6395504942660074, 'gamma': 0.8621458517468381, 'reg_alpha': 0.37333399865187594, 'reg_lambda': 0.5211650364045486, 'scale_pos_weight': 6.481742520656484}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:36,633] Trial 82 finished with value: 0.4304635761589404 and parameters: {'max_depth': 13, 'learning_rate': 0.032415855857776184, 'n_estimators': 294, 'min_child_weight': 5, 'subsample': 0.5005391582670298, 'colsample_bytree': 0.6439232061951201, 'gamma': 0.7538081458310345, 'reg_alpha': 0.35963234872315397, 'reg_lambda': 0.7255865085004681, 'scale_pos_weight': 6.488117138136511}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:37,086] Trial 83 finished with value: 0.4391891891891892 and parameters: {'max_depth': 15, 'learning_rate': 0.038147832436806105, 'n_estimators': 277, 'min_child_weight': 6, 'subsample': 0.5309111594714009, 'colsample_bytree': 0.624710563029735, 'gamma': 0.9716431741698963, 'reg_alpha': 0.27347511498718713, 'reg_lambda': 0.5879873378408991, 'scale_pos_weight': 5.678771144090579}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:37,752] Trial 84 finished with value: 0.44014084507042256 and parameters: {'max_depth': 15, 'learning_rate': 0.030523110193112397, 'n_estimators': 278, 'min_child_weight': 4, 'subsample': 0.5300483016475747, 'colsample_bytree': 0.5856860655925514, 'gamma': 0.993015545911988, 'reg_alpha': 0.2626540102237877, 'reg_lambda': 0.5919511092311616, 'scale_pos_weight': 4.572423650503869}. Best is trial 35 with value: 0.4416961130742049.
# [I 2026-01-19 19:22:38,278] Trial 85 finished with value: 0.44483985765124556 and parameters: {'max_depth': 15, 'learning_rate': 0.03781307643877439, 'n_estimators': 278, 'min_child_weight': 4, 'subsample': 0.517298452740764, 'colsample_bytree': 0.60324111827723, 'gamma': 0.9908827569174644, 'reg_alpha': 0.253116388630534, 'reg_lambda': 0.5899503064772872, 'scale_pos_weight': 5.657246526035888}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:38,813] Trial 86 finished with value: 0.43010752688172044 and parameters: {'max_depth': 15, 'learning_rate': 0.03863506889875226, 'n_estimators': 277, 'min_child_weight': 4, 'subsample': 0.5233894656207835, 'colsample_bytree': 0.5865890573483767, 'gamma': 0.9893242735332195, 'reg_alpha': 0.2565975225002513, 'reg_lambda': 0.6314400695233104, 'scale_pos_weight': 4.59174863577282}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:39,373] Trial 87 finished with value: 0.35019455252918286 and parameters: {'max_depth': 16, 'learning_rate': 0.05584612830609675, 'n_estimators': 264, 'min_child_weight': 4, 'subsample': 0.5311877551328439, 'colsample_bytree': 0.60276618219083, 'gamma': 0.9682102181270524, 'reg_alpha': 0.19197489620212968, 'reg_lambda': 0.5782946035923856, 'scale_pos_weight': 4.008930422420749}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:39,997] Trial 88 finished with value: 0.40636042402826855 and parameters: {'max_depth': 17, 'learning_rate': 0.04650907723882733, 'n_estimators': 255, 'min_child_weight': 4, 'subsample': 0.5575984155563007, 'colsample_bytree': 0.5657418309868982, 'gamma': 0.9225057217677253, 'reg_alpha': 0.1501344814552379, 'reg_lambda': 0.7082790092030288, 'scale_pos_weight': 5.217210936306582}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:40,538] Trial 89 finished with value: 0.3873239436619718 and parameters: {'max_depth': 15, 'learning_rate': 0.043471944450806085, 'n_estimators': 274, 'min_child_weight': 4, 'subsample': 0.7664981474802762, 'colsample_bytree': 0.5447815416348265, 'gamma': 0.9592964380499179, 'reg_alpha': 0.2862455280743389, 'reg_lambda': 0.6099695894474763, 'scale_pos_weight': 5.680886952904114}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:41,046] Trial 90 finished with value: 0.37656903765690375 and parameters: {'max_depth': 18, 'learning_rate': 0.05203898984603488, 'n_estimators': 268, 'min_child_weight': 3, 'subsample': 0.530125380254035, 'colsample_bytree': 0.6216328741591791, 'gamma': 0.9724383428799488, 'reg_alpha': 0.23764082718136426, 'reg_lambda': 0.5424403388765332, 'scale_pos_weight': 2.897109513663401}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:41,758] Trial 91 finished with value: 0.4126984126984127 and parameters: {'max_depth': 14, 'learning_rate': 0.030958766077285666, 'n_estimators': 284, 'min_child_weight': 4, 'subsample': 0.513601758391382, 'colsample_bytree': 0.5806651100699088, 'gamma': 0.9024053379451041, 'reg_alpha': 0.22898249213353128, 'reg_lambda': 0.5036120665520084, 'scale_pos_weight': 6.775852495397727}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:42,497] Trial 92 finished with value: 0.43478260869565216 and parameters: {'max_depth': 16, 'learning_rate': 0.024933386164278603, 'n_estimators': 279, 'min_child_weight': 5, 'subsample': 0.5124363570681951, 'colsample_bytree': 0.6134746213100124, 'gamma': 0.9212509499845987, 'reg_alpha': 0.15439655322491788, 'reg_lambda': 0.5799224230347158, 'scale_pos_weight': 5.379270014188966}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:43,077] Trial 93 finished with value: 0.4355400696864111 and parameters: {'max_depth': 15, 'learning_rate': 0.03425124335317186, 'n_estimators': 287, 'min_child_weight': 4, 'subsample': 0.5488502178732039, 'colsample_bytree': 0.5958398917599702, 'gamma': 0.9414653094294146, 'reg_alpha': 0.28923113749207513, 'reg_lambda': 0.6620209678688511, 'scale_pos_weight': 5.155877841021837}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:43,940] Trial 94 finished with value: 0.42402826855123676 and parameters: {'max_depth': 14, 'learning_rate': 0.03852430386358128, 'n_estimators': 296, 'min_child_weight': 5, 'subsample': 0.5393134965326203, 'colsample_bytree': 0.6780074331568449, 'gamma': 0.7849513479527959, 'reg_alpha': 0.32058415213619784, 'reg_lambda': 0.5500804316263712, 'scale_pos_weight': 5.689771467420738}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:45,060] Trial 95 finished with value: 0.4340277777777778 and parameters: {'max_depth': 15, 'learning_rate': 0.0303793934727158, 'n_estimators': 260, 'min_child_weight': 4, 'subsample': 0.5662226230604703, 'colsample_bytree': 0.5729379955768897, 'gamma': 0.8343032987793672, 'reg_alpha': 0.5277148012497841, 'reg_lambda': 0.4997399060317493, 'scale_pos_weight': 4.539118449182123}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:46,140] Trial 96 finished with value: 0.39568345323741005 and parameters: {'max_depth': 13, 'learning_rate': 0.04075941447191531, 'n_estimators': 300, 'min_child_weight': 4, 'subsample': 0.5008407417588511, 'colsample_bytree': 0.9460391131025279, 'gamma': 0.9847659555118571, 'reg_alpha': 0.39503896151871565, 'reg_lambda': 0.6416086324493464, 'scale_pos_weight': 7.383413733456921}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:46,891] Trial 97 finished with value: 0.42402826855123676 and parameters: {'max_depth': 16, 'learning_rate': 0.03301161942832899, 'n_estimators': 287, 'min_child_weight': 3, 'subsample': 0.5258513856137167, 'colsample_bytree': 0.6450135014211446, 'gamma': 0.8774993531678454, 'reg_alpha': 0.10287900633412889, 'reg_lambda': 0.693351275587461, 'scale_pos_weight': 6.395362785345311}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:47,527] Trial 98 finished with value: 0.4332129963898917 and parameters: {'max_depth': 17, 'learning_rate': 0.027740250038018638, 'n_estimators': 274, 'min_child_weight': 5, 'subsample': 0.585367724472664, 'colsample_bytree': 0.6979870482303835, 'gamma': 0.905097012524701, 'reg_alpha': 0.21690452218282424, 'reg_lambda': 0.6199632806222876, 'scale_pos_weight': 4.0236994355617135}. Best is trial 85 with value: 0.44483985765124556.
# [I 2026-01-19 19:22:48,048] Trial 99 finished with value: 0.41139240506329117 and parameters: {'max_depth': 15, 'learning_rate': 0.07322239174649962, 'n_estimators': 251, 'min_child_weight': 6, 'subsample': 0.5117706330230376, 'colsample_bytree': 0.66700534441737, 'gamma': 0.8141246734714053, 'reg_alpha': 0.7614924877881453, 'reg_lambda': 0.594342985815968, 'scale_pos_weight': 11.75867654608506}. Best is trial 85 with value: 0.44483985765124556.

# %%
# best_params_xgb = grid_xgb.best_params_

# %%
best_params_xgb = study_xgb.best_params

# %%
print(best_params_xgb)
# Out:
# {'max_depth': 15, 'learning_rate': 0.03781307643877439, 'n_estimators': 278, 'min_child_weight': 4, 'subsample': 0.517298452740764, 'colsample_bytree': 0.60324111827723, 'gamma': 0.9908827569174644, 'reg_alpha': 0.253116388630534, 'reg_lambda': 0.5899503064772872, 'scale_pos_weight': 5.657246526035888}

# %%
final_classifier = xgb.XGBClassifier(**best_params_xgb, random_state=42, eval_metric='logloss')

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.60324111827723, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=0.9908827569174644, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03781307643877439,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=278, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[621 108]
#  [ 12  25]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.8433420365535248

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.18796992481203006

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.6756756756756757

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.44483985765124556

# %% [markdown]
# ### Threshold tuning

# %%
best_threshold = 0.5

# %%
best_precision_score = 0

# %%
best_recall_score = 0

# %%
best_f2_score = 0

# %%
for threshold in np.arange(0.1, 0.95, 0.05):
    y_pred_val_threshold = (y_proba_val >= threshold).astype(int)
    recall = recall_score(y_val, y_pred_val_threshold)
    precision = precision_score(y_val, y_pred_val_threshold)
    f2_score = fbeta_score(y_val, y_pred_val_threshold, beta=2)
    
    print(f'Threshold {threshold} has F2 score {f2_score}')
    
    if precision >= 0.15:
        # current_recall_score = recall
        # if current_recall_score > best_recall_score:
        #     best_recall_score = current_recall_score
        #     best_precision_score = precision
        #     best_threshold = threshold
        # elif current_recall_score == best_recall_score and precision > best_precision_score:
        #     best_precision_score = precision
        #     best_threshold = threshold
        
        current_f2_score = f2_score
        if current_f2_score > best_f2_score:
            best_f2_score = current_f2_score
            best_threshold = threshold
# Out:
# Threshold 0.1 has F2 score 0.35639412997903563
# Threshold 0.15000000000000002 has F2 score 0.3733031674208145
# Threshold 0.20000000000000004 has F2 score 0.36585365853658536
# Threshold 0.25000000000000006 has F2 score 0.36175710594315247
# Threshold 0.30000000000000004 has F2 score 0.36312849162011174
# Threshold 0.3500000000000001 has F2 score 0.37572254335260113
# Threshold 0.40000000000000013 has F2 score 0.4126984126984127
# Threshold 0.45000000000000007 has F2 score 0.436241610738255
# Threshold 0.5000000000000001 has F2 score 0.44483985765124556
# Threshold 0.5500000000000002 has F2 score 0.42592592592592593
# Threshold 0.6000000000000002 has F2 score 0.35294117647058826
# Threshold 0.6500000000000001 has F2 score 0.3541666666666667
# Threshold 0.7000000000000002 has F2 score 0.3440366972477064
# Threshold 0.7500000000000002 has F2 score 0.3170731707317073
# Threshold 0.8000000000000002 has F2 score 0.15873015873015872
# Threshold 0.8500000000000002 has F2 score 0.11627906976744186
# Threshold 0.9000000000000002 has F2 score 0.03164556962025317

# %%
print(best_threshold)
# Out:
# 0.5000000000000001

# %%
print(best_recall_score)
# Out:
# 0

# %% [markdown]
# ### Retrain on training + validation set

# %%
X_train_full = pd.concat([X_train_res_retained, X_val_retained], axis=0, ignore_index=True)
y_train_full = pd.concat([y_train_res, y_val], axis=0, ignore_index=True)

# %%
final_classifier.fit(X_train_full, y_train_full)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.60324111827723, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='logloss', feature_types=None, feature_weights=None,
#               gamma=0.9908827569174644, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03781307643877439,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=15, max_leaves=None,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=278, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ### Evaluate on test set

# %%
X_test_retained = X_test[retained_columns]

# %%
y_pred_test = final_classifier.predict(X_test_retained)

# %%
y_proba_test = final_classifier.predict_proba(X_test_retained)[:, 1]

# %%
print(confusion_matrix(y_test, y_pred_test))
# Out:
# [[618 111]
#  [ 20  18]]

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.8292046936114733

# %%
print(precision_score(y_test, y_pred_test))
# Out:
# 0.13953488372093023

# %%
print(recall_score(y_test, y_pred_test))
# Out:
# 0.47368421052631576

# %%
print(fbeta_score(y_test, y_pred_test, beta=2))
# Out:
# 0.3202846975088968
