# %% [markdown]
# # Stroke Prediction

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import optuna
from optuna.samplers import TPESampler
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, fbeta_score, make_scorer

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('../dataset/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.describe(include=[object])
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ## Rename column for consistent formatting of name

# %%
df.rename(columns={'Residence_type': 'residence_type'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Impute missing values in BMI column
# For 201 entries missing BMI values, these entries will be imputed with the median BMI value

# %%
median_bmi = df['bmi'].median()
df['bmi'].fillna(median_bmi, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16808\2337012406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bmi'].fillna(median_bmi, inplace=True)

# %%
print(df['bmi'].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Converting categorical columns to numerical columns

# %%
df['male'] = (df['gender'] == 'Male').astype(int)

# %%
df['ever_married'] = (df['ever_married'] == 'Yes').astype(int)

# %%
df['urban'] = (df['residence_type'] == 'Urban').astype(int)

# %%
df['smoke'] = ((df['smoking_status'] == 'formerly smoked') | (df['smoking_status'] == 'smokes')).astype(int)

# %%
df['have_work'] = ((df['work_type'] == 'Govt_job') | (df['work_type'] == 'Private') | (df['work_type'] == 'Self-employed')).astype(int)

# %%
df['hypertension_or_heart_disease'] = df['hypertension'] | df['heart_disease']

# %%
df = pd.get_dummies(df, columns=['work_type', 'smoking_status'], drop_first = False)

# %% [markdown]
# ### Extra column for the age of married people

# %%
df['age_ever_married'] = df['age'] * df['ever_married']

# %% [markdown]
# ### Creating columns representing outstanding values for BMI and Average Glucose Level

# %%
df['obese'] = df['bmi'] >= 30

# %%
df['high_avg_glucose_level'] = df['avg_glucose_level'] >= 150

# %% [markdown]
# ### Converting boolean columns to numerical

# %%
bool_cols = df.select_dtypes(include='bool').columns
df[bool_cols] = df[bool_cols].astype(int)

# %% [markdown]
# ### Reformatting column names

# %%
df.rename(columns={'work_type_Govt_job': 'work_type_govt_job', 'work_type_Never_worked': 'work_type_never_worked', 'work_type_Private': 'work_type_private', 'work_type_Self-employed': 'work_type_self_employed'}, inplace=True)

# %%
df.rename(columns={'smoking_status_Unknown': 'smoking_status_unknown', 'smoking_status_formerly smoked': 'smoking_status_formerly_smoked', 'smoking_status_never smoked': 'smoking_status_never_smoked'}, inplace=True)

# %%
df.drop(columns=['gender', 'residence_type'], inplace=True)

# %% [markdown]
# ### Log Transforming BMI and Average Glucose Level columns

# %%
df['log_bmi'] = np.log(df['bmi'])

# %%
df['log_avg_glucose_level'] = np.log(df['avg_glucose_level'])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 0   9046  67.0             0              1             1             228.69
# 1  51676  61.0             0              0             1             202.21
# 2  31112  80.0             0              1             1             105.92
# 3  60182  49.0             0              0             1             171.23
# 4   1665  79.0             1              0             1             174.12
#
#     bmi  stroke  male  urban  smoke  have_work  hypertension_or_heart_disease  \
# 0  36.6       1     1      1      1          1                              1
# 1  28.1       1     0      0      0          1                              0
# 2  32.5       1     1      0      0          1                              1
# 3  34.4       1     0      1      1          1                              0
# 4  24.0       1     0      0      0          1                              1
#
#    work_type_govt_job  work_type_never_worked  work_type_private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_self_employed  work_type_children  smoking_status_unknown  \
# 0                        0                   0                       0
# 1                        1                   0                       0
# 2                        0                   0                       0
# 3                        0                   0                       0
# 4                        1                   0                       0
#
#    smoking_status_formerly_smoked  smoking_status_never_smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes  age_ever_married  obese  high_avg_glucose_level  \
# 0                      0              67.0      1                       1
# 1                      0              61.0      0                       1
# 2                      0              80.0      1                       0
# 3                      1              49.0      1                       1
# 4                      0              79.0      0                       1
#
#     log_bmi  log_avg_glucose_level
# 0  3.600048               5.432367
# 1  3.335770               5.309307
# 2  3.481240               4.662684
# 3  3.538057               5.143008
# 4  3.178054               5.159745

# %%
df.shape
# Out:
# (5110, 27)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Splitting to training, validation, and testing sets

# %%
columns_name = columns_name = [col for col in df.columns if col != 'id']

# %%
X = df[columns_name]
X.drop('stroke', axis=1, inplace=True)
y = df['stroke']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16808\91966498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.drop('stroke', axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %% [markdown]
# ### SMOTE Oversampling on Training Data

# %%
resampler = SMOTE()

# %%
X_train_res, y_train_res = resampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### Create base random forest classifier model

# %%
base_classifier = RandomForestClassifier(random_state=42)

# %%
# importance_df = pd.DataFrame({'Feature': X_train_res.columns, 'Importance': base_classifier.feature_importances_})
# importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df)

# %% [markdown]
# ### Fitting base classifier on unsampled data

# %%
base_classifier.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importances = base_classifier.feature_importances_

# %%
feature_imp_df = pd.DataFrame({'Feature':[col for col in X_train], 'Gini Importance': importances}).sort_values(
    'Gini Importance', ascending=False)

# %%
print(feature_imp_df)
# Out:
#                            Feature  Gini Importance
# 0                              age         0.199058
# 20                age_ever_married         0.160089
# 18     smoking_status_never_smoked         0.063458
# 4                avg_glucose_level         0.059405
# 24           log_avg_glucose_level         0.059243
# 16          smoking_status_unknown         0.055780
# 5                              bmi         0.049284
# 23                         log_bmi         0.047983
# 13               work_type_private         0.038769
# 14         work_type_self_employed         0.033162
# 8                            smoke         0.029671
# 11              work_type_govt_job         0.027910
# 3                     ever_married         0.024345
# 7                            urban         0.023269
# 17  smoking_status_formerly_smoked         0.023075
# 21                           obese         0.023023
# 19           smoking_status_smokes         0.020036
# 6                             male         0.017973
# 22          high_avg_glucose_level         0.009129
# 15              work_type_children         0.008561
# 1                     hypertension         0.007361
# 10   hypertension_or_heart_disease         0.007318
# 2                    heart_disease         0.006320
# 9                        have_work         0.005521
# 12          work_type_never_worked         0.000256

# %%
retained_columns = ['age', 'smoking_status_never_smoked', 'smoking_status_unknown', 'log_avg_glucose_level', 'bmi', 'work_type_private', 'ever_married', 'work_type_self_employed', 'urban', 'work_type_govt_job']

# %%
X_train_res_retained = X_train_res[retained_columns]

# %%
X_val_retained = X_val[retained_columns]

# %% [markdown]
# ### Create grid for hyperparameter tuning using GridSearchCV

# %%
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2'],
    'class_weight': ['balanced', 'balanced_subsample']
}

# %%
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
grid_rf = GridSearchCV(
    estimator=base_classifier,
    param_grid=param_grid_rf,
    scoring=f2_scorer,
    cv=5,
    verbose=2,
    n_jobs=-1
)

# %% [markdown]
# ### Create optimizing function for hyperparameter tuning with Optuna

# %%
MIN_PRECISION = 0.15

# %%
def objective_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 300),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', 'balanced_subsample']),
        'random_state': 42
    }
    
    model = RandomForestClassifier(**params)
    
    model.fit(X_train_res_retained, y_train_res)
    
    y_pred_val = model.predict(X_val_retained)
    
    recall = recall_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val)
    
    if precision < MIN_PRECISION:
        return 0
    return recall + (precision * 0.01)

# %%
# grid_rf.fit(X_train_res_retained, y_train_res)

# %%
study_rf = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study_rf.optimize(objective_rf, n_trials=100, show_progress_bar=True)
# Out:
# [I 2026-01-19 11:46:13,485] A new study created in memory with name: no-name-030e79f2-4458-46b1-8a14-5fc8e83920a9
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2026-01-19 11:46:15,086] Trial 0 finished with value: 0.2718327702702703 and parameters: {'n_estimators': 144, 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.2718327702702703.
# [I 2026-01-19 11:46:18,127] Trial 1 finished with value: 0.0 and parameters: {'n_estimators': 227, 'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 0 with value: 0.2718327702702703.
# [I 2026-01-19 11:46:22,113] Trial 2 finished with value: 0.0 and parameters: {'n_estimators': 158, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.2718327702702703.
# [I 2026-01-19 11:46:27,934] Trial 3 finished with value: 0.325990990990991 and parameters: {'n_estimators': 179, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.325990990990991.
# [I 2026-01-19 11:46:28,779] Trial 4 finished with value: 0.0 and parameters: {'n_estimators': 126, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.325990990990991.
# [I 2026-01-19 11:46:31,472] Trial 5 finished with value: 0.0 and parameters: {'n_estimators': 216, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.325990990990991.
# [I 2026-01-19 11:46:39,493] Trial 6 finished with value: 0.2177848436671966 and parameters: {'n_estimators': 200, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 3 with value: 0.325990990990991.
# [I 2026-01-19 11:46:44,508] Trial 7 finished with value: 0.0 and parameters: {'n_estimators': 139, 'max_depth': 8, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.325990990990991.
# [I 2026-01-19 11:46:45,239] Trial 8 finished with value: 0.0 and parameters: {'n_estimators': 51, 'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 3 with value: 0.325990990990991.
# [I 2026-01-19 11:46:46,636] Trial 9 finished with value: 0.0 and parameters: {'n_estimators': 206, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 3 with value: 0.325990990990991.
# [I 2026-01-19 11:46:51,654] Trial 10 finished with value: 0.326063454759107 and parameters: {'n_estimators': 287, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 10 with value: 0.326063454759107.
# [I 2026-01-19 11:46:57,188] Trial 11 finished with value: 0.326063454759107 and parameters: {'n_estimators': 295, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 10 with value: 0.326063454759107.
# [I 2026-01-19 11:47:03,423] Trial 12 finished with value: 0.326063454759107 and parameters: {'n_estimators': 294, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 10 with value: 0.326063454759107.
# [I 2026-01-19 11:47:08,680] Trial 13 finished with value: 0.32611536910044375 and parameters: {'n_estimators': 292, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 13 with value: 0.32611536910044375.
# [I 2026-01-19 11:47:13,463] Trial 14 finished with value: 0.32622908622908625 and parameters: {'n_estimators': 263, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 14 with value: 0.32622908622908625.
# [I 2026-01-19 11:47:19,094] Trial 15 finished with value: 0.3262598081952921 and parameters: {'n_estimators': 253, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.3262598081952921.
# [I 2026-01-19 11:47:23,895] Trial 16 finished with value: 0.2991005759858219 and parameters: {'n_estimators': 238, 'max_depth': 17, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 15 with value: 0.3262598081952921.
# [I 2026-01-19 11:47:28,737] Trial 17 finished with value: 0.35291761641159236 and parameters: {'n_estimators': 258, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:47:30,989] Trial 18 finished with value: 0.0 and parameters: {'n_estimators': 260, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:47:33,703] Trial 19 finished with value: 0.0 and parameters: {'n_estimators': 253, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:47:34,996] Trial 20 finished with value: 0.0 and parameters: {'n_estimators': 72, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:47:39,881] Trial 21 finished with value: 0.2990433290433291 and parameters: {'n_estimators': 266, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:47:44,053] Trial 22 finished with value: 0.2990714908456844 and parameters: {'n_estimators': 239, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:47:49,106] Trial 23 finished with value: 0.2991005759858219 and parameters: {'n_estimators': 273, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:47:54,771] Trial 24 finished with value: 0.32601446516939475 and parameters: {'n_estimators': 252, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:47:58,728] Trial 25 finished with value: 0.0 and parameters: {'n_estimators': 178, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:06,959] Trial 26 finished with value: 0.29898960498960503 and parameters: {'n_estimators': 273, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:13,128] Trial 27 finished with value: 0.0 and parameters: {'n_estimators': 231, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:16,536] Trial 28 finished with value: 0.27190961453256535 and parameters: {'n_estimators': 203, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 6, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:17,962] Trial 29 finished with value: 0.0 and parameters: {'n_estimators': 110, 'max_depth': 12, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:20,561] Trial 30 finished with value: 0.0 and parameters: {'n_estimators': 246, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:29,356] Trial 31 finished with value: 0.3260890302066773 and parameters: {'n_estimators': 277, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:37,585] Trial 32 finished with value: 0.2990433290433291 and parameters: {'n_estimators': 285, 'max_depth': 16, 'min_samples_split': 11, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:44,431] Trial 33 finished with value: 0.2990714908456844 and parameters: {'n_estimators': 220, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:49,712] Trial 34 finished with value: 0.29898960498960503 and parameters: {'n_estimators': 263, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:48:58,024] Trial 35 finished with value: 0.29913063063063067 and parameters: {'n_estimators': 299, 'max_depth': 18, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 17 with value: 0.35291761641159236.
# [I 2026-01-19 11:49:06,200] Trial 36 finished with value: 0.35303966303966305 and parameters: {'n_estimators': 281, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 36 with value: 0.35303966303966305.
# [I 2026-01-19 11:49:10,095] Trial 37 finished with value: 0.0 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 36 with value: 0.35303966303966305.
# [I 2026-01-19 11:49:12,825] Trial 38 finished with value: 0.0 and parameters: {'n_estimators': 161, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 36 with value: 0.35303966303966305.
# [I 2026-01-19 11:49:22,719] Trial 39 finished with value: 0.32592432432432433 and parameters: {'n_estimators': 252, 'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 7, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.35303966303966305.
# [I 2026-01-19 11:49:28,518] Trial 40 finished with value: 0.0 and parameters: {'n_estimators': 188, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 4, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 36 with value: 0.35303966303966305.
# [I 2026-01-19 11:49:39,062] Trial 41 finished with value: 0.3531081081081081 and parameters: {'n_estimators': 282, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 41 with value: 0.3531081081081081.
# [I 2026-01-19 11:49:50,603] Trial 42 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 277, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 42 with value: 0.3531321732691596.
# [I 2026-01-19 11:50:02,320] Trial 43 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 276, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 42 with value: 0.3531321732691596.
# [I 2026-01-19 11:50:13,839] Trial 44 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 280, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 42 with value: 0.3531321732691596.
# [I 2026-01-19 11:50:22,872] Trial 45 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 280, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 42 with value: 0.3531321732691596.
# [I 2026-01-19 11:50:32,283] Trial 46 finished with value: 0.35315690690690693 and parameters: {'n_estimators': 284, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:50:36,311] Trial 47 finished with value: 0.0 and parameters: {'n_estimators': 298, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:50:43,412] Trial 48 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 275, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:50:54,410] Trial 49 finished with value: 0.29898960498960503 and parameters: {'n_estimators': 239, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:50:59,982] Trial 50 finished with value: 0.0 and parameters: {'n_estimators': 288, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:11,274] Trial 51 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 271, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:19,141] Trial 52 finished with value: 0.35303966303966305 and parameters: {'n_estimators': 280, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:25,760] Trial 53 finished with value: 0.3531081081081081 and parameters: {'n_estimators': 268, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:30,574] Trial 54 finished with value: 0.29896396396396396 and parameters: {'n_estimators': 289, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:37,356] Trial 55 finished with value: 0.29898960498960503 and parameters: {'n_estimators': 299, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:39,725] Trial 56 finished with value: 0.35291761641159236 and parameters: {'n_estimators': 110, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:46,996] Trial 57 finished with value: 0.0 and parameters: {'n_estimators': 244, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:53,008] Trial 58 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 265, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:51:55,183] Trial 59 finished with value: 0.0 and parameters: {'n_estimators': 276, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'log2', 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:01,108] Trial 60 finished with value: 0.0 and parameters: {'n_estimators': 291, 'max_depth': 11, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:06,873] Trial 61 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 274, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:13,182] Trial 62 finished with value: 0.325990990990991 and parameters: {'n_estimators': 270, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:17,515] Trial 63 finished with value: 0.3531081081081081 and parameters: {'n_estimators': 259, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:22,087] Trial 64 finished with value: 0.353018018018018 and parameters: {'n_estimators': 285, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:26,562] Trial 65 finished with value: 0.29896396396396396 and parameters: {'n_estimators': 232, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:30,946] Trial 66 finished with value: 0.3260890302066773 and parameters: {'n_estimators': 253, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:35,150] Trial 67 finished with value: 0.3529367172050099 and parameters: {'n_estimators': 245, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:37,271] Trial 68 finished with value: 0.0 and parameters: {'n_estimators': 292, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:40,407] Trial 69 finished with value: 0.0 and parameters: {'n_estimators': 214, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:45,126] Trial 70 finished with value: 0.326063454759107 and parameters: {'n_estimators': 269, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:49,233] Trial 71 finished with value: 0.3531321732691596 and parameters: {'n_estimators': 262, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:53,063] Trial 72 finished with value: 0.35303966303966305 and parameters: {'n_estimators': 280, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:52:56,659] Trial 73 finished with value: 0.35315690690690693 and parameters: {'n_estimators': 264, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:00,472] Trial 74 finished with value: 0.29898960498960503 and parameters: {'n_estimators': 257, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:04,386] Trial 75 finished with value: 0.3260890302066773 and parameters: {'n_estimators': 274, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:09,050] Trial 76 finished with value: 0.35303966303966305 and parameters: {'n_estimators': 300, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:10,383] Trial 77 finished with value: 0.0 and parameters: {'n_estimators': 290, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:14,199] Trial 78 finished with value: 0.35303966303966305 and parameters: {'n_estimators': 281, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:18,954] Trial 79 finished with value: 0.0 and parameters: {'n_estimators': 263, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:22,748] Trial 80 finished with value: 0.0 and parameters: {'n_estimators': 247, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:26,850] Trial 81 finished with value: 0.35315690690690693 and parameters: {'n_estimators': 266, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:31,708] Trial 82 finished with value: 0.3260890302066773 and parameters: {'n_estimators': 271, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:35,806] Trial 83 finished with value: 0.3531081081081081 and parameters: {'n_estimators': 255, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:40,318] Trial 84 finished with value: 0.325990990990991 and parameters: {'n_estimators': 286, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:42,786] Trial 85 finished with value: 0.0 and parameters: {'n_estimators': 277, 'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'class_weight': 'balanced_subsample'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:46,641] Trial 86 finished with value: 0.3260890302066773 and parameters: {'n_estimators': 267, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:51,200] Trial 87 finished with value: 0.29893908834207344 and parameters: {'n_estimators': 295, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:53,714] Trial 88 finished with value: 0.35303966303966305 and parameters: {'n_estimators': 163, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:56,426] Trial 89 finished with value: 0.2988041466123658 and parameters: {'n_estimators': 189, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:53:56,951] Trial 90 finished with value: 0.0 and parameters: {'n_estimators': 68, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'log2', 'class_weight': 'balanced_subsample'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:54:00,572] Trial 91 finished with value: 0.35315690690690693 and parameters: {'n_estimators': 266, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:54:04,447] Trial 92 finished with value: 0.35303966303966305 and parameters: {'n_estimators': 284, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:54:08,528] Trial 93 finished with value: 0.3260890302066773 and parameters: {'n_estimators': 276, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:54:12,594] Trial 94 finished with value: 0.3531081081081081 and parameters: {'n_estimators': 261, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 46 with value: 0.35315690690690693.
# [I 2026-01-19 11:54:16,014] Trial 95 finished with value: 0.3532084942084942 and parameters: {'n_estimators': 140, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 95 with value: 0.3532084942084942.
# [I 2026-01-19 11:54:18,716] Trial 96 finished with value: 0.29896396396396396 and parameters: {'n_estimators': 168, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 95 with value: 0.3532084942084942.
# [I 2026-01-19 11:54:21,261] Trial 97 finished with value: 0.35297635135135136 and parameters: {'n_estimators': 127, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 10, 'max_features': None, 'class_weight': 'balanced_subsample'}. Best is trial 95 with value: 0.3532084942084942.
# [I 2026-01-19 11:54:23,396] Trial 98 finished with value: 0.326063454759107 and parameters: {'n_estimators': 101, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}. Best is trial 95 with value: 0.3532084942084942.
# [I 2026-01-19 11:54:24,571] Trial 99 finished with value: 0.0 and parameters: {'n_estimators': 140, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'class_weight': 'balanced'}. Best is trial 95 with value: 0.3532084942084942.

# %%
# best_params_rf = grid_rf.best_params_

# %%
best_params_rf = study_rf.best_params

# %%
print(best_params_rf)
# Out:
# {'n_estimators': 140, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'class_weight': 'balanced'}

# %%
final_classifier = RandomForestClassifier(**best_params_rf, random_state=42)

# %%
final_classifier.fit(X_train_res_retained, y_train_res)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=13, max_features=None,
#                        min_samples_leaf=9, n_estimators=140, random_state=42)

# %%
y_pred_val = final_classifier.predict(X_val_retained)

# %%
y_proba_val = final_classifier.predict_proba(X_val_retained)[:, 1]

# %%
print(confusion_matrix(y_val, y_pred_val))
# Out:
# [[672  57]
#  [ 24  13]]

# %%
print(accuracy_score(y_val, y_pred_val))
# Out:
# 0.8942558746736292

# %%
print(precision_score(y_val, y_pred_val))
# Out:
# 0.18571428571428572

# %%
print(recall_score(y_val, y_pred_val))
# Out:
# 0.35135135135135137

# %%
print(fbeta_score(y_val, y_pred_val, beta=2))
# Out:
# 0.2981651376146789
